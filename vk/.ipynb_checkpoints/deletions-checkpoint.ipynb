# %%
https://github.com/voronind/vk

# %%
https://sohabr.net/habr/post/242365/?version=67420

# %%
import vk
import vk_requests

# %% [raw]
# vk acces token
# https://api.vk.com/blank.html#access_token=0da5b670ec7b72582a99036336132113eac3fa674594b7a94a98e334d9d7e2604b18bca582d31228fb983&expires_in=0&user_id=544738508&email=v.tratorova@lingualeo.com
#
# 0da5b670ec7b72582a99036336132113eac3fa674594b7a94a98e334d9d7e2604b18bca582d31228fb983

# %%
#standalone ll
SERVICe_standalone = "21f74eaf21f74eaf21f74eaf8f219c63a6221f721f74eaf7cf0253f7e36cf0dac4062da"
service_access = "0da5b670ec7b72582a99036336132113eac3fa674594b7a94a98e334d9d7e2604b18bca582d31228fb983"

# %%
api = vk_requests.create_api(app_id = "7023881",login = "+79262413748",password = "Leo888$english$",service_token = SERVICe_standalone)

# %%
import install vk_auth_port_by_bulates1
# Out:
#   File "<ipython-input-43-974c4ed08243>", line 1
#     import install vk_auth_port_by_bulates1
#                                           ^
# SyntaxError: invalid syntax

# %%
api.access_token=vk_auth_port_by_bulates1.auth("wall", login= "+79262413748",password= "Leo888$english$",app_id= "7023881")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-662be7643df1> in <module>
# ----> 1 api.access_token=vk_auth_port_by_bulates1.auth("wall", login= "+79262413748",password= "Leo888$english$",app_id= "7023881")
#
# NameError: name 'vk_auth_port_by_bulates1' is not defined

# %%
api.wall.get(owner_id = "-15787787")
# Out:
# {'count': 7740,
#  'items': [{'id': 150965,
#    'from_id': -15787787,
#    'owner_id': -15787787,
#    'date': 1560498632,
#    'marked_as_ads': 0,
#    'post_type': 'post',
# ...

# %%
https://vk.com/dev/wall.deleteComment

# %%
api.wall.getComments(owner_id = '-15787787',post_id = '150965',sort = "asc",count = 100)
# Out:
# {'count': 84,
#  'items': [{'id': 150966,
#    'from_id': 24156876,
#    'post_id': 150965,
#    'owner_id': -15787787,
#    'parents_stack': [],
#    'date': 1560498798,
#    'text': 'Скорее бы уже😩 Пожалуйста...',
#    'thread': {'count': 1,
#     'items': [],
#     'can_post': True,
#     'show_reply_button': True,
#     'groups_can_post': True}},
#   {'id': 150967,
#    'from_id': 2513435,
#    'post_id': 150965,
#    'owner_id': -15787787,
#    'parents_stack': [],
#    'date': 1560498986,
#    'text': 'Ежегодная августовская миграция пользователей лингволео🎉 чуть-чуть осталось подождать🎉',
#    'thread': {'count': 0,
#     'items': [],
#     'can_post': True,
#     'show_reply_button': True,
#     'groups_can_post': True}},
#   {'id': 150969,
#    'from_id': 79333573,
#    'post_id': 150965,
#    'owner_id': -15787787,
#    'parents_stack': [],
#    'date': 1560499293,
#    'text': 'Да ладно,серьезно?',
#    'thread': {'count': 0,
#     'items': [],
#     'can_post': True,
# ...

# %%
{'id': 150969,
   'from_id': 79333573,
   'post_id': 150965,
   'owner_id': -15787787,
   'parents_stack': [],
   'date': 1560499293,
   'text': 'Да ладно,серьезно?',
   'thread': {'count': 0,
    'items': [],
    'can_post': True,
    'show_reply_button': True,
    'groups_can_post': True}}

# %%
api.wall.deleteComment(owner_id = -15787787, comment_id = 150969)
# Out:
# ---------------------------------------------------------------------------
# VkAPIError                                Traceback (most recent call last)
# <ipython-input-22-9d40af88d02c> in <module>
# ----> 1 api.wall.deleteComment( comment_id = 150969)
#
# /usr/local/lib/python3.7/site-packages/vk_requests/api.py in __call__(self, **method_args)
#      65     def __call__(self, **method_args):
#      66         self._method_args = method_args
# ---> 67         return self._session.make_request(request=self)
#      68
#      69     def __repr__(self):  # pragma: no cover
#
# /usr/local/lib/python3.7/site-packages/vk_requests/session.py in make_request(self, request, captcha_response)
#     434
#     435             else:
# --> 436                 raise vk_error
#     437         elif 'execute_errors' in response_or_error:
#     438             # can take place while running .execute vk method
#
# ...
