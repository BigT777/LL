# %% [markdown]
# # УЧЕСТЬ ВКЛЮЧЕНИЕ no equality В СТРУКТУРУ
#
# lang должен быть ткой от которого нет no_eq
#
# merge dict запускать не листом а последосвательно к каой паре продумывая какой язык на какое место постпаить
#
# скорее всего это будет lang1 lang2 lang3 : базовый - куда лукап - таргет

# %%
import pandas as pd
from tqdm import tqdm
import math

# %%
df_fr_en_ru = pd.read_csv("/Users/nigula/LL/adjust_unigr_dict/reverse_connected_dicts/y_crossrevers_vs_pos_cycle/fr_en_ru_no_cossim.csv")

# %%
df_en_fr_ru = pd.read_csv("/Users/nigula/LL/adjust_unigr_dict/reverse_connected_dicts/y_crossrevers_vs_pos_cycle/en_fr_ru_no_cossim.csv")

# %%
====endof1

# %%
df_en_ru_fr = pd.read_csv("/Users/nigula/LL/adjust_unigr_dict/reverse_connected_dicts/y_crossrevers_vs_pos_cycle/en_ru_fr_no_cossim.csv")

# %%
====endof2

# %%
df_fr_ru_en = pd.read_csv("/Users/nigula/LL/adjust_unigr_dict/reverse_connected_dicts/y_crossrevers_vs_pos_cycle/fr_ru_en_no_cossim.csv")

# %%
====endof3

# %%
df_ru_fr_en = pd.read_csv("/Users/nigula/LL/adjust_unigr_dict/reverse_connected_dicts/y_crossrevers_vs_pos_cycle/ru_fr_en.csv")

# %%
def detect_nan(string):
    
    if 'float' in str(type(string)): return True
    try:
        isnan = math.isnan(string) 
        if isnan == True: return True
    
    except:
        return False

# %%
def get_df_from_dict(glob_dct, current_lang1, current_lang2, current_lang3):
    lang1_list = []
    lang2_list = []
    lang3_list = []
    votes = []

    for lang_1_word in glob_dct.keys():
        #print(lang_1_word, glob_dct[lang_1_word],'\n')
        for lang_2_word in glob_dct[lang_1_word].keys():
            #print(lang_2_word, glob_dct[lang_1_word],'\n')
            for lang_3_word in glob_dct[lang_1_word][lang_2_word].keys():
                #print(lang_3_word, glob_dct[lang_1_word][lang_2_word])
                lang1_list.append(lang_1_word)
                lang2_list.append(lang_2_word)
                lang3_list.append(lang_3_word)
                votes.append(glob_dct[lang_1_word][lang_2_word][lang_3_word])
    data = pd.DataFrame(list(zip(lang1_list, lang2_list,lang3_list, votes)),
                        columns =[current_lang1, current_lang2, current_lang3,'vote'])
    return data

# %%
def merge_cycle_dicts(overall_df_and_new_df_list, lookup_from, lookup_to, target):
    reversed_dict = {}
    count = 0 
    for df in overall_df_and_new_df_list:
        if 'vote' not in list(df.columns): 
            df['vote'] = [1 for i in range(len(df))]
        for index, row in tqdm(df.iterrows(), total=df.shape[0]):
            #print(row['en'], row['ru'],row['fr'] )
            lang_one_word = row[lookup_from]
            lang_two_word = row[lookup_to]
            lang_three_word = row[target]
            vote = row['vote']
            #print(count, lang_one_word,lang_two_word,  lang_three_word, vote)
            isnan = False
            word_list = [lang_one_word,lang_two_word,  lang_three_word]
            for word in word_list:
                isnan = detect_nan(word)
                if isnan == True:
                    break
            if isnan == False:
                if lang_one_word in reversed_dict :
                    if lang_two_word in reversed_dict[lang_one_word]:
                        if lang_three_word in reversed_dict[lang_one_word][lang_two_word]:
                            #count_element = lang_one_word + '_' + lang_two_word + '_' + lang_three_word
                            reversed_dict[lang_one_word][lang_two_word][lang_three_word] += int(vote) 
                        else:
                            reversed_dict[lang_one_word][lang_two_word][lang_three_word] = int(vote) 
                    else:
                        reversed_dict[lang_one_word][lang_two_word] = {}
                        reversed_dict[lang_one_word][lang_two_word][lang_three_word] = int(vote) 
                else:
                    reversed_dict[lang_one_word] = {}
                    reversed_dict[lang_one_word][lang_two_word] = {}
                    reversed_dict[lang_one_word][lang_two_word][lang_three_word] = int(vote) 
        count += 1
            
    return reversed_dict
gl_dct = merge_cycle_dicts([df_fr_en_ru, df_en_fr_ru], "fr", "en", "ru")
# Out:
# 100%|██████████| 3109/3109 [00:00<00:00, 5309.77it/s]
# 100%|██████████| 920/920 [00:00<00:00, 3639.44it/s]

# %%
gl_dct
# Out:
# {'tomber': {'fall': {'упасть': 2,
#    'падать': 2,
#    'пасть': 2,
#    'оказаться': 2,
#    'опускаться': 1,
#    'выпадать': 1},
#   'fell': {'упасть': 1, 'пасть': 1},
#   'fall down': {'упасть': 1, 'падать': 1}},
#  'pénétrer': {'penetrate': {'проникнуть': 1, 'проникать': 1}},
#  'complet': {'full': {'полный': 1, 'всеобъемлющий': 1, 'всесторонний': 1},
#   'complete': {'полный': 1, 'всесторонний': 1},
#   'comprehensive': {'полный': 1,
#    'всеобъемлющий': 1,
#    'комплексный': 1,
#    'всесторонний': 1,
#    'подробный': 1,
#    'исчерпывающий': 1},
#   'entire': {'полный': 1},
#   'fully': {'полный': 1, 'всесторонний': 1}},
#  'ultérieurement': {'later': {'впоследствии': 1,
#    'поздний': 1,
#    'последующий': 1,
#    'дальнейший': 1},
#   'subsequently': {'впоследствии': 1, 'поздний': 1, 'последующий': 1}},
#  'convenir': {'agree': {'согласовать': 2,
#    'согласиться': 2,
#    'согласование': 2,
#    'соглашаться': 1,
#    'договариваться': 1,
#    'согласовывать': 1,
#    'признать': 1},
#   'suitable': {'no_equality': 1},
#   'suit': {'no_equality': 1},
#   'agreed': {'no_equality': 1}},
#  'réellement': {'actually': {'действительно': 2,
#    'на самый дело': 2,
#    'реально': 2,
#    'фактически': 2,
#    'вправду': 1},
#   'really': {'действительно': 1,
#    'на самый дело': 1,
#    'реально': 1,
#    'поистине': 1}},
#  'devant': {'front': {'впереди': 1,
#    'вперёд': 1,
#    'спереди': 1,
#    'прямо': 1,
#    'перед': 1},
#   'before': {'перед': 1, 'впереди': 1},
#   'ahead': {'впереди': 1, 'вперёд': 1}},
#  'virer': {'turn': {'no_equality': 1}},
#  'alcool': {'alcohol': {'алкоголь': 1,
#    'выпивка': 1,
#    'спиртное': 1,
#    'спирт': 1,
#    'алкогольный напиток': 1,
#    'алкоголизм': 1,
#    'спиртное напиток': 1}},
#  'histoire': {'history': {'история': 1, 'прошлое': 1, 'исторический': 1},
#   'story': {'история': 1,
#    'рассказ': 1,
#    'сказка': 1,
#    'дело': 1,
#    'статья': 1,
#    'сюжет': 1,
#    'версия': 1,
#    'роман': 1,
#    'легенда': 1}},
#  'pile': {'stack': {'куча': 1, 'стопка': 1}, 'battery': {'батарейка': 1}},
#  'unique': {'unique': {'единый': 1,
#    'уникальный': 1,
#    'единственный': 1,
#    'неповторимый': 1},
#   'single': {'единый': 1, 'единственный': 1, 'один': 1}},
#  'exposer': {'expose': {'разоблачить': 1, 'подвергать': 1},
#   'exposed': {'подвергать': 1},
#   'showcase': {'no_equality': 1}},
#  'locomotive': {'locomotive': {'локомотив': 1}},
#  'doigt': {'finger': {'палец': 2, 'пальчик': 2, 'мизинец': 2, 'рука': 1}},
#  'siècle': {'century': {'век': 2, 'столетие': 2, 'сто год': 2, '100 год': 2}},
#  'bandeau': {'headband': {'no_equality': 1}},
#  'auparavant': {'previously': {'ранее': 1,
#    'назад': 1,
#    'прежде': 1,
#    'до это': 1},
#   'before': {'ранее': 2, 'прежде': 2, 'до это': 2}},
#  'repas': {'meal': {'еда': 1,
#    'обед': 1,
#    'ужин': 1,
#    'питание': 1,
#    'блюдо': 1,
#    'пища': 1,
#    'трапеза': 1,
#    'приём пища': 1}},
#  'nettement': {'significantly': {'значительно': 1,
#    'существенно': 1,
#    'гораздо': 1,
#    'намного': 1,
#    'заметно': 1,
#    'резко': 1,
#    'значительный': 1},
#   'considerably': {'значительно': 1,
#    'существенно': 1,
#    'гораздо': 1,
#    'намного': 1,
#    'заметно': 1,
#    'резко': 1,
#    'значительный': 1}},
#  'faculté': {'faculty': {'факультет': 1}},
#  'décoller': {'take off': {'взлететь': 1, 'взлетать': 1}},
#  'zone': {'area': {'зона': 1,
#    'район': 1,
#    'область': 1,
#    'территория': 1,
#    'местность': 1,
#    'место': 1,
#    'участок': 1,
#    'площадь': 1,
#    'регион': 1},
#   'zone': {'зона': 1, 'район': 1}},
#  'maîtrise': {'master': {'магистр': 1}},
#  'sécher': {'dry': {'no_equality': 1,
#    'высохнуть': 1,
#    'высушить': 1,
#    'вытереть': 1,
#    'сохнуть': 1,
#    'сушить': 1,
#    'сушиться': 1,
#    'вытирать': 1,
#    'высыхать': 1},
#   'dried': {'no_equality': 1}},
#  'endroit': {'place': {'место': 1, 'местечко': 1, 'дом': 1}},
#  'docilement': {'obediently': {'no_equality': 1},
#   'meekly': {'no_equality': 1},
#   'docilely': {'no_equality': 1}},
#  'gain': {'gain': {'выгода': 1, 'выигрыш': 1},
#   'earnings': {'no_equality': 1},
#   'winning': {'выигрыш': 1}},
#  'shampooing': {'shampoo': {'шампунь': 2}},
#  'correspondre': {'correspond': {'соответствовать': 1},
#   'correlate': {'no_equality': 1}},
#  'particulièrement': {'particularly': {'особенно': 1,
#    'особо': 1,
#    'наиболее': 1,
#    'весьма': 1,
#    'исключительно': 1,
#    'крайне': 1,
#    'чрезвычайно': 1,
#    'особый': 1,
#    'один очередь': 1},
#   'specifically': {'особенно': 1,
#    'особо': 1,
#    'исключительно': 1,
#    'специально': 1,
#    'частность': 1}},
#  'introduire': {'introduce': {'ввести': 1,
#    'включить': 1,
#    'вводить': 1,
#    'внедрить': 1,
#    'внести': 1,
#    'представить': 1,
#    'принять': 1,
#    'предусмотреть': 1,
#    'внедрение': 1},
#   'bring': {'no_equality': 1},
#   'insert': {'ввести': 1, 'включить': 1, 'включать': 1}},
#  'gelée': {'jelly': {'желе': 1}},
#  'publicitaire': {'advertising': {'рекламный': 1}},
#  'lancer': {'launch': {'начать': 1,
#    'запустить': 1,
#    'провести': 1,
#    'запуск': 1,
#    'начинать': 1,
#    'организовать': 1},
#   'start': {'начать': 1,
#    'запустить': 1,
#    'начало': 1,
#    'запуск': 1,
#    'начинать': 1}},
#  'OK': {'OK': {'так': 1, 'давать': 1}},
#  'origine': {'origin': {'происхождение': 1,
#    'источник': 1,
#    'родные': 1,
#    'откуда': 1,
#    'проживание': 1}},
#  'vol': {'flight': {'рейс': 2,
#    'полёт': 2,
#    'самолёт': 2,
#    'перелёт': 2,
#    'билет': 2,
#    'вылет': 2,
#    'пролёт': 1},
#   'theft': {'кража': 1,
#    'ограбление': 1,
#    'воровство': 1,
#    'хищение': 1,
#    'угон': 1}},
#  'tout': {'all': {'всего': 1, 'так': 1, 'только': 1, 'весь': 1},
#   'everything': {'весь': 2, 'ничто': 2},
#   'all of': {'всего': 1},
#   'any': {'люба': 1, 'никакой': 1}},
#  'partout': {'everywhere': {'повсюду': 2,
#    'везде': 2,
#    'повсеместно': 2,
#    'всюду': 2,
#    'где угодный': 2,
#    'куда угодный': 2,
#    'отовсюду': 2,
#    'вокруг': 2},
#   'throughout': {'повсеместно': 1, 'по весь': 1}},
#  'dîner': {'dinner': {'ужин': 2, 'обед': 2, 'ресторан': 2},
#   'dine': {'поужинать': 1, 'ужинать': 1, 'пообедать': 1, 'обедать': 1}},
#  'entrevue': {'interview': {'интервью': 1, 'собеседование': 1}},
#  'nouveau': {'new': {'новый': 1,
#    'новенький': 1,
#    'ново': 1,
#    'новичок': 1,
#    'новость': 1},
#   'fresh': {'новый': 1}},
#  'lev': {'Lev': {'левый': 1}},
#  'avion': {'aircraft': {'самолёт': 1}},
#  'bière': {'beer': {'пиво': 2, 'пивко': 2, 'пивная': 2}},
#  'boire': {'drink': {'выпить': 1,
#    'пить': 1,
#    'попить': 1,
#    'напиться': 1,
#    'выпивать': 1,
#    'выпивка': 1,
#    'пила': 1,
#    'напиток': 1},
#   'drunk': {'пила': 1}},
#  'magnifique': {'beautiful': {'прекрасный': 1,
#    'красивый': 1,
#    'великолепный': 1,
#    'замечательный': 1,
#    'чудесный': 1,
#    'великолепно': 1,
#    'красавица': 1,
#    'чудесно': 1,
#    'красота': 1},
#   'spectacular': {'потрясать': 1}},
#  'lycée': {'high school': {'лицей': 1, 'старший класс': 1}},
#  'tigre': {'tiger': {'тигр': 2, 'тигрица': 1, 'тигрёнок': 1},
#   'Tigris': {'тигр': 1}},
#  'tigré': {'tabby': {'no_equality': 1}},
#  'génétiquement': {'genetically': {'генетически': 2}},
#  'mer': {'sea': {'мор': 1, 'океан': 1}},
#  'Oriental': {'Eastern': {'восточный': 1}, 'oriental': {'восточный': 1}},
#  'juste': {'just': {'просто': 1,
#    'только': 1,
#    'прямо': 1,
#    'сразу': 1,
#    'так': 1,
#    'справедливый': 1,
#    'всего лишь': 1,
#    'как раз': 1,
#    'хотеть': 1,
#    'точно': 1},
#   'right': {'прямо': 1,
#    'сразу': 1,
#    'так': 1,
#    'вот': 1,
#    'правильный': 1,
#    'правильно': 1,
#    'точно': 1},
#   'fair': {'справедливо': 2, 'справедливый': 2, 'честно': 2}},
#  'fourchette': {'fork': {'вилка': 1}},
#  'arrêté': {'stopped': {'перестать': 1, 'остановиться': 1, 'остановить': 1}},
#  'décrire': {'describe': {'описать': 1,
#    'описывать': 1,
#    'охарактеризовать': 1,
#    'рассказать о': 1,
#    'изложить': 1,
#    'описание': 1},
#   'described': {'описать': 1,
#    'охарактеризовать': 1,
#    'изложить': 1,
#    'описание': 1}},
#  'gisement': {'deposit': {'месторождение': 1}},
#  'intensité': {'intensity': {'интенсивность': 1}},
#  'millénaire': {'Millennium': {'тысячелетие': 1,
#    'рубеж тысячелетие': 1,
#    'црдт': 1}},
#  'excellent': {'excellent': {'прекрасный': 2,
#    'отличный': 2,
#    'превосходный': 2,
#    'великолепный': 2,
#    'замечательный': 2,
#    'великолепно': 2,
#    'отлично': 2},
#   'fine': {'прекрасный': 1, 'отличный': 1, 'хороший': 1}},
#  'stylo': {'pen': {'ручка': 2, 'авторучка': 1, 'карандаш': 1}},
#  'nature': {'nature': {'характер': 1,
#    'природа': 1,
#    'натура': 1,
#    'быть': 1,
#    'сущность': 1,
#    'род': 1,
#    'свой характер': 1}},
#  'terrain': {'field': {'пол': 1, 'место': 1, 'поль': 1, 'область': 1}},
#  'lieu': {'place': {'место': 1}, 'occur': {'no_equality': 1}},
#  'incliner': {'tilt': {'no_equality': 1},
#   'incline': {'no_equality': 1},
#   'slant': {'no_equality': 1},
#   'lean': {'no_equality': 1}},
#  'ruban': {'ribbon': {'лента': 1, 'ленточка': 1}},
#  'trop': {'too': {'слишком': 1,
#    'очень': 1,
#    'так': 1,
#    'чересчур': 1,
#    'чрезмерно': 1},
#   'too much': {'чересчур': 1, 'слишком много': 1, 'столько': 1},
#   'too many': {'столько': 1},
#   'excessive': {'no_equality': 1}},
#  'cache': {'cache': {'кэш': 1, 'тайник': 1},
#   'hide': {'скрывать': 1,
#    'прятаться': 1,
#    'скрываться': 1,
#    'прятать': 1,
#    'скрыть': 1}},
#  'break': {'wagon': {'no_equality': 1}, 'station wagon': {'no_equality': 1}},
#  'chaleur': {'heat': {'тепло': 1, 'жара': 1, 'жар': 1, 'теплота': 1}},
#  'historique': {'historic': {'исторический': 1},
#   'history': {'история': 1, 'предыстория': 1}},
#  'entrer': {'enter': {'войти': 2,
#    'входить': 2,
#    'попасть': 2,
#    'въехать': 2,
#    'въезжать': 2,
#    'выйти': 2,
#    'вводить': 1},
#   'come': {'зайти': 1, 'заходить': 1, 'поступить': 1, 'пойти': 1, 'идти': 1},
#   'walk': {'зайти': 1, 'пройти': 1, 'пойти': 1, 'выйти': 1, 'идти': 1}},
#  'gourou': {'guru': {'гуру': 2}},
#  'adverbe': {'adverb': {'no_equality': 1, 'наречие': 1}},
#  'démarrage': {'boot': {'no_equality': 1},
#   'start': {'начало': 1, 'запуск': 1, 'начать': 1}},
#  'sortie': {'output': {'выход': 1, 'вывод': 1},
#   'exit': {'выход': 1, 'выезд': 1, 'уход': 1, 'съезд': 1, 'поворот': 1}},
#  'entretien': {'maintenance': {'содержание': 1,
#    'эксплуатация': 1,
#    'технический обслуживание': 1,
#    'поддержание': 1,
#    'ремонт': 1,
#    'уход': 1,
#    'техобслуживание': 1},
#   'interview': {'собеседование': 1, 'интервью': 1, 'беседа': 1}},
#  'ouvrir': {'open': {'открыть': 1,
#    'открывать': 1,
#    'начать': 1,
#    'открыться': 1,
#    'вскрыть': 1,
#    'открываться': 1,
#    'вскрывать': 1},
#   'opening': {'no_equality': 1}},
#  'piloter': {'pilot': {'управлять': 1, 'пилотировать': 1},
#   'driving': {'no_equality': 1}},
#  'paysan': {'peasant': {'крестьянин': 1}, 'farming': {'фермер': 1}},
#  'Lion': {'lion': {'левый': 2, 'львов': 1, 'львица': 1, 'львиный': 1}},
#  'connaître': {'know': {'знать': 1,
#    'узнать': 1,
#    'узнавать': 1,
#    'понять': 1,
#    'познать': 1},
#   'experience': {'no_equality': 1}},
#  'chemin': {'path': {'путь': 1,
#    'дорога': 1,
#    'троп': 1,
#    'направление': 1,
#    'способ': 1,
#    'маршрут': 1,
#    'путём': 1,
#    'дорогой': 1}},
#  'gonflable': {'inflatable': {'надувной': 1}},
#  'sélectionner': {'select': {'выбрать': 2,
#    'выделить': 2,
#    'выбирать': 2,
#    'отбирать': 2,
#    'отобрать': 1},
#   'highlight': {'выделить': 1}},
#  'davantage': {'more': {'большой': 1, 'более': 1, 'скорее': 1, 'чаща': 1}},
#  'heure': {'hour': {'час': 1, 'время': 1, 'часы': 1, 'часок': 1},
#   'time': {'час': 1, 'время': 1, 'пора': 1, 'момент': 1}},
#  'habillé': {'clad': {'no_equality': 1}},
#  'courant': {'current': {'течение': 1, 'ток': 1, 'поток': 1, 'текущий': 1},
#   'common': {'no_equality': 1}},
#  'Belgique': {'Belgium': {'бельгия': 2, 'бельгийский': 1}},
#  'enfreindre': {'violate': {'нарушать': 1, 'нарушить': 1},
#   'breach': {'нарушать': 1, 'нарушить': 1}},
#  'dessin': {'design': {'no_equality': 1},
#   'draw': {'no_equality': 1},
#   'drawing': {'рисунок': 1,
#    'рисование': 1,
#    'чертёж': 1,
#    'рисовать': 1,
#    'набросок': 1}},
#  'ravioli': {'ravioli': {'no_equality': 1, 'равиоли': 1, 'пельмень': 1}},
#  'sûr': {'course': {'no_equality': 1},
#   'safe': {'безопасный': 1, 'надёжный': 1, 'безопасно': 1},
#   'sure': {'уверенный': 1, 'точно': 1, 'наверняка': 1, 'знать': 1},
#   'naturally': {'no_equality': 1}},
#  'près': {'near': {'почти': 1,
#    'близко': 1,
#    'вблизи': 1,
#    'близ': 1,
#    'около': 1,
#    'возле': 1},
#   'close': {'близко': 1, 'вблизи': 1},
#   'nearly': {'почти': 1, 'примерно': 1, 'близко': 1, 'приблизительно': 1},
#   'about': {'почти': 1, 'примерно': 1, 'приблизительно': 1, 'при': 1},
#   'around': {'примерно': 1, 'вблизи': 1, 'приблизительно': 1},
#   'closely': {'близко': 1},
#   'nearby': {'вблизи': 1},
#   'close to': {'вблизи': 1}},
#  'prendre': {'take': {'принять': 1,
#    'взять': 1,
#    'принимать': 1,
#    'забрать': 1,
#    'предпринять': 1,
#    'занять': 1,
#    'брать': 1,
#    'предпринимать': 1,
#    'пойти': 1,
#    'занимать': 1,
#    'нести': 1,
#    'украсть': 1},
#   'taking': {'no_equality': 1}},
#  'assez': {'enough': {'достаточно': 2,
#    'довольно': 2,
#    'хватить': 2,
#    'настолько': 2,
#    'слишком': 2,
#    'так': 2,
#    'достаточный': 2,
#    'столько': 2,
#    'вполне': 2,
#    'уже': 2,
#    'предостаточно': 2},
#   'quite': {'довольно': 2, 'очень': 2, 'весьма': 2, 'слишком': 2, 'вполне': 2},
#   'pretty': {'достаточно': 1,
#    'довольно': 1,
#    'очень': 1,
#    'весьма': 1,
#    'слишком': 1,
#    'вполне': 1},
#   'fairly': {'достаточно': 1,
#    'довольно': 1,
#    'весьма': 1,
#    'относительно': 1,
#    'вполне': 1},
#   'very': {'достаточно': 1,
#    'довольно': 1,
#    'очень': 1,
#    'весьма': 1,
#    'слишком': 1}},
#  'gel': {'gel': {'гель': 1},
#   'freeze': {'замораживание': 2,
#    'блокирование': 2,
#    'мораторий': 2,
#    'заморозка': 1},
#   'frost': {'no_equality': 1}},
#  'réalisation': {'achievement': {'достижение': 1,
#    'осуществление': 1,
#    'реализация': 1,
#    'выполнение': 1,
#    'обеспечение': 1},
#   'realization': {'достижение': 1,
#    'осуществление': 1,
#    'реализация': 1,
#    'выполнение': 1,
#    'проведение': 1},
#   'implementation': {'достижение': 1,
#    'осуществление': 1,
#    'реализация': 1,
#    'выполнение': 1,
#    'проведение': 1,
#    'соблюдение': 1},
#   'conduct': {'осуществление': 1, 'проведение': 1},
#   'fulfillment': {'выполнение': 1}},
#  'alarme': {'alarm': {'сигнализация': 2,
#    'тревога': 2,
#    'сигнал тревога': 2,
#    'напоминание': 2,
#    'будильник': 2,
#    'сирена': 1}},
#  'voire': {'even': {'даже': 2, 'вообще': 2}},
#  'indemnité': {'compensation': {'компенсация': 1,
#    'возмещение': 1,
#    'выплата': 1},
#   'allowance': {'пособие': 1, 'надбавка': 1, 'выплата': 1}},
#  'banlieue': {'suburb': {'пригород': 1}, 'suburban': {'no_equality': 1}},
#  'Beaver': {'beaver': {'бивер': 2, 'бобёр': 1, 'бобр': 1, 'бобрик': 1}},
#  'soirée': {'evening': {'вечер': 1, 'ужин': 1}},
#  'démarrer': {'start': {'начать': 1,
#    'начаться': 1,
#    'запустить': 1,
#    'начинать': 1}},
#  'avantage': {'benefit': {'преимущество': 2,
#    'выгода': 2,
#    'польза': 2,
#    'льгота': 1}},
#  'pourboire': {'tip': {'чаевой': 1}},
#  'débutant': {'beginner': {'новичок': 2, 'начинающий': 1}},
#  'exceptionnel': {'exceptional': {'исключительный': 1,
#    'выдающийся': 1,
#    'особый': 1},
#   'outstanding': {'выдающийся': 1},
#   'fantastic': {'no_equality': 1}},
#  'interruption': {'interruption': {'прерывание': 1,
#    'перерыв': 1,
#    'прекращение': 1},
#   'interrupt': {'no_equality': 1},
#   'uninterrupted': {'no_equality': 1}},
#  'exact': {'exact': {'точный': 1, 'точно': 1},
#   'accurate': {'точный': 1, 'правильно': 1, 'точно': 1}},
#  'pêcheur': {'fisherman': {'рыбак': 1}, 'fishermen': {'рыбак': 1}},
#  'vider': {'empty': {'опустошить': 2,
#    'освободить': 1,
#    'очистить': 1,
#    'опорожнять': 1,
#    'освобождать': 1},
#   'clean': {'очистить': 1}},
#  'international': {'international': {'международный': 2,
#    'мировой': 2,
#    'интернешнл': 2,
#    'интернациональный': 1,
#    'межнациональный': 1}},
#  'Best': {'best': {'no_equality': 1, 'хороший': 1}},
#  'novice': {'novice': {'новичок': 1}, 'newbie': {'новичок': 1}},
#  'cinquante': {'fifties': {'no_equality': 1}},
#  'tablette': {'tablet': {'планшет': 1, 'скрижаль': 1},
#   'shelf': {'no_equality': 1}},
#  'parent': {'parent': {'родитель': 2, 'отец': 2, 'родительский': 1}},
#  'océan': {'ocean': {'океан': 2, 'мор': 2, 'морской': 1}},
#  'geler': {'freeze': {'заморозить': 2,
#    'замораживать': 2,
#    'блокировать': 2,
#    'замёрзнуть': 1,
#    'заблокировать': 1,
#    'замерзать': 1},
#   'frozen': {'no_equality': 1},
#   'freezing': {'no_equality': 1},
#   'freeze over': {'no_equality': 1}},
#  'épicé': {'spicy': {'острый': 1}},
#  'séculaire': {'secular': {'no_equality': 1}, 'centuries-old': {'вековой': 1}},
#  'astre': {'celestial body': {'no_equality': 1}},
#  'jurisprudence': {'jurisprudence': {'юриспруденция': 1,
#    'судебный практика': 1,
#    'судебный решение': 1,
#    'правовой практика': 1}},
#  'faire': {'do': {'сделать': 1,
#    'делать': 1,
#    'заниматься': 1,
#    'помочь': 1,
#    'поступить': 1},
#   'make': {'сделать': 1,
#    'делать': 1,
#    'заставить': 1,
#    'добиться': 1,
#    'готовить': 1,
#    'заставлять': 1,
#    'совершать': 1,
#    'производить': 1},
#   'making': {'no_equality': 1},
#   'carry': {'no_equality': 1}},
#  'Euro': {'euro': {'евро': 2, 'еврозона': 2}},
#  'pencher': {'lean': {'no_equality': 1}, 'leaning': {'no_equality': 1}},
#  'moment': {'time': {'момент': 1,
#    'время': 1,
#    'раз': 1,
#    'период': 1,
#    'срок': 1,
#    'долго': 1}},
#  'publicité': {'advertising': {'реклама': 1, 'объявление': 1},
#   'advertise': {'no_equality': 1},
#   'publicize': {'no_equality': 1},
#   'advertisement': {'реклама': 1,
#    'объявление': 1,
#    'рекламный': 1,
#    'рекламный объявление': 1}},
#  'automne': {'fall': {'осень': 2}},
#  'brillant': {'brilliant': {'блестящий': 1,
#    'гениальный': 1,
#    'умный': 1,
#    'великолепный': 1},
#   'bright': {'блестящий': 1, 'умный': 1, 'яркий': 1, 'светлый': 1},
#   'shiny': {'блестящий': 1},
#   'glossy': {'no_equality': 1},
#   'gleaming': {'no_equality': 1},
#   'brilliantly': {'no_equality': 1}},
#  'adjectif': {'adjective': {'прилагательное': 2, 'слово': 1}},
#  'planche': {'board': {'доска': 1}},
#  'époque': {'time': {'время': 1, 'период': 1},
#   'era': {'время': 1, 'эпоха': 1, 'период': 1, 'эра': 1, 'век': 1}},
#  'dynamite': {'dynamite': {'динамит': 2}},
#  'seulement': {'only': {'только': 1,
#    'лишь': 1,
#    'просто': 1,
#    'исключительно': 1,
#    'только лишь': 1}},
#  'vestibule': {'hall': {'no_equality': 1},
#   'vestibule': {'no_equality': 1},
#   'lobby': {'no_equality': 1}},
#  'manière': {'way': {'способ': 1,
#    'путь': 1,
#    'подход': 1,
#    'порядок': 1,
#    'манер': 1,
#    'так': 1,
#    'случай': 1,
#    'путём': 1}},
#  'rompre': {'break': {'разорвать': 1, 'нарушить': 1, 'разрушить': 1},
#   'sever': {'порвать': 1, 'разорвать': 1},
#   'breaking': {'no_equality': 1},
#   'terminate': {'no_equality': 1}},
#  'reprendre': {'resume': {'возобновить': 1,
#    'вернуться к': 1,
#    'продолжить': 1,
#    'восстановить': 1,
#    'возобновиться': 1},
#   'recapture': {'no_equality': 1}},
#  'savoir': {'know': {'знать': 1,
#    'узнать': 1,
#    'понять': 1,
#    'сказать': 1,
#    'понимать': 1,
#    'уметь': 1,
#    'известно': 1},
#   'knowing': {'знать': 1, 'узнать': 1, 'понимать': 1}},
#  'électricité': {'electricity': {'электроэнергия': 2,
#    'электричество': 2,
#    'электроснабжение': 2,
#    'энергоснабжение': 2,
#    'электроэнергетика': 2,
#    'энергия': 2,
#    'электро-': 2,
#    'энергетика': 2,
#    'электроэнергетический': 1}},
#  'éventail': {'range': {'круг': 1,
#    'спектр': 1,
#    'диапазон': 1,
#    'комплекс': 1,
#    'набор': 1,
#    'различный': 1,
#    'ряд': 1},
#   'wide range': {'no_equality': 1}},
#  'bout': {'end': {'конец': 1}, 'tip': {'кончик': 1, 'наконечник': 1}},
#  'présenter': {'present': {'представить': 1,
#    'представлять': 1,
#    'подать': 1,
#    'предъявлять': 1},
#   'have': {'no_equality': 1},
#   'introduce': {'представить': 1,
#    'представлять': 1,
#    'познакомить': 1,
#    'внести': 1}},
#  'déposer': {'file': {'подавать': 2, 'представить': 2, 'представлять': 1},
#   'deposit': {'no_equality': 1}},
#  'Génétique': {'genetic': {'генетический': 1}, 'genetics': {'генетика': 1}},
#  'requis': {'required': {'необходимый': 1, 'требовать': 1}},
#  'clôture': {'closing': {'закрытие': 1, 'завершение': 1},
#   'fence': {'забор': 1, 'ограждение': 1, 'стен': 1, 'ограда': 1}},
#  'écrit': {'writing': {'письменный': 1, 'письмо': 1, 'надпись': 1}},
#  'accès': {'access': {'доступ': 1,
#    'получение': 1,
#    'возможность': 1,
#    'выход': 1}},
#  'désert': {'desert': {'пустыня': 1}},
#  'groupe': {'group': {'группа': 1, 'группировка': 1}},
#  'groupé': {'bulk upload': {'no_equality': 1}},
#  'solitaire': {'lonely': {'одинокий': 1},
#   'lone': {'одинокий': 1},
#   'loner': {'одиночка': 1}},
#  'effectivement': {'actually': {'действительно': 1,
#    'фактически': 1,
#    'реально': 1,
#    'на самый дело': 1},
#   'really': {'действительно': 1,
#    'реально': 1,
#    'на самый дело': 1,
#    'поистине': 1}},
#  'chorégraphie': {'choreography': {'хореография': 1}},
#  'lime': {'lime': {'лайм': 1}},
#  'école': {'school': {'школа': 2,
#    'колледж': 2,
#    'учёба': 2,
#    'образование': 2,
#    'училище': 2,
#    'обучение': 2,
#    'университет': 2,
#    'занятие': 2,
#    'курс': 2}},
#  'sexy': {'sexy': {'сексуальный': 1, 'секси': 1, 'сексуальность': 1}},
#  'fuite': {'leak': {'утечка': 1, 'протечка': 1}},
#  'conjointement': {'jointly': {'совместно': 1,
#    'вместе': 1,
#    'одновременно': 1,
#    'сообща': 1,
#    'совместный': 1,
#    'совместный усилие': 1},
#   'in conjunction': {'наряду': 1, 'одновременно': 1}},
#  'interrogation': {'question': {'допрос': 1},
#   'question mark': {'no_equality': 1}},
#  'rentrer': {'return': {'возвращаться': 1, 'возвратиться': 1, 'вернуться': 1},
#   'come back': {'возвращаться': 1,
#    'зайти': 1,
#    'возвратиться': 1,
#    'прийти': 1,
#    'вернуться': 1}},
#  'loin': {'away': {'далеко': 1, 'прочь': 1},
#   'far': {'далеко': 2,
#    'близко': 2,
#    'глубоко': 2,
#    'намного': 2,
#    'долго': 2,
#    'далёкий': 1}},
#  'gamin': {'kid': {'ребёнок': 1,
#    'парень': 1,
#    'мальчик': 1,
#    'пацан': 1,
#    'малыш': 1,
#    'мальчишка': 1,
#    'паренёк': 1,
#    'парнишка': 1,
#    'сынок': 1,
#    'сын': 1,
#    'детство': 1}},
#  'typhus': {'typhus': {'тиф': 2}},
#  'dire': {'say': {'сказать': 1,
#    'говорить': 1,
#    'рассказать': 1,
#    'сообщить': 1,
#    'считать': 1},
#   'saying': {'сказать': 1, 'говорить': 1}},
#  'aéroport': {'airport': {'аэропорт': 2, 'аэродром': 1}},
#  'dimension': {'dimension': {'аспект': 1,
#    'измерение': 1,
#    'размер': 1,
#    'характер': 1,
#    'фактор': 1,
#    'проблематика': 1,
#    'компонент': 1,
#    'масштаб': 1,
#    'составлять': 1}},
#  'compléter': {'complete': {'дополнить': 1,
#    'завершить': 1,
#    'закончить': 1,
#    'завершение': 1},
#   'complement': {'дополнять': 1, 'дополнить': 1, 'дополняться': 1}},
#  'pécher': {'sin': {'no_equality': 1}, 'err': {'no_equality': 1}},
#  'voir': {'see': {'видеть': 1,
#    'увидеть': 1,
#    'посмотреть': 1,
#    'смотреть': 1,
#    'узнать': 1,
#    'понять': 1,
#    'видно': 1,
#    'повидать': 1}},
#  'édition': {'edition': {'издание': 1, 'выпуск': 1},
#   'edit': {'редактирование': 1, 'правка': 1}},
#  'fil': {'wireless': {'no_equality': 1},
#   'wire': {'провод': 1, 'проволока': 1},
#   'thread': {'нить': 1, 'нитка': 1, 'волосок': 1}},
#  'façon': {'way': {'способ': 1,
#    'образ': 1,
#    'путь': 1,
#    'подход': 1,
#    'метод': 1,
#    'порядок': 1,
#    'манер': 1,
#    'так': 1}},
#  'lumière': {'light': {'свет': 1, 'освещение': 1, 'огонёк': 1, 'огонь': 1},
#   'lights': {'свет': 1,
#    'освещение': 1,
#    'огонёк': 1,
#    'лампочка': 1,
#    'огонь': 1}},
#  'intérêt': {'interest': {'интерес': 1,
#    'заинтересованность': 1,
#    'внимание': 1,
#    'процент': 1}},
#  'choisir': {'choose': {'выбрать': 1,
#    'выбирать': 1,
#    'решить': 1,
#    'решать': 1,
#    'избрать': 1,
#    'принять решение': 1,
#    'избирать': 1,
#    'определять': 1,
#    'выбор': 1},
#   'choice': {'no_equality': 1}},
#  'derrière': {'behind': {'позади': 2,
#    'сзади': 2,
#    'там': 2,
#    'назад': 2,
#    'под': 2}},
#  'écrire': {'write': {'написать': 2,
#    'писать': 2,
#    'записать': 2,
#    'записывать': 2,
#    'написание': 2,
#    'составить': 1,
#    'вписать': 1,
#    'описать': 1}},
#  'problème': {'problem': {'проблема': 1,
#    'вопрос': 1,
#    'задача': 1,
#    'неприятность': 1,
#    'трудность': 1,
#    'беда': 1,
#    'забота': 1,
#    'дело': 1}},
#  'issue': {'outcome': {'результат': 1, 'итог': 1, 'исход': 1, 'решение': 1}},
#  'passé': {'past': {'прошлое': 1, 'прошлый': 1, 'уже': 1, 'позади': 1}},
#  'finalement': {'finally': {'наконец': 1,
#    'в итог': 1,
#    'в заключение': 1,
#    'окончательно': 1,
#    'наконец-то': 1,
#    'всё-таки': 1},
#   'eventually': {'в конец конец': 1,
#    'в итог': 1,
#    'в конечный счёт': 1,
#    'с время': 1}},
#  'vedette': {'star': {'звезда': 2}},
#  'plume': {'feather': {'перо': 1, 'пёрышко': 1}, 'pen': {'перо': 1}},
#  'exercice': {'exercise': {'осуществление': 2,
#    'исполнение': 2,
#    'упражнение': 2,
#    'мероприятие': 2,
#    'работа': 2,
#    'выполнение': 2,
#    'реализация': 2,
#    'пример': 1}},
#  'relativement': {'relatively': {'относительно': 1,
#    'сравнительно': 1,
#    'довольно': 1,
#    'весьма': 1,
#    'относительный': 1},
#   'in respect': {'no_equality': 1},
#   'in respect of': {'относительно': 1}},
#  'domaine': {'area': {'область': 1, 'сфера': 1, 'направление': 1, 'вопрос': 1},
#   'field': {'область': 1, 'сфера': 1}},
#  'blond': {'blond': {'блондин': 1},
#   'blonde hair': {'no_equality': 1},
#   'blond hair': {'no_equality': 1}},
#  'avancé': {'advanced': {'передовой': 2, 'развитый': 2, 'продвинуть': 2}},
#  'éleveur': {'breeder': {'no_equality': 1},
#   'reputable breeder': {'no_equality': 1}},
#  'superbe': {'beautiful': {'прекрасный': 1,
#    'отличный': 1,
#    'красивый': 1,
#    'великолепный': 1,
#    'замечательный': 1},
#   'superb': {'великолепный': 1},
#   'great': {'отличный': 1, 'великолепный': 1, 'замечательный': 1},
#   'lovely': {'прекрасный': 1,
#    'отличный': 1,
#    'красивый': 1,
#    'замечательный': 1},
#   'fine': {'прекрасный': 1, 'отличный': 1}},
#  'fan': {'fan': {'фанат': 1,
#    'поклонник': 1,
#    'фанатка': 1,
#    'поклонница': 1,
#    'фан': 1,
#    'любить': 1}},
#  'prestation': {'benefit': {'пособие': 1}},
#  'choix': {'choice': {'выбор': 1,
#    'решение': 1,
#    'вариант': 1,
#    'выбрать': 1,
#    'усмотрение': 1},
#   'select': {'выбор': 1, 'отбор': 1}},
#  'CA': {'CA': {'к.а': 1, 'са': 1}},
#  'courrier': {'mail': {'почта': 1, 'письмо': 1, 'корреспонденция': 1},
#   'email': {'письмо': 1}},
#  'brûlant': {'burning': {'no_equality': 1}, 'hot': {'no_equality': 1}},
#  'définitivement': {'definitely': {'определённо': 1,
#    'точно': 1,
#    'окончательно': 1,
#    'явно': 1,
#    'безусловно': 1},
#   'permanently': {'окончательно': 1, 'навсегда': 1, 'окончательный': 1},
#   'definitively': {'определённо': 1, 'окончательно': 1, 'окончательный': 1}},
#  'alarmer': {'alarm': {'no_equality': 1,
#    'пугать': 1,
#    'тревожить': 1,
#    'встревожить': 1},
#   'alarmed': {'no_equality': 1}},
#  'trajet': {'journey': {'поездка': 1, 'путь': 1, 'дорога': 1, 'маршрут': 1},
#   'route': {'путь': 1, 'дорога': 1, 'маршрут': 1},
#   'travelling': {'no_equality': 1}},
#  'précisément': {'precisely': {'именно': 1,
#    'точно': 1,
#    'как раз': 1,
#    'чётко': 1,
#    'конкретно': 1,
#    'точный': 1}},
#  'comment': {'how': {'как': 1,
#    'откуда': 1,
#    'какой образ': 1,
#    'насколько': 1,
#    'как именно': 1}},
#  'baisse': {'drop': {'снижение': 1, 'сокращение': 1, 'падение': 1, 'спад': 1}},
#  'saisir': {'enter': {'ввести': 1, 'вводить': 1},
#   'seize': {'воспользоваться': 1,
#    'использовать': 1,
#    'схватить': 1,
#    'конфисковать': 1}},
#  'tasse': {'cup': {'чашка': 1,
#    'чашечка': 1,
#    'кружка': 1,
#    'кофе': 1,
#    'стакан': 1},
#   'mug': {'кружка': 1, 'чашка': 1}},
#  'essuyer': {'wipe': {'вытереть': 1},
#   'wipe away': {'no_equality': 1},
#   'MOP': {'no_equality': 1}},
#  'vide': {'empty': {'пустой': 2, 'пустота': 2, 'порожний': 1},
#   'vacuum': {'вакуум': 1, 'пустота': 1},
#   'blank': {'пустой': 1, 'пусто': 1}},
#  'chaleureusement': {'warmly': {'искренне': 1,
#    'от весь душа': 1,
#    'тепло': 1,
#    'горячо': 1},
#   'warm welcome': {'no_equality': 1}},
#  'baisser': {'lower': {'снижаться': 1,
#    'опустить': 1,
#    'понизить': 1,
#    'снижение': 1,
#    'сокращение': 1},
#   'drop': {'снижаться': 1, 'падать': 1, 'снижение': 1, 'сокращение': 1},
#   'decline': {'снижаться': 1,
#    'сокращаться': 1,
#    'сократиться': 1,
#    'снижение': 1,
#    'сокращение': 1},
#   'decrease': {'снижаться': 1,
#    'сокращаться': 1,
#    'сократиться': 1,
#    'снижение': 1,
#    'сокращение': 1},
#   'cut': {'сокращение': 1}},
#  'additionnel': {'supplementary': {'дополнительный': 1}},
#  'exercer': {'exercise': {'осуществлять': 2,
#    'осуществить': 2,
#    'выполнять': 2,
#    'пользоваться': 2,
#    'проявлять': 2},
#   'carry': {'no_equality': 1},
#   'perform': {'осуществлять': 1,
#    'выполнять': 1,
#    'заниматься': 1,
#    'работать': 1,
#    'выполнение': 1},
#   'practice': {'осуществлять': 1, 'заниматься': 1}},
#  'cursus': {'curriculum': {'no_equality': 1}},
#  'manquer': {'lack': {'не хватать': 1}},
#  'humblement': {'humbly': {'смиренно': 1}},
#  'sécheresse': {'drought': {'засуха': 1}, 'dryness': {'no_equality': 1}},
#  'chambre': {'room': {'комната': 1, 'палата': 1, 'номер': 1},
#   'guest room': {'no_equality': 1}},
#  'poisson': {'fish': {'рыба': 2, 'рыбка': 2, 'рыбина': 1, 'улов': 1}},
#  'apprendre': {'learn': {'узнать': 1,
#    'научиться': 1,
#    'научить': 1,
#    'учиться': 1,
#    'учить': 1,
#    'выучить': 1,
#    'узнавать': 1,
#    'изучать': 1,
#    'понять': 1,
#    'знать': 1,
#    'изучить': 1}},
#  'puissance': {'power': {'держава': 1,
#    'сила': 1,
#    'мощь': 1,
#    'мощность': 1,
#    'энергия': 1,
#    'власть': 1,
#    'могущество': 1}},
#  'danse': {'dance': {'танец': 1}},
#  'but': {'goal': {'цель': 1, 'задача': 1, 'гол': 1},
#   'purpose': {'цель': 1,
#    'задача': 1,
#    'смысл': 1,
#    'предназначение': 1,
#    'назначение': 1},
#   'objective': {'цель': 1, 'задача': 1}},
#  'sélection': {'selection': {'отбор': 1,
#    'выбор': 1,
#    'подбор': 1,
#    'выделение': 1,
#    'избрание': 1}},
#  'percer': {'drill': {'no_equality': 1},
#   'pierce': {'no_equality': 1},
#   'boring': {'no_equality': 1}},
#  'ordonner': {'order': {'приказать': 1, 'предписывать': 1}},
#  'sport': {'sport': {'спорт': 1, 'вид спорт': 1}, 'sports': {'спорт': 1}},
#  'prescrire': {'prescribe': {'no_equality': 1}},
#  'quitter': {'leave': {'покинуть': 1,
#    'покидать': 1,
#    'бросить': 1,
#    'оставить': 1,
#    'бросать': 1,
#    'оставлять': 1,
#    'уходить': 1,
#    'уезжать': 1},
#   'exit': {'покинуть': 2, 'выйти': 2}},
#  'troupe': {'troop': {'отряд': 1}, 'troupe': {'труппа': 1}},
#  'expertise': {'expertise': {'опыт': 2,
#    'экспертиза': 2,
#    'специалист': 2,
#    'квалификация': 1,
#    'компетенция': 1,
#    'эксперт': 1,
#    'экспертный знание': 1,
#    'экспертный потенциал': 1,
#    'знание': 1}},
#  'taille': {'size': {'размер': 2,
#    'рост': 2,
#    'численность': 2,
#    'масштаб': 2,
#    'объём': 2}},
#  'taillé': {'carved': {'no_equality': 1}},
#  'contexte': {'context': {'контекст': 1,
#    'обстановка': 1,
#    'условие': 1,
#    'ситуация': 1,
#    'фон': 1,
#    'учёт': 1,
#    'план': 1}},
#  'simplement': {'simply': {'просто': 1,
#    'только': 1,
#    'исключительно': 1,
#    'простой': 1,
#    'попросту': 1,
#    'просто-напросто': 1}},
#  'test': {'test': {'тест': 1,
#    'проверка': 1,
#    'анализ': 1,
#    'испытание': 1,
#    'тестирование': 1,
#    'экзамен': 1}},
#  'crise': {'crisis': {'кризис': 1, 'кризисный ситуация': 1}},
#  'information': {'information': {'информация': 1,
#    'дать': 1,
#    'информирование': 1,
#    'сведение': 1,
#    'материал': 1,
#    'информационный': 1}},
#  'départ': {'departure': {'отъезд': 1,
#    'уход': 1,
#    'выезд': 1,
#    'вылет': 1,
#    'выход': 1,
#    'отбытие': 1},
#   'depart': {'no_equality': 1}},
#  'question': {'question': {'вопрос': 1, 'проблема': 1},
#   'issue': {'вопрос': 2,
#    'проблема': 2,
#    'тема': 2,
#    'пункт': 2,
#    'аспект': 2,
#    'связь': 2,
#    'задача': 2}},
#  'retrait': {'withdrawal': {'вывод': 1,
#    'уход': 1,
#    'снятие': 1,
#    'отзыв': 1,
#    'отмена': 1,
#    'отвод': 1,
#    'лишение': 1,
#    'аннулирование': 1,
#    'отказ': 1,
#    'свёртывание': 1},
#   'remove': {'no_equality': 1}},
#  'beaucoup': {'many': {'много': 1, 'множество': 1},
#   'lot': {'куча': 1, 'большой количество': 1, 'многий': 1},
#   'much': {'гораздо': 1,
#    'намного': 1,
#    'очень': 1,
#    'значительно': 1,
#    'часто': 1,
#    'большой': 1,
#    'значительный': 1,
#    'немало': 1,
#    'очень много': 1,
#    'весьма': 1},
#   'greatly': {'гораздо': 1,
#    'намного': 1,
#    'очень': 1,
#    'значительно': 1,
#    'весьма': 1}},
#  'membre': {'member': {'сотрудник': 2,
#    'участник': 2,
#    'состав': 2,
#    'представитель': 2,
#    'членство': 2,
#    'входить': 2,
#    'член': 2}},
#  'père': {'father': {'отец': 1,
#    'папа': 1,
#    'папаша': 1,
#    'папочка': 1,
#    'батюшка': 1},
#   'parent': {'отец': 1}},
#  'singulier': {'singular': {'no_equality': 1,
#    'единственный число': 1,
#    'уникальный': 1},
#   'peculiar': {'no_equality': 1}},
#  'tableau': {'table': {'таблица': 2, 'табличный': 1},
#   'array': {'no_equality': 1},
#   'chart': {'таблица': 1}},
#  'tir': {'shooting': {'выстрел': 1, 'стрельба': 1, 'огонь': 1, 'стрелять': 1}},
#  'déjeuner': {'breakfast': {'завтрак': 1, 'позавтракать': 1, 'завтракать': 1},
#   'lunch': {'обед': 1,
#    'завтрак': 1,
#    'ланч': 1,
#    'ленч': 1,
#    'пообедать': 1,
#    'обедать': 1,
#    'перекусить': 1,
#    'поесть': 1}},
#  'guère': {'hardly': {'вряд ли': 1, 'едва ли': 1, 'мало': 1}},
#  'lire': {'read': {'читать': 2,
#    'прочитать': 2,
#    'прочесть': 2,
#    'почитать': 2,
#    'зачитать': 2,
#    'разобрать': 2,
#    'чтение': 2,
#    'зачитывать': 1},
#   'reading': {'чтение': 1}},
#  'mouche': {'fly': {'муха': 2}},
#  'facilement': {'easily': {'легко': 2,
#    'вполне': 2,
#    'запросто': 2,
#    'быстро': 2,
#    'без труд': 2,
#    'свободно': 2,
#    'лёгкость': 2,
#    'беспрепятственно': 1,
#    'трудно': 1,
#    'беспрепятственный': 1},
#   'easy': {'no_equality': 1}},
#  'besoin': {'need': {'нужный': 1,
#    'нуждаться': 1,
#    'потребоваться': 1,
#    'требоваться': 1,
#    'понадобиться': 1,
#    'необходимый': 1}},
#  'annonce': {'ad': {'объявление': 1, 'реклама': 1},
#   'announcement': {'объявление': 1,
#    'заявление': 1,
#    'сообщение': 1,
#    'уведомление': 1}},
#  'annoncé': {'declared': {'заявить': 1, 'объявить': 1}},
#  'plaque': {'plate': {'номер': 2,
#    'табличка': 2,
#    'пластина': 2,
#    'номерной знак': 2,
#    'плита': 1}},
#  'plaqué': {'plywood': {'no_equality': 1}},
#  'rupture': {'break': {'разрыв': 2, 'прорыв': 1, 'нарушение': 1},
#   'rupture': {'разрыв': 1}},
#  'briser': {'break': {'разбить': 2,
#    'сломать': 2,
#    'разрушить': 2,
#    'разорвать': 2,
#    'сломить': 2,
#    'нарушить': 2,
#    'разбивать': 2,
#    'нарушать': 2,
#    'ломать': 2},
#   'breaking': {'no_equality': 1}},
#  'OGM': {'GMOs': {'гио': 1, 'гмо': 1}},
#  'débuter': {'start': {'начаться': 1, 'начать': 1}, 'launch': {'начать': 1}},
#  'laïc': {'lay': {'no_equality': 1}},
#  'disque': {'disk': {'диск': 1}},
#  'principalement': {'mainly': {'главное образ': 1,
#    'прежде всего': 1,
#    'преимущественно': 1,
#    'особенно': 1,
#    'основный': 1,
#    'один очередь': 1}},
#  'incendie': {'fire': {'пожар': 1, 'поджог': 1, 'огонь': 1, 'пожарный': 1}},
#  'aventure': {'adventure': {'приключение': 1,
#    'путешествие': 1,
#    'авантюра': 1}},
#  'petit': {'small': {'маленький': 1, 'небольшой': 1, 'мелкий': 1, 'малое': 1},
#   'little': {'маленький': 1,
#    'небольшой': 1,
#    'мелкий': 1,
#    'малый': 1,
#    'кое-что': 1},
#   'low': {'маленький': 1, 'небольшой': 1, 'малый': 1, 'малое': 1}},
#  'lancement': {'launch': {'запуск': 1,
#    'развёртывание': 1,
#    'презентация': 1,
#    'открытие': 1,
#    'создание': 1},
#   'begin': {'no_equality': 1}},
#  'bien': {'well': {'хорошо': 1,
#    'ладный': 1,
#    'так': 1,
#    'отлично': 1,
#    'хороший': 1,
#    'прекрасно': 1},
#   'although': {'хотя': 1},
#   'properly': {'правильно': 1, 'нормальный': 1},
#   'even': {'хотя': 1, 'гораздо': 1}},
#  'Biên': {'bien': {'no_equality': 1}},
#  'huitième': {'eighth': {'восемь': 2, '8-метр': 1, '8-й': 1},
#   'eight': {'восемь': 1}},
#  'encore': {'yet': {'ещё': 1,
#    'до сей пора': 1,
#    'пока ещё': 1,
#    'хотя': 1,
#    'весь ещё': 1},
#   'still': {'ещё': 1,
#    'по-прежнему': 1,
#    'до сей пора': 1,
#    'пока ещё': 1,
#    'весь равно': 1,
#    'весь ещё': 1}},
#  'extrêmement': {'extremely': {'чрезвычайно': 1,
#    'крайне': 1,
#    'весьма': 1,
#    'очень': 1,
#    'исключительно': 1,
#    'невероятно': 1,
#    'особо': 1,
#    'особенно': 1,
#    'необычайно': 1,
#    'крайний': 1},
#   'very': {'чрезвычайно': 1, 'крайне': 1, 'весьма': 1, 'очень': 1},
#   'hugely': {'чрезвычайно': 1},
#   'tremendously': {'чрезвычайно': 1}},
#  'baril': {'barrel': {'бочка': 1, 'баррель': 1, 'за баррель': 1}},
#  'cultivateur': {'grower': {'no_equality': 1},
#   'cultivator': {'no_equality': 1}},
#  'député': {'deputy': {'депутат': 1, 'заместитель': 1},
#   'MP': {'депутат': 1, 'член парламент': 1}},
#  'commande': {'command': {'команда': 1}},
#  'maman': {'mom': {'мама': 1,
#    'мамочка': 1,
#    'мать': 1,
#    'мамуля': 1,
#    'мамаша': 1,
#    'ма': 1,
#    'мамин': 1},
#   'mommy': {'мама': 1, 'мамочка': 1, 'мамуля': 1, 'мамаша': 1}},
#  'scolaire': {'school': {'школьный': 2,
#    'учебный': 2,
#    'образование': 2,
#    'школа': 2,
#    'обучение': 2,
#    'учебный заведение': 1},
#   'educational': {'учебный': 1}},
#  'danser': {'dance': {'танцевать': 2,
#    'потанцевать': 2,
#    'станцевать': 2,
#    'плясать': 1,
#    'сплясать': 1,
#    'поплясать': 1},
#   'dancing': {'no_equality': 1}},
#  'mieux': {'better': {'хороший': 1, 'больший': 1, 'улучшение': 1}},
#  'étoile': {'star': {'звезда': 2, 'звёздочка': 2}},
#  'mériter': {'deserve': {'заслужить': 1, 'заслуживать': 1},
#   'worth': {'no_equality': 1},
#   'deserved': {'заслужить': 1, 'заслуживать': 1}},
#  'News': {'news': {'ньюс': 1, 'новость': 1}},
#  'entier': {'whole': {'целый': 1,
#    'полный': 1,
#    'всего': 1,
#    'целиком': 1,
#    'полностью': 1,
#    'целое': 1,
#    'весь': 1,
#    'целовать': 1},
#   'worldwide': {'no_equality': 1},
#   'integer': {'no_equality': 1},
#   'entire': {'целый': 1, 'полный': 1}},
#  'merveilleux': {'wonderful': {'замечательный': 1,
#    'прекрасный': 1,
#    'чудесный': 1,
#    'удивительный': 1,
#    'великолепно': 1,
#    'чудесно': 1,
#    'здорово': 1,
#    'чудо': 1},
#   'marvellous': {'чудесный': 1, 'чудесно': 1},
#   'marvelous': {'чудесный': 1, 'чудесно': 1},
#   'beautiful': {'замечательный': 1,
#    'прекрасный': 1,
#    'чудесный': 1,
#    'великолепно': 1,
#    'чудесно': 1},
#   'lovely': {'замечательный': 1,
#    'прекрасный': 1,
#    'чудесный': 1,
#    'чудесно': 1}},
#  'peu': {'little': {'мало': 1,
#    'слегка': 1,
#    'несколько': 1,
#    'слишком': 1,
#    'чуть': 1,
#    'почти': 1,
#    'немножко': 1},
#   'bit': {'немножко': 1, 'немного': 1},
#   'low': {'мало': 1},
#   'short': {'мало': 1}},
#  'Orient': {'East': {'восток': 2},
#   'orient': {'no_equality': 1},
#   'middle East': {'no_equality': 1}},
#  'correct': {'correct': {'правильный': 1},
#   'proper': {'правильный': 1,
#    'надлежащий': 1,
#    'правильно': 1,
#    'нормальный': 1},
#   'incorrect': {'неправильно': 1}},
#  'bar': {'bar': {'бар': 1, 'кафе': 1}, 'pub': {'бар': 1, 'паб': 1}},
#  'consultation': {'consultation': {'консультация': 1, 'консультирование': 1},
#   'advisory': {'консультация': 1, 'консультирование': 1}},
#  'froid': {'cold': {'холодный': 1,
#    'холод': 1,
#    'замёрзлый': 1,
#    'замёрзнуть': 1,
#    'остылый': 1},
#   'chilly': {'холодный': 1},
#   'chill': {'холод': 1}},
#  'est': {'be': {'быть': 1,
#    'являться': 1,
#    'иметь': 1,
#    'не': 1,
#    'заключаться': 1,
#    'находиться': 1},
#   'East': {'восточный': 2, 'восток': 2}},
#  'profit': {'profit': {'прибыль': 1, 'прибыть': 1, 'выгода': 1, 'доход': 1}},
#  'réfugié': {'refugee': {'беженец': 2}},
#  'droit': {'right': {'право': 2, 'правый': 2, 'прямо': 2, 'сразу': 2}},
#  'égal': {'equal': {'равный': 1, 'равноправный': 1, 'одинаковый': 1}},
#  'européen': {'European': {'европейский': 1,
#    'общеевропейский': 1,
#    'европеец': 1,
#    'европа': 1},
#   'Europe': {'европейский': 1}},
#  'équitable': {'fair': {'справедливый': 2},
#   'equitable': {'справедливый': 1,
#    'равноправный': 1,
#    'равный': 1,
#    'справедливость': 1,
#    'сбалансированный': 1,
#    'равномерный': 1}},
#  'beau': {'beautiful': {'красивый': 1, 'прекрасный': 1, 'отличный': 1},
#   'nice': {'красивый': 1,
#    'прекрасный': 1,
#    'хороший': 1,
#    'отличный': 1,
#    'симпатичный': 1,
#    'милый': 1,
#    'мило': 1,
#    'классный': 1},
#   'fine': {'прекрасный': 1, 'хороший': 1, 'отличный': 1, 'прекрасно': 1},
#   'pleasant': {'no_equality': 1}},
#  'rencontre': {'meeting': {'встреча': 1,
#    'совещание': 1,
#    'заседание': 1,
#    'мероприятие': 1,
#    'встретиться': 1},
#   'meet': {'no_equality': 1},
#   'Convention': {'no_equality': 1}},
#  'conduite': {'driving': {'вождение': 2, 'движение': 2},
#   'conduct': {'поведение': 1,
#    'проведение': 1,
#    'ведение': 1,
#    'руководство': 1,
#    'действие': 1,
#    'осуществление': 1},
#   'sedan': {'no_equality': 1}},
#  'approuver': {'approve': {'утвердить': 1,
#    'одобрить': 1,
#    'утверждать': 1,
#    'одобрять': 1,
#    'утверждение': 1,
#    'одобрение': 1}},
#  'mondial': {'global': {'глобальный': 1,
#    'мировой': 1,
#    'всемирный': 1,
#    'общемировой': 1},
#   'world': {'мировой': 1, 'всемирный': 1, 'мир': 1},
#   'globally': {'no_equality': 1}},
#  'sommet': {'summit': {'саммит': 1,
#    'встреча на высокий уровень': 1,
#    'вершина': 1}},
#  'facilité': {'ease': {'лёгкость': 1, 'простота': 1}},
#  'intelligent': {'intelligent': {'умный': 2,
#    'разумный': 2,
#    'интеллигентный': 1,
#    'разумно': 1},
#   'clever': {'умный': 1, 'умно': 1}},
#  'hormis': {'apart': {'no_equality': 1},
#   'except': {'за исключение': 1, 'кроме': 1, 'помимо': 1},
#   'except for': {'за исключение': 1, 'если не считать': 1, 'кроме': 1}},
#  'définitif': {'final': {'окончательный': 1, 'заключительный': 1},
#   'definitive': {'окончательный': 1, 'окончательно': 1}},
#  'flamme': {'flame': {'пламя': 1, 'огонь': 1}},
#  'sujet': {'subject': {'вопрос': 1,
#    'тема': 1,
#    'повод': 1,
#    'счёт': 1,
#    'предмет': 1,
#    'субъект': 1,
#    'объект': 1},
#   'about it': {'no_equality': 1}},
#  'largement': {'widely': {'активно': 1,
#    'повсеместно': 1,
#    'широко': 1,
#    'широкий': 1},
#   'largely': {'в многое': 1,
#    'значительно': 1,
#    'существенно': 1,
#    'главное образ': 1,
#    'широко': 1},
#   'extensively': {'активно': 1, 'широко': 1, 'широкий': 1}},
#  'essentiellement': {'mainly': {'главное образ': 1,
#    'прежде всего': 1,
#    'преимущественно': 1,
#    'особенно': 1,
#    'основный': 1},
#   'essentially': {'главное образ': 1,
#    'прежде всего': 1,
#    'преимущественно': 1,
#    'по существо': 1,
#    'по суть': 1},
#   'basically': {'главное образ': 1, 'по существо': 1, 'по суть': 1}},
#  'transport': {'transport': {'перевозка': 1,
#    'транспорт': 1,
#    'транспортировка': 1,
#    'перенос': 1,
#    'доставка': 1,
#    'груз': 1,
#    'проезд': 1}},
#  'avis': {'notice': {'уведомление': 1, 'объявление': 1, 'извещение': 1},
#   'opinion': {'мнение': 1, 'точка зрение': 1, 'взгляд': 1, 'заключение': 1}},
#  'séculier': {'secular': {'no_equality': 1, 'светский': 1, 'мирской': 1}},
#  'fin': {'end': {'конец': 1,
#    'прекращение': 1,
#    'окончание': 1,
#    'завершение': 1,
#    'цель': 1,
#    'концовка': 1,
#    'закончиться': 1,
#    'заканчиваться': 1},
#   'late': {'конец': 1, 'поздний': 1}},
#  'enfin': {'finally': {'наконец': 2, 'в заключение': 2, 'наконец-то': 2}},
#  'région': {'region': {'регион': 1,
#    'район': 1,
#    'область': 1,
#    'округа': 1,
#    'округ': 1,
#    'зона': 1},
#   'area': {'регион': 1, 'район': 1, 'область': 1, 'местность': 1, 'зона': 1}},
#  'renvoyer': {'return': {'вернуть': 1, 'возвращать': 1},
#   'refer': {'передать': 1, 'передавать': 1, 'передача': 1}},
#  'suffisamment': {'enough': {'достаточно': 1,
#    'настолько': 1,
#    'хватить': 1,
#    'довольно': 1,
#    'достаточный количество': 1},
#   'sufficiently': {'достаточно': 1,
#    'настолько': 1,
#    'должное образ': 1,
#    'надлежащий образ': 1},
#   'sufficient': {'no_equality': 1},
#   'ample': {'no_equality': 1}},
#  'commencement': {'beginning': {'начать': 1, 'начало': 1}},
#  'assiette': {'plate': {'тарелка': 1}, 'dish': {'тарелка': 1}},
#  'enrichir': {'enrich': {'обогатить': 1, 'обогащать': 1, 'обогащение': 1}},
#  'bientôt': {'soon': {'скоро': 1,
#    'вскоре': 1,
#    'увидеться': 1,
#    'скорый': 1,
#    'скорый время': 1,
#    'ближний будущее': 1}},
#  'désengagement': {'disengagement': {'разъединение': 1,
#    'размежевание': 1,
#    'уход': 1}},
#  'route': {'road': {'дорога': 1, 'путь': 1, 'шоссе': 1}},
#  'numéro': {'number': {'номер': 1, 'телефон': 1, 'число': 1}},
#  'gagner': {'win': {'выиграть': 1,
#    'победить': 1,
#    'завоевать': 1,
#    'выигрывать': 1,
#    'получить': 1,
#    'заслужить': 1,
#    'побеждать': 1},
#   'winning': {'no_equality': 1},
#   'earn': {'зарабатывать': 1,
#    'заработать': 1,
#    'заслужить': 1,
#    'получать': 1,
#    'получить': 1,
#    'подзаработать': 1,
#    'заслуживать': 1}},
#  'mettre': {'put': {'положить': 1,
#    'поставить': 1,
#    'надеть': 1,
#    'ставить': 1,
#    'поместить': 1,
#    'оставить': 1,
#    'засунуть': 1,
#    'посадить': 1,
#    'класть': 1,
#    'сажать': 1},
#   'set': {'поставить': 1, 'использовать': 1, 'ставить': 1, 'установить': 1},
#   'update': {'no_equality': 1},
#   'bring': {'положить': 1, 'привести': 1},
#   'introduce': {'установить': 1}},
#  'chaud': {'hot': {'горячий': 2,
#    'жаркий': 2,
#    'жар': 2,
#    'жаркое': 2,
#    'круто': 1},
#   'warm': {'горячий': 2, 'тёплый': 2, 'тепло': 2}},
#  'inquiéter': {'worry': {'волноваться': 1,
#    'беспокоиться': 1,
#    'переживать': 1,
#    'беспокоить': 1,
#    'волновать': 1},
#   'worry about': {'беспокоить': 1, 'волновать': 1},
#   'fret': {'волноваться': 1, 'беспокоиться': 1},
#   'concerned about': {'беспокоить': 1, 'волновать': 1}},
#  'gosse': {'kid': {'ребёнок': 1,
#    'парень': 1,
#    'пацан': 1,
#    'мальчик': 1,
#    'мальчишка': 1,
#    'сын': 1,
#    'парнишка': 1,
#    'малыш': 1,
#    'паренёк': 1}},
#  'justice': {'justice': {'правосудие': 1,
#    'справедливость': 1,
#    'юстиция': 1,
#    'суд': 1,
#    'судебный': 1,
#    'судопроизводство': 1}},
#  'déclencher': {'trigger': {'вызвать': 1,
#    'спровоцировать': 1,
#    'привести к': 1},
#   'spark': {'no_equality': 1}},
#  'chacun': {'each': {'каждый': 1},
#   'everyone': {'каждый': 2, 'весь': 2, 'всякий': 1},
#   'every': {'каждый': 1, 'весь': 1, 'люба': 1}},
#  'table': {'table': {'стол': 2, 'столик': 2, 'таблица': 2}},
#  'alcoolisme': {'alcoholism': {'алкоголизм': 1}},
#  'hasard': {'chance': {'случайность': 1, 'случай': 1},
#   'random': {'no_equality': 1}},
#  'incroyable': {'incredible': {'невероятный': 1,
#    'потрясать': 1,
#    'удивительный': 1,
#    'невероятно': 1}},
#  'allocation': {'allocation': {'распределение': 1,
#    'выделение': 1,
#    'ассигнование': 1},
#   'allowance': {'пособие': 1, 'надбавка': 1}},
#  'fichier': {'file': {'файл': 2,
#    'досье': 2,
#    'папка': 1,
#    'документ': 1,
#    'картотека': 1}},
#  'laver': {'wash': {'помыть': 1,
#    'мыть': 1,
#    'вымыть': 1,
#    'стирать': 1,
#    'постирать': 1,
#    'мыться': 1,
#    'умыться': 1,
#    'помыться': 1},
#   'washing': {'no_equality': 1},
#   'washing machine': {'no_equality': 1}},
#  'déclin': {'decline': {'упадок': 1,
#    'спад': 1,
#    'снижение': 1,
#    'падение': 1,
#    'уменьшение': 1,
#    'сокращение': 1}},
#  'rater': {'miss': {'пропустить': 1, 'упустить': 1, 'пропускать': 1}},
#  'meilleur': {'best': {'хороший': 2, 'оптимальный': 2}},
#  'stade': {'stage': {'этап': 1, 'стадия': 1}, 'stadium': {'стадион': 1}},
#  'noter': {'note': {'отметить': 1, 'отмечать': 1, 'заметить': 1, 'учесть': 1},
#   'please note': {'no_equality': 1},
#   'noted': {'отметить': 1, 'отмечать': 1, 'указать': 1, 'отмечаться': 1}},
#  'rêver': {'dream': {'мечтать': 2,
#    'видеть сон': 2,
#    'сниться': 1,
#    'помечтать': 1,
#    'спать': 1,
#    'присниться': 1,
#    'грезить': 1,
#    'увидеть в сон': 1,
#    'видеть в сон': 1,
#    'фантазировать': 1},
#   'dream of': {'мечтать': 1},
#   'dream about': {'no_equality': 1},
#   'daydream': {'no_equality': 1}},
#  'actualité': {'topical': {'no_equality': 1}, 'actuality': {'no_equality': 1}},
#  'enfant': {'child': {'ребёнок': 2,
#    'дитя': 2,
#    'мальчик': 2,
#    'девочка': 2,
#    'дочь': 2,
#    'детский': 2},
#   'infant': {'ребёнок': 1, 'младенец': 1}},
#  'secteur': {'sector': {'сектор': 1,
#    'сфера': 1,
#    'область': 1,
#    'отрасль': 1,
#    'система': 1,
#    'секторальный': 1}},
#  'expérience': {'experience': {'опыт': 1,
#    'практика': 1,
#    'переживание': 1,
#    'знание': 1,
#    'стаж': 1}},
#  'escalier': {'stairs': {'лестница': 1, 'по лестница': 1}},
#  'sonnerie': {'ringtone': {'рингтон': 1}},
#  'élément': {'element': {'элемент': 1,
#    'компонент': 1,
#    'фактор': 1,
#    'аспект': 1,
#    'значение': 1,
#    'стихия': 1,
#    'составлять': 1},
#   'component': {'элемент': 1,
#    'компонент': 1,
#    'часть': 1,
#    'аспект': 1,
#    'составлять': 1}},
#  'fortuit': {'fortuitous': {'no_equality': 1},
#   'incidental': {'no_equality': 1},
#   'accidental': {'no_equality': 1},
#   'adventitious': {'no_equality': 1},
#   'by chance': {'no_equality': 1},
# ...
#  'index': {'index': {'индекс': 1, 'указатель': 1}},
#  'ultime': {'ultimate': {'конечный': 1, 'главный': 1, 'высокий': 1},
#   'final': {'конечный': 1, 'последний': 1}},
#  'dépôt': {'deposit': {'депозит': 1, 'депонирование': 1, 'вклад': 1}},
#  'partir': {'leave': {'уйти': 1,
#    'уехать': 1,
#    'уходить': 1,
#    'идти': 1,
#    'уезжать': 1,
#    'покинуть': 1,
#    'покидать': 1}},
#  'jouer': {'play': {'играть': 1,
#    'сыграть': 1,
#    'поиграть': 1,
#    'выполнять': 1,
#    'выступать': 1,
#    'внести': 1,
#    'разыгрывать': 1},
#   'star': {'no_equality': 1}},
#  'très': {'very': {'очень': 1,
#    'весьма': 1,
#    'крайне': 1,
#    'довольно': 1,
#    'чрезвычайно': 1,
#    'слишком': 1,
#    'сильно': 1,
#    'совсем': 1,
#    'совершенно': 1},
#   'highly': {'очень': 1,
#    'весьма': 1,
#    'крайне': 1,
#    'чрезвычайно': 1,
#    'сильно': 1},
#   'quite': {'очень': 1,
#    'весьма': 1,
#    'крайне': 1,
#    'довольно': 1,
#    'слишком': 1,
#    'сильно': 1,
#    'совсем': 1,
#    'совершенно': 1,
#    'вполне': 1}},
#  'ensuite': {'then': {'впоследствии': 1,
#    'далёкий': 1,
#    'после это': 1,
#    'далее': 1,
#    'теперь': 1},
#   'afterwards': {'впоследствии': 2,
#    'поздний': 2,
#    'дальнейший': 1,
#    'последующий': 1},
#   'after': {'поздний': 1},
#   'furthermore': {'далее': 1}},
#  'commencer': {'start': {'начать': 2,
#    'начинать': 2,
#    'начаться': 2,
#    'начинаться': 2,
#    'приступить к': 2,
#    'приступать': 2,
#    'открыть': 2},
#   'beginning': {'no_equality': 1},
#   'begin': {'начать': 1,
#    'начаться': 1,
#    'начинать': 1,
#    'приступить к': 1,
#    'начинаться': 1,
#    'стать': 1,
#    'начало': 1}},
#  'format': {'format': {'формат': 1, 'форма': 1}},
#  'vraiment': {'really': {'действительно': 1,
#    'очень': 1,
#    'на самый дело': 1,
#    'совсем': 1,
#    'так': 1,
#    'серьёзно': 1,
#    'реально': 1,
#    'точно': 1,
#    'просто': 1,
#    'сильно': 1,
#    'особо': 1,
#    'правда': 1,
#    'по-настоящему': 1},
#   'actually': {'действительно': 1,
#    'на самый дело': 1,
#    'реально': 1,
#    'вправду': 1,
#    'правда': 1},
#   'very': {'очень': 1, 'совсем': 1, 'сильно': 1},
#   'quite': {'очень': 1, 'совсем': 1, 'сильно': 1}},
#  'indiquer': {'indicate': {'указать': 1,
#    'указывать': 1,
#    'отметить': 1,
#    'определить': 1,
#    'указываться': 1,
#    'показать': 1},
#   'say': {'заявить': 1, 'сказать': 1},
#   'specify': {'указать': 1, 'указывать': 1, 'определить': 1, 'указываться': 1},
#   'state': {'указать': 1, 'заявить': 1},
#   'designate': {'определить': 1}},
#  'ailleurs': {'elsewhere': {'в друг место': 1,
#    'в другой место': 1,
#    'повсюду': 1,
#    'другой место': 1,
#    'другой страна': 1,
#    'другой район': 1,
#    'где-то ещё': 1,
#    'другой регион': 1},
#   'furthermore': {'no_equality': 1},
#   'besides': {'кстати': 1, 'между прочить': 1},
#   'else': {'no_equality': 1}},
#  'souper': {'dinner': {'ужин': 1, 'обед': 1}},
#  'collège': {'college': {'колледж': 1, 'коллегия': 1}},
#  'lettre': {'letter': {'письмо': 2,
#    'буква': 2,
#    'записка': 2,
#    'послание': 2,
#    'письменный': 1}},
#  'lettré': {'literate': {'no_equality': 1}},
#  'clair': {'clear': {'ясно': 1,
#    'очевидно': 1,
#    'чётко': 1,
#    'явно': 1,
#    'чёткий': 1,
#    'ясный': 1,
#    'понятный': 1},
#   'bright': {'ясный': 1},
#   'plain': {'ясно': 1},
#   'clearly': {'ясно': 1, 'очевидно': 1, 'чётко': 1, 'явно': 1, 'точно': 1},
#   'obvious': {'понятный': 1, 'очевидный': 1}},
#  'air': {'air': {'воздух': 2, 'эйр': 2, 'вид': 1}},
#  'thème': {'theme': {'тема': 1,
#    'вопрос': 1,
#    'тематика': 1,
#    'тематический': 1,
#    'под название': 1},
#   'topic': {'тема': 1,
#    'вопрос': 1,
#    'проблема': 1,
#    'тематика': 1,
#    'предмет': 1,
#    'тематический': 1},
#   'subject': {'тема': 1, 'вопрос': 1, 'предмет': 1}},
#  'pause': {'break': {'перерыв': 2, 'отдых': 2, 'прорыв': 1},
#   'pause': {'перерыв': 1, 'пауза': 1}},
#  'shampoing': {'shampoo': {'шампунь': 1}},
#  'justement': {'precisely': {'как раз': 1, 'именно': 1},
#   'rightly': {'справедливо': 1},
#   'exactly': {'как раз': 1, 'именно': 1, 'вот': 1},
#   'correctly': {'справедливо': 1}},
#  'mille': {'mile': {'no_equality': 1}},
#  'dernier': {'last': {'последний': 1, 'прошлый': 1, 'предыдущий': 1},
#   'latest': {'последний': 1},
#   'past': {'прошлый': 1},
#   'recent': {'последний': 1}},
#  'complémentaire': {'complementary': {'дополнительный': 1,
#    'взаимодополняющий': 1,
#    'дополнять': 1,
#    'дополнение': 1},
#   'supplemental': {'дополнительный': 1}},
#  'sortir': {'release': {'no_equality': 1},
#   'leave': {'уйти': 1, 'покинуть': 1, 'идти': 1, 'уходить': 1},
#   'come out': {'выйти': 1,
#    'выбраться': 1,
#    'выходить': 1,
#    'пойти': 1,
#    'вылезать': 1},
#   'exit': {'выйти': 1, 'уйти': 1, 'покинуть': 1}},
#  'Dance': {'dance': {'танец': 2}},
#  'déjà': {'already': {'уже': 1, 'так': 1, 'ранее': 1, 'давно': 1}},
#  'âgé': {'old': {'старый': 1, 'пожилой': 1, 'взрослый': 1},
#   'elderly': {'пожилой': 1},
#   'aged': {'старший': 1}},
#  'excepté': {'except': {'за исключение': 2,
#    'кроме': 2,
#    'исключая': 1,
#    'не считать тот': 1},
#   'apart from': {'за исключение': 1, 'кроме': 1}},
#  'début': {'beginning': {'начать': 1, 'начало': 1, 'начинаться': 1},
#   'early': {'начать': 1, 'начало': 1},
#   'begin': {'no_equality': 1},
#   'start': {'начать': 1, 'начало': 1, 'старт': 1}},
#  'vite': {'fast': {'быстро': 1, 'быстрый': 1, 'скорый': 1, 'срочно': 1},
#   'quickly': {'быстро': 1, 'быстрый': 1, 'скоро': 1, 'скорый': 1, 'срочно': 1},
#   'soon': {'быстро': 1, 'быстрый': 1, 'скоро': 1, 'скорый': 1, 'рано': 1}},
#  'pouvoir': {'power': {'власть': 1,
#    'сила': 1,
#    'полномочие': 1,
#    'возможность': 1,
#    'право': 1,
#    'способность': 1}},
#  'plupart': {'majority': {'большинство': 1, 'большой часть': 1}},
#  'autre': {'other': {'другой': 1, 'иной': 1},
#   'else': {'другой': 1, 'остальной': 1, 'иной': 1}},
#  'accepter': {'accept': {'принять': 1,
#    'согласиться с': 1,
#    'принимать': 1,
#    'признать': 1,
#    'признавать': 1,
#    'взять': 1,
#    'пойти': 1,
#    'мириться с': 1,
#    'брать': 1,
#    'допустить': 1},
#   'accepted': {'no_equality': 1},
#   'agree': {'соглашаться': 1, 'признать': 1}},
#  'Convention': {'Convention': {'конвенция': 1, 'соглашение': 1, 'договор': 1},
#   'agreement': {'соглашение': 1, 'договор': 1, 'договорённость': 1}},
#  'autrement': {'otherwise': {'иначе': 1, 'иной образ': 1}},
#  'réunion': {'meeting': {'совещание': 2,
#    'встреча': 2,
#    'заседание': 2,
#    'собрание': 2,
#    'сессия': 2,
#    'мероприятие': 2,
#    'конференция': 2}},
#  'presque': {'almost': {'почти': 2,
#    'практически': 2,
#    'чуть не': 2,
#    'уже': 2,
#    'около': 2,
#    'примерно': 2,
#    'фактически': 2,
#    'скоро': 2},
#   'virtually': {'почти': 1, 'практически': 1, 'фактически': 1}},
#  'spécifiquement': {'specifically': {'специально': 1,
#    'непосредственно': 1,
#    'особенно': 1,
#    'особо': 1,
#    'конкретно': 1,
#    'конкретный': 1,
#    'частность': 1}},
#  'écouter': {'listen': {'слушать': 1,
#    'послушать': 1,
#    'выслушать': 1,
#    'услышать': 1,
#    'выслушивать': 1,
#    'слышать': 1,
#    'слушаться': 1,
#    'прислушиваться': 1,
#    'послушаться': 1,
#    'прослушивать': 1}},
#  'commander': {'order': {'заказать': 2,
#    'заказывать': 2,
#    'приказывать': 1,
#    'командовать': 1}},
#  'super': {'super': {'супер': 1, 'очень': 1},
#   'excellent': {'прекрасный': 1,
#    'отличный': 1,
#    'превосходный': 1,
#    'замечательный': 1,
#    'великолепно': 1}},
#  'même': {'even': {'даже': 2, 'вообще': 2}},
#  'conseiller': {'advisor': {'советник': 1, 'консультант': 1},
#   'counsellor': {'советник': 1, 'консультант': 1},
#   'adviser': {'советник': 1, 'консультант': 1},
#   'counsel': {'советник': 1,
#    'консультант': 1,
#    'адвокат': 1,
#    'совет': 1,
#    'консультировать': 1},
#   'councillor': {'советник': 1},
#   'advise': {'консультирование': 1,
#    'консультировать': 1,
#    'посоветовать': 1,
#    'советовать': 1},
#   'advice': {'консультирование': 1, 'совет': 1}},
#  'formidable': {'great': {'замечательный': 1, 'отличный': 1},
#   'formidable': {'no_equality': 1},
#   'terrific': {'замечательный': 1, 'потрясать': 1, 'отличный': 1}},
#  'fantastique': {'fantastic': {'фантастический': 2,
#    'потрясать': 2,
#    'фантастика': 2,
#    'здорово': 2,
#    'великолепно': 1,
#    'чудесно': 1,
#    'невероятно': 1,
#    'великолепный': 1},
#   'amazing': {'потрясать': 1, 'здорово': 1}},
#  'décevoir': {'disappoint': {'разочаровать': 1,
#    'разочаровывать': 1,
#    'расстраивать': 1},
#   'frustrate': {'no_equality': 1}},
#  'enclos': {'enclosure': {'no_equality': 1},
#   'paddock': {'no_equality': 1},
#   'pen': {'ручка': 1, 'загон': 1}},
#  'nouveauté': {'novelty': {'новизна': 1}},
#  'concours': {'contest': {'конкурс': 1, 'соревнование': 1, 'состязание': 1}},
#  'stellaire': {'stellar': {'no_equality': 1}},
#  'agriculteur': {'farmer': {'фермер': 2, 'земледелец': 1}},
#  'seul': {'single': {'единственный': 1, 'один': 1, 'одинокий': 1, 'единый': 1},
#   'alone': {'единственный': 2,
#    'один': 2,
#    'одинокий': 2,
#    'наедине': 2,
#    'самостоятельно': 2},
#   'sole': {'единственный': 1, 'единый': 1}},
#  'fermier': {'farmer': {'фермер': 1}},
#  'panneau': {'panel': {'панель': 1}, 'control panel': {'no_equality': 1}},
#  'Université': {'University': {'университет': 1}},
#  'message': {'message': {'сообщение': 1,
#    'послание': 1,
#    'сигнал': 1,
#    'идея': 1,
#    'смс': 1,
#    'записка': 1,
#    'письмо': 1,
#    'мысль': 1,
#    'смысл': 1,
#    'призыв': 1,
#    'посыл': 1,
#    'обращение': 1,
#    'заявление': 1}},
#  'mécanicien': {'mechanic': {'механик': 1}},
#  'puis': {'then': {'теперь': 1,
#    'после что': 1,
#    'вот': 1,
#    'пока': 1,
#    'вдруг': 1,
#    'далёкий': 1,
#    'впоследствии': 1,
#    'но': 1,
#    'далее': 1}},
#  'formation': {'training': {'обучение': 1,
#    'образование': 1,
#    'профессиональный подготовка': 1,
#    'курс': 1,
#    'учёба': 1,
#    'занятие': 1,
#    'подготовка': 1,
#    'подготовка кадр': 1,
#    'учебный': 1}},
#  'approbation': {'approval': {'утверждение': 1,
#    'одобрение': 1,
#    'согласие': 1,
#    'принятие': 1,
#    'разрешение': 1,
#    'санкция': 1,
#    'одобрить': 1,
#    'утвердить': 1}},
#  'bénéficier': {'benefit': {'пользоваться': 2,
#    'воспользоваться': 2,
#    'получать': 2,
#    'получить': 2,
#    'приносить польза': 1}},
#  'bande': {'band': {'банда': 2,
#    'полоса': 2,
#    'лента': 2,
#    'диапазон': 1,
#    'шайка': 1,
#    'полоска': 1},
#   'strip': {'полоса': 1}},
#  'publier': {'publish': {'опубликовать': 1,
#    'публиковать': 1,
#    'издать': 1,
#    'издавать': 1,
#    'выпускать': 1,
#    'напечатать': 1,
#    'обнародовать': 1},
#   'release': {'выпустить': 1, 'выпускать': 1, 'публикация': 1, 'выпуск': 1}},
#  'fanfare': {'fanfare': {'no_equality': 1}, 'brass band': {'no_equality': 1}},
#  'fort': {'strong': {'сильный': 1,
#    'сильно': 1,
#    'высокий': 1,
#    'крепкий': 1,
#    'большой': 1,
#    'мощный': 1}},
#  'enregistrer': {'record': {'записать': 1,
#    'регистрировать': 1,
#    'зарегистрировать': 1,
#    'записывать': 1,
#    'запись': 1},
#   'save': {'сохранить': 1, 'сохранять': 1}},
#  'interrogatoire': {'interrogation': {'допрос': 1, 'допросный': 1}},
#  'bénéfice': {'profit': {'прибыль': 1, 'прибыть': 1, 'выгода': 1}},
#  'mère': {'mother': {'мать': 2,
#    'мама': 2,
#    'матерь': 2,
#    'мамочка': 2,
#    'матушка': 2,
#    'мамаша': 2,
#    'матереть': 2,
#    'материнский': 2},
#   'motherboard': {'no_equality': 1},
#   'mom': {'мать': 1,
#    'мама': 1,
#    'мамочка': 1,
#    'мамаша': 1,
#    'мамуля': 1,
#    'ма': 1}},
#  'voler': {'steal': {'украсть': 1,
#    'красть': 1,
#    'воровать': 1,
#    'угнать': 1,
#    'стащить': 1,
#    'выкрасть': 1,
#    'похитить': 1},
#   'fly': {'летать': 2, 'лететь': 2, 'полететь': 2, 'взлететь': 2},
#   'flying': {'no_equality': 1},
#   'stealing': {'no_equality': 1}},
#  'ajuster': {'adjust': {'скорректировать': 1,
#    'корректировать': 1,
#    'корректировка': 1},
#   'adjusted': {'скорректировать': 1, 'корректировать': 1, 'корректировка': 1}},
#  'environ': {'about': {'примерно': 1,
#    'приблизительно': 1,
#    'порядок': 1,
#    'почти': 1,
#    'около': 1}},
#  'bal': {'ballroom': {'no_equality': 1}, 'ball': {'бал': 1, 'балл': 1}},
#  'spécialement': {'specially': {'специально': 1,
#    'особенно': 1,
#    'особо': 1,
#    'специальный': 1,
#    'конкретно': 1,
#    'частность': 1},
#   'especially': {'специально': 1,
#    'особенно': 1,
#    'особо': 1,
#    'прежде всего': 1,
#    'конкретно': 1,
#    'частность': 1,
#    'особый': 1}},
#  'fille': {'girl': {'дочь': 1,
#    'девушка': 1,
#    'девочка': 1,
#    'девчонка': 1,
#    'дочка': 1}},
#  'lors': {'during': {'в время': 1, 'после': 1, 'этап': 1}},
#  'durant': {'during': {'в ход': 1,
#    'на протяжение': 1,
#    'в течение': 1,
#    'в время': 1,
#    'пока': 1,
#    'летом': 1,
#    'этап': 1}},
#  'fût': {'drum': {'no_equality': 1}},
#  'réchauffer': {'warm': {'согреть': 1,
#    'согревать': 1,
#    'погреть': 1,
#    'подогревать': 1}},
#  'collision': {'collide': {'no_equality': 1}},
#  'heurter': {'collide': {'сталкиваться': 1}},
#  'fond': {'background': {'фон': 1, 'основа': 1, 'задний план': 1}},
#  'excuser': {'apologise': {'извиняться': 1,
#    'извиниться': 1,
#    'принести извинение': 1}},
#  'excuse': {'apologise': {'no_equality': 1}},
#  'coco': {'coconut': {'кокос': 1, 'кокосовый': 1}},
#  'cocotier': {'coconut': {'кокос': 1}},
#  'océanique': {'ocean': {'океанский': 1, 'океанический': 1, 'морской': 1}},
#  'coïncidence': {'coincidental': {'случайно': 1,
#    'совпадение': 1,
#    'случайность': 1,
#    'случайный': 1}},
#  'buzzer': {'buzzer': {'звонок': 1, 'зуммер': 1, 'сирена': 1, 'баззер': 1}},
#  'peur': {'afraid': {'no_equality': 1}},
#  'craindre': {'afraid': {'no_equality': 1}},
#  'émettre': {'issue': {'выдавать': 1,
#    'издавать': 1,
#    'издать': 1,
#    'выдать': 1,
#    'выпускать': 1}},
#  'pâte': {'pasta': {'паста': 1}},
#  'Pasta': {'pasta': {'паста': 1}},
#  'moteur': {'engine': {'двигатель': 1,
#    'мотор': 1,
#    'движок': 1,
#    'локомотив': 1,
#    'механизм': 1,
#    'движущий силой': 1,
#    'движущий сила': 1}},
#  'Advanced': {'advanced': {'no_equality': 1}},
#  'sec': {'dry': {'сухой': 1, 'сухо': 1}},
#  'séchage': {'dry': {'no_equality': 1}},
#  'vingts': {'eighty': {'no_equality': 1}},
#  'Eighty': {'eighty': {'no_equality': 1}},
#  'coucher': {'bedroom': {'no_equality': 1}},
#  'cadrer': {'fit': {'соответствовать': 1}},
#  'ajustement': {'fit': {'no_equality': 1}},
#  'apte': {'fit': {'no_equality': 1}},
#  'Extra': {'extra': {'дополнительный': 1, 'экстра': 1, 'сверху': 1}},
#  'tombe': {'fall': {'no_equality': 1}},
#  'nouvelles': {'news': {'новость': 1}},
#  'électrique': {'electric': {'электрический': 1,
#    'электричество': 1,
#    'электроснабжение': 1,
#    'электроэнергия': 1}},
#  'réfugiée': {'refugee': {'беженец': 1}},
#  'Fair': {'fair': {'справедливый': 1}},
#  'cuillère': {'spoon': {'ложка': 1, 'ложечка': 1, 'обнимка': 1}},
#  'Spoon': {'spoon': {'ложка': 1, 'спуна': 1}},
#  'parcours': {'journey': {'путешествие': 1,
#    'путь': 1,
#    'рейс': 1,
#    'маршрут': 1}},
#  'périple': {'journey': {'путешествие': 1, 'путь': 1, 'поездка': 1}},
#  'shampoings': {'shampoo': {'шампунь': 1}},
#  'Shampoo': {'shampoo': {'no_equality': 1}},
#  'ajout': {'add': {'no_equality': 1}},
#  'pointer': {'point': {'указывать': 1, 'направлять': 1}},
#  'curriculum': {'curriculum': {'no_equality': 1}},
#  'ensemble': {'entire': {'no_equality': 1}},
#  'intégralité': {'entire': {'целое': 1, 'полный': 1, 'весь': 1, 'всего': 1}},
#  'entendre': {'hear': {'слышать': 1,
#    'услышать': 1,
#    'послушать': 1,
#    'слушать': 1,
#    'выслушать': 1,
#    'узнать': 1,
#    'знать': 1,
#    'заслушать': 1,
#    'расслышать': 1,
#    'заслушивать': 1,
#    'слышный': 1}},
#  'entendu': {'hear': {'слышать': 1,
#    'услышать': 1,
#    'узнать': 1,
#    'заслушать': 1,
#    'расслышать': 1,
#    'говорят': 1}},
#  'Guru': {'guru': {'гуру': 1}},
#  'Etoiles': {'star': {'no_equality': 1}},
#  'accord': {'agree': {'no_equality': 1}},
#  'lettres': {'letter': {'письмо': 1, 'буква': 1}},
#  'impérieux': {'driving': {'no_equality': 1}},
#  'conduire': {'driving': {'no_equality': 1}},
#  'America': {'America': {'америка': 1}},
#  'laïque': {'secular': {'светский': 1, 'мирской': 1}},
#  'profane': {'secular': {'no_equality': 1}},
#  'extrême': {'far': {'no_equality': 1}},
#  'aérien': {'air': {'воздушный': 1}},
#  'dessous': {'below': {'внизу': 1}},
#  'dansant': {'dance': {'танцевать': 1}},
#  'échec': {'fail': {'no_equality': 1}},
#  'faut': {'necessary': {'необходимый': 1,
#    'нужный': 1,
#    'потребоваться': 1,
#    'требоваться': 1}},
#  'lecture': {'read': {'чтение': 1}}}

# %%
df_step_1 = get_df_from_dict(gl_dct, "fr", "en", "ru")

# %%
df_step_1.head()
# Out:
#        fr    en          ru  vote
# 0  tomber  fall      упасть     2
# 1  tomber  fall      падать     2
# 2  tomber  fall       пасть     2
# 3  tomber  fall   оказаться     2
# 4  tomber  fall  опускаться     1

# %%
gl_dct_2 = merge_cycle_dicts([df_step_1, df_en_ru_fr], "en","ru", "fr")
# Out:
# 100%|██████████| 3473/3473 [00:00<00:00, 4550.08it/s]
# 100%|██████████| 1685/1685 [00:00<00:00, 5987.68it/s]

# %%
gl_dct_2
# Out:
# {'fall': {'упасть': {'tomber': 3},
#   'падать': {'tomber': 2},
#   'пасть': {'tomber': 2},
#   'оказаться': {'tomber': 3},
#   'опускаться': {'tomber': 1},
#   'выпадать': {'tomber': 1},
#   'осень': {'automne': 3},
#   'падение': {'chute': 2, 'baisse': 1, 'déclin': 1},
#   'снижение': {'chute': 1},
#   'сокращение': {'chute': 1},
#   'no_equality': {'tombe': 1},
#   'снижаться': {'baisser': 1},
#   'попадать': {'no_equality': 1},
#   'приходиться': {'no_equality': 1},
#   'впадать': {'no_equality': 1},
#   'подпадать': {'no_equality': 1},
#   'влюбляться': {'no_equality': 1},
#   'обрушиться': {'no_equality': 1},
#   'попасться': {'no_equality': 1},
#   'грехопадение': {'chute': 1},
#   'осенний': {'no_equality': 1}},
#  'fell': {'упасть': {'tomber': 1}, 'пасть': {'tomber': 1}},
#  'fall down': {'упасть': {'tomber': 1}, 'падать': {'tomber': 1}},
#  'penetrate': {'проникнуть': {'pénétrer': 1}, 'проникать': {'pénétrer': 1}},
#  'full': {'полный': {'complet': 1},
#   'всеобъемлющий': {'complet': 1},
#   'всесторонний': {'complet': 1}},
#  'complete': {'полный': {'complet': 1},
#   'всесторонний': {'complet': 1},
#   'дополнить': {'compléter': 1},
#   'завершить': {'compléter': 1},
#   'закончить': {'compléter': 1},
#   'завершение': {'compléter': 1}},
#  'comprehensive': {'полный': {'complet': 1},
#   'всеобъемлющий': {'complet': 1},
#   'комплексный': {'complet': 1},
#   'всесторонний': {'complet': 1},
#   'подробный': {'complet': 1},
#   'исчерпывающий': {'complet': 1}},
#  'entire': {'полный': {'complet': 1, 'entier': 1, 'intégralité': 1},
#   'целый': {'entier': 2},
#   'no_equality': {'ensemble': 1},
#   'целое': {'intégralité': 1},
#   'весь': {'intégralité': 1, 'tout': 1, 'complet': 1},
#   'всего': {'intégralité': 1},
#   'целостный': {'no_equality': 1},
#   'целиком': {'no_equality': 1}},
#  'fully': {'полный': {'complet': 1}, 'всесторонний': {'complet': 1}},
#  'later': {'впоследствии': {'ultérieurement': 1, 'après': 1},
#   'поздний': {'ultérieurement': 1, 'après': 1},
#   'последующий': {'ultérieurement': 1},
#   'дальнейший': {'ultérieurement': 1},
#   'после': {'après': 1},
#   'спустя': {'après': 1},
#   'через': {'après': 1}},
#  'subsequently': {'впоследствии': {'ultérieurement': 1},
#   'поздний': {'ultérieurement': 1},
#   'последующий': {'ultérieurement': 1}},
#  'agree': {'согласовать': {'convenir': 2},
#   'согласиться': {'convenir': 2},
#   'согласование': {'convenir': 2},
#   'соглашаться': {'convenir': 1, 'accepter': 2, "être d'accord": 1},
#   'договариваться': {'convenir': 2},
#   'согласовывать': {'convenir': 1},
#   'признать': {'convenir': 1, 'accepter': 1},
#   'no_equality': {'accord': 1},
#   'согласоваться': {'no_equality': 1},
#   'сходиться': {'no_equality': 1},
#   'одобрить': {'accepter': 1, 'approuver': 1},
#   'быть согласным': {'no_equality': 1},
#   'сходиться во мнениях': {'no_equality': 1},
#   'сговориться': {'no_equality': 1}},
#  'suitable': {'no_equality': {'convenir': 1}},
#  'suit': {'no_equality': {'convenir': 1}},
#  'agreed': {'no_equality': {'convenir': 1}},
#  'actually': {'действительно': {'réellement': 3,
#    'effectivement': 2,
#    'véritablement': 2,
#    'vraiment': 2,
#    'en fait': 1,
#    'bien': 1,
#    'en effet': 1},
#   'на самый дело': {'réellement': 2, 'effectivement': 1, 'vraiment': 1},
#   'реально': {'réellement': 2,
#    'effectivement': 1,
#    'véritablement': 1,
#    'vraiment': 1},
#   'фактически': {'réellement': 3,
#    'effectivement': 2,
#    'en fait': 1,
#    'en réalité': 1,
#    'même': 1,
#    'véritablement': 1,
#    'en effet': 1,
#    'ailleurs': 1},
#   'вправду': {'réellement': 1, 'vraiment': 1},
#   'правда': {'vraiment': 1},
#   'вообще-то': {'en fait': 1,
#    'vraiment': 1,
#    'en réalité': 1,
#    'plutôt': 1,
#    'justement': 1,
#    'vrai dire': 1},
#   'по существу': {'en fait': 1, 'en effet': 1},
#   'как ни странно': {'no_equality': 1},
#   'фактический': {'no_equality': 1}},
#  'really': {'действительно': {'réellement': 1,
#    'effectivement': 1,
#    'vraiment': 1},
#   'на самый дело': {'réellement': 1, 'effectivement': 1, 'vraiment': 1},
#   'реально': {'réellement': 1, 'effectivement': 1, 'vraiment': 1},
#   'поистине': {'réellement': 1, 'effectivement': 1},
#   'очень': {'vraiment': 1},
#   'совсем': {'vraiment': 1},
#   'так': {'vraiment': 1},
#   'серьёзно': {'vraiment': 1},
#   'точно': {'vraiment': 1},
#   'просто': {'vraiment': 1},
#   'сильно': {'vraiment': 1},
#   'особо': {'vraiment': 1},
#   'правда': {'vraiment': 1},
#   'по-настоящему': {'vraiment': 1}},
#  'front': {'впереди': {'devant': 1},
#   'вперёд': {'devant': 1},
#   'спереди': {'devant': 1},
#   'прямо': {'devant': 1},
#   'перед': {'devant': 1}},
#  'before': {'перед': {'devant': 1, 'avant': 2},
#   'впереди': {'devant': 2},
#   'ранее': {'auparavant': 2, 'précédemment': 1, 'avant': 2},
#   'прежде': {'auparavant': 3,
#    'précédemment': 2,
#    'avant': 3,
#    'déjà': 1,
#    'passé': 1},
#   'до это': {'auparavant': 2},
#   'ранний': {'précédemment': 1, 'avant': 2},
#   'пока': {'avant': 2, 'avant que': 1},
#   'прежде чем': {'avant': 3, 'avant que': 1},
#   'до тот': {'avant': 2},
#   'до наступление': {'avant': 2},
#   'до': {'avant': 1, 'auparavant': 1, 'précédant': 1},
#   'пред': {'devant': 1},
#   'накануне': {'juste avant': 1},
#   'передо': {'devant': 1},
#   'раньше': {'avant': 1,
#    'déjà': 1,
#    'précédemment': 1,
#    'auparavant': 1,
#    'passé': 1},
#   'до этого': {'auparavant': 1},
#   'в преддверии': {'avant': 1},
#   'до наступления': {'avant': 1},
#   'прежде нежели': {'avant': 1, 'déjà': 1, 'auparavant': 1}},
#  'ahead': {'впереди': {'devant': 1}, 'вперёд': {'devant': 1}},
#  'turn': {'no_equality': {'virer': 1}},
#  'alcohol': {'алкоголь': {'alcool': 2, 'boire': 1},
#   'выпивка': {'alcool': 1},
#   'спиртное': {'alcool': 1},
#   'спирт': {'alcool': 2},
#   'алкогольный напиток': {'alcool': 1},
#   'алкоголизм': {'alcool': 1, 'alcoolisme': 1},
#   'спиртное напиток': {'alcool': 1},
#   'употребление алкоголя': {'no_equality': 1},
#   'алкогольный': {'no_equality': 1}},
#  'history': {'история': {'histoire': 1, 'historique': 1},
#   'прошлое': {'histoire': 1},
#   'исторический': {'histoire': 1},
#   'предыстория': {'historique': 1}},
#  'story': {'история': {'histoire': 1},
#   'рассказ': {'histoire': 1},
#   'сказка': {'histoire': 1},
#   'дело': {'histoire': 1},
#   'статья': {'histoire': 1},
#   'сюжет': {'histoire': 1},
#   'версия': {'histoire': 1},
#   'роман': {'histoire': 1},
#   'легенда': {'histoire': 1}},
#  'stack': {'куча': {'pile': 1}, 'стопка': {'pile': 1}},
#  'battery': {'батарейка': {'pile': 1}},
#  'unique': {'единый': {'unique': 1},
#   'уникальный': {'unique': 1},
#   'единственный': {'unique': 1},
#   'неповторимый': {'unique': 1}},
#  'single': {'единый': {'unique': 1, 'seul': 1},
#   'единственный': {'unique': 1, 'seul': 1},
#   'один': {'unique': 1, 'seul': 1},
#   'одинокий': {'seul': 1}},
#  'expose': {'разоблачить': {'exposer': 1}, 'подвергать': {'exposer': 1}},
#  'exposed': {'подвергать': {'exposer': 1}},
#  'showcase': {'no_equality': {'exposer': 1}},
#  'locomotive': {'локомотив': {'locomotive': 1}},
#  'finger': {'палец': {'doigt': 3, 'index': 1},
#   'пальчик': {'doigt': 2},
#   'мизинец': {'doigt': 2},
#   'рука': {'doigt': 1},
#   'отпечаток пальца': {'no_equality': 1},
#   'указующий перст': {'no_equality': 1},
#   'пальцевой': {'no_equality': 1},
#   'пальчиковый': {'no_equality': 1},
#   'теребить': {'no_equality': 1}},
#  'century': {'век': {'siècle': 3, 'époque': 1},
#   'столетие': {'siècle': 2},
#   'сто год': {'siècle': 2},
#   '100 год': {'siècle': 2},
#   'столетье': {'siècle': 1},
#   'центурия': {'no_equality': 1},
#   'вековой': {'no_equality': 1},
#   'в.': {'no_equality': 1}},
#  'headband': {'no_equality': {'bandeau': 1}},
#  'previously': {'ранее': {'auparavant': 1, 'précédemment': 1},
#   'назад': {'auparavant': 1},
#   'прежде': {'auparavant': 1, 'précédemment': 1},
#   'до это': {'auparavant': 1},
#   'выше': {'précédemment': 1},
#   'ранний': {'précédemment': 1}},
#  'meal': {'еда': {'repas': 1},
#   'обед': {'repas': 1},
#   'ужин': {'repas': 1},
#   'питание': {'repas': 1},
#   'блюдо': {'repas': 1},
#   'пища': {'repas': 1},
#   'трапеза': {'repas': 1},
#   'приём пища': {'repas': 1}},
#  'significantly': {'значительно': {'nettement': 1},
#   'существенно': {'nettement': 1},
#   'гораздо': {'nettement': 1},
#   'намного': {'nettement': 1},
#   'заметно': {'nettement': 1},
#   'резко': {'nettement': 1},
#   'значительный': {'nettement': 1}},
#  'considerably': {'значительно': {'nettement': 1},
#   'существенно': {'nettement': 1},
#   'гораздо': {'nettement': 1},
#   'намного': {'nettement': 1},
#   'заметно': {'nettement': 1},
#   'резко': {'nettement': 1},
#   'значительный': {'nettement': 1}},
#  'faculty': {'факультет': {'faculté': 1}},
#  'take off': {'взлететь': {'décoller': 1}, 'взлетать': {'décoller': 1}},
#  'area': {'зона': {'zone': 1, 'région': 1},
#   'район': {'zone': 1, 'région': 1},
#   'область': {'zone': 1, 'domaine': 1, 'région': 1},
#   'территория': {'zone': 1},
#   'местность': {'zone': 1, 'région': 1},
#   'место': {'zone': 1},
#   'участок': {'zone': 1},
#   'площадь': {'zone': 1},
#   'регион': {'zone': 1, 'région': 1},
#   'сфера': {'domaine': 1},
#   'направление': {'domaine': 1},
#   'вопрос': {'domaine': 1}},
#  'zone': {'зона': {'zone': 1}, 'район': {'zone': 1}},
#  'master': {'магистр': {'maîtrise': 1}},
#  'dry': {'no_equality': {'sécher': 1, 'séchage': 1},
#   'высохнуть': {'sécher': 1},
#   'высушить': {'sécher': 1},
#   'вытереть': {'sécher': 2, 'essuyer': 1},
#   'сохнуть': {'sécher': 1},
#   'сушить': {'sécher': 2},
#   'сушиться': {'sécher': 1},
#   'вытирать': {'sécher': 1},
#   'высыхать': {'sécher': 1},
#   'сухой': {'sec': 2},
#   'сухо': {'sec': 1},
#   'суховатый': {'sec': 1},
#   'высыхание': {'no_equality': 1},
#   'сухость': {'sécheresse': 1, 'dry': 1},
#   'просушивать': {'no_equality': 1},
#   'насухо': {'no_equality': 1}},
#  'dried': {'no_equality': {'sécher': 1}},
#  'place': {'место': {'endroit': 1, 'lieu': 1},
#   'местечко': {'endroit': 1},
#   'дом': {'endroit': 1}},
#  'obediently': {'no_equality': {'docilement': 1}},
#  'meekly': {'no_equality': {'docilement': 1}},
#  'docilely': {'no_equality': {'docilement': 1}},
#  'gain': {'выгода': {'gain': 1}, 'выигрыш': {'gain': 1}},
#  'earnings': {'no_equality': {'gain': 1}},
#  'winning': {'выигрыш': {'gain': 1}, 'no_equality': {'gagner': 1}},
#  'shampoo': {'шампунь': {'shampooing': 3, 'shampoing': 2, 'shampoings': 1},
#   'no_equality': {'Shampoo': 1},
#   'мытье головы': {'no_equality': 1},
#   'мыть': {'laver': 1}},
#  'correspond': {'соответствовать': {'correspondre': 1}},
#  'correlate': {'no_equality': {'correspondre': 1}},
#  'particularly': {'особенно': {'particulièrement': 1, 'notamment': 1},
#   'особо': {'particulièrement': 1, 'notamment': 1},
#   'наиболее': {'particulièrement': 1},
#   'весьма': {'particulièrement': 1},
#   'исключительно': {'particulièrement': 1},
#   'крайне': {'particulièrement': 1},
#   'чрезвычайно': {'particulièrement': 1},
#   'особый': {'particulièrement': 1},
#   'один очередь': {'particulièrement': 1},
#   'прежде всего': {'notamment': 1}},
#  'specifically': {'особенно': {'particulièrement': 1, 'spécifiquement': 1},
#   'особо': {'particulièrement': 1, 'spécifiquement': 1},
#   'исключительно': {'particulièrement': 1},
#   'специально': {'particulièrement': 1, 'spécifiquement': 1},
#   'частность': {'particulièrement': 1, 'spécifiquement': 1},
#   'непосредственно': {'spécifiquement': 1},
#   'конкретно': {'spécifiquement': 1},
#   'конкретный': {'spécifiquement': 1}},
#  'introduce': {'ввести': {'introduire': 1},
#   'включить': {'introduire': 1},
#   'вводить': {'introduire': 1},
#   'внедрить': {'introduire': 1},
#   'внести': {'introduire': 1, 'présenter': 1},
#   'представить': {'introduire': 1, 'présenter': 1},
#   'принять': {'introduire': 1},
#   'предусмотреть': {'introduire': 1},
#   'внедрение': {'introduire': 1},
#   'представлять': {'présenter': 1},
#   'познакомить': {'présenter': 1},
#   'установить': {'mettre': 1}},
#  'bring': {'no_equality': {'introduire': 1},
#   'положить': {'mettre': 1},
#   'привести': {'mettre': 1}},
#  'insert': {'ввести': {'introduire': 1},
#   'включить': {'introduire': 1},
#   'включать': {'introduire': 1}},
#  'jelly': {'желе': {'gelée': 1}},
#  'advertising': {'рекламный': {'publicitaire': 1},
#   'реклама': {'publicité': 1},
#   'объявление': {'publicité': 1}},
#  'launch': {'начать': {'lancer': 1, 'débuter': 1},
#   'запустить': {'lancer': 1},
#   'провести': {'lancer': 1},
#   'запуск': {'lancer': 1, 'lancement': 1},
#   'начинать': {'lancer': 1},
#   'организовать': {'lancer': 1},
#   'развёртывание': {'lancement': 1},
#   'презентация': {'lancement': 1},
#   'открытие': {'lancement': 1},
#   'создание': {'lancement': 1}},
#  'start': {'начать': {'lancer': 1,
#    'démarrage': 1,
#    'démarrer': 2,
#    'débuter': 2,
#    'commencer': 2,
#    'début': 1,
#    'entamer': 1,
#    'mettre': 1,
#    'engager': 1,
#    'entreprendre': 1,
#    'reprendre': 1,
#    'déclencher': 1},
#   'запустить': {'lancer': 1,
#    'démarrer': 2,
#    'faire': 1,
#    'mettre': 1,
#    'déclencher': 1},
#   'начало': {'lancer': 1,
#    'démarrage': 2,
#    'début': 2,
#    'départ': 1,
#    'lancement': 1,
#    'commencement': 1},
#   'запуск': {'lancer': 1, 'démarrage': 1},
#   'начинать': {'lancer': 1, 'démarrer': 1, 'commencer': 2},
#   'начаться': {'démarrer': 1, 'débuter': 1, 'commencer': 2},
#   'начинаться': {'commencer': 2},
#   'приступить к': {'commencer': 2},
#   'приступать': {'commencer': 2},
#   'открыть': {'commencer': 2},
#   'старт': {'début': 2, 'départ': 1},
#   'вздрагивать': {'no_equality': 1},
#   'завести': {'démarrer': 1, 'faire': 1},
#   'заняться': {'commencer': 1, 'faire': 1, 'entreprendre': 1},
#   'затеять': {'no_equality': 1},
#   'начальный': {'no_equality': 1}},
#  'OK': {'так': {'OK': 1}, 'давать': {'OK': 1}},
#  'origin': {'происхождение': {'origine': 1},
#   'источник': {'origine': 1},
#   'родные': {'origine': 1},
#   'откуда': {'origine': 1},
#   'проживание': {'origine': 1}},
#  'flight': {'рейс': {'vol': 2},
#   'полёт': {'vol': 2},
#   'самолёт': {'vol': 2},
#   'перелёт': {'vol': 2},
#   'билет': {'vol': 2},
#   'вылет': {'vol': 2},
#   'пролёт': {'vol': 1},
#   'полет': {'vol': 1},
#   'стая': {'no_equality': 1},
#   'бегство': {'fuite': 1},
#   'пролет': {'escalier': 1},
#   'взлет': {'no_equality': 1},
#   'налет': {'vol': 1},
#   'облет': {'no_equality': 1},
#   'отлет': {'no_equality': 1},
#   'летный': {'no_equality': 1},
#   'бортовой': {'no_equality': 1},
#   'взлетный': {'no_equality': 1},
#   'летать': {'voler': 1}},
#  'theft': {'кража': {'vol': 1},
#   'ограбление': {'vol': 1},
#   'воровство': {'vol': 1},
#   'хищение': {'vol': 1},
#   'угон': {'vol': 1}},
#  'all': {'всего': {'tout': 1},
#   'так': {'tout': 1},
#   'только': {'tout': 1},
#   'весь': {'tout': 1}},
#  'everything': {'весь': {'tout': 2},
#   'ничто': {'tout': 2},
#   'все': {'tout': 1, 'ça': 1},
#   'что угодно': {'no_equality': 1}},
#  'all of': {'всего': {'tout': 1}},
#  'any': {'люба': {'tout': 1}, 'никакой': {'tout': 1}},
#  'everywhere': {'повсюду': {'partout': 2},
#   'везде': {'partout': 3, 'tout': 1},
#   'повсеместно': {'partout': 2},
#   'всюду': {'partout': 2},
#   'где угодный': {'partout': 2},
#   'куда угодный': {'partout': 2},
#   'отовсюду': {'partout': 2},
#   'вокруг': {'partout': 2},
#   'во всем мире': {'dans le monde entier': 1},
#   'куда бы': {'no_equality': 1},
#   'сплошь': {'no_equality': 1},
#   'вездесущий': {'no_equality': 1}},
#  'throughout': {'повсеместно': {'partout': 1}, 'по весь': {'partout': 1}},
#  'dinner': {'ужин': {'dîner': 2, 'souper': 1},
#   'обед': {'dîner': 3, 'souper': 2, 'repas': 1, 'déjeuner': 1},
#   'ресторан': {'dîner': 2},
#   'торжественный обед': {'dîner': 1, 'repas': 1, 'déjeuner': 1},
#   'обеденный': {'no_equality': 1},
#   'званый': {'dîner': 1}},
#  'dine': {'поужинать': {'dîner': 1},
#   'ужинать': {'dîner': 1},
#   'пообедать': {'dîner': 1},
#   'обедать': {'dîner': 1}},
#  'interview': {'интервью': {'entrevue': 1, 'entretien': 1},
#   'собеседование': {'entrevue': 1, 'entretien': 1},
#   'беседа': {'entretien': 1}},
#  'new': {'новый': {'nouveau': 1, 'nouvelle': 1},
#   'новенький': {'nouveau': 1, 'nouvelle': 1},
#   'ново': {'nouveau': 1},
#   'новичок': {'nouveau': 1, 'nouvelle': 1},
#   'новость': {'nouveau': 1, 'nouvelle': 1}},
#  'fresh': {'новый': {'nouveau': 1}},
#  'Lev': {'левый': {'lev': 1}},
#  'aircraft': {'самолёт': {'avion': 1}},
#  'beer': {'пиво': {'bière': 3, 'boire': 1},
#   'пивко': {'bière': 2},
#   'пивная': {'bière': 2, 'no_equality': 1},
#   'сорт пива': {'bière': 1},
#   'пивной': {'no_equality': 1},
#   'пчелиный': {'no_equality': 1}},
#  'drink': {'выпить': {'boire': 1},
#   'пить': {'boire': 1},
#   'попить': {'boire': 1},
#   'напиться': {'boire': 1},
#   'выпивать': {'boire': 1},
#   'выпивка': {'boire': 1},
#   'пила': {'boire': 1},
#   'напиток': {'boire': 1}},
#  'drunk': {'пила': {'boire': 1}},
#  'beautiful': {'прекрасный': {'magnifique': 1,
#    'superbe': 1,
#    'merveilleux': 1,
#    'beau': 1},
#   'красивый': {'magnifique': 1, 'superbe': 1, 'beau': 1},
#   'великолепный': {'magnifique': 1, 'superbe': 1},
#   'замечательный': {'magnifique': 1, 'superbe': 1, 'merveilleux': 1},
#   'чудесный': {'magnifique': 1, 'merveilleux': 1},
#   'великолепно': {'magnifique': 1, 'merveilleux': 1},
#   'красавица': {'magnifique': 1},
#   'чудесно': {'magnifique': 1, 'merveilleux': 1},
#   'красота': {'magnifique': 1},
#   'отличный': {'superbe': 1, 'beau': 1}},
#  'spectacular': {'потрясать': {'magnifique': 1}},
#  'high school': {'лицей': {'lycée': 1}, 'старший класс': {'lycée': 1}},
#  'tiger': {'тигр': {'tigre': 3},
#   'тигрица': {'tigre': 1},
#   'тигрёнок': {'tigre': 1},
#   'зверь': {'no_equality': 1},
#   'тигриный': {'no_equality': 1}},
#  'Tigris': {'тигр': {'tigre': 1}},
#  'tabby': {'no_equality': {'tigré': 1}},
#  'genetically': {'генетически': {'génétiquement': 3, 'génétique': 1, 'ogm': 1},
#   'генетический': {'no_equality': 1}},
#  'sea': {'мор': {'mer': 1}, 'океан': {'mer': 1}},
#  'Eastern': {'восточный': {'Oriental': 1}},
#  'oriental': {'восточный': {'Oriental': 1}},
#  'just': {'просто': {'juste': 1},
#   'только': {'juste': 1},
#   'прямо': {'juste': 1},
#   'сразу': {'juste': 1},
#   'так': {'juste': 1},
#   'справедливый': {'juste': 1},
#   'всего лишь': {'juste': 1},
#   'как раз': {'juste': 1},
#   'хотеть': {'juste': 1},
#   'точно': {'juste': 1}},
#  'right': {'прямо': {'juste': 1, 'droit': 2, 'no_equality': 1},
#   'сразу': {'juste': 1, 'droit': 2, 'no_equality': 1},
#   'так': {'juste': 1},
#   'вот': {'juste': 1},
#   'правильный': {'juste': 1},
#   'правильно': {'juste': 1,
#    'bien': 1,
#    'exact': 1,
#    'correct': 1,
#    'hein': 1,
#    "c'est ça": 1,
#    "n'est-ce pas": 1,
#    'non': 1},
#   'точно': {'juste': 1},
#   'право': {'droit': 3, 'droite': 2},
#   'правый': {'droit': 3, 'droite': 1},
#   'правая сторона': {'droite': 1},
#   'правда': {'bien': 1, 'hein': 1},
#   'правота': {'no_equality': 1},
#   'нужный': {'bon': 1},
#   'подходящий': {'bon': 1},
#   'вправо': {'no_equality': 1},
#   'хорошо': {'bien': 1, "d'accord": 1, 'ok': 1}},
#  'fair': {'справедливо': {'juste': 2, 'équitablement': 1},
#   'справедливый': {'juste': 3, 'équitable': 3, 'Fair': 1},
#   'честно': {'juste': 2},
#   'no_equality': {'impartial': 1},
#   'красивый': {'beau': 1},
#   'светлый': {'beau': 1, 'clair': 1, 'blond': 1},
#   'беспристрастный': {'impartial': 1},
#   'белокурый': {'blond': 1},
#   'ярмарочный': {'no_equality': 1},
#   'изрядный': {'no_equality': 1},
#   'удовлетворительно': {'no_equality': 1},
#   'попутный': {'no_equality': 1},
#   'чистовой': {'no_equality': 1},
#   'выставка': {'exposition': 1},
#   'справедливость': {'équité': 1, 'justice': 1},
#   'салон': {'salon': 1}},
#  'fork': {'вилка': {'fourchette': 1}},
#  'stopped': {'перестать': {'arrêté': 1},
#   'остановиться': {'arrêté': 1},
#   'остановить': {'arrêté': 1}},
#  'describe': {'описать': {'décrire': 1},
#   'описывать': {'décrire': 1},
#   'охарактеризовать': {'décrire': 1},
#   'рассказать о': {'décrire': 1},
#   'изложить': {'décrire': 1},
#   'описание': {'décrire': 1}},
#  'described': {'описать': {'décrire': 1},
#   'охарактеризовать': {'décrire': 1},
#   'изложить': {'décrire': 1},
#   'описание': {'décrire': 1}},
#  'deposit': {'месторождение': {'gisement': 1},
#   'no_equality': {'déposer': 1},
#   'депозит': {'dépôt': 1},
#   'депонирование': {'dépôt': 1},
#   'вклад': {'dépôt': 1}},
#  'intensity': {'интенсивность': {'intensité': 1}},
#  'Millennium': {'тысячелетие': {'millénaire': 1},
#   'рубеж тысячелетие': {'millénaire': 1},
#   'црдт': {'millénaire': 1}},
#  'excellent': {'прекрасный': {'excellent': 2, 'super': 1},
#   'отличный': {'excellent': 3, 'super': 1, 'très bon': 1, 'superbe': 1},
#   'превосходный': {'excellent': 2, 'super': 1},
#   'великолепный': {'excellent': 2},
#   'замечательный': {'excellent': 2, 'super': 1},
#   'великолепно': {'excellent': 2, 'super': 1},
#   'отлично': {'excellent': 2},
#   'исключительный': {'exceptionnel': 1},
#   'блестящий': {'brillant': 1},
#   'первоклассный': {'no_equality': 1}},
#  'fine': {'прекрасный': {'excellent': 1, 'superbe': 1, 'beau': 1},
#   'отличный': {'excellent': 1, 'superbe': 1, 'beau': 1},
#   'хороший': {'excellent': 1, 'beau': 1},
#   'прекрасно': {'beau': 1}},
#  'pen': {'ручка': {'stylo': 3, 'enclos': 1},
#   'авторучка': {'stylo': 1},
#   'карандаш': {'stylo': 1},
#   'перо': {'plume': 1},
#   'загон': {'enclos': 2},
#   'рейсфедер': {'no_equality': 1},
#   'фломастер': {'feutre': 1},
#   'Перу': {'no_equality': 1},
#   'пена': {'no_equality': 1},
#   'пенал': {'no_equality': 1},
#   'световое перо': {'plume': 1},
#   'писать': {'écrire': 1},
#   'перьевой': {'no_equality': 1}},
#  'nature': {'характер': {'nature': 1},
#   'природа': {'nature': 1},
#   'натура': {'nature': 1},
#   'быть': {'nature': 1},
#   'сущность': {'nature': 1},
#   'род': {'nature': 1},
#   'свой характер': {'nature': 1}},
#  'field': {'пол': {'terrain': 1, 'champ': 2},
#   'место': {'terrain': 1},
#   'поль': {'terrain': 1, 'champ': 2},
#   'область': {'terrain': 1, 'domaine': 2, 'champ': 3, 'secteur': 1, 'zone': 1},
#   'сфера': {'domaine': 1},
#   'поле': {'champ': 1, 'domaine': 1, 'terrain': 1, 'zone': 1},
#   'пространство': {'no_equality': 1},
#   'месторождение': {'gisement': 1},
#   'отрасль': {'secteur': 1},
#   'нива': {'no_equality': 1},
#   'поприще': {'no_equality': 1},
#   'промысел': {'no_equality': 1},
#   'полевой': {'no_equality': 1},
#   'промысловый': {'no_equality': 1},
#   'походный': {'no_equality': 1},
#   'в полевых условиях': {'no_equality': 1}},
#  'occur': {'no_equality': {'lieu': 1}},
#  'tilt': {'no_equality': {'incliner': 1}},
#  'incline': {'no_equality': {'incliner': 1}},
#  'slant': {'no_equality': {'incliner': 1}},
#  'lean': {'no_equality': {'incliner': 1, 'pencher': 1}},
#  'ribbon': {'лента': {'ruban': 1}, 'ленточка': {'ruban': 1}},
#  'too': {'слишком': {'trop': 1},
#   'очень': {'trop': 1},
#   'так': {'trop': 1},
#   'чересчур': {'trop': 1},
#   'чрезмерно': {'trop': 1}},
#  'too much': {'чересчур': {'trop': 1},
#   'слишком много': {'trop': 1},
#   'столько': {'trop': 1}},
#  'too many': {'столько': {'trop': 1}},
#  'excessive': {'no_equality': {'trop': 1}},
#  'cache': {'кэш': {'cache': 1}, 'тайник': {'cache': 1}},
#  'hide': {'скрывать': {'cache': 1},
#   'прятаться': {'cache': 1},
#   'скрываться': {'cache': 1},
#   'прятать': {'cache': 1},
#   'скрыть': {'cache': 1}},
#  'wagon': {'no_equality': {'break': 1}},
#  'station wagon': {'no_equality': {'break': 1}},
#  'heat': {'тепло': {'chaleur': 1},
#   'жара': {'chaleur': 1},
#   'жар': {'chaleur': 1},
#   'теплота': {'chaleur': 1}},
#  'historic': {'исторический': {'historique': 1}},
#  'enter': {'войти': {'entrer': 2},
#   'входить': {'entrer': 3, 'rentrer': 1},
#   'попасть': {'entrer': 2},
#   'въехать': {'entrer': 2},
#   'въезжать': {'entrer': 3},
#   'выйти': {'entrer': 2},
#   'вводить': {'entrer': 1, 'saisir': 1},
#   'ввести': {'saisir': 2, 'introduire': 1},
#   'ввод': {'entrée': 2},
#   'заключать': {'no_equality': 1},
#   'проникать': {'pénétrer': 1},
#   'вступить': {'no_equality': 1},
#   'указать': {'indiquer': 1}},
#  'come': {'зайти': {'entrer': 1},
#   'заходить': {'entrer': 1},
#   'поступить': {'entrer': 1},
#   'пойти': {'entrer': 1},
#   'идти': {'entrer': 1}},
#  'walk': {'зайти': {'entrer': 1},
#   'пройти': {'entrer': 1},
#   'пойти': {'entrer': 1},
#   'выйти': {'entrer': 1},
#   'идти': {'entrer': 1}},
#  'guru': {'гуру': {'gourou': 3, 'Guru': 1}},
#  'adverb': {'no_equality': {'adverbe': 1}, 'наречие': {'adverbe': 2}},
#  'boot': {'no_equality': {'démarrage': 1}},
#  'output': {'выход': {'sortie': 1}, 'вывод': {'sortie': 1}},
#  'exit': {'выход': {'sortie': 2, 'issue': 1, 'retrait': 1},
#   'выезд': {'sortie': 2, 'départ': 1},
#   'уход': {'sortie': 1, 'retrait': 1, 'départ': 1, 'désengagement': 1},
#   'съезд': {'sortie': 1, 'no_equality': 1},
#   'поворот': {'sortie': 1},
#   'покинуть': {'quitter': 2, 'sortir': 1},
#   'выйти': {'quitter': 3, 'sortir': 2},
#   'уйти': {'sortir': 1},
#   'свернуть': {'no_equality': 1},
#   'выездной': {'no_equality': 1},
#   'выходной': {'no_equality': 1}},
#  'maintenance': {'содержание': {'entretien': 1},
#   'эксплуатация': {'entretien': 1},
#   'технический обслуживание': {'entretien': 1},
#   'поддержание': {'entretien': 1},
#   'ремонт': {'entretien': 1},
#   'уход': {'entretien': 1},
#   'техобслуживание': {'entretien': 1}},
#  'open': {'открыть': {'ouvrir': 1},
#   'открывать': {'ouvrir': 1},
#   'начать': {'ouvrir': 1},
#   'открыться': {'ouvrir': 1},
#   'вскрыть': {'ouvrir': 1},
#   'открываться': {'ouvrir': 1},
#   'вскрывать': {'ouvrir': 1}},
#  'opening': {'no_equality': {'ouvrir': 1}},
#  'pilot': {'управлять': {'piloter': 1}, 'пилотировать': {'piloter': 1}},
#  'driving': {'no_equality': {'piloter': 1, 'impérieux': 1, 'conduire': 1},
#   'вождение': {'conduite': 3},
#   'движение': {'conduite': 2, 'no_equality': 1},
#   'управление': {'conduite': 1},
#   'руль': {'no_equality': 1},
#   'перегон': {'no_equality': 1},
#   'проходка': {'no_equality': 1},
#   'автовождение': {'no_equality': 1},
#   'забивка': {'no_equality': 1},
#   'движущий': {'no_equality': 1},
#   'движущийся': {'no_equality': 1},
#   'управляющий': {'no_equality': 1},
#   'въезжающий': {'no_equality': 1},
#   'приводящий в движение': {'no_equality': 1},
#   'гоняющий': {'no_equality': 1},
#   'приводной': {'no_equality': 1},
#   'ездовой': {'no_equality': 1}},
#  'peasant': {'крестьянин': {'paysan': 1}},
#  'farming': {'фермер': {'paysan': 1}},
#  'lion': {'левый': {'Lion': 2},
#   'львов': {'Lion': 1},
#   'львица': {'Lion': 1},
#   'львиный': {'Lion': 1, 'no_equality': 1},
#   'лев': {'lion': 1, 'lev': 1}},
#  'know': {'знать': {'connaître': 1, 'savoir': 1},
#   'узнать': {'connaître': 1, 'savoir': 1},
#   'узнавать': {'connaître': 1},
#   'понять': {'connaître': 1, 'savoir': 1},
#   'познать': {'connaître': 1},
#   'сказать': {'savoir': 1},
#   'понимать': {'savoir': 1},
#   'уметь': {'savoir': 1},
#   'известно': {'savoir': 1}},
#  'experience': {'no_equality': {'connaître': 1},
#   'опыт': {'expérience': 1},
#   'практика': {'expérience': 1},
#   'переживание': {'expérience': 1},
#   'знание': {'expérience': 1},
#   'стаж': {'expérience': 1}},
#  'path': {'путь': {'chemin': 1},
#   'дорога': {'chemin': 1},
#   'троп': {'chemin': 1},
#   'направление': {'chemin': 1},
#   'способ': {'chemin': 1},
#   'маршрут': {'chemin': 1},
#   'путём': {'chemin': 1},
#   'дорогой': {'chemin': 1}},
#  'inflatable': {'надувной': {'gonflable': 1}},
#  'select': {'выбрать': {'sélectionner': 2},
#   'выделить': {'sélectionner': 3},
#   'выбирать': {'sélectionner': 3, 'choisir': 1},
#   'отбирать': {'sélectionner': 2},
#   'отобрать': {'sélectionner': 1},
#   'выбор': {'choix': 1},
#   'отбор': {'choix': 2, 'sélection': 1},
#   'избирать': {'choisir': 1},
#   'указать': {'désigner': 1},
#   'отборный': {'no_equality': 1}},
#  'highlight': {'выделить': {'sélectionner': 1}},
#  'more': {'большой': {'davantage': 1},
#   'более': {'davantage': 1},
#   'скорее': {'davantage': 1},
#   'чаща': {'davantage': 1}},
#  'hour': {'час': {'heure': 1},
#   'время': {'heure': 1},
#   'часы': {'heure': 1},
#   'часок': {'heure': 1}},
#  'time': {'час': {'heure': 1},
#   'время': {'heure': 1, 'moment': 1, 'époque': 1},
#   'пора': {'heure': 1},
#   'момент': {'heure': 1, 'moment': 1},
#   'раз': {'moment': 1},
#   'период': {'moment': 1, 'époque': 1},
#   'срок': {'moment': 1},
#   'долго': {'moment': 1}},
#  'clad': {'no_equality': {'habillé': 1}},
#  'current': {'течение': {'courant': 1},
#   'ток': {'courant': 1},
#   'поток': {'courant': 1},
#   'текущий': {'courant': 1}},
#  'common': {'no_equality': {'courant': 1}},
#  'Belgium': {'бельгия': {'Belgique': 2},
#   'бельгийский': {'Belgique': 1},
#   'Бельгия': {'belgique': 1}},
#  'violate': {'нарушать': {'enfreindre': 1, 'violer': 1},
#   'нарушить': {'enfreindre': 1, 'violer': 1},
#   'нарушение': {'violer': 1}},
#  'breach': {'нарушать': {'enfreindre': 1}, 'нарушить': {'enfreindre': 1}},
#  'design': {'no_equality': {'dessin': 1}},
#  'draw': {'no_equality': {'dessin': 1},
#   'извлечь': {'tirer': 1},
#   'извлекать': {'tirer': 1},
#   'тянуть': {'tirer': 1},
#   'получать': {'tirer': 1}},
#  'drawing': {'рисунок': {'dessin': 2},
#   'рисование': {'dessin': 2},
#   'чертёж': {'dessin': 1},
#   'рисовать': {'dessin': 1},
#   'набросок': {'dessin': 1},
#   'волочение': {'no_equality': 1},
#   'розыгрыш': {'no_equality': 1},
#   'заимствование': {'no_equality': 1},
#   'графика': {'no_equality': 1},
#   'нанесение': {'no_equality': 1},
#   'составление': {'no_equality': 1},
#   'вытяжка': {'no_equality': 1},
#   'тираж': {'tirage': 1},
#   'чертежный': {'no_equality': 1},
#   'графический': {'no_equality': 1},
#   'рисующий': {'no_equality': 1},
#   'привлекающий': {'no_equality': 1},
#   'рисуемый': {'no_equality': 1}},
#  'ravioli': {'no_equality': {'ravioli': 1},
#   'равиоли': {'ravioli': 2},
#   'пельмень': {'ravioli': 1},
#   'пельменный': {'no_equality': 1}},
#  'course': {'no_equality': {'sûr': 1}},
#  'safe': {'безопасный': {'sûr': 1},
#   'надёжный': {'sûr': 1},
#   'безопасно': {'sûr': 1}},
#  'sure': {'уверенный': {'sûr': 1},
#   'точно': {'sûr': 1},
#   'наверняка': {'sûr': 1},
#   'знать': {'sûr': 1}},
#  'naturally': {'no_equality': {'sûr': 1}},
#  'near': {'почти': {'près': 1},
#   'близко': {'près': 1},
#   'вблизи': {'près': 1},
#   'близ': {'près': 1},
#   'около': {'près': 1},
#   'возле': {'près': 1}},
#  'close': {'близко': {'près': 1}, 'вблизи': {'près': 1}},
#  'nearly': {'почти': {'près': 1},
#   'примерно': {'près': 1},
#   'близко': {'près': 1},
#   'приблизительно': {'près': 1}},
#  'about': {'почти': {'près': 1, 'environ': 1},
#   'примерно': {'près': 1, 'environ': 1},
#   'приблизительно': {'près': 1, 'environ': 1},
#   'при': {'près': 1},
#   'порядок': {'environ': 1},
#   'около': {'environ': 1}},
#  'around': {'примерно': {'près': 1},
#   'вблизи': {'près': 1},
#   'приблизительно': {'près': 1}},
#  'closely': {'близко': {'près': 1}},
#  'nearby': {'вблизи': {'près': 1}},
#  'close to': {'вблизи': {'près': 1}},
#  'take': {'принять': {'prendre': 1},
#   'взять': {'prendre': 1, 'avoir': 1},
#   'принимать': {'prendre': 1},
#   'забрать': {'prendre': 1},
#   'предпринять': {'prendre': 1},
#   'занять': {'prendre': 1},
#   'брать': {'prendre': 1},
#   'предпринимать': {'prendre': 1},
#   'пойти': {'prendre': 1},
#   'занимать': {'prendre': 1},
#   'нести': {'prendre': 1},
#   'украсть': {'prendre': 1},
#   'иметь': {'avoir': 1}},
#  'taking': {'no_equality': {'prendre': 1}},
#  'enough': {'достаточно': {'assez': 3, 'suffisamment': 2, 'trop': 1},
#   'довольно': {'assez': 2, 'suffisamment': 1},
#   'хватить': {'assez': 2, 'suffisamment': 1},
#   'настолько': {'assez': 2, 'suffisamment': 1},
#   'слишком': {'assez': 2},
#   'так': {'assez': 2},
#   'достаточный': {'assez': 2},
#   'столько': {'assez': 2},
#   'вполне': {'assez': 2},
#   'уже': {'assez': 2},
#   'предостаточно': {'assez': 3},
#   'достаточный количество': {'suffisamment': 1},
#   'достаточное количество': {'no_equality': 1},
#   'маловато': {'no_equality': 1},
#   'достаточно многие': {'no_equality': 1}},
#  'quite': {'довольно': {'assez': 3,
#    'très': 2,
#    'bien': 1,
#    'plutôt': 1,
#    'vraiment': 1,
#    'beaucoup': 1,
#    'relativement': 1,
#    'peu': 1},
#   'очень': {'assez': 2, 'très': 1, 'vraiment': 1},
#   'весьма': {'assez': 2, 'très': 1},
#   'слишком': {'assez': 2, 'très': 1},
#   'вполне': {'assez': 2, 'très': 1},
#   'крайне': {'très': 1},
#   'сильно': {'très': 1, 'vraiment': 1},
#   'совсем': {'très': 1, 'vraiment': 1},
#   'совершенно': {'très': 1},
#   'немало': {'beaucoup': 1},
#   'неплохой': {'no_equality': 1},
#   'самое': {'très': 1}},
#  'pretty': {'достаточно': {'assez': 1},
#   'довольно': {'assez': 1},
#   'очень': {'assez': 1},
#   'весьма': {'assez': 1},
#   'слишком': {'assez': 1},
#   'вполне': {'assez': 1}},
#  'fairly': {'достаточно': {'assez': 1},
#   'довольно': {'assez': 1},
#   'весьма': {'assez': 1},
#   'относительно': {'assez': 1},
#   'вполне': {'assez': 1}},
#  'very': {'достаточно': {'assez': 1},
#   'довольно': {'assez': 1, 'très': 1},
#   'очень': {'assez': 1, 'extrêmement': 1, 'très': 1, 'vraiment': 1},
#   'весьма': {'assez': 1, 'extrêmement': 1, 'très': 1},
#   'слишком': {'assez': 1, 'très': 1},
#   'чрезвычайно': {'extrêmement': 1, 'très': 1},
#   'крайне': {'extrêmement': 1, 'très': 1},
#   'сильно': {'très': 1, 'vraiment': 1},
#   'совсем': {'très': 1, 'vraiment': 1},
#   'совершенно': {'très': 1}},
#  'gel': {'гель': {'gel': 1}},
#  'freeze': {'замораживание': {'gel': 3},
#   'блокирование': {'gel': 2},
#   'мораторий': {'gel': 2},
#   'заморозка': {'gel': 1},
#   'заморозить': {'geler': 2},
#   'замораживать': {'geler': 3},
#   'блокировать': {'geler': 2},
#   'замёрзнуть': {'geler': 1},
#   'заблокировать': {'geler': 1},
#   'замерзать': {'geler': 2},
#   'застывать': {'no_equality': 1},
#   'примерзать': {'no_equality': 1},
#   'зависать': {'no_equality': 1},
#   'отморозить': {'no_equality': 1},
#   'заледенеть': {'no_equality': 1},
#   'вмерзнуть': {'geler': 1},
#   'зависание': {'no_equality': 1},
#   'мороз': {'froid': 1, 'gelée': 1}},
#  'frost': {'no_equality': {'gel': 1}},
#  'achievement': {'достижение': {'réalisation': 1},
#   'осуществление': {'réalisation': 1},
#   'реализация': {'réalisation': 1},
#   'выполнение': {'réalisation': 1},
#   'обеспечение': {'réalisation': 1}},
#  'realization': {'достижение': {'réalisation': 1},
#   'осуществление': {'réalisation': 1},
#   'реализация': {'réalisation': 1},
#   'выполнение': {'réalisation': 1},
#   'проведение': {'réalisation': 1}},
#  'implementation': {'достижение': {'réalisation': 1},
#   'осуществление': {'réalisation': 1},
#   'реализация': {'réalisation': 1},
#   'выполнение': {'réalisation': 1},
#   'проведение': {'réalisation': 1},
#   'соблюдение': {'réalisation': 1}},
#  'conduct': {'осуществление': {'réalisation': 1, 'conduite': 1},
#   'проведение': {'réalisation': 1, 'conduite': 1},
#   'поведение': {'conduite': 1},
#   'ведение': {'conduite': 1},
#   'руководство': {'conduite': 1},
#   'действие': {'conduite': 1}},
#  'fulfillment': {'выполнение': {'réalisation': 1}},
#  'alarm': {'сигнализация': {'alarme': 3},
#   'тревога': {'alarme': 3},
#   'сигнал тревога': {'alarme': 2},
#   'напоминание': {'alarme': 2},
#   'будильник': {'alarme': 3, 'réveil': 1},
#   'сирена': {'alarme': 1},
#   'no_equality': {'alarmer': 1},
#   'пугать': {'alarmer': 1},
#   'тревожить': {'alarmer': 1},
#   'встревожить': {'alarmer': 2, 'inquiéter': 1},
#   'сигнал тревоги': {'alarme': 1},
#   'предупредительный сигнал': {'no_equality': 1},
#   'сигнализатор': {'no_equality': 1},
#   'набат': {'no_equality': 1},
#   'настораживать': {'no_equality': 1},
#   'аварийный': {'no_equality': 1},
#   'сигнализационный': {'no_equality': 1}},
#  'even': {'даже': {'voire': 3,
#    'même': 3,
#    'encore': 1,
#    'bien': 1,
#    'y compris': 1,
#    'voire même': 1},
#   'вообще': {'voire': 2, 'même': 2},
#   'хотя': {'bien': 1},
#   'гораздо': {'bien': 1},
#   'ровный': {'égal': 1},
#   'четный': {'pair': 1},
#   'эвенский': {'no_equality': 1},
#   'вечер': {'no_equality': 1},
#   'эвен': {'no_equality': 1},
#   'выравнивать': {'no_equality': 1},
#   'и': {'no_equality': 1},
#   'пусть': {'no_equality': 1}},
#  'compensation': {'компенсация': {'indemnité': 1},
#   'возмещение': {'indemnité': 1},
#   'выплата': {'indemnité': 1}},
#  'allowance': {'пособие': {'indemnité': 1, 'allocation': 1},
#   'надбавка': {'indemnité': 1, 'allocation': 1},
#   'выплата': {'indemnité': 1}},
#  'suburb': {'пригород': {'banlieue': 1}},
#  'suburban': {'no_equality': {'banlieue': 1}},
#  'beaver': {'бивер': {'Beaver': 2},
#   'бобёр': {'Beaver': 1, 'castor': 1},
#   'бобр': {'Beaver': 1, 'castor': 2},
#   'бобрик': {'Beaver': 1},
#   'Бобрик': {'beaver': 1},
#   'Бивер': {'beaver': 1},
#   'работяга': {'no_equality': 1},
#   'бородач': {'no_equality': 1},
#   'бобровый': {'no_equality': 1}},
#  'evening': {'вечер': {'soirée': 1}, 'ужин': {'soirée': 1}},
#  'benefit': {'преимущество': {'avantage': 3},
#   'выгода': {'avantage': 3,
#    'bénéfice': 1,
#    'profit': 1,
#    'intérêt': 1,
#    'gain': 1},
#   'польза': {'avantage': 2},
#   'льгота': {'avantage': 1},
#   'пособие': {'prestation': 2, 'allocation': 1, 'indemnité': 1},
#   'пользоваться': {'bénéficier': 2},
#   'воспользоваться': {'bénéficier': 2},
#   'получать': {'bénéficier': 2},
#   'получить': {'bénéficier': 2},
#   'приносить польза': {'bénéficier': 1},
#   'привилегия': {'no_equality': 1},
#   'благо': {'intérêt': 1, 'bien': 1},
#   'прибыль': {'bénéfice': 1, 'profit': 1},
#   'эффект': {'no_equality': 1},
#   'выигрыш': {'no_equality': 1},
#   'плод': {'no_equality': 1},
#   'приносить пользу': {'bénéficier': 1},
#   'принести пользу': {'no_equality': 1},
#   'выигрывать': {'no_equality': 1},
#   'выгодный': {'no_equality': 1}},
#  'tip': {'чаевой': {'pourboire': 1},
#   'кончик': {'bout': 2},
#   'наконечник': {'bout': 1},
#   'совет': {'conseil': 2},
#   'чаевые': {'pourboire': 1},
#   'тонкий конец': {'no_equality': 1},
#   'верхушка': {'pointe': 1},
#   'подсказка': {'no_equality': 1},
#   'Совет': {'conseil': 1},
#   'оконечность': {'no_equality': 1},
#   'отзыв': {'no_equality': 1},
#   'полезный Совет': {'no_equality': 1},
#   'зонд': {'no_equality': 1},
#   'подачка': {'no_equality': 1},
#   'вершинка': {'sommet': 1},
#   'наклонять': {'pencher': 1, 'incliner': 1},
#   'опрокинуться': {'no_equality': 1},
#   'давать чаевые': {'donner un pourboire': 1},
#   'на чай': {'pourboire': 1}},
#  'beginner': {'новичок': {'débutant': 3, 'novice': 1},
#   'начинающий': {'débutant': 2},
#   'начальный уровень': {'no_equality': 1},
#   'начинающий фотограф': {'débutant': 1},
#   'начальный': {'no_equality': 1}},
#  'exceptional': {'исключительный': {'exceptionnel': 1},
#   'выдающийся': {'exceptionnel': 1},
#   'особый': {'exceptionnel': 1}},
#  'outstanding': {'выдающийся': {'exceptionnel': 1}},
#  'fantastic': {'no_equality': {'exceptionnel': 1},
#   'фантастический': {'fantastique': 3},
#   'потрясать': {'fantastique': 2},
#   'фантастика': {'fantastique': 2},
#   'здорово': {'fantastique': 2},
#   'великолепно': {'fantastique': 1},
#   'чудесно': {'fantastique': 1},
#   'невероятно': {'fantastique': 1},
#   'великолепный': {'fantastique': 1},
#   'причудливый': {'no_equality': 1},
#   'замечательный': {'formidable': 1,
#    'magnifique': 1,
#    'super': 1,
#    'merveilleux': 1,
#    'excellent': 1,
#    'incroyable': 1,
#    'beau': 1},
#   'отличный': {'superbe': 1, 'super': 1, 'excellent': 1, 'beau': 1},
#   'сказовый': {'no_equality': 1},
#   'просто фантастический': {'fantastique': 1, 'fantastic': 1},
#   'небывалый': {'extraordinaire': 1},
#   'умопомрачительный': {'no_equality': 1},
#   'потрясающий': {'super': 1},
#   'фантастически': {'no_equality': 1}},
#  'interruption': {'прерывание': {'interruption': 1},
#   'перерыв': {'interruption': 1},
#   'прекращение': {'interruption': 1}},
#  'interrupt': {'no_equality': {'interruption': 1}},
#  'uninterrupted': {'no_equality': {'interruption': 1}},
#  'exact': {'точный': {'exact': 1}, 'точно': {'exact': 1}},
#  'accurate': {'точный': {'exact': 1},
#   'правильно': {'exact': 1},
#   'точно': {'exact': 1}},
#  'fisherman': {'рыбак': {'pêcheur': 1}},
#  'fishermen': {'рыбак': {'pêcheur': 1}},
#  'empty': {'опустошить': {'vider': 2},
#   'освободить': {'vider': 1},
#   'очистить': {'vider': 2},
#   'опорожнять': {'vider': 2},
#   'освобождать': {'vider': 1},
#   'пустой': {'vide': 3},
#   'пустота': {'vide': 2, 'no_equality': 1},
#   'порожний': {'vide': 1},
#   'no_equality': {'creux': 1},
#   'бессодержательный': {'creux': 1},
#   'пустынный': {'désert': 1},
#   'свободный': {'libre': 1},
#   'голодный': {'no_equality': 1},
#   'пустеть': {'no_equality': 1},
#   'высыпать': {'no_equality': 1},
#   'опорожнение': {'no_equality': 1},
#   'пустышка': {'no_equality': 1},
#   'порожняк': {'no_equality': 1},
#   'пустующий': {'no_equality': 1},
#   'порожняком': {'no_equality': 1}},
#  'clean': {'очистить': {'vider': 1}},
#  'international': {'международный': {'international': 3, 'mondial': 1},
#   'мировой': {'international': 2},
#   'интернешнл': {'international': 2},
#   'интернациональный': {'international': 1},
#   'межнациональный': {'international': 1},
#   'Интернационал': {'no_equality': 1}},
#  'best': {'no_equality': {'Best': 1},
#   'хороший': {'Best': 1, 'meilleur': 2},
#   'оптимальный': {'meilleur': 2},
#   'лучший': {'meilleur': 1, 'bon': 1, 'idéal': 1},
#   'наивысший': {'no_equality': 1},
#   'лучше всего': {'mieux': 1, 'le mieux': 1},
#   'Бест': {'best': 1}},
#  'novice': {'новичок': {'novice': 1}},
#  'newbie': {'новичок': {'novice': 1}},
#  'fifties': {'no_equality': {'cinquante': 1}},
#  'tablet': {'планшет': {'tablette': 1}, 'скрижаль': {'tablette': 1}},
#  'shelf': {'no_equality': {'tablette': 1}},
#  'parent': {'родитель': {'parent': 3, 'père': 1},
#   'отец': {'parent': 3, 'père': 2},
#   'родительский': {'parent': 1, 'no_equality': 1},
#   'предок': {'no_equality': 1},
#   'родительский элемент': {'parental': 1},
#   'родительница': {'no_equality': 1},
#   'исходный': {'no_equality': 1},
#   'вышестоящий': {'no_equality': 1},
#   'один из родителей': {'no_equality': 1}},
#  'ocean': {'океан': {'océan': 3, 'mer': 1},
#   'мор': {'océan': 2},
#   'морской': {'océan': 1, 'océanique': 1},
#   'океанский': {'océanique': 1, 'no_equality': 1},
#   'океанический': {'océanique': 1},
#   'дно океана': {'no_equality': 1}},
#  'frozen': {'no_equality': {'geler': 1}},
#  'freezing': {'no_equality': {'geler': 1}},
#  'freeze over': {'no_equality': {'geler': 1}},
#  'spicy': {'острый': {'épicé': 1}},
#  'secular': {'no_equality': {'séculaire': 1, 'séculier': 1, 'profane': 1},
#   'светский': {'séculier': 2, 'laïque': 1, 'laïc': 1},
#   'мирской': {'séculier': 1, 'laïque': 1},
#   'вековой': {'séculaire': 1},
#   'долговременный': {'no_equality': 1},
#   'секуляристский': {'no_equality': 1},
#   'мирянин': {'no_equality': 1},
#   'светскость': {'no_equality': 1}},
#  'centuries-old': {'вековой': {'séculaire': 1}},
#  'celestial body': {'no_equality': {'astre': 1}},
#  'jurisprudence': {'юриспруденция': {'jurisprudence': 1},
#   'судебный практика': {'jurisprudence': 1},
#   'судебный решение': {'jurisprudence': 1},
#   'правовой практика': {'jurisprudence': 1}},
#  'do': {'сделать': {'faire': 1},
#   'делать': {'faire': 1},
#   'заниматься': {'faire': 1},
#   'помочь': {'faire': 1},
#   'поступить': {'faire': 1}},
#  'make': {'сделать': {'faire': 1},
#   'делать': {'faire': 1},
#   'заставить': {'faire': 1},
#   'добиться': {'faire': 1},
#   'готовить': {'faire': 1},
#   'заставлять': {'faire': 1},
#   'совершать': {'faire': 1},
#   'производить': {'faire': 1}},
#  'making': {'no_equality': {'faire': 1}},
#  'carry': {'no_equality': {'faire': 1, 'exercer': 1}},
#  'euro': {'евро': {'Euro': 2, 'euro': 1},
#   'еврозона': {'Euro': 2},
#   'ЕРБ': {'no_equality': 1},
#   'европейский': {'européen': 1}},
#  'leaning': {'no_equality': {'pencher': 1}},
#  'advertise': {'no_equality': {'publicité': 1}},
#  'publicize': {'no_equality': {'publicité': 1}},
#  'advertisement': {'реклама': {'publicité': 2, 'pub': 1},
#   'объявление': {'publicité': 1},
#   'рекламный': {'publicité': 1, 'pub': 1},
#   'рекламный объявление': {'publicité': 1},
#   'анонс': {'annonce': 1},
#   'рекламный материал': {'publicité': 1, 'publicitaire': 1, 'pub': 1},
#   'рекламный ролик': {'publicité': 1, 'pub': 1},
#   'рекламное сообщение': {'message': 1},
#   'рекламоноситель': {'no_equality': 1},
#   'рекламирование': {'publicité': 1}},
#  'brilliant': {'блестящий': {'brillant': 1},
#   'гениальный': {'brillant': 1},
#   'умный': {'brillant': 1},
#   'великолепный': {'brillant': 1}},
#  'bright': {'блестящий': {'brillant': 1},
#   'умный': {'brillant': 1},
#   'яркий': {'brillant': 1},
#   'светлый': {'brillant': 1},
#   'ясный': {'clair': 1}},
#  'shiny': {'блестящий': {'brillant': 1}},
#  'glossy': {'no_equality': {'brillant': 1}},
#  'gleaming': {'no_equality': {'brillant': 1}},
#  'brilliantly': {'no_equality': {'brillant': 1}},
#  'adjective': {'прилагательное': {'adjectif': 3},
#   'слово': {'adjectif': 1},
#   'определение': {'no_equality': 1},
#   'характеристика': {'no_equality': 1}},
#  'board': {'доска': {'planche': 1}},
#  'era': {'время': {'époque': 1},
#   'эпоха': {'époque': 1},
#   'период': {'époque': 1},
#   'эра': {'époque': 1},
#   'век': {'époque': 1}},
#  'dynamite': {'динамит': {'dynamite': 3},
#   'динамитная шашка': {'no_equality': 1},
#   'динамитный': {'no_equality': 1},
#   'взрывной': {'no_equality': 1}},
#  'only': {'только': {'seulement': 1, 'uniquement': 1},
#   'лишь': {'seulement': 1},
#   'просто': {'seulement': 1, 'uniquement': 1},
#   'исключительно': {'seulement': 1, 'uniquement': 1},
#   'только лишь': {'seulement': 1}},
#  'hall': {'no_equality': {'vestibule': 1}},
#  'vestibule': {'no_equality': {'vestibule': 1}},
#  'lobby': {'no_equality': {'vestibule': 1}},
#  'way': {'способ': {'manière': 1, 'façon': 1, 'mode': 1},
#   'путь': {'manière': 1, 'façon': 1},
#   'подход': {'manière': 1, 'façon': 1},
#   'порядок': {'manière': 1, 'façon': 1, 'mode': 1},
#   'манер': {'manière': 1, 'façon': 1},
#   'так': {'manière': 1, 'façon': 1},
#   'случай': {'manière': 1},
#   'путём': {'manière': 1},
#   'образ': {'façon': 1},
#   'метод': {'façon': 1, 'mode': 1}},
#  'break': {'разорвать': {'rompre': 2, 'briser': 3, 'sortir': 1},
#   'нарушить': {'rompre': 1, 'briser': 2},
#   'разрушить': {'rompre': 2, 'briser': 3},
#   'разрыв': {'rupture': 3, 'fracture': 1},
#   'прорыв': {'rupture': 1, 'pause': 1},
#   'нарушение': {'rupture': 1},
#   'разбить': {'briser': 2, 'casser': 1},
#   'сломать': {'briser': 2, 'casser': 1},
#   'сломить': {'briser': 2},
#   'разбивать': {'briser': 3, 'casser': 2},
#   'нарушать': {'briser': 3, 'enfreindre': 1, 'violer': 1},
#   'ломать': {'briser': 3, 'casser': 2},
#   'взломать': {'casser': 1},
#   'сломаться': {'casser': 1},
#   'перерыв': {'pause': 3, 'break': 1, 'interruption': 1},
#   'отдых': {'pause': 2},
#   'прорваться': {'percer': 1},
#   'вырваться': {'rompre': 1, 'sortir': 1},
#   'разбиться': {'no_equality': 1},
#   'разразиться': {'no_equality': 1},
#   'пробить': {'briser': 1, 'percer': 1},
#   'преодолеть': {'sortir': 1},
#   'отколоться': {'no_equality': 1},
#   'вырывать': {'no_equality': 1},
#   'преломлять': {'no_equality': 1},
#   'пролом': {'no_equality': 1},
#   'каникулы': {'vacance': 1},
#   'передышка': {'no_equality': 1}},
#  'sever': {'порвать': {'rompre': 1}, 'разорвать': {'rompre': 1}},
#  'breaking': {'no_equality': {'rompre': 1, 'briser': 1, 'casser': 1}},
#  'terminate': {'no_equality': {'rompre': 1}},
#  'resume': {'возобновить': {'reprendre': 1},
#   'вернуться к': {'reprendre': 1},
#   'продолжить': {'reprendre': 1},
#   'восстановить': {'reprendre': 1},
#   'возобновиться': {'reprendre': 1}},
#  'recapture': {'no_equality': {'reprendre': 1}},
#  'knowing': {'знать': {'savoir': 1},
#   'узнать': {'savoir': 1},
#   'понимать': {'savoir': 1}},
#  'electricity': {'электроэнергия': {'électricité': 2},
#   'электричество': {'électricité': 3, 'courant': 1},
#   'электроснабжение': {'électricité': 2},
#   'энергоснабжение': {'électricité': 2},
#   'электроэнергетика': {'électricité': 2},
#   'энергия': {'électricité': 2},
#   'электро-': {'électricité': 2},
#   'энергетика': {'électricité': 2},
#   'электроэнергетический': {'électricité': 1},
#   'свет': {'électricité': 1, 'courant': 1, 'lumière': 1},
#   'электрический': {'no_equality': 1}},
#  'range': {'круг': {'éventail': 1},
#   'спектр': {'éventail': 1},
#   'диапазон': {'éventail': 1},
#   'комплекс': {'éventail': 1},
#   'набор': {'éventail': 1},
#   'различный': {'éventail': 1},
#   'ряд': {'éventail': 1}},
#  'wide range': {'no_equality': {'éventail': 1}},
#  'end': {'конец': {'bout': 1, 'fin': 1},
#   'прекращение': {'fin': 1},
#   'окончание': {'fin': 1},
#   'завершение': {'fin': 1},
#   'цель': {'fin': 1},
#   'концовка': {'fin': 1},
#   'закончиться': {'fin': 1},
#   'заканчиваться': {'fin': 1}},
#  'present': {'представить': {'présenter': 1},
#   'представлять': {'présenter': 1},
#   'подать': {'présenter': 1},
#   'предъявлять': {'présenter': 1}},
#  'have': {'no_equality': {'présenter': 1},
#   'быть': {'avoir': 1},
#   'иметь': {'avoir': 1},
#   'получить': {'avoir': 1},
#   'есть': {'avoir': 1}},
#  'file': {'подавать': {'déposer': 3, 'présenter': 1},
#   'представить': {'déposer': 2},
#   'представлять': {'déposer': 1},
#   'файл': {'fichier': 2},
#   'досье': {'fichier': 3, 'dossier': 1},
#   'папка': {'fichier': 1, 'dossier': 1},
#   'документ': {'fichier': 1},
#   'картотека': {'fichier': 2},
#   'напильник': {'lime': 1},
#   'дело': {'dossier': 1},
#   'массив': {'no_equality': 1},
#   'подача': {'dépôt': 1},
#   'файловый': {'no_equality': 1},
#   'хранить': {'no_equality': 1}},
#  'genetic': {'генетический': {'Génétique': 1}},
#  'genetics': {'генетика': {'Génétique': 1}},
#  'required': {'необходимый': {'requis': 1}, 'требовать': {'requis': 1}},
# ...
#   'дополнять': {'complémentaire': 1},
#   'дополнение': {'complémentaire': 1}},
#  'supplemental': {'дополнительный': {'complémentaire': 1}},
#  'release': {'no_equality': {'sortir': 1},
#   'выпустить': {'publier': 1},
#   'выпускать': {'publier': 1},
#   'публикация': {'publier': 1},
#   'выпуск': {'publier': 1}},
#  'come out': {'выйти': {'sortir': 1},
#   'выбраться': {'sortir': 1},
#   'выходить': {'sortir': 1},
#   'пойти': {'sortir': 1},
#   'вылезать': {'sortir': 1}},
#  'already': {'уже': {'déjà': 1},
#   'так': {'déjà': 1},
#   'ранее': {'déjà': 1},
#   'давно': {'déjà': 1}},
#  'old': {'старый': {'âgé': 1}, 'пожилой': {'âgé': 1}, 'взрослый': {'âgé': 1}},
#  'elderly': {'пожилой': {'âgé': 1}},
#  'aged': {'старший': {'âgé': 1},
#   'престарелый': {'no_equality': 1},
#   'взрослый': {'âgé': 1},
#   'выдержанный': {'no_equality': 1},
#   'состаренный': {'no_equality': 1},
#   'достигший': {'âgé': 1},
#   'постаревший': {'no_equality': 1},
#   'в возрасте': {'no_equality': 1}},
#  'early': {'начать': {'début': 1}, 'начало': {'début': 1}},
#  'fast': {'быстро': {'vite': 1},
#   'быстрый': {'vite': 1},
#   'скорый': {'vite': 1},
#   'срочно': {'vite': 1}},
#  'quickly': {'быстро': {'vite': 1},
#   'быстрый': {'vite': 1},
#   'скоро': {'vite': 1},
#   'скорый': {'vite': 1},
#   'срочно': {'vite': 1}},
#  'majority': {'большинство': {'plupart': 1}, 'большой часть': {'plupart': 1}},
#  'other': {'другой': {'autre': 1}, 'иной': {'autre': 1}},
#  'accept': {'принять': {'accepter': 1},
#   'согласиться с': {'accepter': 1},
#   'принимать': {'accepter': 1},
#   'признать': {'accepter': 1},
#   'признавать': {'accepter': 1},
#   'взять': {'accepter': 1},
#   'пойти': {'accepter': 1},
#   'мириться с': {'accepter': 1},
#   'брать': {'accepter': 1},
#   'допустить': {'accepter': 1}},
#  'accepted': {'no_equality': {'accepter': 1}},
#  'agreement': {'соглашение': {'Convention': 1},
#   'договор': {'Convention': 1},
#   'договорённость': {'Convention': 1}},
#  'listen': {'слушать': {'écouter': 1},
#   'послушать': {'écouter': 1},
#   'выслушать': {'écouter': 1},
#   'услышать': {'écouter': 1},
#   'выслушивать': {'écouter': 1},
#   'слышать': {'écouter': 1},
#   'слушаться': {'écouter': 1},
#   'прислушиваться': {'écouter': 1},
#   'послушаться': {'écouter': 1},
#   'прослушивать': {'écouter': 1}},
#  'super': {'супер': {'super': 1}, 'очень': {'super': 1}},
#  'advisor': {'советник': {'conseiller': 1}, 'консультант': {'conseiller': 1}},
#  'counsellor': {'советник': {'conseiller': 1},
#   'консультант': {'conseiller': 1}},
#  'adviser': {'советник': {'conseiller': 1}, 'консультант': {'conseiller': 1}},
#  'counsel': {'советник': {'conseiller': 1},
#   'консультант': {'conseiller': 1},
#   'адвокат': {'conseiller': 1},
#   'совет': {'conseiller': 1},
#   'консультировать': {'conseiller': 1}},
#  'councillor': {'советник': {'conseiller': 1}},
#  'advise': {'консультирование': {'conseiller': 1},
#   'консультировать': {'conseiller': 1},
#   'посоветовать': {'conseiller': 1},
#   'советовать': {'conseiller': 1}},
#  'formidable': {'no_equality': {'formidable': 1}},
#  'terrific': {'замечательный': {'formidable': 1},
#   'потрясать': {'formidable': 1},
#   'отличный': {'formidable': 1}},
#  'disappoint': {'разочаровать': {'décevoir': 1},
#   'разочаровывать': {'décevoir': 1},
#   'расстраивать': {'décevoir': 1}},
#  'frustrate': {'no_equality': {'décevoir': 1}},
#  'enclosure': {'no_equality': {'enclos': 1}},
#  'paddock': {'no_equality': {'enclos': 1}},
#  'novelty': {'новизна': {'nouveauté': 1}},
#  'contest': {'конкурс': {'concours': 1},
#   'соревнование': {'concours': 1},
#   'состязание': {'concours': 1}},
#  'stellar': {'no_equality': {'stellaire': 1}},
#  'farmer': {'фермер': {'agriculteur': 3, 'fermier': 2},
#   'земледелец': {'agriculteur': 2, 'fermier': 1, 'cultivateur': 1},
#   'хуторянин': {'no_equality': 1},
#   'откупщик': {'no_equality': 1},
#   'сельхозпроизводитель': {'no_equality': 1},
#   'крестьянин': {'paysan': 1},
#   'колхозник': {'no_equality': 1},
#   'фармер': {'farmer': 1},
#   'фермерство': {'fermier': 1},
#   'хозяин': {'no_equality': 1},
#   'животновод': {'éleveur': 1},
#   'огородник': {'no_equality': 1},
#   'хлебороб': {'no_equality': 1},
#   'сельский хозяин': {'no_equality': 1},
#   'единоличник': {'no_equality': 1},
#   'фермерша': {'fermier': 1},
#   'фермерский': {'no_equality': 1}},
#  'alone': {'единственный': {'seul': 3},
#   'один': {'seul': 3},
#   'одинокий': {'seul': 3, 'solitaire': 1},
#   'наедине': {'seul': 2},
#   'самостоятельно': {'seul': 2, 'tout seul': 1, 'toute seule': 1},
#   'таковая': {'no_equality': 1},
#   'только': {'seulement': 1, 'uniquement': 1},
#   'исключительно': {'seulement': 1, 'uniquement': 1, 'exclusivement': 1},
#   'одиноко': {'seul': 1, 'solitaire': 1},
#   'в одиночку': {'tout seul': 1, 'toute seule': 1}},
#  'sole': {'единственный': {'seul': 1}, 'единый': {'seul': 1}},
#  'panel': {'панель': {'panneau': 1}},
#  'control panel': {'no_equality': {'panneau': 1}},
#  'University': {'университет': {'Université': 1}},
#  'message': {'сообщение': {'message': 1},
#   'послание': {'message': 1},
#   'сигнал': {'message': 1},
#   'идея': {'message': 1},
#   'смс': {'message': 1},
#   'записка': {'message': 1},
#   'письмо': {'message': 1},
#   'мысль': {'message': 1},
#   'смысл': {'message': 1},
#   'призыв': {'message': 1},
#   'посыл': {'message': 1},
#   'обращение': {'message': 1},
#   'заявление': {'message': 1}},
#  'mechanic': {'механик': {'mécanicien': 1}},
#  'training': {'обучение': {'formation': 1},
#   'образование': {'formation': 1},
#   'профессиональный подготовка': {'formation': 1},
#   'курс': {'formation': 1},
#   'учёба': {'formation': 1},
#   'занятие': {'formation': 1},
#   'подготовка': {'formation': 1},
#   'подготовка кадр': {'formation': 1},
#   'учебный': {'formation': 1}},
#  'approval': {'утверждение': {'approbation': 1},
#   'одобрение': {'approbation': 1},
#   'согласие': {'approbation': 1},
#   'принятие': {'approbation': 1},
#   'разрешение': {'approbation': 1},
#   'санкция': {'approbation': 1},
#   'одобрить': {'approbation': 1},
#   'утвердить': {'approbation': 1}},
#  'band': {'банда': {'bande': 3, 'groupe': 1},
#   'полоса': {'bande': 2},
#   'лента': {'bande': 2, 'ruban': 1},
#   'диапазон': {'bande': 1, 'fourchette': 1},
#   'шайка': {'bande': 1},
#   'полоска': {'bande': 1},
#   'оркестр': {'groupe': 1, 'orchestre': 1, 'fanfare': 1},
#   'отряд': {'troupe': 1},
#   'узы': {'no_equality': 1},
#   'повязка': {'bandeau': 1},
#   'зона': {'no_equality': 1},
#   'музыкальная группа': {'groupe': 1, 'orchestre': 1},
#   'ленточный': {'no_equality': 1},
#   'диапазонный': {'no_equality': 1},
#   'ленточнопильный': {'no_equality': 1},
#   'Band': {'no_equality': 1}},
#  'strip': {'полоса': {'bande': 1}},
#  'fanfare': {'no_equality': {'fanfare': 1}},
#  'brass band': {'no_equality': {'fanfare': 1}},
#  'strong': {'сильный': {'fort': 1},
#   'сильно': {'fort': 1},
#   'высокий': {'fort': 1},
#   'крепкий': {'fort': 1},
#   'большой': {'fort': 1},
#   'мощный': {'fort': 1}},
#  'record': {'записать': {'enregistrer': 1},
#   'регистрировать': {'enregistrer': 1},
#   'зарегистрировать': {'enregistrer': 1},
#   'записывать': {'enregistrer': 1},
#   'запись': {'enregistrer': 1}},
#  'save': {'сохранить': {'enregistrer': 1}, 'сохранять': {'enregistrer': 1}},
#  'interrogation': {'допрос': {'interrogatoire': 1},
#   'допросный': {'interrogatoire': 1}},
#  'mother': {'мать': {'mère': 3, 'maman': 1},
#   'мама': {'mère': 2},
#   'матерь': {'mère': 2},
#   'мамочка': {'mère': 2},
#   'матушка': {'mère': 2},
#   'мамаша': {'mère': 3, 'maman': 1},
#   'матереть': {'mère': 2},
#   'материнский': {'mère': 2, 'no_equality': 1},
#   'родной': {'no_equality': 1},
#   'мамин': {'no_equality': 1}},
#  'motherboard': {'no_equality': {'mère': 1}},
#  'steal': {'украсть': {'voler': 1},
#   'красть': {'voler': 1},
#   'воровать': {'voler': 1},
#   'угнать': {'voler': 1},
#   'стащить': {'voler': 1},
#   'выкрасть': {'voler': 1},
#   'похитить': {'voler': 1}},
#  'flying': {'no_equality': {'voler': 1}},
#  'stealing': {'no_equality': {'voler': 1}},
#  'adjust': {'скорректировать': {'ajuster': 1},
#   'корректировать': {'ajuster': 1},
#   'корректировка': {'ajuster': 1}},
#  'adjusted': {'скорректировать': {'ajuster': 1},
#   'корректировать': {'ajuster': 1},
#   'корректировка': {'ajuster': 1}},
#  'ballroom': {'no_equality': {'bal': 1}},
#  'ball': {'бал': {'bal': 1}, 'балл': {'bal': 1}},
#  'specially': {'специально': {'spécialement': 1},
#   'особенно': {'spécialement': 1},
#   'особо': {'spécialement': 1},
#   'специальный': {'spécialement': 1},
#   'конкретно': {'spécialement': 1},
#   'частность': {'spécialement': 1}},
#  'girl': {'дочь': {'fille': 1},
#   'девушка': {'fille': 1},
#   'девочка': {'fille': 1},
#   'девчонка': {'fille': 1},
#   'дочка': {'fille': 1}},
#  'during': {'в время': {'lors': 1, 'durant': 1},
#   'после': {'lors': 1},
#   'этап': {'lors': 1, 'durant': 1},
#   'в ход': {'durant': 1},
#   'на протяжение': {'durant': 1},
#   'в течение': {'durant': 1, 'pendant': 1},
#   'пока': {'durant': 1},
#   'летом': {'durant': 1},
#   'во время': {'pendant': 1},
#   'в процессе': {'pendant': 1},
#   'во': {'no_equality': 1}},
#  'collide': {'no_equality': {'collision': 1},
#   'сталкиваться': {'heurter': 1, 'no_equality': 1},
#   'конфликтовать': {'no_equality': 1},
#   'наехать': {'no_equality': 1},
#   'соударяться': {'no_equality': 1},
#   'в конфликт': {'no_equality': 1}},
#  'background': {'фон': {'fond': 2, 'arrière-plan': 1},
#   'основа': {'fond': 1},
#   'задний план': {'fond': 1},
#   'предпосылка': {'no_equality': 1},
#   'происхождение': {'origine': 1},
#   'подготовка': {'formation': 1},
#   'история': {'antécédent': 1, 'historique': 1, 'passé': 1, 'histoire': 1},
#   'сведения': {'information': 1},
#   'фоновый режим': {'no_equality': 1},
#   'опыт': {'expérience': 1},
#   'справочная информация': {'historique': 1},
#   'история вопроса': {'historique': 1},
#   'прошлое': {'passé': 1, 'histoire': 1},
#   'образование': {'formation': 1},
#   'корень': {'no_equality': 1},
#   'исходная информация': {'no_equality': 1},
#   'контекст': {'contexte': 1},
#   'общие сведения': {'historique': 1},
#   'исток': {'no_equality': 1},
#   'фоновое изображение': {'no_equality': 1},
#   'фоновая': {'no_equality': 1},
#   'фоновый': {'de fond': 1},
#   'справочный': {'référence': 1},
#   'второстепенный': {'no_equality': 1}},
#  'apologise': {'извиняться': {'excuser': 1},
#   'извиниться': {'excuser': 1,
#    "s'excuser": 1,
#    'demander pardon': 1,
#    "m'excuser": 1,
#    'suis désolé': 1,
#    "m'excuse": 1},
#   'принести извинение': {'excuser': 1},
#   'no_equality': {'excuse': 1}},
#  'coconut': {'кокос': {'coco': 1, 'cocotier': 1, 'noix de coco': 1},
#   'кокосовый': {'coco': 1, 'no_equality': 1},
#   'мякоть кокоса': {'noix de coco': 1}},
#  'buzzer': {'звонок': {'buzzer': 1, 'sonnette': 1, 'sonnerie': 1},
#   'зуммер': {'buzzer': 1},
#   'сирена': {'buzzer': 1, 'no_equality': 1},
#   'баззер': {'buzzer': 1},
#   'пищалка': {'no_equality': 1},
#   'зуммерный': {'no_equality': 1}},
#  'afraid': {'no_equality': {'peur': 1, 'craindre': 1},
#   'испуганный': {'effrayé': 1, 'effrayée': 1, 'apeuré': 1},
#   'боящийся': {'no_equality': 1},
#   'напуганный': {'effrayé': 1, 'effrayée': 1, 'apeuré': 1},
#   'страшно': {'effrayé': 1},
#   'боязно': {'no_equality': 1}},
#  'pasta': {'паста': {'pâte': 1, 'Pasta': 1, 'no_equality': 1},
#   'блюда из макарон': {'no_equality': 1}},
#  'engine': {'двигатель': {'moteur': 2},
#   'мотор': {'moteur': 1},
#   'движок': {'moteur': 1},
#   'локомотив': {'moteur': 1, 'locomotive': 1},
#   'механизм': {'moteur': 2, 'machine': 1},
#   'движущий силой': {'moteur': 1},
#   'движущий сила': {'moteur': 1},
#   'машина': {'machine': 1},
#   'ядро': {'no_equality': 1},
#   'движитель': {'no_equality': 1},
#   'машинный': {'no_equality': 1},
#   'движущий': {'no_equality': 1}},
#  'eighty': {'no_equality': {'vingts': 1, 'Eighty': 1},
#   'восемьдесят': {'no_equality': 1},
#   'восемьдесят лет': {'no_equality': 1},
#   'восьмидесятый': {'no_equality': 1}},
#  'bedroom': {'no_equality': {'coucher': 1},
#   'спальня': {'chambre': 1},
#   'спальная': {'no_equality': 1}},
#  'fit': {'соответствовать': {'cadrer': 1, 'correspondre': 1},
#   'no_equality': {'ajustement': 1, 'apte': 1},
#   'пригонка': {'no_equality': 1},
#   'припадок': {'crise': 1},
#   'помещаться': {'no_equality': 1},
#   'подходить': {'no_equality': 1},
#   'приспосабливать': {'no_equality': 1},
#   'установить': {'no_equality': 1},
#   'вписываться': {'no_equality': 1},
#   'поместить': {'no_equality': 1},
#   'подогнать': {'ajuster': 1},
#   'вписать': {'no_equality': 1},
#   'влезть': {'no_equality': 1},
#   'встраивать': {'no_equality': 1},
#   'втиснуть': {'no_equality': 1},
#   'уложиться': {'no_equality': 1},
#   'пригодный': {'no_equality': 1},
#   'годный': {'no_equality': 1},
#   'нужный': {'no_equality': 1}},
#  'electric': {'электрический': {'électrique': 2},
#   'электричество': {'électrique': 1},
#   'электроснабжение': {'électrique': 1},
#   'электроэнергия': {'électrique': 1},
#   'электромонтажный': {'no_equality': 1},
#   'электроизмерительный': {'no_equality': 1},
#   'наэлектризованный': {'no_equality': 1}},
#  'spoon': {'ложка': {'cuillère': 2, 'Spoon': 1},
#   'ложечка': {'cuillère': 1},
#   'обнимка': {'cuillère': 1},
#   'спуна': {'Spoon': 1},
#   'блесна': {'no_equality': 1},
#   'обниматься': {'no_equality': 1},
#   'черпать ложкой': {'no_equality': 1}},
#  'hear': {'слышать': {'entendre': 2,
#    'entendu': 1,
#    'écouter': 1,
#    'savoir': 1,
#    'apprendre': 1,
#    'entendre parler': 1,
#    'entendre dire': 1},
#   'услышать': {'entendre': 1, 'entendu': 1},
#   'послушать': {'entendre': 1},
#   'слушать': {'entendre': 1},
#   'выслушать': {'entendre': 1},
#   'узнать': {'entendre': 2,
#    'entendu': 1,
#    'savoir': 1,
#    'apprendre': 1,
#    'connaître': 1,
#    'voir': 1,
#    'avoir': 1},
#   'знать': {'entendre': 1},
#   'заслушать': {'entendre': 1, 'entendu': 1},
#   'расслышать': {'entendre': 2, 'entendu': 1},
#   'заслушивать': {'entendre': 1},
#   'слышный': {'entendre': 1, 'no_equality': 1},
#   'говорят': {'entendu': 1},
#   'звучать': {'no_equality': 1},
#   'слыхать': {'no_equality': 1},
#   'заслышать': {'entendre': 1, 'écouter': 1}},
#  'below': {'внизу': {'dessous': 1, 'en dessous': 1, 'en bas': 1},
#   'ниже': {'ci-après': 1,
#    'en dessous': 1,
#    'en-dessous': 1,
#    'plus loin': 1,
#    'plus bas': 1,
#    'en bas': 1,
#    'suit': 1},
#   'далее': {'ci-après': 1, 'plus loin': 1},
#   'меньше': {'no_equality': 1},
#   'под': {'no_equality': 1},
#   'нижеуказанный': {'no_equality': 1}},
#  'dressed': {'одетый': {'habillé': 1},
#   'облаченный': {'no_equality': 1},
#   'заправленный': {'no_equality': 1},
#   'выделанный': {'no_equality': 1},
#   'украшенный': {'no_equality': 1},
#   'обтесанный': {'no_equality': 1},
#   'одеваемый': {'no_equality': 1},
#   'одевший': {'no_equality': 1}},
#  'along': {'по': {'no_equality': 1},
#   'вдоль': {'le long': 1},
#   'вместе': {'conjointement': 1},
#   'вперед': {'no_equality': 1},
#   'с собой': {'no_equality': 1},
#   'рядом': {'no_equality': 1}},
#  'exhaustively': {'исчерпывающе': {'exhaustivement': 1},
#   'полностью': {'no_equality': 1},
#   'тщательно': {'no_equality': 1}},
#  'apoplexy': {'удар': {'no_equality': 1},
#   'инсульт': {'no_equality': 1},
#   'кровоизлияние': {'no_equality': 1},
#   'апоплексический': {'no_equality': 1}},
#  'synchrophasotron': {'синхрофазотрон': {'no_equality': 1}},
#  'peremptory': {'императивный': {'impératif': 1},
#   'безапелляционный': {'no_equality': 1}},
#  'precedent': {'прецедент': {'précédent': 1, 'jurisprudence': 1},
#   'предыдущий': {'no_equality': 1},
#   'прецедентный': {'no_equality': 1},
#   'предшествующий': {'no_equality': 1}},
#  'fifty': {'пятьдесят': {'cinquante': 1},
#   'полсотни': {'no_equality': 1},
#   'пятьдесят человек': {'no_equality': 1},
#   'полусотня': {'no_equality': 1},
#   'полтинник': {'50 ans': 1},
#   'пятидесятый': {'no_equality': 1}},
#  'thousand': {'тыс.': {'no_equality': 1},
#   'тысячелетие': {'millénaire': 1},
#   'множество': {'no_equality': 1},
#   'тысяча долларов': {'no_equality': 1},
#   'тысяча': {'mille': 1, 'millier': 1},
#   'тысячный': {'no_equality': 1}},
#  'aeroplane': {'самолет': {'avion': 1, 'aéronef': 1}},
#  'earring': {'серьга': {"boucle d'oreille": 1}},
#  'ago': {'назад': {'heure': 1,
#    'auparavant': 1,
#    'plus tôt': 1,
#    'arrière': 1,
#    'il y a': 1}},
#  'grandchild': {'внук': {'petit-fils': 1, 'petit fils': 1}},
#  'submissively': {'покорно': {'docilement': 1, 'humblement': 1}},
#  'approbation': {'одобрение': {'approbation': 1}}}

# %%
df_after_step_2 = get_df_from_dict(gl_dct_2, "en","ru", "fr")

# %%
#df_fr_ru_en
gl_dct_3 = merge_cycle_dicts([df_after_step_2, df_fr_ru_en], "fr","ru","en" )
# Out:
# 100%|██████████| 4891/4891 [00:00<00:00, 5779.66it/s]
# 100%|██████████| 8385/8385 [00:01<00:00, 4614.33it/s]

# %%
df_after_step_3 = get_df_from_dict(gl_dct_3, "fr","ru","en" )

# %%
df_after_step_3.head()
# Out:
#        fr      ru         en  vote
# 0  tomber  упасть       fall     4
# 1  tomber  упасть       fell     1
# 2  tomber  упасть  fall down     2
# 3  tomber  упасть       drop     1
# 4  tomber  падать       fall     2

# %%
gl_dct_4 = merge_cycle_dicts([df_after_step_3, df_ru_fr_en], "ru","fr","en" )
# Out:
# 100%|██████████| 12092/12092 [00:03<00:00, 3679.57it/s]
# 100%|██████████| 36425/36425 [00:07<00:00, 4844.00it/s]

# %%
df_after_step_4 = get_df_from_dict(gl_dct_4, "ru","fr","en")

# %%
df_after_step_4.head()
# Out:
#        ru       fr         en  vote
# 0  упасть   tomber       fall     5
# 1  упасть   tomber       fell     1
# 2  упасть   tomber  fall down     3
# 3  упасть   tomber       drop     2
# 4  упасть  baisser       fall     1

# %%
gl_dct = merge_cycle_dicts(df_en_ru_fr, "en","ru", "fr")

# %%
[df_fr_en_ru, df_en_ru_fr, df_en_fr_ru, df_fr_ru_en]

# %%
gl_dct

# %%
gl_dct

# %%
data.to_csv("/Users/nigula/LL/adjust_unigr_dict/reverse_connected_dicts/y_crossrevers_vs_pos_cycle/three_links_dict.csv")

# %%
data.to_csv("/Users/nigula/LL/adjust_unigr_dict/reverse_connected_dicts/y_crossrevers_vs_pos_cycle/four_links_dict.csv")

# %%
data.info()
