# %%
import requests
import json

# %%
from bs4 import BeautifulSoup as bs

# %%
url = "https://context.reverso.net/перевод/английский-русский/book"
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/537.36'}
response = requests.get(url, headers=headers)
response.encoding = 'utf-8' 

soup = bs(response.text, 'html.parser')
#soup = bs(response.text, 'lxml')

# %%
soup = bs(response.text, 'html.parser')
#soup.title
for link in soup.find_all("a", attrs={"class" : "translation"}):
    #print (link)
    print(link.text.strip())
    #print("|||", link.text.strip(),"|||")
    #print ( )

# %%
# Out:
# <!DOCTYPE html>
# <html lang="ru" dir="ltr">
#   <head>
#     <meta http-equiv="Content-Type" content="text/html; charset=utf-8"/>
#     <title>book - Перевод на русский - примеры английский | Reverso Context</title>
# <meta http-equiv='X-UA-Compatible' content='IE=edge,chrome=1'/>
# <meta name="description" content="Перевод контекст &quot;book&quot; c английский на русский от Reverso Context: to book, book about, comic book, new book, address book" />
# <link rel="alternate" hreflang="en" href="https://context.reverso.net/translation/english-russian/book" /><link rel="alternate" hreflang="ru" href="https://context.reverso.net/%D0%BF%D0%B5%D1%80%D0%B5%D0%B2%D0%BE%D0%B4/%D0%B0%D0%BD%D0%B3%D0%BB%D0%B8%D0%B9%D1%81%D0%BA%D0%B8%D0%B9-%D1%80%D1%83%D1%81%D1%81%D0%BA%D0%B8%D0%B9/book" /><link rel="alternate" href="android-app://com.softissimo.reverso.context/reversocontext/context.reverso.net/%D0%BF%D0%B5%D1%80%D0%B5%D0%B2%D0%BE%D0%B4/%D0%B0%D0%BD%D0%B3%D0%BB%D0%B8%D0%B9%D1%81%D0%BA%D0%B8%D0%B9-%D1%80%D1%83%D1%81%D1%81%D0%BA%D0%B8%D0%B9/book" />
#   <meta name="apple-itunes-app" content="app-id=919979642, app-argument=reversocontext://context.reverso.net/%D0%BF%D0%B5%D1%80%D0%B5%D0%B2%D0%BE%D0%B4/%D0%B0%D0%BD%D0%B3%D0%BB%D0%B8%D0%B9%D1%81%D0%BA%D0%B8%D0%B9-%D1%80%D1%83%D1%81%D1%81%D0%BA%D0%B8%D0%B9/book"/>
# <link rel="canonical" href="/%D0%BF%D0%B5%D1%80%D0%B5%D0%B2%D0%BE%D0%B4/%D0%B0%D0%BD%D0%B3%D0%BB%D0%B8%D0%B9%D1%81%D0%BA%D0%B8%D0%B9-%D1%80%D1%83%D1%81%D1%81%D0%BA%D0%B8%D0%B9/book"/>
#
# <script type="text/javascript">
#   var request = {
#     srctext: "book",
#     trgtext: "",
#     srclang: "en",
#     trglang: "ru",
#     rpage: 1,
#     rmode: 0,
#     original: "book"
#   };
# </script>
# <meta name="keywords" content="значение слова, перевод в контексте, перевод онлайн, Reverso Context, идиомы в контексте, инструмент поиска переводов, идиоматический перевод, перевод идиом, пример перевода, примеры перевода, Английский, Французский, Испанский, Иврит, Русский, Арабский, Португальский, Итальянский, Немецкий, Голландский, Польский, Иврит, идиоматические переводы, двуязычный конкорданс, контекстный словарь, пример употребления, примеры употребления, перевод в контексте, любители языка, контекстный пример, идиоматические выражения, словарь, примеры и идиомы, инструмент составления конкорданса">
#   <meta name="google-play-app" content="app-id=com.softissimo.reverso.context">
#   <meta name="google" content="notranslate"/>
# <meta name="viewport" content="initial-scale=1.0">
#
# <link href="https://cdn.reverso.net/context/v51300/images/reverso-context-logo-for-facebook.png" rel="image_src" />
# <link rel="shortcut icon" href="https://cdn.reverso.net/context/v51300/images/reverso-context.ico">
# <link rel="apple-touch-icon" href="https://cdn.reverso.net/context/v51300/images/reverso-context-app-fav-apple.png">
# <link rel="apple-touch-icon" sizes="16x16" href="https://cdn.reverso.net/context/v51300/images/reverso-context-app-fav-apple-16x16.png">
# <link rel="apple-touch-icon" sizes="72x72" href="https://cdn.reverso.net/context/v51300/images/reverso-context-app-fav-apple-72x72.png">
# <link rel="apple-touch-icon" sizes="114x114" href="https://cdn.reverso.net/context/v51300/images/reverso-context-app-fav-apple-114x114.png">
#
# <style class="font-family">
#   @font-face{font-family:'contexticons';font-display: swap;src:url('https://cdn.reverso.net/context/v51300/fonts/contexticons.eot?phzsmg');src:url('https://cdn.reverso.net/context/v51300/fonts/contexticons.eot?phzsmg#iefix') format('embedded-opentype'),url('https://cdn.reverso.net/context/v51300/fonts/contexticons.ttf?phzsmg') format('truetype'),url('https://cdn.reverso.net/context/v51300/fonts/contexticons.woff?phzsmg') format('woff'),url('https://cdn.reverso.net/context/v51300/fonts/contexticons.svg?phzsmg#contexticons') format('svg');font-weight: normal;font-style: normal;}
# </style>
# <link href="https://fonts.googleapis.com/css?family=Montserrat:300,400,500,700|Roboto+Condensed:300,400&amp;subset=cyrillic,cyrillic-ext,latin-ext" rel="stylesheet">
#
# <link rel="stylesheet" type="text/css" href="https://cdn.reverso.net/context/v51300/css/bst.style.css">
# <script type="text/javascript" src="//cdn.reverso.net/abp/v1/Static/JS/advertising.js?ch=1"></script>
#     <script type="text/javascript" src="//cdn.reverso.net/abp/v1/Static/JS/advertising.js?ch=2"></script>
#   <script type="text/javascript" src="//cdn.reverso.net/predib/predib-0-33-0.js" async></script>
#     <script type="text/javascript" src="//cdn.reverso.net/predib/conf/reverso_context.js"></script>
#     <script type="text/javascript">
#
#   if(typeof window.request === "undefined") {
#     window.request = {
#       srctext: "",
#       trgtext: "",
#       srclang: "en",
#       trglang: "ru",
#       rpage: 1,
#       rmode: 0
#     };
#   }
#   var logLOCD = false;
#   var context_path = '';
#   var special_chars = "،؟י¬¿¡ºª·؛";
#   var is_rtl = false;
#
#   window.mobilecheck = function() {
#     var check = false;
#     (function (a) {
#       if (/(android|bb\d+|meego).+mobile|avantgo|bada\/|blackberry|blazer|compal|elaine|fennec|hiptop|iemobile|ip(hone|od)|iris|kindle|lge |maemo|midp|mmp|mobile.+firefox|netfront|opera m(ob|in)i|palm( os)?|phone|p(ixi|re)\/|plucker|pocket|psp|series(4|6)0|symbian|treo|up\.(browser|link)|vodafone|wap|windows ce|xda|xiino/i.test(a)||/1207|6310|6590|3gso|4thp|50[1-6]i|770s|802s|a wa|abac|ac(er|oo|s\-)|ai(ko|rn)|al(av|ca|co)|amoi|an(ex|ny|yw)|aptu|ar(ch|go)|as(te|us)|attw|au(di|\-m|r |s )|avan|be(ck|ll|nq)|bi(lb|rd)|bl(ac|az)|br(e|v)w|bumb|bw\-(n|u)|c55\/|capi|ccwa|cdm\-|cell|chtm|cldc|cmd\-|co(mp|nd)|craw|da(it|ll|ng)|dbte|dc\-s|devi|dica|dmob|do(c|p)o|ds(12|\-d)|el(49|ai)|em(l2|ul)|er(ic|k0)|esl8|ez([4-7]0|os|wa|ze)|fetc|fly(\-|_)|g1 u|g560|gene|gf\-5|g\-mo|go(\.w|od)|gr(ad|un)|haie|hcit|hd\-(m|p|t)|hei\-|hi(pt|ta)|hp( i|ip)|hs\-c|ht(c(\-| |_|a|g|p|s|t)|tp)|hu(aw|tc)|i\-(20|go|ma)|i230|iac( |\-|\/)|ibro|idea|ig01|ikom|im1k|inno|ipaq|iris|ja(t|v)a|jbro|jemu|jigs|kddi|keji|kgt( |\/)|klon|kpt |kwc\-|kyo(c|k)|le(no|xi)|lg( g|\/(k|l|u)|50|54|\-[a-w])|libw|lynx|m1\-w|m3ga|m50\/|ma(te|ui|xo)|mc(01|21|ca)|m\-cr|me(rc|ri)|mi(o8|oa|ts)|mmef|mo(01|02|bi|de|do|t(\-| |o|v)|zz)|mt(50|p1|v )|mwbp|mywa|n10[0-2]|n20[2-3]|n30(0|2)|n50(0|2|5)|n7(0(0|1)|10)|ne((c|m)\-|on|tf|wf|wg|wt)|nok(6|i)|nzph|o2im|op(ti|wv)|oran|owg1|p800|pan(a|d|t)|pdxg|pg(13|\-([1-8]|c))|phil|pire|pl(ay|uc)|pn\-2|po(ck|rt|se)|prox|psio|pt\-g|qa\-a|qc(07|12|21|32|60|\-[2-7]|i\-)|qtek|r380|r600|raks|rim9|ro(ve|zo)|s55\/|sa(ge|ma|mm|ms|ny|va)|sc(01|h\-|oo|p\-)|sdk\/|se(c(\-|0|1)|47|mc|nd|ri)|sgh\-|shar|sie(\-|m)|sk\-0|sl(45|id)|sm(al|ar|b3|it|t5)|so(ft|ny)|sp(01|h\-|v\-|v )|sy(01|mb)|t2(18|50)|t6(00|10|18)|ta(gt|lk)|tcl\-|tdg\-|tel(i|m)|tim\-|t\-mo|to(pl|sh)|ts(70|m\-|m3|m5)|tx\-9|up(\.b|g1|si)|utst|v400|v750|veri|vi(rg|te)|vk(40|5[0-3]|\-v)|vm40|voda|vulc|vx(52|53|60|61|70|80|81|83|85|98)|w3c(\-| )|webc|whit|wi(g |nc|nw)|wmlb|wonu|x700|yas\-|your|zeto|zte\-/i.test(a.substr(0,4)))
#         check = true
#       })(navigator.userAgent || navigator.vendor || window.opera);
#     return check;
#   };
#
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#     (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#     m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   var ga_log = [];
#
#   function sendGA(command, type, category, action, label, options) {
#     var object = {
#       "command": command,
#       "type": type,
#       "category": category,
#       "action": action,
#       "label": label
#     };
#     ga_log.push(object);
#     if(label !== undefined) ga(command, type, category, action, label, options);
#     else if(action !== undefined) ga(command, type, category, action, options);
#     else if(category !== undefined) ga(command, type, category, options);
#     else ga(command, type, options);
#   };
#
#   sendGA('create', 'UA-2834324-41', 'reverso.net');
#   sendGA('create', 'UA-2834324-49', 'auto', 'keywordTracker');
#   sendGA('require', 'displayfeatures');
#   sendGA('keywordTracker.require', 'displayfeatures');
#   sendGA('set', 'dimension1', logLOCD ? (is_premium ? 'premium' : 'registered') : 'anonymous');
#
#     sendGA('set', 'dimension4', typeof(adblock)=='undefined' ? 'yes' : (typeof(abp)!='undefined' && abp ? 'abp' : 'no' ));
#
#   sendGA('send', 'pageview', '/bst/result/en-ru/1w/translations-precomputed');
#   sendGA('keywordTracker.send', 'pageview');
#
#     var googletag = googletag || {};
#     googletag.cmd = googletag.cmd || [];
#
#     googletag.cmd.push(function() {
#         googletag.pubads().disableInitialLoad();
#         setReversoTargeting();
#     });
#     if (typeof (adblock) != 'undefined') {
#       var device = (window.mobilecheck() ? "mobile" : (window.innerWidth>1024 ? "desktop" : "tablet"));
#
#       var prebid_config = prebid_config || new prebidConfig();
#       var PREBID_TIMEOUT = prebid_config.getTimeout() || 800;
#       var GA_VARIATION = typeof(prebid_config) != 'undefined' ? prebid_config.getVariation() : 0;
#
#       var ads_array = [];
#       if (device === "desktop") {
#         ads_array = ['Reverso_Ctxt_D_Result_300x250_ATF', 'Reverso_Ctxt_D_Result_300x250_BTF', 'Reverso_Ctxt_D_Result_300x600_BTF', 'Reverso_Ctxt_D_Result_728x90_BTF']
#       }
#       else if (device === "mobile") {
#         ads_array = ['Reverso_Ctxt_M_Result_320x50_BTF'];
#       }
#       else {
#         ads_array = ['Reverso_Ctxt_D_Result_728x90_BTF'];
#       }
#
#         ads_array.push('Reverso_Ctxt_R_Result_InFeed_ATF');
#
#
#       var adsetup = prebid_config.getAdSetup(ads_array) || [];
#       var adUnits = prebid_config.getAdUnits(adsetup) || [];
#
#       if(typeof(abp) != 'undefined' && abp){adUnits=[];}
#
#       (function() {
#           var gads = document.createElement('script');
#           gads.async = true;
#           gads.type = 'text/javascript';
#           var useSSL = 'https:' == document.location.protocol;
#           gads.src = (useSSL ? 'https:' : 'http:') +
#           '//www.googletagservices.com/tag/js/gpt.js';
#           var node = document.getElementsByTagName('script')[0];
#           node.parentNode.insertBefore(gads, node);
#       })();
#
#       var slots = [];
#
#       googletag.cmd.push(function() {
#           for (var i in adsetup) {
#             n = adsetup[i];
#             slots[n['slotcode']] = googletag.defineSlot('/2629866/'+n['slotname'][0], n['slotsizes'], n['slotcode']).addService(googletag.pubads());
#           }
#
#           googletag.pubads().enableSingleRequest();
#           googletag.enableServices();
#       });
#
#       var pbjs = pbjs || {};
#       pbjs.que = pbjs.que || [];
#
#       prebid_config.setBidderSettings(pbjs);
#       prebid_config.setConfig(pbjs);
#       prebid_config.setAnalyticsSettings(pbjs);
#
#       pbjs.que.push(function() {
#         pbjs.addAdUnits(adUnits);
#         if(device === "desktop"){
#           pbjs.requestBids({
#             timeout: adUnits.length ? PREBID_TIMEOUT : 100,
#             adUnitCodes: ['div-gpt-ad-Reverso_Ctxt_D_Result_300x250_ATF', 'div-gpt-ad-Reverso_Ctxt_D_Result_300x250_BTF'],
#             bidsBackHandler: sendAdserverRequest
#           });
#         }
#         });
#
#       function isGptPubadsDefined() {
#         return window.googletag && typeof window.googletag.pubads === "function" && typeof window.googletag.pubads().getSlots === "function";
#       }
#
#       function refreshBids(adUnitCodes) {
#           if (!isGptPubadsDefined()) {
#             setTimeout(function() {
#               refreshBids(adUnitCodes);
#             }, 100);
#             return;
#           }
#           refresh_adsetup = prebid_config.getAdSetup(adUnitCodes) || [];
#           refresh_adunits = prebid_config.getAdUnits(refresh_adsetup) || [];
#           var gptAdSlots = [];
#           for (i in refresh_adsetup) {
#             gptAdSlots.push(slots[refresh_adsetup[i].slotcode]);
#           }
#           if(refresh_adunits.length && (typeof(abp) == 'undefined' || !abp)){
#             pbjs.que.push(function() {
#               pbjs.requestBids({
#                 timeout: PREBID_TIMEOUT,
#                 adUnitCodes: refresh_adunits.map(function (x) { return x.code; }),
#                 bidsBackHandler: function() {
#                   pbjs.setTargetingForGPTAsync(adUnitCodes);
#                   googletag.pubads().refresh(gptAdSlots, {changeCorrelator: false});
#                 }
#               });
#             });
#           }
#           else{
#               googletag.pubads().refresh(gptAdSlots, {changeCorrelator: false});
#           }
#       }
#
#       function setReversoTargeting() {
#           var adtargeting = {};
#
#           adtargeting['abtest'] = GA_VARIATION || 0;
#           adtargeting['Interface'] = 'RU';
#           adtargeting['device'] = device;
#           adtargeting['Status'] = 'prod';
#
#             adtargeting['Direction'] = 'EN-RU';
#
#
#           if(typeof(abp) != 'undefined' && abp){
#             adtargeting['abp'] = '1';
#         	}
#
#           for (var i in adtargeting) {
#             googletag.pubads().clearTargeting(i);
#             googletag.pubads().setTargeting(i, adtargeting[i]);
#           }
#       }
#
#       function sendAdserverRequest() {
#           if (pbjs.adserverRequestSent) return;
#           pbjs.adserverRequestSent = true;
#           googletag.cmd.push(function() {
#               pbjs.que.push(function() {
#                   setReversoTargeting();
#                   if(device === "desktop"){
#                       pbjs.setTargetingForGPTAsync(['div-gpt-ad-Reverso_Ctxt_D_Result_300x250_ATF', 'div-gpt-ad-Reverso_Ctxt_D_Result_300x250_BTF']);
#                       googletag.pubads().refresh([slots['div-gpt-ad-Reverso_Ctxt_D_Result_300x250_ATF'], slots['div-gpt-ad-Reverso_Ctxt_D_Result_300x250_BTF']], {changeCorrelator: false});
#                   }
#               });
#           });
#       }
#
#       setTimeout(function() {sendAdserverRequest();}, (PREBID_TIMEOUT*1.5));
# 	}
#   </script>
# </head>
#   <body class="locked mobile-locked  noticed">
#     <div class="loading-pannel">
#   <span class="icon"></span>
# </div>
# <div id="wrapper" class=" results">
#       <section id="top-content">
#   <a class="reverso-logo nonselectable no-loading" href="/%D0%BF%D0%B5%D1%80%D0%B5%D0%B2%D0%BE%D0%B4/" title="Reverso Context: поисковая система для переводов в контексте">
#   <div class="logo">
#     <span class="icon reverso-logo-red"></span>
#     <span class="icon reverso-logo-blue"></span>
#   </div>
#   <div class="text">
#     <span class="icon reverso-text"></span>
#     <span class="icon context-text"></span>
#   </div>
# </a>
# <div id="mobile-menu" class="closed">
#     <span class="icon menu"></span>
#     <div class="floating-menu">
#       <a class="option register" href="https://account.reverso.net/register/context.reverso.net/ru?utm_source=contextweb&utm_medium=usertopmenu&utm_campaign=register">
#           <span class="icon add-user"></span>
#           <span class="text">Зарегистрироваться</span>
#         </a>
#         <a class="option login" href="https://account.reverso.net/login/context.reverso.net/ru?utm_source=contextweb&utm_medium=usertopmenu&utm_campaign=login">
#           <span class="icon login"></span>
#           <span class="text">Войти</span>
#         </a>
#       <button class="font-resize grey" data-size="0">
#         <span class="icon font-resize"></span>
#         <span class="text">Font size</span>
#       </button>
#       <a class="option help grey" href="/%D0%BF%D0%B5%D1%80%D0%B5%D0%B2%D0%BE%D0%B4/about">
#         <span class="icon help"></span>
#         <span class="text">Помощь</span>
#       </a>
#       <button class="option locale grey">
#         <span class="icon lang"></span>
#         <span class="text">русский</span>
#         <span class="icon down-caret"></span>
#       </button>
#       <div class="interface-langs closed">
#         <button class="option" data-value="ar">العربية</button>
#         <button class="option" data-value="de">Deutsch</button>
#         <button class="option" data-value="en">English</button>
#         <button class="option" data-value="es">Español</button>
#         <button class="option" data-value="fr">Français</button>
#         <button class="option" data-value="he">עברית</button>
#         <button class="option" data-value="it">Italiano</button>
#         <button class="option" data-value="ja">日本語</button>
#         <button class="option" data-value="nl">Nederlands</button>
#         <button class="option" data-value="pl">Polski</button>
#         <button class="option" data-value="pt">Português</button>
#         <button class="option" data-value="ro">Română</button>
#         <button class="option selected" data-value="ru">Русский</button>
#         <button class="option" data-value="tr">Türkçe</button>
#         </div>
#     </div>
#   </div>
#   <div id="top-menu" class="selector closed nonselectable">
#     <span class="option front icon horizontal-dots"></span>
#     <span class="option front space-filler">···</span>
#     <div class="drop-down">
#       <a class="option translation" target="_blank" href="http://www.reverso.net/text_translation.aspx?lang=RU">
#         <span class="icon lang"></span>
#         <span class="text">Перевод</span>
#       </a>
#       <a class="option dictionary" target="_blank" href="https://dictionary.reverso.net">
#         <span class="icon dictionary"></span>
#         <span class="text">Словарь</span>
#       </a>
#       <a class="option speller" target="_blank" href="http://www.reverso.net/spell-checker/english-spelling-grammar/">
#         <span class="icon spellcheck"></span>
#         <span class="text">Корректор</span>
#       </a>
#       <a class="option conjugation" target="_blank" href="http://glagol.reverso.net/%D1%81%D0%BF%D1%80%D1%8F%D0%B6%D0%B5%D0%BD%D0%B8%D0%B5-%D1%80%D1%83%D1%81%D1%81%D0%BA%D0%B8%D0%B9.html">
#         <span class="icon conjugator"></span>
#         <span class="text">Спряжение</span>
#       </a>
#       <a class="option synonyms" target="_blank" href="https://synonyms.reverso.net/%D1%81%D0%B8%D0%BD%D0%BE%D0%BD%D0%B8%D0%BC%D1%8B/">
#         <span class="icon synonyms"></span>
#         <span class="text">Синонимы</span>
#       </a>
#       <a class="option grammar" target="_blank" href="http://grammar.reverso.net/">
#         <span class="icon translate"></span>
#         <span class="text">Грамматика</span>
#       </a>
#       <a class="option document" target="_blank" href="https://documents.reverso.net/Default.aspx?lang=en">
#         <span class="icon document"></span>
#         <span class="text">Перевод документов и сайтов</span>
#       </a>
#       <a class="option corporate" href="https://www.corporate-translation.reverso.com/">
#         <span class="icon corporate"></span>
#         <span class="text">Корпоративные решения</span>
#       </a>
#       <a class="option newsletter" target="_blank" href="http://www.reverso.net/tricks.aspx?type=3&lang=RU">
#         <span class="icon mail"></span>
#         <span class="text">Новостная рассылка</span>
#       </a>
#       <a class="option help" href="/%D0%BF%D0%B5%D1%80%D0%B5%D0%B2%D0%BE%D0%B4/about">
#         <span class="icon help"></span>
#         <span class="text">Помощь</span>
#       </a>
#     </div>
#   </div>
#   <div id="lang-selector" class="selector closed double nonselectable">
#     <span class="option front">ru</span>
#     <span class="icon down-caret"></span>
#     <span class="option front space-filler">···</span>
#     <div class="drop-down">
#     <div class="option" data-value="ar">العربية</div>
#     <div class="option" data-value="de">Deutsch</div>
#     <div class="option" data-value="en">English</div>
#     <div class="option" data-value="es">Español</div>
#     <div class="option" data-value="fr">Français</div>
#     <div class="option" data-value="he">עברית</div>
#     <div class="option" data-value="it">Italiano</div>
#     <div class="option" data-value="ja">日本語</div>
#     <div class="option" data-value="nl">Nederlands</div>
#     <div class="option" data-value="pl">Polski</div>
#     <div class="option" data-value="pt">Português</div>
#     <div class="option" data-value="ro">Română</div>
#     <div class="option selected" data-value="ru">Русский</div>
#     <div class="option" data-value="tr">Türkçe</div>
#     </div>
#   </div>
#   <button class="icon font-resize" data-size="0" title="Кликните, чтобы увеличить или уменьшить размер текста."></button>
#   <div class="reverso-links">
#     <a class="translation-link" target="_blank" href="http://www.reverso.net/text_translation.aspx?lang=RU">
#       Перевод</a>
#
#     <a class="dictionary-link" target="_blank" href="https://dictionary.reverso.net">
#       Словарь</a>
#
#     <a class="speller-link" target="_blank" href="http://www.reverso.net/spell-checker/english-spelling-grammar/">
#       Корректор</a>
#     <a class="conjugation-link" target="_blank" href="http://glagol.reverso.net/%D1%81%D0%BF%D1%80%D1%8F%D0%B6%D0%B5%D0%BD%D0%B8%D0%B5-%D1%80%D1%83%D1%81%D1%81%D0%BA%D0%B8%D0%B9.html">
#       Спряжение</a>
#
#     <a class="synonyms-link " target="_blank" href="https://synonyms.reverso.net/%D1%81%D0%B8%D0%BD%D0%BE%D0%BD%D0%B8%D0%BC%D1%8B/">
#       Синонимы</a>
#
#     <a class="grammar-link last" target="_blank" href="http://grammar.reverso.net/">
#       Грамматика</a>
#
#     </div>
#   <div class="social-content">
#     <a class="facebook-link icon facebook" target="_blank" href="https://www.facebook.com/Reverso.net?ref=ts" title="Facebook"></a>
#     <a class="twitter-link icon twitter" target="_blank" href="https://twitter.com/ReversoEN" title="Twitter"></a>
#     <a class="instagram-link icon instagram" target="_blank" href="https://www.instagram.com/reverso_app/?hl=ru" title="Instagram"></a>
#   </div>
#   <!-- end top-bar -->
# </section>
# <section id="reverso-nav">
#   <a class="translation-link" target="_blank" href="http://www.reverso.net/text_translation.aspx?lang=RU">
#     Перевод</a>
#   <span>Context</span>
#   <a class="conjugation-link" target="_blank" href="http://glagol.reverso.net/%D1%81%D0%BF%D1%80%D1%8F%D0%B6%D0%B5%D0%BD%D0%B8%D0%B5-%D1%80%D1%83%D1%81%D1%81%D0%BA%D0%B8%D0%B9.html">
#     Спряжение</a>
#   <a class="synonyms-link" target="_blank" href="https://synonyms.reverso.net/%D1%81%D0%B8%D0%BD%D0%BE%D0%BD%D0%B8%D0%BC%D1%8B/">
#     Синонимы</a>
# </section>
# <section id="body-content">
#   <div class="right-content">
#     <section id="subtop-content">
#   <script>
#     var register_link = "https://account.reverso.net/register/context.reverso.net/ru?utm_source=contextweb&utm_medium={0}&utm_campaign=register";
#     var login_link = "https://account.reverso.net/login/context.reverso.net/ru?utm_source=contextweb&utm_medium={0}&utm_campaign=login";
#   </script>
#   <div id="user-menu" class="selector closed nonselectable ">
#     <span class="icon down-caret"></span>
#     <span class="option front"><span class="icon user">
#       <span class="icon rocket"></span>
#     </span>Присоединиться к Reverso</span>
#     <div class="drop-down">
#     <a class="option register" href="https://account.reverso.net/register/context.reverso.net/ru?utm_source=contextweb&utm_medium=usertopmenu&utm_campaign=register">
#         <span class="icon add-user"></span>
#         <span class="text">Зарегистрироваться</span>
#       </a>
#       <a class="option login" href="https://account.reverso.net/login/context.reverso.net/ru?utm_source=contextweb&utm_medium=usertopmenu&utm_campaign=login">
#         <span class="icon login"></span>
#         <span class="text">Войти</span>
#       </a>
#       <span id="fb-content" class="option facebook" data-url="null">
#         <span class="icon facebook"></span>
#         <span class="text">Войти через Facebook</span>
#       </span>
#       <span id="google-content" class="option google" data-url="null">
#         <span class="icon google3"></span>
#         <span class="text">Войти через Google</span>
#       </span>
#     </div>
#   </div>
#   <div id="title-content">
#     </div>
# </section>
# <div id="rca">
#   <!-- /64378609/Context_300x250_Top -->
#   <span class="rca-title">Реклама</span>
#   <div id='div-gpt-ad-Reverso_Ctxt_D_Result_300x250_ATF' class="rca">
#     <script type='text/javascript'>
#       if(!window.mobilecheck()) {
#         googletag.cmd.push(function() {
#           googletag.display('div-gpt-ad-Reverso_Ctxt_D_Result_300x250_ATF');
#         });
#       }
#     </script>
#   </div>
#   <div id="side-badges">
#     <a id="extension-badge" href target="_blank" class="badge extension disabled mobile-hidden">
#       <span class="logo"></span>
#       <span class="text">Добавить Reverso в {0} <b>Бесплатно</b></span>
#     </a>
#     <div class="badges pannel">
#       <a class="text" href="/перевод/mobile-app?utm_source=contextweb&utm_medium=banner&utm_campaign=ctxtresultpage&utm_content=ctxtappdl">Скачать наше <b>бесплатное</b> приложение</a>
#       <a href="/перевод/mobile-app?utm_source=contextweb&utm_medium=banner&utm_campaign=ctxtresultpage&utm_content=ctxtappdl" class="badge and no-loading ru">
#       </a>
#       <a href="/перевод/mobile-app?utm_source=contextweb&utm_medium=banner&utm_campaign=ctxtresultpage&utm_content=ctxtappdl" class="badge ios no-loading ru">
#       </a>
#     </div>
#   </div>
#   <!-- /64378609/Context_300x250_Bottom -->
#   <span class="rca-title">Реклама</span>
#   <div id='div-gpt-ad-Reverso_Ctxt_D_Result_300x250_BTF' class="rca">
#     <script type='text/javascript'>
#       if(!window.mobilecheck()) {
#         googletag.cmd.push(function() {
#           googletag.display('div-gpt-ad-Reverso_Ctxt_D_Result_300x250_BTF');
#         });
#       }
#     </script>
#   </div>
#   <!-- /64378609/Context_300x600 -->
#     <span class="rca-title disabled tall-rca">Реклама</span>
#     <div id='div-gpt-ad-Reverso_Ctxt_D_Result_300x600_BTF' class="rca disabled tall-rca">
#       <script type='text/javascript'>
#         if(!window.mobilecheck()) {
# 		  googletag.cmd.push(function() {
# 			googletag.display('div-gpt-ad-Reverso_Ctxt_D_Result_300x600_BTF');
# 		  });
#         }
#       </script>
#     </div>
#   </div>
# </div>
#   <div class="left-content">
#     <div id="register-popup-bottom" class="popup closed">
#   <div class="header">
#     <span class="title">Присоединяйтесь к Reverso, это <b>удобно и бесплатно</b>!</span>
#     <button class="icon up-arrow" title="закрыть"></button>
#   </div>
#   <div class="body wide-container">
#     <a class="button register" href="https://account.reverso.net/register/context.reverso.net/ru?utm_source=contextweb&utm_medium=floatingpopup&utm_campaign=register"><span class="icon add-user"></span>Зарегистрироваться</a>
#     <a class="button login" href="https://account.reverso.net/login/context.reverso.net/ru?utm_source=contextweb&utm_medium=floatingpopup&utm_campaign=login"><span class="icon login"></span>Войти</a>
#   </div>
# </div>
# <section id="search-content">
#   <div id="search">
#     <div id="search-input" class="ltr">
#       <div class="icons">
#         <button class="icon exclude" title="Кликните здесь, чтобы исключить некоторые слова из поиска. Например, слово1 -{слово2} : будут найдены примеры, которые содержат слово1 и НЕ содержат слово2"></button>
#         <button class="icon cancel" title="Очистить ввод"></button>
#       </div>
#       <input tabindex="1" type="text" name="text" id="entry" value="book" autocapitalize="none" autocomplete="off" class="keyboardInput ui-autocomplete-input ltr" placeholder="Введите или вставьте текст"/>
#     </div>
#     <div id="pair-selector" class="nonselectable">
#       <div id="src-selector" class="selector double closed" tabindex="2">
#         <span class="icon down-caret"></span>
#         <span class="option front" data-value="en">английский</span>
#         <span class="space-filler"></span>
#         <div class="drop-down">
#           <span class="option" data-value="ar">арабский</span>
#           <span class="option" data-value="de">немецкий</span>
#           <span class="option selected" data-value="en">английский</span>
#           <span class="option" data-value="es">испанский</span>
#           <span class="option" data-value="fr">французский</span>
#           <span class="option" data-value="he">иврит</span>
#           <span class="option" data-value="it">итальянский</span>
#           <span class="option" data-value="ja">японский</span>
#           <span class="option" data-value="nl">голландский</span>
#           <span class="option" data-value="pl">польский</span>
#           <span class="option" data-value="pt">португальский</span>
#           <span class="option" data-value="ro">румынский</span>
#           <span class="option" data-value="ru">русский</span>
#           <span class="option" data-value="tr">турецкий</span>
#           </div>
#       </div>
#       <div class="swap-content" title="Сменить направление перевода">
#         <div class="icons" tabindex="3">
#           <span class="icon reverso-top"></span>
#           <span class="icon reverso-bottom"></span>
#         </div>
#       </div>
#       <div id="trg-selector" class="selector double closed" tabindex="4">
#         <span class="icon down-caret"></span>
#         <span class="option front" data-value="ru">русский</span>
#         <span class="space-filler"></span>
#         <div class="drop-down">
#           <span class="option" data-value="ar">арабский</span>
#           <span class="option" data-value="de">немецкий</span>
#           <span class="option" data-value="en">английский</span>
#           <span class="option" data-value="es">испанский</span>
#           <span class="option" data-value="fr">французский</span>
#           <span class="option" data-value="he">иврит</span>
#           <span class="option" data-value="it">итальянский</span>
#           <span class="option" data-value="ja">японский</span>
#           <span class="option" data-value="nl">голландский</span>
#           <span class="option" data-value="pl">польский</span>
#           <span class="option" data-value="pt">португальский</span>
#           <span class="option" data-value="ro">румынский</span>
#           <span class="option selected" data-value="ru">русский</span>
#           <span class="option" data-value="tr">турецкий</span>
#           </div>
#       </div>
#     </div>
#     <button id="search-button" class="icon search" title="Поиск" tabindex="5"></button>
#     <div class="exclude-content">
#       <button class="icon add disabled"></button>
#       <div class="input-content">
#         <input placeholder="Исключить из поиска">
#       </div>
#     </div>
#   </div>
#   </section>
# <section id="notice-content">
#   <div id="search-links" >
#     <a class="icon synonyms" data-value="synonyms" target="_blank" href="https://synonyms.reverso.net/%D1%81%D0%B8%D0%BD%D0%BE%D0%BD%D0%B8%D0%BC%D1%8B/en/book" title="Искать в Синонимы"></a>
#     <a class="icon conjugator" data-value="conjugator" target="_blank" href="http://glagol.reverso.net/%D1%81%D0%BF%D1%80%D1%8F%D0%B6%D0%B5%D0%BD%D0%B8%D0%B5-%D0%B0%D0%BD%D0%B3%D0%BB%D0%B8%D0%B9%D1%81%D0%BA%D0%B8%D0%B9-%D0%B3%D0%BB%D0%B0%D0%B3%D0%BE%D0%BB-book.html" title="Искать в Спряжение"></a>
#     <button class="icon web" data-value="web" data-url="https://www.google.com/search?hl=en&q=" title="Искать в Интернете"></button>
#     <button class="icon wikipedia" data-value="wikipedia" data-url="https://en.wikipedia.org/wiki/" title="Искать в Wikipedia"></button>
#     <button class="icon images" data-value="images" data-url="https://www.google.com/search?hl=en&tbm=isch&q=" title="Искать в Картинках"></button>
#     <a class="icon dictionary" data-value="definition" target="_blank" href="https://dictionary.reverso.net/english-definition/book" title="Искать в Oпределение"></a>
#     </div>
#   <div id="seealso-content" class="notice">
#       <span class="icon info"></span>
#       <span class="message">Посмотреть также:</span>
#       <a href="/перевод/английский-русский/to+book" class="">to book</a>
#         <a href="/перевод/английский-русский/comic+book" class="">comic book</a>
#         <a href="/перевод/английский-русский/by+the+book" class="">by the book</a>
#         </div>
#     <script>sendGA("send", "event", "seealso", "display", "en-ru");</script>
#   <div id="conj_search" class="notice">
#         <i class="icon info"></i>
#         <a class="message" target="_blank" class="suggestion" href="http://glagol.reverso.net/%D1%81%D0%BF%D1%80%D1%8F%D0%B6%D0%B5%D0%BD%D0%B8%D0%B5-%D0%B0%D0%BD%D0%B3%D0%BB%D0%B8%D0%B9%D1%81%D0%BA%D0%B8%D0%B9-%D0%B3%D0%BB%D0%B0%D0%B3%D0%BE%D0%BB-book.html">Conjugation of this verb</a>
#       </div>
#   <div id="rude" class="notice">
#     <i class="icon warning"></i>
#     <span class="message">На основании Вашего запроса эти примеры могут содержать грубую лексику.</span>
#   </div>
#   <div id="colloquial" class="notice">
#     <i class="icon warning"></i>
#     <span class="message">На основании Вашего запроса эти примеры могут содержать разговорную лексику.</span>
#   </div>
# </section>
# <section id="top-results">
#   <section id="search-options" class="">
#     <button class="icon down-arrow detailed-view closed" title="Показать подробности и рекомендации"></button>
#
#     <div class="title-content">
#       <h1>Перевод &quot;book&quot; на русский</h1>
#     </div>
#   </section>
#   <div id="pos-filters">
#
#       <button class="n" data-pos="n." data-index="0" title="Показать все переводы, отмеченные как Существительное">
#         Сущ.</button>
#       <button class="adj" data-pos="adj." data-index="1" title="Показать все переводы, отмеченные как Прилагательное">
#         Прил.</button>
#       <button class="v" data-pos="v." data-index="2" title="Показать все переводы, отмеченные как Глагол">
#         Глагол</button>
#       <div id="synonyms-button-container" >
#       <a id="synonyms-button" class="icon synonyms" title="Синонимы" target="_blank" dir=" ltr " href="https://synonyms.reverso.net/%D1%81%D0%B8%D0%BD%D0%BE%D0%BD%D0%B8%D0%BC%D1%8B/en/book" ></a>
# 	     </div>
#       </div> <div id="filtered-entry" class="wide-container">
#     </div>
#     <div id="translations-content" class="wide-container">
#     <a href="/перевод/русский-английский/%D0%BA%D0%BD%D0%B8%D0%B3%D0%B0" class="translation ltr dict n" data-pos='[nf]' data-pos-index='0' data-posGroup="1" data-freq="18521" title="<div class='nobold'>Посмотреть примеры с переводом <em class='translation'>книга</em><br>Существительное - женский род<br>(+10k примеров, содержащих перевод)</div>">
#           <div class="pos-mark">
#               <span class="n" title="Существительное - женский род"></span>
#                   </div>
#           книга</a>
#       <a href="/перевод/русский-английский/%D0%BA%D0%BD%D0%B8%D0%B6%D0%BA%D0%B0" class="translation ltr dict n" data-pos='[nf]' data-pos-index='0' data-posGroup="1" data-freq="1094" title="<div class='nobold'>Посмотреть примеры с переводом <em class='translation'>книжка</em><br>Существительное - женский род<br>(1094 примеров, содержащих перевод)</div>">
#           <div class="pos-mark">
#               <span class="n" title="Существительное - женский род"></span>
#                   </div>
#           книжка</a>
#       <a href="/перевод/русский-английский/%D1%81%D0%BF%D1%80%D0%B0%D0%B2%D0%BE%D1%87%D0%BD%D0%B8%D0%BA" class="translation ltr dict n" data-pos='[nm]' data-pos-index='0' data-posGroup="1" data-freq="199" title="<div class='nobold'>Посмотреть примеры с переводом <em class='translation'>справочник</em><br>Существительное - мужской род<br>(199 примеров, содержащих перевод)</div>">
#           <div class="pos-mark">
#               <span class="n" title="Существительное - мужской род"></span>
#                   </div>
#           справочник</a>
#       <a href="/перевод/русский-английский/%D1%83%D1%87%D0%B5%D0%B1%D0%BD%D0%B8%D0%BA" class="translation ltr dict n" data-pos='[nm]' data-pos-index='0' data-posGroup="1" data-freq="181" title="<div class='nobold'>Посмотреть примеры с переводом <em class='translation'>учебник</em><br>Существительное - мужской род<br>(181 примеров, содержащих перевод)</div>">
#           <div class="pos-mark">
#               <span class="n" title="Существительное - мужской род"></span>
#                   </div>
#           учебник</a>
#       <a href="/перевод/русский-английский/%D0%B6%D1%83%D1%80%D0%BD%D0%B0%D0%BB" class="translation ltr dict n" data-pos='[nm]' data-pos-index='0' data-posGroup="1" data-freq="89" title="<div class='nobold'>Посмотреть примеры с переводом <em class='translation'>журнал</em><br>Существительное - мужской род<br>(89 примеров, содержащих перевод)</div>">
#           <div class="pos-mark">
#               <span class="n" title="Существительное - мужской род"></span>
#                   </div>
#           журнал</a>
#       <a href="/перевод/русский-английский/%D0%B0%D0%BB%D1%8C%D0%B1%D0%BE%D0%BC" class="translation ltr dict n" data-pos='[nm]' data-pos-index='0' data-posGroup="1" data-freq="75" title="<div class='nobold'>Посмотреть примеры с переводом <em class='translation'>альбом</em><br>Существительное - мужской род<br>(75 примеров, содержащих перевод)</div>">
#           <div class="pos-mark">
#               <span class="n" title="Существительное - мужской род"></span>
#                   </div>
#           альбом</a>
#       <a href="/перевод/русский-английский/%D1%82%D0%B5%D1%82%D1%80%D0%B0%D0%B4%D1%8C" class="translation ltr dict n" data-pos='[n]' data-pos-index='0' data-posGroup="1" data-freq="73" title="<div class='nobold'>Посмотреть примеры с переводом <em class='translation'>тетрадь</em><br>Существительное<br>(73 примеров, содержащих перевод)</div>">
#           <div class="pos-mark">
#               <span class="n" title="Существительное"></span>
#                   </div>
#           тетрадь</a>
#       <a href="/перевод/русский-английский/%D0%B1%D0%BB%D0%BE%D0%BA%D0%BD%D0%BE%D1%82" class="translation ltr dict first n" data-pos='[nm]' data-pos-index='0' data-posGroup="1" data-freq="60" title="<div class='nobold'>Посмотреть примеры с переводом <em class='translation'>блокнот</em><br>Существительное - мужской род<br>(60 примеров, содержащих перевод)</div>">
#           <div class="pos-mark">
#               <span class="n" title="Существительное - мужской род"></span>
#                   </div>
#           блокнот</a>
#       <a href="/перевод/русский-английский/%D0%BA%D0%BD%D0%B8%D0%B6%D0%BD%D1%8B%D0%B9" class="translation ltr dict first adj" data-pos='[adj]' data-pos-index='1' data-posGroup="2" data-freq="743" title="<div class='nobold'>Посмотреть примеры с переводом <em class='translation'>книжный</em><br>Прилагательное<br>(743 примеров, содержащих перевод)</div>">
#           <div class="pos-mark">
#               <span class="adj" title="Прилагательное"></span>
#                   </div>
#           книжный</a>
#       <a href="/перевод/русский-английский/%D0%B7%D0%B0%D0%B1%D1%80%D0%BE%D0%BD%D0%B8%D1%80%D0%BE%D0%B2%D0%B0%D1%82%D1%8C" class="translation ltr dict v" data-pos='[v]' data-pos-index='2' data-posGroup="3" data-freq="205" title="<div class='nobold'>Посмотреть примеры с переводом <em class='translation'>забронировать</em><br>Глагол<br>(205 примеров, содержащих перевод)</div>">
#           <div class="pos-mark">
#               <span class="v" title="Глагол"></span>
#                   </div>
#           забронировать</a>
#       <a href="/перевод/русский-английский/%D0%B7%D0%B0%D0%BA%D0%B0%D0%B7%D0%B0%D1%82%D1%8C" class="translation ltr dict mobile-hidden v" data-pos='[v]' data-pos-index='2' data-posGroup="3" data-freq="166" title="<div class='nobold'>Посмотреть примеры с переводом <em class='translation'>заказать</em><br>Глагол<br>(166 примеров, содержащих перевод)</div>">
#           <div class="pos-mark">
#               <span class="v" title="Глагол"></span>
#                   </div>
#           заказать</a>
#       <a href="/перевод/русский-английский/%D0%B1%D1%80%D0%BE%D0%BD%D0%B8%D1%80%D0%BE%D0%B2%D0%B0%D1%82%D1%8C" class="translation ltr dict mobile-hidden v" data-pos='[v]' data-pos-index='2' data-posGroup="3" data-freq="37" title="<div class='nobold'>Посмотреть примеры с переводом <em class='translation'>бронировать</em><br>Глагол<br>(37 примеров, содержащих перевод)</div>">
#           <div class="pos-mark">
#               <span class="v" title="Глагол"></span>
#                   </div>
#           бронировать</a>
#       <div class="translation ltr dict mobile-hidden v" data-pos='[v]' data-pos-index='2' data-posGroup="3" data-freq="18" title="<div class='nobold'>Посмотреть примеры с переводом <em class='translation'>заказывать</em><br>Глагол<br>(18 примеров, содержащих перевод)</div>">
#           <div class="pos-mark">
#               <span class="v" title="Глагол"></span>
#                   </div>
#           заказывать</div>
#       <div class="translation ltr dict first mobile-hidden v" data-pos='[v]' data-pos-index='2' data-posGroup="3" data-freq="6" title="<div class='nobold'>Посмотреть примеры с переводом <em class='translation'>зарегистрировать</em><br>Глагол<br>(6 примеров, содержащих перевод)</div>">
#           <div class="pos-mark">
#               <span class="v" title="Глагол"></span>
#                   </div>
#           зарегистрировать</div>
#       <a href="/перевод/русский-английский/%D1%81%D0%B1%D0%BE%D1%80%D0%BD%D0%B8%D0%BA" class="translation ltr dict mobile-hidden n" data-pos='[n]' data-pos-index='0' data-posGroup="4" data-freq="44" title="<div class='nobold'>Посмотреть примеры с переводом <em class='translation'>сборник</em><br>Существительное<br>(44 примеров, содержащих перевод)</div>">
#           <div class="pos-mark">
#               <span class="n" title="Существительное"></span>
#                   </div>
#           сборник</a>
#       <a href="/перевод/русский-английский/%D0%BA%D0%BD%D0%B8%D0%B6%D0%B5%D1%87%D0%BA%D0%B0" class="translation ltr dict mobile-hidden n" data-pos='[nf]' data-pos-index='0' data-posGroup="4" data-freq="40" title="<div class='nobold'>Посмотреть примеры с переводом <em class='translation'>книжечка</em><br>Существительное - женский род<br>(40 примеров, содержащих перевод)</div>">
#           <div class="pos-mark">
#               <span class="n" title="Существительное - женский род"></span>
#                   </div>
#           книжечка</a>
#       <a href="/перевод/русский-английский/%D0%BF%D1%80%D0%B0%D0%B2%D0%B8%D0%BB%D0%B0%D0%BC" class="translation ltr dict mobile-hidden translation-hidden no-pos"  data-posGroup="6" data-freq="102" title="<div class='nobold'>Посмотреть примеры с переводом <em class='translation'>правилам</em><br>(102 примеров, содержащих перевод)</div>">
#           правилам</a>
#       <div class="translation ltr dict mobile-hidden translation-hidden n" data-pos='[nn]' data-pos-index='0' data-posGroup="4" data-freq="7" title="<div class='nobold'>Посмотреть примеры с переводом <em class='translation'>либретто</em><br>Существительное - средний род<br>(7 примеров, содержащих перевод)</div>">
#           <div class="pos-mark">
#               <span class="n" title="Существительное - средний род"></span>
#                   </div>
#           либретто</div>
#       <div class="translation ltr dict mobile-hidden translation-hidden n" data-pos='[n]' data-pos-index='0' data-posGroup="4" data-freq="2" title="<div class='nobold'>Посмотреть примеры с переводом <em class='translation'>книжица</em><br>Существительное<br>(2 примеров, содержащих перевод)</div>">
#           <div class="pos-mark">
#               <span class="n" title="Существительное"></span>
#                   </div>
#           книжица</div>
#       <div title="Больше" class="translation icon horizontal-dots"></div>
#       </div>
#   <section id="filters-content" class="wide-container">
#     <button class="other-content" data-other="0" data-negative=" -{книга} -{книжка} -{справочник} -{учебник} -{журнал} -{альбом} -{тетрадь} -{блокнот} -{книжный} -{забронировать} -{заказать} -{бронировать} -{заказывать} -{зарегистрировать} -{сборник} -{книжечка} -{правилам} -{либретто} -{книжица}">Другие переводы</button>
#     <div class="filter-form closed">
#       <button class="icon filter" title="Вы можете получить более точные результаты, указав слово или несколько слов, которые должен содержать перевод. В результате будут показаны только примеры, которые содержат эти слова."></button>
#       <button class="icon cancel" title="Очистить фильтр"></button>
#       <div class="input-content">
#         <button class="icon exclude" title="Кликните здесь, чтобы исключить некоторые слова из поиска. Например, слово1 -{слово2} : будут найдены примеры, которые содержат слово1 и НЕ содержат слово2"></button>
#         <input placeholder="Показать переводы, содержащие..." autocomplete="off" readonly>
#       </div>
#     </div>
#   </section>
#   <section id="top-suggestions" class="wide-container">
#     <h3>Предложения</h3>
#     <div class="wide-container">
#       <div class="suggestion negative" title="Это предложение исключено из результатов">
#             <span class="icon pf"></span>
#             <button class="text" data-url="/перевод/английский-русский/to+book">to book</button>
#             <span class="figure ">494</span>
#             </div>
#         <div class="suggestion">
#             <a href="/перевод/английский-русский/book+about" class="text" lang='en'>book about</a>
#             <span class="figure ">426</span>
#             </div>
#         <div class="suggestion negative" title="Это предложение исключено из результатов">
#             <span class="icon pf"></span>
#             <button class="text" data-url="/перевод/английский-русский/comic+book">comic book</button>
#             <span class="figure ">383</span>
#             </div>
#         <div class="suggestion">
#             <a href="/перевод/английский-русский/new+book" class="text" lang='en'>new book</a>
#             <span class="figure ">316</span>
#             </div>
#         <div class="suggestion">
#             <a href="/перевод/английский-русский/address+book" class="text" lang='en'>address book</a>
#             <span class="figure ">247</span>
#             </div>
#         <div class="suggestion">
#             <a href="/перевод/английский-русский/blue+book" class="text" lang='en'>blue book</a>
#             <span class="figure ">245</span>
#             </div>
#         <div class="suggestion negative" title="Это предложение исключено из результатов">
#             <span class="icon pf"></span>
#             <button class="text" data-url="/перевод/английский-русский/by+the+book">by the book</button>
#             <span class="figure ">236</span>
#             </div>
#         <div class="suggestion">
#             <a href="/перевод/английский-русский/read+the+book" class="text" lang='en'>read the book</a>
#             <span class="figure ">230</span>
#             </div>
#         <div class="suggestion">
#             <a href="/перевод/английский-русский/read+a+book" class="text" lang='en'>read a book</a>
#             <span class="figure ">230</span>
#             </div>
#         <button class="icon other other-suggestions" title="Другие переводы" data-negative="-{to book} -{book about} -{comic book} -{new book} -{address book} -{blue book} -{by the book} -{read the book} -{read a book}">
#         </button>
#     </div>
#   </section>
#   <button id="mobile-detailed-view" class="icon down-arrow detailed-view closed" title="Показать подробности и рекомендации"></button>
#   </section>
# <section id="examples-content" class="wide-container ">
#   <div id="MULTIUN-V1.EN-RU_13889900" class="example">
#       <div class="src ltr">
#         <span class="text" lang='en'>
#           The <em>book</em> was less useful when talking about regulatory systems.</span>
#       </div>
#       <div class="trg ltr">
#         <span class="icon jump-right"></span>
#         <span class="text">
#           Если говорить о системах нормативного регулирования, то <a class="link_highlighted" href='/перевод/русский-английский/%D0%BA%D0%BD%D0%B8%D0%B3%D0%B0' rel="nofollow"><em>книга</em></a> является менее полезной.</span>
#       </div>
#       <div class="options">
#         <div class="src">
#           <button data-id="MULTIUN-V1.EN-RU_13889900" class="voice icon stopped" title="Произношение" data-lang="en"></button>
#           </div>
#         <div class="trg">
#           <button class="icon more-context" title="Посмотреть примеры для этого перевода в контексте (https://conferences.unite.un.org/UNCorpus)" data-id="MULTIUN-V1.EN-RU_13889900"></button>
#           <button class="report icon thumb-down" title="Сообщить о проблеме в этом примере" data-id="MULTIUN-V1.EN-RU_13889900"></button>
# ...
#           <button class="report icon thumb-down" title="Сообщить о проблеме в этом примере" data-id="OPENSUBTITLES-2016.EN-RU_15285801"></button>
#           <button class="add icon addentry " title="Добавить этот перевод в коллективный словарь Reverso" data-url="https://dictionary.reverso.net/CollabDict.aspx?view=2&lang=RU" data-id="OPENSUBTITLES-2016.EN-RU_15285801" data-text="В первую очередь, надо <em>записать её</em> на приём в больницу."></button>
#           <button class="copy icon mobile-hidden" title="Скопировать перевод" data-id="OPENSUBTITLES-2016.EN-RU_15285801"></button>
#           <button class="icon non-favourite " title="Отметить пример в качестве избранного" data-id="OPENSUBTITLES-2016.EN-RU_15285801"></button>
#           <button data-id="OPENSUBTITLES-2016.EN-RU_15285801" class="voice icon stopped" title="Произношение" data-lang="ru"></button>
#           </div>
#       </div>
#       <button data-id="OPENSUBTITLES-2016.EN-RU_15285801" class="mobile-voice icon stopped played"></button>
#       </div>
#     <div id="OPENSUBTITLES-2016.EN-RU_14980095" class="example blocked">
#       <div class="src ltr">
#         <span class="text" lang='en'>
#           But he's okay in my <em>book</em>.</span>
#       </div>
#       <div class="trg ltr">
#         <span class="icon jump-right"></span>
#         <span class="text">
#           Но в моей <a class="link_highlighted" href='/перевод/русский-английский/%D0%BA%D0%BD%D0%B8%D0%B6%D0%BA%D0%B5' rel="nofollow"><em>книжке</em></a> с ним все в порядке.</span>
#       </div>
#       <div class="options">
#         <div class="src">
#           <button data-id="OPENSUBTITLES-2016.EN-RU_14980095" class="voice icon stopped" title="Произношение" data-lang="en"></button>
#           </div>
#         <div class="trg">
#           <button class="icon more-context" title="Посмотреть примеры для этого перевода в контексте (http://opus.nlpl.eu/OpenSubtitles2016.php)" data-id="OPENSUBTITLES-2016.EN-RU_14980095"></button>
#           <button class="report icon thumb-down" title="Сообщить о проблеме в этом примере" data-id="OPENSUBTITLES-2016.EN-RU_14980095"></button>
#           <button class="add icon addentry " title="Добавить этот перевод в коллективный словарь Reverso" data-url="https://dictionary.reverso.net/CollabDict.aspx?view=2&lang=RU" data-id="OPENSUBTITLES-2016.EN-RU_14980095" data-text="Но в моей <em>книжке</em> с ним все в порядке."></button>
#           <button class="copy icon mobile-hidden" title="Скопировать перевод" data-id="OPENSUBTITLES-2016.EN-RU_14980095"></button>
#           <button class="icon non-favourite " title="Отметить пример в качестве избранного" data-id="OPENSUBTITLES-2016.EN-RU_14980095"></button>
#           <button data-id="OPENSUBTITLES-2016.EN-RU_14980095" class="voice icon stopped" title="Произношение" data-lang="ru"></button>
#           </div>
#       </div>
#       <button data-id="OPENSUBTITLES-2016.EN-RU_14980095" class="mobile-voice icon stopped played"></button>
#       </div>
#     <div id="OPENSUBTITLES-2016.EN-RU_14586129" class="example blocked">
#       <div class="src ltr">
#         <span class="text" lang='en'>
#           Literally wrote the <em>book</em> on modern naval warfare.</span>
#       </div>
#       <div class="trg ltr">
#         <span class="icon jump-right"></span>
#         <span class="text">
#           Он в буквальном смысле написал <a class="link_highlighted" href='/перевод/русский-английский/%D0%BA%D0%BD%D0%B8%D0%B3%D1%83' rel="nofollow"><em>книгу</em></a> о современной войне на море.</span>
#       </div>
#       <div class="options">
#         <div class="src">
#           <button data-id="OPENSUBTITLES-2016.EN-RU_14586129" class="voice icon stopped" title="Произношение" data-lang="en"></button>
#           </div>
#         <div class="trg">
#           <button class="icon more-context" title="Посмотреть примеры для этого перевода в контексте (http://opus.nlpl.eu/OpenSubtitles2016.php)" data-id="OPENSUBTITLES-2016.EN-RU_14586129"></button>
#           <button class="report icon thumb-down" title="Сообщить о проблеме в этом примере" data-id="OPENSUBTITLES-2016.EN-RU_14586129"></button>
#           <button class="add icon addentry " title="Добавить этот перевод в коллективный словарь Reverso" data-url="https://dictionary.reverso.net/CollabDict.aspx?view=2&lang=RU" data-id="OPENSUBTITLES-2016.EN-RU_14586129" data-text="Он в буквальном смысле написал <em>книгу</em> о современной войне на море."></button>
#           <button class="copy icon mobile-hidden" title="Скопировать перевод" data-id="OPENSUBTITLES-2016.EN-RU_14586129"></button>
#           <button class="icon non-favourite " title="Отметить пример в качестве избранного" data-id="OPENSUBTITLES-2016.EN-RU_14586129"></button>
#           <button data-id="OPENSUBTITLES-2016.EN-RU_14586129" class="voice icon stopped" title="Произношение" data-lang="ru"></button>
#           </div>
#       </div>
#       <button data-id="OPENSUBTITLES-2016.EN-RU_14586129" class="mobile-voice icon stopped played"></button>
#       </div>
#     <div id="OPENSUBTITLES-2016.EN-RU_12878035" class="example blocked">
#       <div class="src ltr">
#         <span class="text" lang='en'>
#           Let me interview you for my <em>book</em>.</span>
#       </div>
#       <div class="trg ltr">
#         <span class="icon jump-right"></span>
#         <span class="text">
#           Позвольте мне взять у вас интервью для моей <a class="link_highlighted" href='/перевод/русский-английский/%D0%BA%D0%BD%D0%B8%D0%B3%D0%B8' rel="nofollow"><em>книги</em></a>.</span>
#       </div>
#       <div class="options">
#         <div class="src">
#           <button data-id="OPENSUBTITLES-2016.EN-RU_12878035" class="voice icon stopped" title="Произношение" data-lang="en"></button>
#           </div>
#         <div class="trg">
#           <button class="icon more-context" title="Посмотреть примеры для этого перевода в контексте (http://opus.nlpl.eu/OpenSubtitles2016.php)" data-id="OPENSUBTITLES-2016.EN-RU_12878035"></button>
#           <button class="report icon thumb-down" title="Сообщить о проблеме в этом примере" data-id="OPENSUBTITLES-2016.EN-RU_12878035"></button>
#           <button class="add icon addentry " title="Добавить этот перевод в коллективный словарь Reverso" data-url="https://dictionary.reverso.net/CollabDict.aspx?view=2&lang=RU" data-id="OPENSUBTITLES-2016.EN-RU_12878035" data-text="Позвольте мне взять у вас интервью для моей <em>книги</em>."></button>
#           <button class="copy icon mobile-hidden" title="Скопировать перевод" data-id="OPENSUBTITLES-2016.EN-RU_12878035"></button>
#           <button class="icon non-favourite " title="Отметить пример в качестве избранного" data-id="OPENSUBTITLES-2016.EN-RU_12878035"></button>
#           <button data-id="OPENSUBTITLES-2016.EN-RU_12878035" class="voice icon stopped" title="Произношение" data-lang="ru"></button>
#           </div>
#       </div>
#       <button data-id="OPENSUBTITLES-2016.EN-RU_12878035" class="mobile-voice icon stopped played"></button>
#       </div>
#     <div id="blocked-rude-results-banner" class="popup wide-container">
#     <div class="header"></div>
#     <div class="body">
#       <span>Возможно неприемлемое содержание</span>
#       <div class="buttons-content">
#         <button class="button close">Показать</button>
#       </div>
#       <span class="disclaimer">
#         Примеры предназначены только для помощи в переводе искомых слов и выражений в различных контекстах. Мы не выбираем и не утверждаем примеры, и они могут содержать неприемлемые слова или идеи. Пожалуйста, сообщайте нам о примерах, которые, на Ваш взгляд, необходимо исправить или удалить. Грубые или разговорные переводы обычно отмечены красным или оранжевым цветом.</span>
#     </div>
#   </div>
#   <div id="blocked-results-banner" class="popup wide-container">
#       <div class="header">
#         <button class="icon close"></button>
#       </div>
#       <div class="body">
#         <span>Зарегистрируйтесь, чтобы увидеть больше примеров.</span>
#         <div class="buttons-content">
#           <a href="https://account.reverso.net/register/context.reverso.net/ru?utm_source=contextweb&utm_medium=blockedexamples&utm_campaign=register" class="button register">Зарегистрироваться</a>
#           <a href="https://account.reverso.net/login/context.reverso.net/ru?utm_source=contextweb&utm_medium=blockedexamples&utm_campaign=login" class="button login">Войти</a>
#         </div>
#       </div>
#     </div>
#   </section>
# <section id="no-results">
#   <span class="wide-container message">Ничего не найдено для этого значения.</span>
#   <div class="wide-container">
#       <button id="add-example" title="Предложить пример для &quot;book&quot;" data-ga="display-noexamples">Предложить пример</button>
#     </div>
#   </section>
# <section id="examples-bottom">
#   <div class="loading-pannel">
#   <span class="icon"></span>
# </div>
# <button id="load-more-examples" class="button load-more unregistered">Больше примеров</button>
#   <div id="result-info" class="wide-container" data-exact="25624">
#       <p>Результатов: <span id="nrows">25624</span>. Точных совпадений: <span id="nrows_exact">25624</span>. Затраченное время: <span id="time">113</span> мс</p>
#     </div>
#   <div class="wide-container">
#       <button id="add-example" title="Предложить пример для &quot;book&quot;" data-ga="display-examplesbottom">Предложить пример</button>
#     </div>
#   <section id="bottom-suggestions" class="wide-container">
#     <div class="suggestion hidden" title="Это предложение исключено из результатов">
#             <span class="text" data-url="/перевод/английский-русский/to+book">to book</span>
#             <span class="figure ">494</span>
#             </div>
#         <div class="suggestion">
#             <a href="/перевод/английский-русский/book+about" class="text">book about</a>
#             <span class="figure ">426</span>
#             </div>
#         <div class="suggestion hidden" title="Это предложение исключено из результатов">
#             <span class="text" data-url="/перевод/английский-русский/comic+book">comic book</span>
#             <span class="figure ">383</span>
#             </div>
#         <div class="suggestion">
#             <a href="/перевод/английский-русский/new+book" class="text">new book</a>
#             <span class="figure ">316</span>
#             </div>
#         <div class="suggestion">
#             <a href="/перевод/английский-русский/address+book" class="text">address book</a>
#             <span class="figure ">247</span>
#             </div>
#         <div class="suggestion">
#             <a href="/перевод/английский-русский/blue+book" class="text">blue book</a>
#             <span class="figure ">245</span>
#             </div>
#         <div class="suggestion hidden" title="Это предложение исключено из результатов">
#             <span class="text" data-url="/перевод/английский-русский/by+the+book">by the book</span>
#             <span class="figure ">236</span>
#             </div>
#         <div class="suggestion">
#             <a href="/перевод/английский-русский/read+the+book" class="text">read the book</a>
#             <span class="figure ">230</span>
#             </div>
#         <div class="suggestion">
#             <a href="/перевод/английский-русский/read+a+book" class="text">read a book</a>
#             <span class="figure ">230</span>
#             </div>
#         <button class="icon other other-suggestions" title="Другие переводы" data-negative="-{to book} -{book about} -{comic book} -{new book} -{address book} -{blue book} -{by the book} -{read the book} -{read a book}">
#       </button>
#     </section>
#   </section>
# </div>
#   <!-- /64378609/Context_MegaBanner_Bottom -->
#   <div id="bottom-mega-rca-box" class="hidden">
#     <div id='div-gpt-ad-Reverso_Ctxt_D_Result_728x90_BTF' class="bottom-rca mega-rca">
#       <script type='text/javascript'>
#         if(!window.mobilecheck()) {
#           googletag.cmd.push(function() {
#             googletag.display('div-gpt-ad-Reverso_Ctxt_D_Result_728x90_BTF');
#           });
#         }
#       </script>
#     </div>
#     <span class="rca-title rca-title-vertical bottom-rca">Реклама</span>
#   </div>
#   </section>
# <section id="sitemaps">
#   <p>Индекс слова: <a href="/перевод/index/английский-русский/w-1-300.html">1-300</a>, <a href="/перевод/index/английский-русский/w-301-600.html">301-600</a>, <a href="/перевод/index/английский-русский/w-601-900.html">601-900</a>, <a href="/перевод/index/английский-русский/w.html">Больше</a><p>Индекс выражения: <a href="/перевод/index/английский-русский/e-1-400.html">1-400</a>, <a href="/перевод/index/английский-русский/e-401-800.html">401-800</a>, <a href="/перевод/index/английский-русский/e-801-1200.html">801-1200</a>, <a href="/перевод/index/английский-русский/e.html">Больше</a><p>Индекс фразы: <a href="/перевод/index/английский-русский/p-1-400.html">1-400</a>, <a href="/перевод/index/английский-русский/p-401-800.html">401-800</a>, <a href="/перевод/index/английский-русский/p-801-1200.html">801-1200</a>, <a href="/перевод/index/английский-русский/p.html">Больше</a></section>
#     <p class="developers wide-container">Разработано Prompsit Language Engineering для Softissimo</p>
# <section id="footer">
#   <div class="wide-container">
#     <a href="/перевод/about">Что такое контекстный словарь</a>
#     <a class="app-link" href="/перевод/mobile-app">Скачать приложение</a>
#     <a target="_blank" href="http://www.reverso.net/feedback.aspx?type=3&lang=RU">Контакты</a>
#     <a href="/перевод/legal">Правовые вопросы</a>
#   </div>
#   <div class="wide-container">
#     <a href="/translation/">Translation in context</a><a href="/traduction/">Traduction en contexte</a><a href="/traduccion/">Traducción en contexto</a><a href="/traducao/">Tradução em contexto</a><a href="/traduzione/">Traduzione in contesto</a><a href="/übersetzung/">Übersetzung im Kontext</a><a href="/الترجمة/">الترجمة في السياق</a><a href="/翻訳/">文脈に沿った翻訳</a><a href="/vertaling/">Vertaling in context</a><a href="/תרגום/">תרגום בהקשר</a><a href="/tłumaczenie/">Tłumaczenie w kontekście</a><a href="/traducere/">Traducere în context</a><a href="/çeviri/">İçerik tercümesi</a></div>
#   <div class="wide-container">
#     <a target="_blank" href="https://synonyms.reverso.net/%D1%81%D0%B8%D0%BD%D0%BE%D0%BD%D0%B8%D0%BC%D1%8B/">Синонимы</a>
#     <a target="_blank" href="http://glagol.reverso.net/%D1%81%D0%BF%D1%80%D1%8F%D0%B6%D0%B5%D0%BD%D0%B8%D0%B5-%D1%80%D1%83%D1%81%D1%81%D0%BA%D0%B8%D0%B9.html">Спряжение</a>
#     <a target="_blank" href="https://www.corporate-translation.reverso.com/">Reverso Corporate</a>
#     </div>
#   <p class="copy">&copy;  2013-2019 Softissimo Inc. Все права защищены.</p>
# </section>
# </div>
#     <script type="text/javascript" src="https://cdn.reverso.net/context/v51300/js/bst.constants-ru.js"></script>
# <script type="text/javascript" src="https://cdn.reverso.net/context/v51300/js/bst.scripts.js"></script>
# <script type="text/javascript">
#   !function(f,b,e,v,n,t,s){if(f.fbq)return;n=f.fbq=function(){n.callMethod?
#   n.callMethod.apply(n,arguments):n.queue.push(arguments)};if(!f._fbq)f._fbq=n;
#   n.push=n;n.loaded=!0;n.version='2.0';n.queue=[];t=b.createElement(e);t.async=!0;
#   t.src=v;s=b.getElementsByTagName(e)[0];s.parentNode.insertBefore(t,s)}(window,
#   document,'script','https://connect.facebook.net/en_US/fbevents.js');
#   fbq('init', '1090291004350551');
#   fbq('track', "PageView");
#
#   var ezt = ezt ||[];
#   (function(){
#     var elem = document.createElement('script');
#     elem.src = (document.location.protocol == "https:" ? "https://secure" : "http://pixel") + ".quantserve.com/aquant.js?a=p-9z6v4xdJwT5Z-";
#     elem.async = true;
#     elem.type = "text/javascript";
#     var scpt = document.getElementsByTagName('script')[0];
#     scpt.parentNode.insertBefore(elem,scpt);
#   }());
#   ezt.push({qacct: 'p-9z6v4xdJwT5Z-', labels: 'context', uid: '' });
# </script><noscript><img src="//pixel.quantserve.com/pixel/p-9z6v4xdJwT5Z-.gif?labels=context" style="display: none;" height="1" width="1" alt=""/>
#   <img height="1" width="1" style="display:none" src="https://www.facebook.com/tr?id=1090291004350551&ev=PageView&noscript=1" alt=""/>
# </noscript></body>
# </html>

# %%
soup.find_all("em", class_="translation")
soup.find_all("em",attrs={"class" : "translation"})
for l in soup.find_all("a"):
    print (l)

# %%
url = "https://context.reverso.net/перевод/английский-русский/book#книга"
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/537.36'}
response = requests.get(url, headers=headers)
response.encoding = 'utf-8'
soup = bs(response.text, 'html.parser')

# %%
# Out:
# Перевод
# поезд
# подготовка
# обучение
# вагон
# метро
# состав
# обучать
# тренироваться
# готовить
# тренировать
# подготовить
# обучить
# научить
# учить
# железнодорожный
# поездной
# натренировать

# %%
for link in soup.find_all('em'):
    print(link)
    print(link.em)
    print(link.get('class'))
    print(link.attrs)
    print("===")
# Out:
# <em>book</em>
# None
# None
# {}
# ===
# <em>книга</em>
# None
# None
# {}
# ===
# <em>book</em>
# None
# None
# {}
# ===
# <em>книга</em>
# None
# None
# {}
# ===
# <em>book</em>
# None
# None
# {}
# ===
# <em>книжка</em>
# None
# None
# {}
# ===
# <em>book</em>
# None
# None
# {}
# ===
# <em>книга</em>
# None
# None
# {}
# ===
# <em>book</em>
# None
# None
# {}
# ===
# <em>книга</em>
# None
# None
# {}
# ===
# <em>book</em>
# None
# None
# {}
# ===
# <em>книга</em>
# None
# None
# {}
# ===
# <em>book</em>
# None
# None
# {}
# ===
# <em>книга</em>
# None
# None
# {}
# ===
# <em>book</em>
# None
# None
# {}
# ===
# <em>книга</em>
# None
# None
# {}
# ===
# <em>book</em>
# None
# None
# {}
# ===
# <em>книга</em>
# None
# None
# {}
# ===
# <em>book</em>
# None
# None
# {}
# ===
# <em>book</em>
# None
# None
# {}
# ===
# <em>book</em>
# None
# None
# {}
# ===
# <em>Книга</em>
# None
# None
# {}
# ===
# <em>Книга</em>
# None
# None
# {}
# ===
# <em>Книга</em>
# None
# None
# {}
# ===
# <em>book</em>
# None
# None
# {}
# ===
# <em>book</em>
# None
# None
# {}
# ===
# <em>book</em>
# None
# None
# {}
# ===
# <em>книга</em>
# None
# None
# {}
# ===
# <em>книга</em>
# None
# None
# {}
# ===
# <em>книга</em>
# None
# None
# {}
# ===
# <em>book</em>
# None
# None
# {}
# ===
# <em>book</em>
# None
# None
# {}
# ===
# <em>книга</em>
# None
# None
# {}
# ===
# <em>книга</em>
# None
# None
# {}
# ===
# <em>book</em>
# None
# None
# {}
# ===
# <em>книжные</em>
# None
# None
# {}
# ===
# <em>book</em>
# None
# None
# {}
# ===
# <em>книгу</em>
# None
# None
# {}
# ===
# <em>book</em>
# None
# None
# {}
# ===
# <em>заказать</em>
# None
# None
# {}
# ===
# <em>book</em>
# None
# None
# {}
# ===
# <em>книги</em>
# None
# None
# {}
# ===
# <em>book</em>
# None
# None
# {}
# ===
# <em>записать её</em>
# None
# None
# {}
# ===
# <em>book</em>
# None
# None
# {}
# ===
# <em>книжке</em>
# None
# None
# {}
# ===
# <em>book</em>
# None
# None
# {}
# ===
# <em>книгу</em>
# None
# None
# {}
# ===
# <em>book</em>
# None
# None
# {}
# ===
# <em>книги</em>
# None
# None
# {}
# ===

# %%
soup = bs(response.text,"lxml")
allLines = soup.text.split('\n') 

for line in allLines: # you iterate through the list, and print the single lines
    print(line)
# Out:
# book - Перевод на русский - примеры английский | Reverso Context
#
#
#
#
#
#
#   var request = {
#     srctext: "book",
#     trgtext: "",
#     srclang: "en",
#     trglang: "ru",
#     rpage: 1,
#     rmode: 0,
#     original: "book"
#   };
#
#
#
#
#
#
#
#
#
#
#
#
#   @font-face{font-family:'contexticons';font-display: swap;src:url('https://cdn.reverso.net/context/v51300/fonts/contexticons.eot?phzsmg');src:url('https://cdn.reverso.net/context/v51300/fonts/contexticons.eot?phzsmg#iefix') format('embedded-opentype'),url('https://cdn.reverso.net/context/v51300/fonts/contexticons.ttf?phzsmg') format('truetype'),url('https://cdn.reverso.net/context/v51300/fonts/contexticons.woff?phzsmg') format('woff'),url('https://cdn.reverso.net/context/v51300/fonts/contexticons.svg?phzsmg#contexticons') format('svg');font-weight: normal;font-style: normal;}
#
#
#
#
#
#
#
#
#
#   if(typeof window.request === "undefined") {
#     window.request = {
#       srctext: "",
#       trgtext: "",
#       srclang: "en",
#       trglang: "ru",
#       rpage: 1,
#       rmode: 0
#     };
#   }
#   var logLOCD = false;
#   var context_path = '';
#   var special_chars = "،؟י¬¿¡ºª·؛";
#   var is_rtl = false;
#
#   window.mobilecheck = function() {
#     var check = false;
#     (function (a) {
#       if (/(android|bb\d+|meego).+mobile|avantgo|bada\/|blackberry|blazer|compal|elaine|fennec|hiptop|iemobile|ip(hone|od)|iris|kindle|lge |maemo|midp|mmp|mobile.+firefox|netfront|opera m(ob|in)i|palm( os)?|phone|p(ixi|re)\/|plucker|pocket|psp|series(4|6)0|symbian|treo|up\.(browser|link)|vodafone|wap|windows ce|xda|xiino/i.test(a)||/1207|6310|6590|3gso|4thp|50[1-6]i|770s|802s|a wa|abac|ac(er|oo|s\-)|ai(ko|rn)|al(av|ca|co)|amoi|an(ex|ny|yw)|aptu|ar(ch|go)|as(te|us)|attw|au(di|\-m|r |s )|avan|be(ck|ll|nq)|bi(lb|rd)|bl(ac|az)|br(e|v)w|bumb|bw\-(n|u)|c55\/|capi|ccwa|cdm\-|cell|chtm|cldc|cmd\-|co(mp|nd)|craw|da(it|ll|ng)|dbte|dc\-s|devi|dica|dmob|do(c|p)o|ds(12|\-d)|el(49|ai)|em(l2|ul)|er(ic|k0)|esl8|ez([4-7]0|os|wa|ze)|fetc|fly(\-|_)|g1 u|g560|gene|gf\-5|g\-mo|go(\.w|od)|gr(ad|un)|haie|hcit|hd\-(m|p|t)|hei\-|hi(pt|ta)|hp( i|ip)|hs\-c|ht(c(\-| |_|a|g|p|s|t)|tp)|hu(aw|tc)|i\-(20|go|ma)|i230|iac( |\-|\/)|ibro|idea|ig01|ikom|im1k|inno|ipaq|iris|ja(t|v)a|jbro|jemu|jigs|kddi|keji|kgt( |\/)|klon|kpt |kwc\-|kyo(c|k)|le(no|xi)|lg( g|\/(k|l|u)|50|54|\-[a-w])|libw|lynx|m1\-w|m3ga|m50\/|ma(te|ui|xo)|mc(01|21|ca)|m\-cr|me(rc|ri)|mi(o8|oa|ts)|mmef|mo(01|02|bi|de|do|t(\-| |o|v)|zz)|mt(50|p1|v )|mwbp|mywa|n10[0-2]|n20[2-3]|n30(0|2)|n50(0|2|5)|n7(0(0|1)|10)|ne((c|m)\-|on|tf|wf|wg|wt)|nok(6|i)|nzph|o2im|op(ti|wv)|oran|owg1|p800|pan(a|d|t)|pdxg|pg(13|\-([1-8]|c))|phil|pire|pl(ay|uc)|pn\-2|po(ck|rt|se)|prox|psio|pt\-g|qa\-a|qc(07|12|21|32|60|\-[2-7]|i\-)|qtek|r380|r600|raks|rim9|ro(ve|zo)|s55\/|sa(ge|ma|mm|ms|ny|va)|sc(01|h\-|oo|p\-)|sdk\/|se(c(\-|0|1)|47|mc|nd|ri)|sgh\-|shar|sie(\-|m)|sk\-0|sl(45|id)|sm(al|ar|b3|it|t5)|so(ft|ny)|sp(01|h\-|v\-|v )|sy(01|mb)|t2(18|50)|t6(00|10|18)|ta(gt|lk)|tcl\-|tdg\-|tel(i|m)|tim\-|t\-mo|to(pl|sh)|ts(70|m\-|m3|m5)|tx\-9|up(\.b|g1|si)|utst|v400|v750|veri|vi(rg|te)|vk(40|5[0-3]|\-v)|vm40|voda|vulc|vx(52|53|60|61|70|80|81|83|85|98)|w3c(\-| )|webc|whit|wi(g |nc|nw)|wmlb|wonu|x700|yas\-|your|zeto|zte\-/i.test(a.substr(0,4)))
#         check = true
#       })(navigator.userAgent || navigator.vendor || window.opera);
#     return check;
#   };
#
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#     (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#     m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   var ga_log = [];
#
#   function sendGA(command, type, category, action, label, options) {
#     var object = {
#       "command": command,
#       "type": type,
#       "category": category,
#       "action": action,
#       "label": label
#     };
#     ga_log.push(object);
#     if(label !== undefined) ga(command, type, category, action, label, options);
#     else if(action !== undefined) ga(command, type, category, action, options);
#     else if(category !== undefined) ga(command, type, category, options);
#     else ga(command, type, options);
#   };
#
#   sendGA('create', 'UA-2834324-41', 'reverso.net');
#   sendGA('create', 'UA-2834324-49', 'auto', 'keywordTracker');
#   sendGA('require', 'displayfeatures');
#   sendGA('keywordTracker.require', 'displayfeatures');
#   sendGA('set', 'dimension1', logLOCD ? (is_premium ? 'premium' : 'registered') : 'anonymous');
#
#     sendGA('set', 'dimension4', typeof(adblock)=='undefined' ? 'yes' : (typeof(abp)!='undefined' && abp ? 'abp' : 'no' ));
#
#   sendGA('send', 'pageview', '/bst/result/en-ru/1w/translations-precomputed');
#   sendGA('keywordTracker.send', 'pageview');
#
#     var googletag = googletag || {};
#     googletag.cmd = googletag.cmd || [];
#
#     googletag.cmd.push(function() {
#         googletag.pubads().disableInitialLoad();
#         setReversoTargeting();
#     });
#     if (typeof (adblock) != 'undefined') {
#       var device = (window.mobilecheck() ? "mobile" : (window.innerWidth>1024 ? "desktop" : "tablet"));
#
#       var prebid_config = prebid_config || new prebidConfig();
#       var PREBID_TIMEOUT = prebid_config.getTimeout() || 800;
#       var GA_VARIATION = typeof(prebid_config) != 'undefined' ? prebid_config.getVariation() : 0;
#
#       var ads_array = [];
#       if (device === "desktop") {
#         ads_array = ['Reverso_Ctxt_D_Result_300x250_ATF', 'Reverso_Ctxt_D_Result_300x250_BTF', 'Reverso_Ctxt_D_Result_300x600_BTF', 'Reverso_Ctxt_D_Result_728x90_BTF']
#       }
#       else if (device === "mobile") {
#         ads_array = ['Reverso_Ctxt_M_Result_320x50_BTF'];
#       }
#       else {
#         ads_array = ['Reverso_Ctxt_D_Result_728x90_BTF'];
#       }
#
#         ads_array.push('Reverso_Ctxt_R_Result_InFeed_ATF');
#
#
#       var adsetup = prebid_config.getAdSetup(ads_array) || [];
#       var adUnits = prebid_config.getAdUnits(adsetup) || [];
#
#       if(typeof(abp) != 'undefined' && abp){adUnits=[];}
#
#       (function() {
#           var gads = document.createElement('script');
#           gads.async = true;
#           gads.type = 'text/javascript';
#           var useSSL = 'https:' == document.location.protocol;
#           gads.src = (useSSL ? 'https:' : 'http:') +
#           '//www.googletagservices.com/tag/js/gpt.js';
#           var node = document.getElementsByTagName('script')[0];
#           node.parentNode.insertBefore(gads, node);
#       })();
#
#       var slots = [];
#
#       googletag.cmd.push(function() {
#           for (var i in adsetup) {
#             n = adsetup[i];
#             slots[n['slotcode']] = googletag.defineSlot('/2629866/'+n['slotname'][0], n['slotsizes'], n['slotcode']).addService(googletag.pubads());
#           }
#
#           googletag.pubads().enableSingleRequest();
#           googletag.enableServices();
#       });
#
#       var pbjs = pbjs || {};
#       pbjs.que = pbjs.que || [];
#
#       prebid_config.setBidderSettings(pbjs);
#       prebid_config.setConfig(pbjs);
#       prebid_config.setAnalyticsSettings(pbjs);
#
#       pbjs.que.push(function() {
#         pbjs.addAdUnits(adUnits);
#         if(device === "desktop"){
#           pbjs.requestBids({
#             timeout: adUnits.length ? PREBID_TIMEOUT : 100,
#             adUnitCodes: ['div-gpt-ad-Reverso_Ctxt_D_Result_300x250_ATF', 'div-gpt-ad-Reverso_Ctxt_D_Result_300x250_BTF'],
#             bidsBackHandler: sendAdserverRequest
#           });
#         }
#         });
#
#       function isGptPubadsDefined() {
#         return window.googletag && typeof window.googletag.pubads === "function" && typeof window.googletag.pubads().getSlots === "function";
#       }
#
#       function refreshBids(adUnitCodes) {
#           if (!isGptPubadsDefined()) {
#             setTimeout(function() {
#               refreshBids(adUnitCodes);
#             }, 100);
#             return;
#           }
#           refresh_adsetup = prebid_config.getAdSetup(adUnitCodes) || [];
#           refresh_adunits = prebid_config.getAdUnits(refresh_adsetup) || [];
#           var gptAdSlots = [];
#           for (i in refresh_adsetup) {
#             gptAdSlots.push(slots[refresh_adsetup[i].slotcode]);
#           }
#           if(refresh_adunits.length && (typeof(abp) == 'undefined' || !abp)){
#             pbjs.que.push(function() {
#               pbjs.requestBids({
#                 timeout: PREBID_TIMEOUT,
#                 adUnitCodes: refresh_adunits.map(function (x) { return x.code; }),
#                 bidsBackHandler: function() {
#                   pbjs.setTargetingForGPTAsync(adUnitCodes);
#                   googletag.pubads().refresh(gptAdSlots, {changeCorrelator: false});
#                 }
#               });
#             });
#           }
#           else{
#               googletag.pubads().refresh(gptAdSlots, {changeCorrelator: false});
#           }
#       }
#
#       function setReversoTargeting() {
#           var adtargeting = {};
#
#           adtargeting['abtest'] = GA_VARIATION || 0;
#           adtargeting['Interface'] = 'RU';
#           adtargeting['device'] = device;
#           adtargeting['Status'] = 'prod';
#
#             adtargeting['Direction'] = 'EN-RU';
#
#
#           if(typeof(abp) != 'undefined' && abp){
#             adtargeting['abp'] = '1';
#         	}
#
#           for (var i in adtargeting) {
#             googletag.pubads().clearTargeting(i);
#             googletag.pubads().setTargeting(i, adtargeting[i]);
#           }
#       }
#
#       function sendAdserverRequest() {
#           if (pbjs.adserverRequestSent) return;
#           pbjs.adserverRequestSent = true;
#           googletag.cmd.push(function() {
#               pbjs.que.push(function() {
#                   setReversoTargeting();
#                   if(device === "desktop"){
#                       pbjs.setTargetingForGPTAsync(['div-gpt-ad-Reverso_Ctxt_D_Result_300x250_ATF', 'div-gpt-ad-Reverso_Ctxt_D_Result_300x250_BTF']);
#                       googletag.pubads().refresh([slots['div-gpt-ad-Reverso_Ctxt_D_Result_300x250_ATF'], slots['div-gpt-ad-Reverso_Ctxt_D_Result_300x250_BTF']], {changeCorrelator: false});
#                   }
#               });
#           });
#       }
#
#       setTimeout(function() {sendAdserverRequest();}, (PREBID_TIMEOUT*1.5));
# 	}
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Зарегистрироваться
#
#
#
# Войти
#
#
#
# Font size
#
#
#
# Помощь
#
#
#
# русский
#
#
#
# العربية
# Deutsch
# English
# Español
# Français
# עברית
# Italiano
# 日本語
# Nederlands
# Polski
# Português
# Română
# Русский
# Türkçe
#
#
#
#
#
# ···
#
#
#
# Перевод
#
#
#
# Словарь
#
#
#
# Корректор
#
#
#
# Спряжение
#
#
#
# Синонимы
#
#
#
# Грамматика
#
#
#
# Перевод документов и сайтов
#
#
#
# Корпоративные решения
#
#
#
# Новостная рассылка
#
#
#
# Помощь
#
#
#
#
# ru
#
# ···
#
# العربية
# Deutsch
# English
# Español
# Français
# עברית
# Italiano
# 日本語
# Nederlands
# Polski
# Português
# Română
# Русский
# Türkçe
#
#
#
#
#
#       Перевод
#
#       Словарь
#
#       Корректор
#
#       Спряжение
#
#       Синонимы
#
#       Грамматика
#
#
#
#
#
#
#
#
#
#
#     Перевод
# Context
#
#     Спряжение
#
#     Синонимы
#
#
#
#
#
#     var register_link = "https://account.reverso.net/register/context.reverso.net/ru?utm_source=contextweb&utm_medium={0}&utm_campaign=register";
#     var login_link = "https://account.reverso.net/login/context.reverso.net/ru?utm_source=contextweb&utm_medium={0}&utm_campaign=login";
#
#
#
#
#
# Присоединиться к Reverso
#
#
#
# Зарегистрироваться
#
#
#
# Войти
#
#
#
# Войти через Facebook
#
#
#
# Войти через Google
#
#
#
#
#
#
#
#
# Реклама
#
#
#       if(!window.mobilecheck()) {
#         googletag.cmd.push(function() {
#           googletag.display('div-gpt-ad-Reverso_Ctxt_D_Result_300x250_ATF');
#         });
#       }
#
#
#
#
#
# Добавить Reverso в {0} Бесплатно
#
#
# Скачать наше бесплатное приложение
#
#
#
#
#
#
#
# Реклама
#
#
#       if(!window.mobilecheck()) {
#         googletag.cmd.push(function() {
#           googletag.display('div-gpt-ad-Reverso_Ctxt_D_Result_300x250_BTF');
#         });
#       }
#
#
#
# Реклама
#
#
#         if(!window.mobilecheck()) {
# 		  googletag.cmd.push(function() {
# 			googletag.display('div-gpt-ad-Reverso_Ctxt_D_Result_300x600_BTF');
# 		  });
#         }
#
#
#
#
#
#
#
# Присоединяйтесь к Reverso, это удобно и бесплатно!
#
#
#
# Зарегистрироваться
# Войти
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# английский
#
#
# арабский
# немецкий
# английский
# испанский
# французский
# иврит
# итальянский
# японский
# голландский
# польский
# португальский
# румынский
# русский
# турецкий
#
#
#
#
#
#
#
#
#
#
# русский
#
#
# арабский
# немецкий
# английский
# испанский
# французский
# иврит
# итальянский
# японский
# голландский
# польский
# португальский
# румынский
# русский
# турецкий
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Посмотреть также:
# to book
# comic book
# by the book
#
# sendGA("send", "event", "seealso", "display", "en-ru");
#
#
# Conjugation of this verb
#
#
#
# На основании Вашего запроса эти примеры могут содержать грубую лексику.
#
#
#
# На основании Вашего запроса эти примеры могут содержать разговорную лексику.
#
#
#
#
#
#
# Перевод "book" на русский
#
#
#
#
#         Сущ.
#
#         Прил.
#
#         Глагол
#
#
#
#
#
#
#
#
#
#
#           книга
#
#
#
#
#           книжка
#
#
#
#
#           справочник
#
#
#
#
#           учебник
#
#
#
#
#           журнал
#
#
#
#
#           альбом
#
#
#
#
#           тетрадь
#
#
#
#
#           блокнот
#
#
#
#
#           книжный
#
#
#
#
#           забронировать
#
#
#
#
#           заказать
#
#
#
#
#           бронировать
#
#
#
#
#           заказывать
#
#
#
#
#           зарегистрировать
#
#
#
#
#           сборник
#
#
#
#
#           книжечка
#
#           правилам
#
#
#
#
#           либретто
#
#
#
#
#           книжица
#
#
#
# Другие переводы
#
#
#
#
#
#
#
#
#
#
# Предложения
#
#
#
# to book
# 494
#
#
# book about
# 426
#
#
#
# comic book
# 383
#
#
# new book
# 316
#
#
# address book
# 247
#
#
# blue book
# 245
#
#
#
# by the book
# 236
#
#
# read the book
# 230
#
#
# read a book
# 230
#
#
#
#
#
#
#
#
#
#
#
#           The book was less useful when talking about regulatory systems.
#
#
#
#
#           Если говорить о системах нормативного регулирования, то книга является менее полезной.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#           This book is about the human puzzle.
#
#
#
#
#           Эта книга говорит о человеке, как о мозаике.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#           One address book, imitation red leather.
#
#
#
#
#           Одна записная книжка, в обложке из красного кожзаменителя.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#           This book was selected for classroom libraries.
#
#
#
#
#           Эта книга была отобрана в качестве пособия для школьных библиотек.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 	            googletag.cmd.push(function() { googletag.display('div-gpt-ad-Reverso_Ctxt_R_Result_InFeed_ATF'); });
#
#
#
#
#
#
#           I can't believe you have this book.
#
#
#
#
#           Не могу поверить, что у тебя есть эта книга.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#           She had a book of mythology that she treasured.
#
#
#
#
#           У нее была книга по мифологии, которой она очень дорожила.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#           Now her book makes Fifty Shades look like a Disney story.
#
#
#
#
#           Она, как и ее книга "Пятьдесят оттенков", выглядит как диснеевский персонаж.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#           This month my book is getting published.
#
#
#
#
#           }В следующем месяце выходит моя книга "Польские цыгане".
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#           I have owned your book for 20 years.
#
#
#
#
#           У меня есть ваша книга уже в течение 20 лет.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#           Okay, book, book, book.
#
#
#
#
#           Ок, Книга, Книга, Книга...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#           This is my book, my book, my book...
#
#
#
#
#           Это моя книга, моя книга, моя книга...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#           I got you a great book, an absolutely terrific book.
#
#
#
#
#           У меня для тебя отличная книга, абсолютно потрясающая книга.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#           Several missions such as MINURCAT have book clubs.
#
#
#
#
#           У некоторых миссий, как, например, МИНУРКАТ, имеются свои книжные клубы.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#           Including his book on the game.
#
#
#
#
#           В том числе и книгу об этой игре.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#           Please note that you should book the hotel yourself.
#
#
#
#
#           Просьба учесть, что Вам необходимо самим заказать номер в гостинице.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#           At your age, with each book anything may happen.
#
#
#
#
#           В твои годы при чтении любой книги может случиться, что угодно.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#           So book a hospital appointment first.
#
#
#
#
#           В первую очередь, надо записать её на приём в больницу.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#           But he's okay in my book.
#
#
#
#
#           Но в моей книжке с ним все в порядке.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#           Literally wrote the book on modern naval warfare.
#
#
#
#
#           Он в буквальном смысле написал книгу о современной войне на море.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#           Let me interview you for my book.
#
#
#
#
#           Позвольте мне взять у вас интервью для моей книги.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Возможно неприемлемое содержание
#
# Показать
#
#
#         Примеры предназначены только для помощи в переводе искомых слов и выражений в различных контекстах. Мы не выбираем и не утверждаем примеры, и они могут содержать неприемлемые слова или идеи. Пожалуйста, сообщайте нам о примерах, которые, на Ваш взгляд, необходимо исправить или удалить. Грубые или разговорные переводы обычно отмечены красным или оранжевым цветом.
#
#
#
#
#
#
#
# Зарегистрируйтесь, чтобы увидеть больше примеров.
#
# Зарегистрироваться
# Войти
#
#
#
#
#
# Ничего не найдено для этого значения.
#
# Предложить пример
#
#
#
#
#
#
# Больше примеров
#
# Результатов: 25624. Точных совпадений: 25624. Затраченное время: 113 мс
#
#
# Предложить пример
#
#
#
# to book
# 494
#
#
# book about
# 426
#
#
# comic book
# 383
#
#
# new book
# 316
#
#
# address book
# 247
#
#
# blue book
# 245
# by the book
# 236
#
#
# read the book
# 230
#
#
# read a book
# 230
#
#
#
#
#
#
#
#
#
#
#         if(!window.mobilecheck()) {
#           googletag.cmd.push(function() {
#             googletag.display('div-gpt-ad-Reverso_Ctxt_D_Result_728x90_BTF');
#           });
#         }
#
#
# Реклама
#
#
#
# Индекс слова: 1-300, 301-600, 601-900, БольшеИндекс выражения: 1-400, 401-800, 801-1200, БольшеИндекс фразы: 1-400, 401-800, 801-1200, Больше
# Разработано Prompsit Language Engineering для Softissimo
#
#
# Что такое контекстный словарь
# Скачать приложение
# Контакты
# Правовые вопросы
#
#
# Translation in contextTraduction en contexteTraducción en contextoTradução em contextoTraduzione in contestoÜbersetzung im Kontextالترجمة في السياق文脈に沿った翻訳Vertaling in contextתרגום בהקשרTłumaczenie w kontekścieTraducere în contextİçerik tercümesi
#
# Синонимы
# Спряжение
# Reverso Corporate
#
# ©  2013-2019 Softissimo Inc. Все права защищены.
#
#
#
#
#
#   !function(f,b,e,v,n,t,s){if(f.fbq)return;n=f.fbq=function(){n.callMethod?
#   n.callMethod.apply(n,arguments):n.queue.push(arguments)};if(!f._fbq)f._fbq=n;
#   n.push=n;n.loaded=!0;n.version='2.0';n.queue=[];t=b.createElement(e);t.async=!0;
#   t.src=v;s=b.getElementsByTagName(e)[0];s.parentNode.insertBefore(t,s)}(window,
#   document,'script','https://connect.facebook.net/en_US/fbevents.js');
#   fbq('init', '1090291004350551');
#   fbq('track', "PageView");
#
#   var ezt = ezt ||[];
#   (function(){
#     var elem = document.createElement('script');
#     elem.src = (document.location.protocol == "https:" ? "https://secure" : "http://pixel") + ".quantserve.com/aquant.js?a=p-9z6v4xdJwT5Z-";
#     elem.async = true;
#     elem.type = "text/javascript";
#     var scpt = document.getElementsByTagName('script')[0];
#     scpt.parentNode.insertBefore(elem,scpt);
#   }());
#   ezt.push({qacct: 'p-9z6v4xdJwT5Z-', labels: 'context', uid: '' });
