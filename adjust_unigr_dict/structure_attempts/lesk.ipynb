# %%
from nltk.stem import WordNetLemmatizer
from nltk.corpus import wordnet as wn
from nltk.corpus import stopwords 
stop_words = set(stopwords.words('english'))
from string import punctuation
punct = punctuation+'«»—…“”*№–'
import numpy as np
import math

# %% [markdown]
# # ПЛАН ДЕЙСВТИЙ
#
#
# 2) СХЛОПНУТЬ УНИГРАММЫ ИДЕНТИЧНЫЕ (за счет проставления айдишников верных лемм?) --- если нужно - заполняем хэшом а если не нужно то зануляем хэш
#
# 3) БРАТЬ ЗА ОСНОВУ МНОГЗНАЧНОСТЬ ИЗ ИСТОЧНИКОВ И К НЕЙ ПОДТИЯГИВАТЬ СУЩЕСТВУЮЩИЕ СЛУЧАИ
#
# ---
#
#
# 1) ДОБИТЬ АЛГОРИТМ ДИЗАМБИГУАЦИИ ЗА СЧЕТ ВОРД2ВЕК

# %%
def tokenize(text):
    #print(text)
    wordnet_lemmatizer = WordNetLemmatizer()
    words = [word.strip(punct) for word in text.lower().split() if word and word not in stop_words]
    words = [word for word in words if word]
    words = [wordnet_lemmatizer.lemmatize(w) for w in words] 

    return words

# %%
import gensim.downloader as api
model = api.load('glove-twitter-100')
# Out:
# [==================================================] 100.0% 387.1/387.1MB downloaded

# %%
model.similarity('crash', 'car')
# Out:
# 0.616397

# %%
model['mother']
# Out:
# array([ 0.44615  , -0.3426   , -0.16236  ,  0.70221  , -0.0063556,
#        -0.66198  ,  0.50239  ,  0.72514  ,  0.40139  , -0.19318  ,
#        -0.55705  ,  0.47563  , -3.7614   ,  0.062386 , -0.28429  ,
#         0.64277  ,  0.14114  , -0.17907  , -0.084768 ,  0.10419  ,
#         0.29275  , -0.56099  , -0.58851  ,  0.30293  ,  0.91432  ,
#         0.18194  ,  0.022049 , -0.26197  ,  0.17343  ,  0.13126  ,
#         0.088969 , -0.66559  , -0.038818 ,  0.23208  , -0.55856  ,
#         1.2076   ,  0.41975  ,  0.43664  , -0.18751  , -0.046753 ,
#        -0.23344  ,  0.15437  ,  0.14866  ,  0.11116  ,  0.31672  ,
#         0.23532  ,  0.73886  ,  0.32192  ,  0.27266  ,  0.26554  ,
#        -0.41621  ,  0.0088457, -0.035569 , -0.51636  ,  0.27591  ,
#        -0.26439  , -0.13055  ,  0.27277  , -0.16856  ,  0.48667  ,
#        -0.21558  ,  0.33781  ,  0.6418   , -0.1669   , -0.1454   ,
#         0.55402  , -0.19883  , -0.2383   ,  0.1369   ,  0.20284  ,
#         0.096421 , -0.7681   , -0.1644   ,  0.012845 ,  0.54505  ,
#        -0.086329 ,  0.037127 , -0.31277  , -0.44848  , -0.062021 ,
#         1.4831   ,  0.12172  ,  0.043023 ,  0.32032  , -0.48186  ,
#         0.18818  , -0.47621  ,  0.75735  , -0.24576  , -0.054743 ,
#         0.1499   , -0.72105  ,  0.22443  ,  0.25044  ,  0.45977  ,
#         0.61291  , -0.32129  ,  0.41959  , -0.28156  , -0.70013  ],
#       dtype=float32)

# %%
def lesk( word, sentence, debug = False, show_sentence = False,show_all = False):
    
    
    """Ваш код тут"""
    sentence =  sentence.split(" ")
    sentence = [w for w in sentence if not w in stop_words] 
    wordnet_lemmatizer = WordNetLemmatizer()
    sentence = [wordnet_lemmatizer.lemmatize(w) for w in sentence]
    
    bestsense = 0
    #maxoverlap = 0
    min_mean_overlap_dist = 100#начальная точка новой метрики
    final_definition = ''
    
    word_index = sentence.index(word)#индекс исследуемого слова в предложении
    
    #получаем часть речи для дальнейшего отграничения ранжира поиска
    #pos_sentence = nltk.pos_tag(sentence)
    #word_pos = get_pos(pos_sentence, word)
    #if (debug): print("word_pos", word_pos)
    
    for i, synset in enumerate(wn.synsets(word)):
        #if (debug): print(i, synset)
        comparison_data = []    
        current_definition = synset.definition()
        
        definition = tokenize(current_definition)
        #print(definition)
        #if (debug):print("DEFINITION FULL",current_definition)
        
        #if (debug):print("DEFINITION PROCESSED",definition)
        
        
        examples =  synset.examples()
        comparison_data = [tokenize(ex_snetence) for ex_snetence in examples]
        sentence_set = set(sentence)
        #if (show_sentence): print("SETENCE",  sentence)
        
        #if (debug): print(definition & sentence_set)
        mean_overlap_distance = 0
        comparison_data.append(definition)#теперь сюда входят и примеры и само значение
        #print(comparison_data) 
        comparison_data_set = [set(el) for el in comparison_data]
        if (show_sentence): print("SETENCE",  sentence)
        if (debug): print("START ITERATING OVER AL DATA")
        
        word_distance = []
        for comp_sentence_set,comp_sentence in zip(comparison_data_set, comparison_data):
            if (debug):print("comp_sentence:",' '.join(comp_sentence))
            overlap_words_set = sentence_set & comp_sentence_set
            if(word in overlap_words_set):
                overlap_words_set.remove(word)

            if (overlap_words_set and debug):print("overlap_words_set",overlap_words_set)
            for overlapped_word in overlap_words_set:
                if (debug): print("disambig_word_index = ", word_index)
                ind = sentence.index(overlapped_word)
                if (debug):print("overlapped_word = ", overlapped_word)
                if (debug): print("overlapped_word_ind", ind)
                abs_distance = abs(ind - word_index)
                if (debug): print("abs_distance", abs_distance)
                word_distance.append(abs_distance)  
        
        
        #overlap_len = len(overlap)
        if (debug): print("word_distance" , word_distance)
        #применяем новую метрику
        mean_overlap_distance = np.mean(word_distance) / len(word_distance)
        if (debug):
            if ( mean_overlap_distance == 0 or math.isnan(mean_overlap_distance) ): 
                print("ITERATING FINISHED.NO OVERLAP FOUND",'\n')
        if(mean_overlap_distance > 0):
            if (debug):print("OVERLAP_FOUND")
            if (debug):print("EXAMPLES_ORIGINAL = ", examples)
            if (debug):print("ALL_COMPAR_DATA = ", comparison_data)
            if (debug): print(i, synset)
            if (debug):print("DEFINITION FULL",current_definition)
            if (debug):print("DEFINITION PROCESSED",definition)
            if (show_sentence): print("SETENCE",  sentence)
            if (debug): print("mean_overlap_distance", mean_overlap_distance)
                
            if (debug): print("\n")
        
        #обновляем посчитанное значение если оно меньше предыдущего
        if (mean_overlap_distance < min_mean_overlap_dist):
            min_mean_overlap_dist = mean_overlap_distance
            bestsense = i
            final_definition = current_definition
    
    return bestsense, final_definition
lesk("break", "They break the rules in order to convince the rule-makers",debug = True, show_sentence = True)#True False
# Out:
# SETENCE ['They', 'break', 'rule', 'order', 'convince', 'rule-makers']
# START ITERATING OVER AL DATA
# comp_sentence: telephone annoying interruption
# comp_sentence: break action player hurt
# comp_sentence: abrupt occurrence interrupt ongoing activity
# word_distance []
# ITERATING FINISHED.NO OVERLAP FOUND
#
# SETENCE ['They', 'break', 'rule', 'order', 'convince', 'rule-makers']
# START ITERATING OVER AL DATA
# comp_sentence: finally got big break
# comp_sentence: unexpected piece good luck
# word_distance []
# ITERATING FINISHED.NO OVERLAP FOUND
#
# SETENCE ['They', 'break', 'rule', 'order', 'convince', 'rule-makers']
# START ITERATING OVER AL DATA
# comp_sentence: built right geological fault
# comp_sentence: studied faulting earth's crust
# comp_sentence: geology crack earth's crust resulting displacement one side respect
# word_distance []
# ITERATING FINISHED.NO OVERLAP FOUND
#
# SETENCE ['They', 'break', 'rule', 'order', 'convince', 'rule-makers']
# START ITERATING OVER AL DATA
# comp_sentence: hoped avoid break relation
# comp_sentence: personal social separation a opposing faction
# word_distance []
# ITERATING FINISHED.NO OVERLAP FOUND
#
# SETENCE ['They', 'break', 'rule', 'order', 'convince', 'rule-makers']
# START ITERATING OVER AL DATA
# comp_sentence: took 10-minute break
# comp_sentence: took time recuperate
# comp_sentence: pause something a work
# word_distance []
# ITERATING FINISHED.NO OVERLAP FOUND
#
# SETENCE ['They', 'break', 'rule', 'order', 'convince', 'rule-makers']
# START ITERATING OVER AL DATA
# comp_sentence: breakage unavoidable
# comp_sentence: act breaking something
# word_distance []
# ITERATING FINISHED.NO OVERLAP FOUND
#
# SETENCE ['They', 'break', 'rule', 'order', 'convince', 'rule-makers']
# START ITERATING OVER AL DATA
# comp_sentence: time interval temporary cessation something
# word_distance []
# ITERATING FINISHED.NO OVERLAP FOUND
#
# SETENCE ['They', 'break', 'rule', 'order', 'convince', 'rule-makers']
# START ITERATING OVER AL DATA
# comp_sentence: nasty fracture
# comp_sentence: break seems caused fall
# comp_sentence: breaking hard tissue bone
# word_distance []
# ITERATING FINISHED.NO OVERLAP FOUND
#
# SETENCE ['They', 'break', 'rule', 'order', 'convince', 'rule-makers']
# START ITERATING OVER AL DATA
# comp_sentence: break dam threatened valley
# comp_sentence: occurrence breaking
# word_distance []
# ITERATING FINISHED.NO OVERLAP FOUND
#
# SETENCE ['They', 'break', 'rule', 'order', 'convince', 'rule-makers']
# START ITERATING OVER AL DATA
# comp_sentence: break voice
# comp_sentence: abrupt change tone register voice a puberty due emotion
# word_distance []
# ITERATING FINISHED.NO OVERLAP FOUND
#
# SETENCE ['They', 'break', 'rule', 'order', 'convince', 'rule-makers']
# START ITERATING OVER AL DATA
# comp_sentence: opening shot scatter ball billiards pool
# word_distance []
# ITERATING FINISHED.NO OVERLAP FOUND
#
# SETENCE ['They', 'break', 'rule', 'order', 'convince', 'rule-makers']
# START ITERATING OVER AL DATA
# comp_sentence: two break second set
# comp_sentence: tennis score consisting winning game opponent serving
# word_distance []
# ITERATING FINISHED.NO OVERLAP FOUND
#
# SETENCE ['They', 'break', 'rule', 'order', 'convince', 'rule-makers']
# START ITERATING OVER AL DATA
# comp_sentence: presented without commercial break
# comp_sentence: gap account
# comp_sentence: act delaying interrupting continuity
# word_distance []
# ITERATING FINISHED.NO OVERLAP FOUND
#
# SETENCE ['They', 'break', 'rule', 'order', 'convince', 'rule-makers']
# START ITERATING OVER AL DATA
# comp_sentence: made break open door
# comp_sentence: sudden dash
# word_distance []
# ITERATING FINISHED.NO OVERLAP FOUND
#
# SETENCE ['They', 'break', 'rule', 'order', 'convince', 'rule-makers']
# START ITERATING OVER AL DATA
# comp_sentence: break eighth frame cost match
# comp_sentence: frame bowler fails make strike spare
# word_distance []
# ITERATING FINISHED.NO OVERLAP FOUND
#
# SETENCE ['They', 'break', 'rule', 'order', 'convince', 'rule-makers']
# START ITERATING OVER AL DATA
# comp_sentence: breakout carefully planned
# comp_sentence: escape jail
# word_distance []
# ITERATING FINISHED.NO OVERLAP FOUND
#
# SETENCE ['They', 'break', 'rule', 'order', 'convince', 'rule-makers']
# START ITERATING OVER AL DATA
# comp_sentence: interrupted pregnancy
# comp_sentence: break lucky streak
# comp_sentence: break cycle poverty
# comp_sentence: terminate
# word_distance []
# ITERATING FINISHED.NO OVERLAP FOUND
#
# SETENCE ['They', 'break', 'rule', 'order', 'convince', 'rule-makers']
# START ITERATING OVER AL DATA
# comp_sentence: figurine broke
# comp_sentence: freshly baked loaf fell apart
# comp_sentence: become separated piece fragment
# word_distance []
# ITERATING FINISHED.NO OVERLAP FOUND
#
# SETENCE ['They', 'break', 'rule', 'order', 'convince', 'rule-makers']
# START ITERATING OVER AL DATA
# comp_sentence: broke alarm clock took apart
# comp_sentence: render inoperable ineffective
# word_distance []
# ITERATING FINISHED.NO OVERLAP FOUND
#
# SETENCE ['They', 'break', 'rule', 'order', 'convince', 'rule-makers']
# START ITERATING OVER AL DATA
# comp_sentence: busted radio
# comp_sentence: ruin completely
# word_distance []
# ITERATING FINISHED.NO OVERLAP FOUND
#
# SETENCE ['They', 'break', 'rule', 'order', 'convince', 'rule-makers']
# START ITERATING OVER AL DATA
# comp_sentence: broke glass plate
# comp_sentence: broke match
# comp_sentence: destroy integrity of usually force cause separate piece fragment
# word_distance []
# ITERATING FINISHED.NO OVERLAP FOUND
#
# SETENCE ['They', 'break', 'rule', 'order', 'convince', 'rule-makers']
# START ITERATING OVER AL DATA
# comp_sentence: offend law humanity
# comp_sentence: violate basic law human civilization
# comp_sentence: break law
# comp_sentence: break promise
# comp_sentence: act disregard law rule contract promise
# overlap_words_set {'rule'}
# disambig_word_index =  1
# overlapped_word =  rule
# overlapped_word_ind 2
# abs_distance 1
# word_distance [1]
# OVERLAP_FOUND
# EXAMPLES_ORIGINAL =  ['offend all laws of humanity', 'violate the basic laws or human civilization', 'break a law', 'break a promise']
# ALL_COMPAR_DATA =  [['offend', 'law', 'humanity'], ['violate', 'basic', 'law', 'human', 'civilization'], ['break', 'law'], ['break', 'promise'], ['act', 'disregard', 'law', 'rule', 'contract', 'promise']]
# 21 Synset('transgress.v.01')
# DEFINITION FULL act in disregard of laws, rules, contracts, or promises
# DEFINITION PROCESSED ['act', 'disregard', 'law', 'rule', 'contract', 'promise']
# SETENCE ['They', 'break', 'rule', 'order', 'convince', 'rule-makers']
# mean_overlap_distance 1.0
#
#
# SETENCE ['They', 'break', 'rule', 'order', 'convince', 'rule-makers']
# START ITERATING OVER AL DATA
# comp_sentence: horse broke stable
# comp_sentence: three inmate broke jail
# comp_sentence: nobody break out--this prison high security
# comp_sentence: move away escape suddenly
# word_distance []
# ITERATING FINISHED.NO OVERLAP FOUND
#
# SETENCE ['They', 'break', 'rule', 'order', 'convince', 'rule-makers']
# START ITERATING OVER AL DATA
# comp_sentence: cloud broke heavy downpour
# comp_sentence: scatter part
# word_distance []
# ITERATING FINISHED.NO OVERLAP FOUND
#
# SETENCE ['They', 'break', 'rule', 'order', 'convince', 'rule-makers']
# START ITERATING OVER AL DATA
# comp_sentence: break tear
# comp_sentence: erupt anger
# comp_sentence: force release suddenly often violently something pent
# word_distance []
# ITERATING FINISHED.NO OVERLAP FOUND
#
# SETENCE ['They', 'break', 'rule', 'order', 'convince', 'rule-makers']
# START ITERATING OVER AL DATA
# comp_sentence: stop project
# comp_sentence: break negotiation
# comp_sentence: prevent completion
# word_distance []
# ITERATING FINISHED.NO OVERLAP FOUND
#
# SETENCE ['They', 'break', 'rule', 'order', 'convince', 'rule-makers']
# START ITERATING OVER AL DATA
# comp_sentence: someone broke vacation
# comp_sentence: broke car stole radio
# comp_sentence: broke account last night
# comp_sentence: enter someone's virtual real property unauthorized manner usually intent steal commit violent act
# word_distance []
# ITERATING FINISHED.NO OVERLAP FOUND
#
# SETENCE ['They', 'break', 'rule', 'order', 'convince', 'rule-makers']
# START ITERATING OVER AL DATA
# comp_sentence: horse tough break
# comp_sentence: broke new intern
# comp_sentence: make submissive obedient useful
# word_distance []
# ITERATING FINISHED.NO OVERLAP FOUND
#
# SETENCE ['They', 'break', 'rule', 'order', 'convince', 'rule-makers']
# START ITERATING OVER AL DATA
# comp_sentence: sentence violates rule syntax
# overlap_words_set {'rule'}
# disambig_word_index =  1
# overlapped_word =  rule
# overlapped_word_ind 2
# abs_distance 1
# comp_sentence: fail agree with violation of rule pattern
# overlap_words_set {'rule'}
# disambig_word_index =  1
# overlapped_word =  rule
# overlapped_word_ind 2
# abs_distance 1
# word_distance [1, 1]
# OVERLAP_FOUND
# EXAMPLES_ORIGINAL =  ['This sentence violates the rules of syntax']
# ALL_COMPAR_DATA =  [['sentence', 'violates', 'rule', 'syntax'], ['fail', 'agree', 'with', 'violation', 'of', 'rule', 'pattern']]
# 28 Synset('violate.v.01')
# DEFINITION FULL fail to agree with; be in violation of; as of rules or patterns
# DEFINITION PROCESSED ['fail', 'agree', 'with', 'violation', 'of', 'rule', 'pattern']
# SETENCE ['They', 'break', 'rule', 'order', 'convince', 'rule-makers']
# mean_overlap_distance 0.5
#
#
# SETENCE ['They', 'break', 'rule', 'order', 'convince', 'rule-makers']
# START ITERATING OVER AL DATA
# comp_sentence: bettered record
# comp_sentence: break record
# comp_sentence: surpass excellence
# word_distance []
# ITERATING FINISHED.NO OVERLAP FOUND
#
# SETENCE ['They', 'break', 'rule', 'order', 'convince', 'rule-makers']
# START ITERATING OVER AL DATA
# comp_sentence: auction house would disclose price van gogh sold
# comp_sentence: actress reveal old
# comp_sentence: bring truth
# comp_sentence: broke news
# comp_sentence: unwrap evidence murder case
# comp_sentence: make known public information previously known people meant kept secret
# word_distance []
# ITERATING FINISHED.NO OVERLAP FOUND
#
# SETENCE ['They', 'break', 'rule', 'order', 'convince', 'rule-makers']
# START ITERATING OVER AL DATA
# comp_sentence: light broke horizon
# comp_sentence: voice broke air
# comp_sentence: come
# word_distance []
# ITERATING FINISHED.NO OVERLAP FOUND
#
# SETENCE ['They', 'break', 'rule', 'order', 'convince', 'rule-makers']
# START ITERATING OVER AL DATA
# comp_sentence: engine finally went
# comp_sentence: car died road
# comp_sentence: bus travelled broke way town
# comp_sentence: coffee maker broke
# comp_sentence: engine failed way town
# comp_sentence: eyesight went accident
# comp_sentence: stop operating functioning
# word_distance []
# ITERATING FINISHED.NO OVERLAP FOUND
#
# SETENCE ['They', 'break', 'rule', 'order', 'convince', 'rule-makers']
# START ITERATING OVER AL DATA
# comp_sentence: broken traditional pattern
# comp_sentence: interrupt continued activity
# word_distance []
# ITERATING FINISHED.NO OVERLAP FOUND
#
# SETENCE ['They', 'break', 'rule', 'order', 'convince', 'rule-makers']
# START ITERATING OVER AL DATA
# comp_sentence: rank broke
# comp_sentence: make rupture rank enemy one's quitting fleeing
# word_distance []
# ITERATING FINISHED.NO OVERLAP FOUND
#
# SETENCE ['They', 'break', 'rule', 'order', 'convince', 'rule-makers']
# START ITERATING OVER AL DATA
# comp_sentence: surf broke
# comp_sentence: curl fall apart surf foam wave
# word_distance []
# ITERATING FINISHED.NO OVERLAP FOUND
#
# SETENCE ['They', 'break', 'rule', 'order', 'convince', 'rule-makers']
# START ITERATING OVER AL DATA
# comp_sentence: soften shock
# comp_sentence: break fall
# comp_sentence: lessen force effect
# word_distance []
# ITERATING FINISHED.NO OVERLAP FOUND
#
# SETENCE ['They', 'break', 'rule', 'order', 'convince', 'rule-makers']
# START ITERATING OVER AL DATA
# comp_sentence: new teacher break we'll add stress
# comp_sentence: broken
# word_distance []
# ITERATING FINISHED.NO OVERLAP FOUND
#
# SETENCE ['They', 'break', 'rule', 'order', 'convince', 'rule-makers']
# START ITERATING OVER AL DATA
# comp_sentence: heat wave finally broke yesterday
# comp_sentence: come end
# word_distance []
# ITERATING FINISHED.NO OVERLAP FOUND
#
# SETENCE ['They', 'break', 'rule', 'order', 'convince', 'rule-makers']
# START ITERATING OVER AL DATA
# comp_sentence: flat plain broken tall mesa
# comp_sentence: vary interrupt uniformity continuity
# word_distance []
# ITERATING FINISHED.NO OVERLAP FOUND
#
# SETENCE ['They', 'break', 'rule', 'order', 'convince', 'rule-makers']
# START ITERATING OVER AL DATA
# comp_sentence: finally broke smoking cigarette
# comp_sentence: cause give habit
# word_distance []
# ITERATING FINISHED.NO OVERLAP FOUND
#
# SETENCE ['They', 'break', 'rule', 'order', 'convince', 'rule-makers']
# START ITERATING OVER AL DATA
# comp_sentence: break cigarette smoking
# comp_sentence: give
# word_distance []
# ITERATING FINISHED.NO OVERLAP FOUND
#
# SETENCE ['They', 'break', 'rule', 'order', 'convince', 'rule-makers']
# START ITERATING OVER AL DATA
# comp_sentence: first winter storm broke new york
# comp_sentence: come forth begin state latency
# word_distance []
# ITERATING FINISHED.NO OVERLAP FOUND
#
# SETENCE ['They', 'break', 'rule', 'order', 'convince', 'rule-makers']
# START ITERATING OVER AL DATA
# comp_sentence: thing breaking pretty well u past month
# comp_sentence: happen take place
# word_distance []
# ITERATING FINISHED.NO OVERLAP FOUND
#
# SETENCE ['They', 'break', 'rule', 'order', 'convince', 'rule-makers']
# START ITERATING OVER AL DATA
# comp_sentence: peccadillo finally broke marriage
# comp_sentence: play either make break playwright
# comp_sentence: cause failure ruin
# word_distance []
# ITERATING FINISHED.NO OVERLAP FOUND
#
# SETENCE ['They', 'break', 'rule', 'order', 'convince', 'rule-makers']
# START ITERATING OVER AL DATA
# comp_sentence: broken
# comp_sentence: invalidate judicial action
# word_distance []
# ITERATING FINISHED.NO OVERLAP FOUND
#
# SETENCE ['They', 'break', 'rule', 'order', 'convince', 'rule-makers']
# START ITERATING OVER AL DATA
# comp_sentence: business partner broke tax question
# comp_sentence: couple separated 25 year marriage
# comp_sentence: friend split
# comp_sentence: discontinue association relation go different way
# word_distance []
# ITERATING FINISHED.NO OVERLAP FOUND
#
# SETENCE ['They', 'break', 'rule', 'order', 'convince', 'rule-makers']
# START ITERATING OVER AL DATA
# comp_sentence: demoted always speaks
# comp_sentence: broken sergeant
# comp_sentence: assign lower position reduce rank
# word_distance []
# ITERATING FINISHED.NO OVERLAP FOUND
#
# SETENCE ['They', 'break', 'rule', 'order', 'convince', 'rule-makers']
# START ITERATING OVER AL DATA
# comp_sentence: daughter's fancy wedding going break me
# comp_sentence: slump financial market smashed
# comp_sentence: reduce bankruptcy
# word_distance []
# ITERATING FINISHED.NO OVERLAP FOUND
#
# SETENCE ['They', 'break', 'rule', 'order', 'convince', 'rule-makers']
# START ITERATING OVER AL DATA
# comp_sentence: change direction suddenly
# word_distance []
# ITERATING FINISHED.NO OVERLAP FOUND
#
# SETENCE ['They', 'break', 'rule', 'order', 'convince', 'rule-makers']
# START ITERATING OVER AL DATA
# comp_sentence: whale broke
# comp_sentence: emerge surface body water
# word_distance []
# ITERATING FINISHED.NO OVERLAP FOUND
#
# SETENCE ['They', 'break', 'rule', 'order', 'convince', 'rule-makers']
# START ITERATING OVER AL DATA
# comp_sentence: wall collapsed
# comp_sentence: business collapsed
# comp_sentence: dam broke
# comp_sentence: roof collapsed
# comp_sentence: wall gave
# comp_sentence: roof finally gave weight ice
# comp_sentence: break down literally metaphorically
# word_distance []
# ITERATING FINISHED.NO OVERLAP FOUND
#
# SETENCE ['They', 'break', 'rule', 'order', 'convince', 'rule-makers']
# START ITERATING OVER AL DATA
# comp_sentence: kid break-dancing street corner
# comp_sentence: break dance
# word_distance []
# ITERATING FINISHED.NO OVERLAP FOUND
#
# SETENCE ['They', 'break', 'rule', 'order', 'convince', 'rule-makers']
# START ITERATING OVER AL DATA
# comp_sentence: break 100 bill buy candy
# comp_sentence: exchange smaller unit money
# word_distance []
# ITERATING FINISHED.NO OVERLAP FOUND
#
# SETENCE ['They', 'break', 'rule', 'order', 'convince', 'rule-makers']
# START ITERATING OVER AL DATA
# comp_sentence: book dealer would break set
# comp_sentence: destroy completeness set related item
# word_distance []
# ITERATING FINISHED.NO OVERLAP FOUND
#
# SETENCE ['They', 'break', 'rule', 'order', 'convince', 'rule-makers']
# START ITERATING OVER AL DATA
# comp_sentence: make opening shot scatter ball
# word_distance []
# ITERATING FINISHED.NO OVERLAP FOUND
#
# SETENCE ['They', 'break', 'rule', 'order', 'convince', 'rule-makers']
# START ITERATING OVER AL DATA
# comp_sentence: referee broke boxer
# comp_sentence: separate clinch boxing
# word_distance []
# ITERATING FINISHED.NO OVERLAP FOUND
#
# SETENCE ['They', 'break', 'rule', 'order', 'convince', 'rule-makers']
# START ITERATING OVER AL DATA
# comp_sentence: lawn mower finally broke
# comp_sentence: gear wore
# comp_sentence: old chair finally fell apart completely
# comp_sentence: go piece
# word_distance []
# ITERATING FINISHED.NO OVERLAP FOUND
#
# SETENCE ['They', 'break', 'rule', 'order', 'convince', 'rule-makers']
# START ITERATING OVER AL DATA
# comp_sentence: break branch tree
# comp_sentence: break piece whole
# word_distance []
# ITERATING FINISHED.NO OVERLAP FOUND
#
# SETENCE ['They', 'break', 'rule', 'order', 'convince', 'rule-makers']
# START ITERATING OVER AL DATA
# comp_sentence: skin broke
# comp_sentence: become punctured penetrated
# word_distance []
# ITERATING FINISHED.NO OVERLAP FOUND
#
# SETENCE ['They', 'break', 'rule', 'order', 'convince', 'rule-makers']
# START ITERATING OVER AL DATA
# comp_sentence: blade broke skin
# comp_sentence: pierce penetrate
# word_distance []
# ITERATING FINISHED.NO OVERLAP FOUND
#
# SETENCE ['They', 'break', 'rule', 'order', 'convince', 'rule-makers']
# START ITERATING OVER AL DATA
# comp_sentence: news death broke morning
# comp_sentence: released become known news
# word_distance []
# ITERATING FINISHED.NO OVERLAP FOUND
#
# SETENCE ['They', 'break', 'rule', 'order', 'convince', 'rule-makers']
# START ITERATING OVER AL DATA
# comp_sentence: pause station identification
# comp_sentence: let's break lunch
# comp_sentence: cease action temporarily
# word_distance []
# ITERATING FINISHED.NO OVERLAP FOUND
#
# SETENCE ['They', 'break', 'rule', 'order', 'convince', 'rule-makers']
# START ITERATING OVER AL DATA
# comp_sentence: break circuit
# comp_sentence: interrupt flow current
# word_distance []
# ITERATING FINISHED.NO OVERLAP FOUND
#
# SETENCE ['They', 'break', 'rule', 'order', 'convince', 'rule-makers']
# START ITERATING OVER AL DATA
# comp_sentence: simple vowel broke many germanic language
# comp_sentence: undergo breaking
# word_distance []
# ITERATING FINISHED.NO OVERLAP FOUND
#
# SETENCE ['They', 'break', 'rule', 'order', 'convince', 'rule-makers']
# START ITERATING OVER AL DATA
# comp_sentence: break alibi
# comp_sentence: break proof
# comp_sentence: find flaw
# word_distance []
# ITERATING FINISHED.NO OVERLAP FOUND
#
# SETENCE ['They', 'break', 'rule', 'order', 'convince', 'rule-makers']
# START ITERATING OVER AL DATA
# comp_sentence: break code
# comp_sentence: find solution key
# word_distance []
# ITERATING FINISHED.NO OVERLAP FOUND
#
# SETENCE ['They', 'break', 'rule', 'order', 'convince', 'rule-makers']
# START ITERATING OVER AL DATA
# comp_sentence: voice broke whisper started talk child
# comp_sentence: change suddenly one tone quality register another
# word_distance []
# ITERATING FINISHED.NO OVERLAP FOUND
#
# SETENCE ['They', 'break', 'rule', 'order', 'convince', 'rule-makers']
# START ITERATING OVER AL DATA
# comp_sentence: report news develops
# comp_sentence: political movement recrudesce time time
# comp_sentence: happen
# word_distance []
# ITERATING FINISHED.NO OVERLAP FOUND
#
# SETENCE ['They', 'break', 'rule', 'order', 'convince', 'rule-makers']
# START ITERATING OVER AL DATA
# comp_sentence: glass cracked heated
# comp_sentence: become fractured break crack surface
# word_distance []
# ITERATING FINISHED.NO OVERLAP FOUND
#
# SETENCE ['They', 'break', 'rule', 'order', 'convince', 'rule-makers']
# START ITERATING OVER AL DATA
# comp_sentence: voice breaking--he longer sing choir
# comp_sentence: crack male voice puberty
# word_distance []
# ITERATING FINISHED.NO OVERLAP FOUND
#
# SETENCE ['They', 'break', 'rule', 'order', 'convince', 'rule-makers']
# START ITERATING OVER AL DATA
# comp_sentence: stock price broke
# comp_sentence: fall sharply
# word_distance []
# ITERATING FINISHED.NO OVERLAP FOUND
#
# SETENCE ['They', 'break', 'rule', 'order', 'convince', 'rule-makers']
# START ITERATING OVER AL DATA
# comp_sentence: broke foot playing hockey
# comp_sentence: fracture bone
# word_distance []
# ITERATING FINISHED.NO OVERLAP FOUND
#
# SETENCE ['They', 'break', 'rule', 'order', 'convince', 'rule-makers']
# START ITERATING OVER AL DATA
# comp_sentence: patient's fever broke last night
# comp_sentence: diminish discontinue abruptly
# word_distance []
# ITERATING FINISHED.NO OVERLAP FOUND
#
# SETENCE ['They', 'break', 'rule', 'order', 'convince', 'rule-makers']
# START ITERATING OVER AL DATA
# comp_sentence: resistance broken
# comp_sentence: man broken terrible experience near-death
# comp_sentence: weaken destroy spirit body
# word_distance []
# ITERATING FINISHED.NO OVERLAP FOUND
# (28, 'fail to agree with; be in violation of; as of rules or patterns')
