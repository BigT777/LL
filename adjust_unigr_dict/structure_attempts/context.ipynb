# %%
import requests
import json
from bs4 import BeautifulSoup as bs
import time
import random
import re

# %%
re.findall("\Wbook\w{0,2}\W", "he is a bookmaker of the book kkk")
# Out:
# [' book ']

# %%
'book' in "has published as a co-author with Ra-Ma the book enti"
# Out:
# True

# %%
def get_definitions(word, from_lang, to_lang):
    url = "https://context.reverso.net/перевод/" + from_lang + "-" + to_lang + "/" + word 
    login = {'inUserName': 'n.babakov@lingualeo.com', 'inUserPass': '33vec33'}
    header_main = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/537.36'}
    response = requests.get(url, headers=header_main, data = login)
    response.encoding = 'utf-8' 
    soup = bs(response.text, 'html.parser')
    first_string_passed = False
    translations_variants = []
    for link in soup.find_all("a", attrs={"class" : "translation"}):
        if first_string_passed == True:
            sence_word = link.text.strip()
            print(sence_word)
            translations_variants.append(sence_word)
        first_string_passed = True
    time.sleep(2)
    for transl_word in translations_variants:
        time.sleep(random.uniform(0.4,2.9))
        url_example = "https://context.reverso.net/перевод/" + to_lang + "-" + from_lang + "/" + transl_word
        response_ex = requests.get(url_example, headers=header_main)
        soup_sub = bs(response_ex.text, 'html.parser')
        print("========================================")
        print("\nEXAMPLES FOR SENCE ",transl_word,"\n" )
        for l in soup_sub.find_all('span', attrs = {'class':'text', 'lang':'en'}):
            example = l.text.strip()
            #print(example, word in example, type(l.text.strip()), word)
            regex = "\W" + word + "\w{0,2}\W"
            find = re.findall(regex, example)
            if len(find) > 0 :
                print(example)
        
 
get_definitions("mothers", "русский", "английский")
# Out:
# матерей
# матери
# матерям
# матерями
# женщин
# материнства
# мать
# женщины
# мамы
# женщинам
# матерях
# матерью
# мам
# женщин-матерей
# мамами
# ========================================
#
# EXAMPLES FOR SENCE  матерей
#
# After the mothers come back here, the depression is almost unbearable.
# We're here to serve the mothers and babies of the district.
# Of concern to the Special Rapporteur is the situation of babies who are born to unmarried mothers.
# The doctor's symptoms were identical to those of the mothers who were dying.
# This should make it possible to optimize health care delivery for mothers and children in particular.
# The children born of HIV-positive mothers are provided with artificial feeding free of charge.
# Midwives were trained to check on the psychological welfare of new mothers and to offer them assistance if required.
# There is also a lack of sanitary facilities especially for pregnant and lactating mothers.
# Switzerland encourages cultural and language studies, and has set up programmes for mothers and children.
# Evening classes are the only way for single mothers to continue their education.
# Obviously, the situation regarding children is directly related to the status of their mothers.
# Owing to the strong interest from mothers, such meetings were organized in different regions of Poland.
# Every year, the foundation runs a health education programme for children and mothers.
# It is important to shed a new light on mothers and the significant role that they play in the well-being of society.
# By the end of 2010, the programme had reached more than 250,000 mothers.
# For approximately 73 per cent of the HIV-positive children, the transmission has occurred through their mothers.
# ========================================
#
# EXAMPLES FOR SENCE  матери
#
# For example, mothers living with HIV are able to give birth to uninfected children.
# The protection of the health of mothers and children is a very important indicator of a country's level of social and economic well-being.
# The opinion of mothers or fathers deprived of their liberty is taken into account.
# The project also provides some day care services to babies whose mothers are enrolled into the programme.
# The health indicators for mothers and children improved.
# ========================================
#
# EXAMPLES FOR SENCE  матерям
#
# The mothers are given a longer period of leave with pay after the childbirth.
# A lump-sum allowance is payable to all mothers on the birth of a child.
# At the convention recommendations were adopted urging all those involved in this type of proceedings to pay special attention to equal treatment of fathers and mothers.
# This precarious situation prevents many mothers from working in the formal sector.
# It is also forbidden to give these items to mothers and family members.
# Maternity protection standards have been improving over time, with more countries providing benefits to mothers following the birth of a child.
# Our income distribution programmes place mothers as the central figures in the scheme.
# All teenage mothers are allowed to return to school after the birth of their children.
# Article 9 prohibits the abandonment of children by mothers infected with HIV/AIDS.
# This is as a result of the change in society's attitude to unmarried mothers and abortion in addition to improved methods of contraception.
# There is no written regulation which prohibits teen mothers from attending school.
# From April, 2004 free ARV drugs have been made available to mothers living with HIV.
# These expectant mothers are usually given tetanus toxoid after the first trimester of pregnancy.
# The system of higher education provides social guarantees to studying mothers.
# This kind of pension is allocated to 191,500 mothers and amounts to the sum of 80.70 euros per month.
# Providing our mothers and babies with the very best care.
# I like to show my mothers what's available.
# ========================================
#
# EXAMPLES FOR SENCE  матерями
#
# Please include information on the enjoyment of the right to education by pregnant girls and young mothers.
# The increase in the number of HIV-positive women of reproductive age has led to an increase in children born of HIV-positive mothers.
# It should be noted that the mothers and widows of victims of the national tragedy constitute the majority of those beneficiaries.
# Efforts have been made to address the special difficulties encountered by mothers living in poverty.
# There is a general prohibition to assign pregnant women or breastfeeding mothers to certain jobs.
# You embarrassed me in front of all the other mothers.
# You are stuck with two mothers, whether you like it or not.
# The incidence of young mothers or pregnant women among adolescents with primary schooling is 30.6 per cent.
# The number of lawsuits brought before the courts by pregnant women or mothers of small children who had been wrongfully dismissed was increasing.
# Listen to these letters sent by Russian mothers to their sons on the front.
# Got to be firm with the mothers, too.
# Every spring, the Emissary holds a ceremony to bless the women who want to be mothers.
# By the end of 2004, over 15,000 children were born to HIV-infected mothers.
# Certain instances of mothers leaving their children in hospital had been cited.
# Some of us aren't cut out to be mothers.
# ========================================
#
# EXAMPLES FOR SENCE  женщин
#
# ========================================
#
# EXAMPLES FOR SENCE  материнства
#
# ========================================
#
# EXAMPLES FOR SENCE  мать
#
# ========================================
#
# EXAMPLES FOR SENCE  женщины
#
# ========================================
#
# EXAMPLES FOR SENCE  мамы
#
# ========================================
#
# EXAMPLES FOR SENCE  женщинам
#
# ========================================
#
# EXAMPLES FOR SENCE  матерях
#
# Families have the obligation to take care of mothers and children to ensure their good health.
# That is why you were asking about the absentee mothers.
# Speakin' of mothers, let me give that oatmeal some brown sugar.
# They... they don't even think about their birth mothers.
# And I'm going to talk about annual pregnancies and HIV-positive mothers.
# All of these conditions affect mothers, families and communities in the context of their relationships and in psychological, emotional and financial terms.
# The burden of unpaid care work for mothers is higher in developing countries, where such work too often compensates for the lack of public infrastructures and services.
# Breastfeeding mothers - additional breaks every 3 hours for a period of no less than 30 minutes;
# I don't think most people could say that about their mothers.
# However, in collecting gender disaggregated data, there was a tendency to focus on women as mothers.
# The community and the Peruvian State afford special protection to children, adolescents, mothers and elderly persons who have been abandoned.
# You want to talk about crazy mothers, Leonard's mom wouldn't give him any sort of approval growing up.
# It makes me think of the horrible, frigid stage mothers who forced the babies into it.
# Sons do grow up to marry their mothers.
# We are talking about human beings, babies and mothers.
# I know more about mothers than he does.
# If my subjects to marry their mothers, we would have fewer divorces.
# All this talk about mothers, I'm not in the mood.
# Yes, I know all about mothers.
# I think all daughters feel that way about their mothers.
# ========================================
#
# EXAMPLES FOR SENCE  матерью
#
# ========================================
#
# EXAMPLES FOR SENCE  мам
#
# ========================================
#
# EXAMPLES FOR SENCE  женщин-матерей
#
# It also protects and advocates the interests of mothers in national and international forums.
# The State manifests its concern for the situation of mothers primarily through the labour legislation.
# The State pays particular attention to protection of the rights of mothers.
# A special system of guarantees was set up by law with regard to mothers.
# The Committee is also concerned that HIV/AIDS infection rates for mothers and children are on the rise.
# It should be noted that national criminal law contains no discriminatory provisions; what's more, the Criminal Code includes norms that take into account the physiological features of women and mothers.
# It supports initiatives that encourage mothers to take their rightful place in local and national structures warranted by their particular expertise as mothers.
# The Labor Standards Law, which applies to all workers, stipulates the following measures to protect mothers:
# Medical institutions under national supervision provide inpatient and consultative (outpatient) care for all children and mothers;
# The situation of mothers showed how important it was that international and national strategies should provide not only for gender equality, but also for the various social categories of women.
# Groups of mothers were formed in the areas most affected by violence and movement restrictions, such as those in the proximity of settlements or the wall.
# The principal institutions under municipal supervision providing care for children and mothers are: children's hospitals, children's polyclinics, maternity homes and prenatal clinics;
# In Zambia, an MTCT project in three districts has resulted in an increase in the number of mothers tested and undergoing treatment, and has been fully adopted by district authorities.
# The WMM "Living Together Agenda" has also been considered as a tool for wide-ranging cooperation among elected officials, social workers and mothers.
# The focus is on providing vocational training for the following categories of unemployed persons: youth, the long-term unemployed, persons with disabilities, single parents, parents with large families and mothers.
# The Committee expresses concern about food taboos, which are not only detrimental to the health of women, especially mothers, but also have serious consequences for the health of future generations.
# Activities Discussion groups are organized specifically and separately for women, men, women along with other immigrants who do not reside in the asylum network, single women who share a dormitory, or mothers.
# In this area, the Ministry of Women has become an advocate of mothers' right to breastfeed their babies.
# ========================================
#
# EXAMPLES FOR SENCE  мамами
#
# I know you'll want to come back with your mothers.
# No, sons don't usually sleep with their mothers.
# Well, mothers aren't always easy to live with.
# Though nowadays, even schoolgirls become mothers.
# You've dealt with unmarried mothers before.
# Thought maybe we could start by talking to their mothers, Look for fences missing a gate.

# %%
БОЛЬШЕ ПРИМЕРОВ И САМОЙ СТРАНИЦЫ

# %%
url = "https://context.reverso.net/перевод/русский-английский/наличие" 
login = {'inUserName': 'n.babakov@lingualeo.com', 'inUserPass': '33vec33'}
header_main = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/537.36'}
response = requests.get(url, headers=header_main, data = login)
response.encoding = 'utf-8' 
soup = bs(response.text, 'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="ru">
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <title>
#    наличие - Перевод на английский - примеры русский | Reverso Context
#   </title>
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
#   <meta content='Перевод контекст "наличие" c русский на английский от Reverso Context: обеспечить наличие, несмотря на наличие, является наличие, также наличие, предполагает наличие' name="description"/>
#   <link href="https://context.reverso.net/%D0%BF%D0%B5%D1%80%D0%B5%D0%B2%D0%BE%D0%B4/%D1%80%D1%83%D1%81%D1%81%D0%BA%D0%B8%D0%B9-%D0%B0%D0%BD%D0%B3%D0%BB%D0%B8%D0%B9%D1%81%D0%BA%D0%B8%D0%B9/%D0%BD%D0%B0%D0%BB%D0%B8%D1%87%D0%B8%D0%B5" hreflang="ru" rel="alternate"/>
#   <link href="https://context.reverso.net/translation/russian-english/%D0%BD%D0%B0%D0%BB%D0%B8%D1%87%D0%B8%D0%B5" hreflang="en" rel="alternate"/>
#   <link href="android-app://com.softissimo.reverso.context/reversocontext/context.reverso.net/%D0%BF%D0%B5%D1%80%D0%B5%D0%B2%D0%BE%D0%B4/%D1%80%D1%83%D1%81%D1%81%D0%BA%D0%B8%D0%B9-%D0%B0%D0%BD%D0%B3%D0%BB%D0%B8%D0%B9%D1%81%D0%BA%D0%B8%D0%B9/%D0%BD%D0%B0%D0%BB%D0%B8%D1%87%D0%B8%D0%B5" rel="alternate"/>
#   <meta content="app-id=919979642, app-argument=reversocontext://context.reverso.net/%D0%BF%D0%B5%D1%80%D0%B5%D0%B2%D0%BE%D0%B4/%D1%80%D1%83%D1%81%D1%81%D0%BA%D0%B8%D0%B9-%D0%B0%D0%BD%D0%B3%D0%BB%D0%B8%D0%B9%D1%81%D0%BA%D0%B8%D0%B9/%D0%BD%D0%B0%D0%BB%D0%B8%D1%87%D0%B8%D0%B5" name="apple-itunes-app"/>
#   <link href="/%D0%BF%D0%B5%D1%80%D0%B5%D0%B2%D0%BE%D0%B4/%D1%80%D1%83%D1%81%D1%81%D0%BA%D0%B8%D0%B9-%D0%B0%D0%BD%D0%B3%D0%BB%D0%B8%D0%B9%D1%81%D0%BA%D0%B8%D0%B9/%D0%BD%D0%B0%D0%BB%D0%B8%D1%87%D0%B8%D0%B5" rel="canonical"/>
#   <script type="text/javascript">
#    var request = {
#     srctext: "\u043D\u0430\u043B\u0438\u0447\u0438\u0435",
#     trgtext: "",
#     srclang: "ru",
#     trglang: "en",
#     rpage: 1,
#     rmode: 0,
#     original: "\u043D\u0430\u043B\u0438\u0447\u0438\u0435"
#   };
#   </script>
#   <meta content="значение слова, перевод в контексте, перевод онлайн, Reverso Context, идиомы в контексте, инструмент поиска переводов, идиоматический перевод, перевод идиом, пример перевода, примеры перевода, Английский, Французский, Испанский, Иврит, Русский, Арабский, Португальский, Итальянский, Немецкий, Голландский, Польский, Иврит, идиоматические переводы, двуязычный конкорданс, контекстный словарь, пример употребления, примеры употребления, перевод в контексте, любители языка, контекстный пример, идиоматические выражения, словарь, примеры и идиомы, инструмент составления конкорданса" name="keywords"/>
#   <meta content="app-id=com.softissimo.reverso.context" name="google-play-app"/>
#   <meta content="notranslate" name="google">
#    <meta content="initial-scale=1.0" name="viewport"/>
#    <link href="https://cdn.reverso.net/context/v51300/images/reverso-context-logo-for-facebook.png" rel="image_src"/>
#    <link href="https://cdn.reverso.net/context/v51300/images/reverso-context.ico" rel="shortcut icon"/>
#    <link href="https://cdn.reverso.net/context/v51300/images/reverso-context-app-fav-apple.png" rel="apple-touch-icon"/>
#    <link href="https://cdn.reverso.net/context/v51300/images/reverso-context-app-fav-apple-16x16.png" rel="apple-touch-icon" sizes="16x16"/>
#    <link href="https://cdn.reverso.net/context/v51300/images/reverso-context-app-fav-apple-72x72.png" rel="apple-touch-icon" sizes="72x72"/>
#    <link href="https://cdn.reverso.net/context/v51300/images/reverso-context-app-fav-apple-114x114.png" rel="apple-touch-icon" sizes="114x114"/>
#    <style class="font-family">
#     @font-face{font-family:'contexticons';font-display: swap;src:url('https://cdn.reverso.net/context/v51300/fonts/contexticons.eot?phzsmg');src:url('https://cdn.reverso.net/context/v51300/fonts/contexticons.eot?phzsmg#iefix') format('embedded-opentype'),url('https://cdn.reverso.net/context/v51300/fonts/contexticons.ttf?phzsmg') format('truetype'),url('https://cdn.reverso.net/context/v51300/fonts/contexticons.woff?phzsmg') format('woff'),url('https://cdn.reverso.net/context/v51300/fonts/contexticons.svg?phzsmg#contexticons') format('svg');font-weight: normal;font-style: normal;}
#    </style>
#    <link href="https://fonts.googleapis.com/css?family=Montserrat:300,400,500,700|Roboto+Condensed:300,400&amp;subset=cyrillic,cyrillic-ext,latin-ext" rel="stylesheet"/>
#    <link href="https://cdn.reverso.net/context/v51300/css/bst.style.css" rel="stylesheet" type="text/css"/>
#    <script src="//cdn.reverso.net/abp/v1/Static/JS/advertising.js?ch=1" type="text/javascript">
#    </script>
#    <script src="//cdn.reverso.net/abp/v1/Static/JS/advertising.js?ch=2" type="text/javascript">
#    </script>
#    <script async="" src="//cdn.reverso.net/predib/predib-0-33-0.js" type="text/javascript">
#    </script>
#    <script src="//cdn.reverso.net/predib/conf/reverso_context.js" type="text/javascript">
#    </script>
#    <script type="text/javascript">
#     if(typeof window.request === "undefined") {
#     window.request = {
#       srctext: "",
#       trgtext: "",
#       srclang: "ru",
#       trglang: "en",
#       rpage: 1,
#       rmode: 0
#     };
#   }
#   var logLOCD = false;
#   var context_path = '';
#   var special_chars = "،؟י¬¿¡ºª·؛";
#   var is_rtl = false;
#
#   window.mobilecheck = function() {
#     var check = false;
#     (function (a) {
#       if (/(android|bb\d+|meego).+mobile|avantgo|bada\/|blackberry|blazer|compal|elaine|fennec|hiptop|iemobile|ip(hone|od)|iris|kindle|lge |maemo|midp|mmp|mobile.+firefox|netfront|opera m(ob|in)i|palm( os)?|phone|p(ixi|re)\/|plucker|pocket|psp|series(4|6)0|symbian|treo|up\.(browser|link)|vodafone|wap|windows ce|xda|xiino/i.test(a)||/1207|6310|6590|3gso|4thp|50[1-6]i|770s|802s|a wa|abac|ac(er|oo|s\-)|ai(ko|rn)|al(av|ca|co)|amoi|an(ex|ny|yw)|aptu|ar(ch|go)|as(te|us)|attw|au(di|\-m|r |s )|avan|be(ck|ll|nq)|bi(lb|rd)|bl(ac|az)|br(e|v)w|bumb|bw\-(n|u)|c55\/|capi|ccwa|cdm\-|cell|chtm|cldc|cmd\-|co(mp|nd)|craw|da(it|ll|ng)|dbte|dc\-s|devi|dica|dmob|do(c|p)o|ds(12|\-d)|el(49|ai)|em(l2|ul)|er(ic|k0)|esl8|ez([4-7]0|os|wa|ze)|fetc|fly(\-|_)|g1 u|g560|gene|gf\-5|g\-mo|go(\.w|od)|gr(ad|un)|haie|hcit|hd\-(m|p|t)|hei\-|hi(pt|ta)|hp( i|ip)|hs\-c|ht(c(\-| |_|a|g|p|s|t)|tp)|hu(aw|tc)|i\-(20|go|ma)|i230|iac( |\-|\/)|ibro|idea|ig01|ikom|im1k|inno|ipaq|iris|ja(t|v)a|jbro|jemu|jigs|kddi|keji|kgt( |\/)|klon|kpt |kwc\-|kyo(c|k)|le(no|xi)|lg( g|\/(k|l|u)|50|54|\-[a-w])|libw|lynx|m1\-w|m3ga|m50\/|ma(te|ui|xo)|mc(01|21|ca)|m\-cr|me(rc|ri)|mi(o8|oa|ts)|mmef|mo(01|02|bi|de|do|t(\-| |o|v)|zz)|mt(50|p1|v )|mwbp|mywa|n10[0-2]|n20[2-3]|n30(0|2)|n50(0|2|5)|n7(0(0|1)|10)|ne((c|m)\-|on|tf|wf|wg|wt)|nok(6|i)|nzph|o2im|op(ti|wv)|oran|owg1|p800|pan(a|d|t)|pdxg|pg(13|\-([1-8]|c))|phil|pire|pl(ay|uc)|pn\-2|po(ck|rt|se)|prox|psio|pt\-g|qa\-a|qc(07|12|21|32|60|\-[2-7]|i\-)|qtek|r380|r600|raks|rim9|ro(ve|zo)|s55\/|sa(ge|ma|mm|ms|ny|va)|sc(01|h\-|oo|p\-)|sdk\/|se(c(\-|0|1)|47|mc|nd|ri)|sgh\-|shar|sie(\-|m)|sk\-0|sl(45|id)|sm(al|ar|b3|it|t5)|so(ft|ny)|sp(01|h\-|v\-|v )|sy(01|mb)|t2(18|50)|t6(00|10|18)|ta(gt|lk)|tcl\-|tdg\-|tel(i|m)|tim\-|t\-mo|to(pl|sh)|ts(70|m\-|m3|m5)|tx\-9|up(\.b|g1|si)|utst|v400|v750|veri|vi(rg|te)|vk(40|5[0-3]|\-v)|vm40|voda|vulc|vx(52|53|60|61|70|80|81|83|85|98)|w3c(\-| )|webc|whit|wi(g |nc|nw)|wmlb|wonu|x700|yas\-|your|zeto|zte\-/i.test(a.substr(0,4)))
#         check = true
#       })(navigator.userAgent || navigator.vendor || window.opera);
#     return check;
#   };
#
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#     (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#     m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   var ga_log = [];
#
#   function sendGA(command, type, category, action, label, options) {
#     var object = {
#       "command": command,
#       "type": type,
#       "category": category,
#       "action": action,
#       "label": label
#     };
#     ga_log.push(object);
#     if(label !== undefined) ga(command, type, category, action, label, options);
#     else if(action !== undefined) ga(command, type, category, action, options);
#     else if(category !== undefined) ga(command, type, category, options);
#     else ga(command, type, options);
#   };
#
#   sendGA('create', 'UA-2834324-41', 'reverso.net');
#   sendGA('create', 'UA-2834324-49', 'auto', 'keywordTracker');
#   sendGA('require', 'displayfeatures');
#   sendGA('keywordTracker.require', 'displayfeatures');
#   sendGA('set', 'dimension1', logLOCD ? (is_premium ? 'premium' : 'registered') : 'anonymous');
#
#     sendGA('set', 'dimension4', typeof(adblock)=='undefined' ? 'yes' : (typeof(abp)!='undefined' && abp ? 'abp' : 'no' ));
#
#   sendGA('send', 'pageview', '/bst/result/ru-en/1w/translations-precomputed');
#   sendGA('keywordTracker.send', 'pageview');
#
#     var googletag = googletag || {};
#     googletag.cmd = googletag.cmd || [];
#
#     googletag.cmd.push(function() {
#         googletag.pubads().disableInitialLoad();
#         setReversoTargeting();
#     });
#     if (typeof (adblock) != 'undefined') {
#       var device = (window.mobilecheck() ? "mobile" : (window.innerWidth>1024 ? "desktop" : "tablet"));
#
#       var prebid_config = prebid_config || new prebidConfig();
#       var PREBID_TIMEOUT = prebid_config.getTimeout() || 800;
#       var GA_VARIATION = typeof(prebid_config) != 'undefined' ? prebid_config.getVariation() : 0;
#
#       var ads_array = [];
#       if (device === "desktop") {
#         ads_array = ['Reverso_Ctxt_D_Result_300x250_ATF', 'Reverso_Ctxt_D_Result_300x250_BTF', 'Reverso_Ctxt_D_Result_300x600_BTF', 'Reverso_Ctxt_D_Result_728x90_BTF']
#       }
#       else if (device === "mobile") {
#         ads_array = ['Reverso_Ctxt_M_Result_320x50_BTF'];
#       }
#       else {
#         ads_array = ['Reverso_Ctxt_D_Result_728x90_BTF'];
#       }
#
#         ads_array.push('Reverso_Ctxt_R_Result_InFeed_ATF');
#
#
#       var adsetup = prebid_config.getAdSetup(ads_array) || [];
#       var adUnits = prebid_config.getAdUnits(adsetup) || [];
#
#       if(typeof(abp) != 'undefined' && abp){adUnits=[];}
#
#       (function() {
#           var gads = document.createElement('script');
#           gads.async = true;
#           gads.type = 'text/javascript';
#           var useSSL = 'https:' == document.location.protocol;
#           gads.src = (useSSL ? 'https:' : 'http:') +
#           '//www.googletagservices.com/tag/js/gpt.js';
#           var node = document.getElementsByTagName('script')[0];
#           node.parentNode.insertBefore(gads, node);
#       })();
#
#       var slots = [];
#
#       googletag.cmd.push(function() {
#           for (var i in adsetup) {
#             n = adsetup[i];
#             slots[n['slotcode']] = googletag.defineSlot('/2629866/'+n['slotname'][0], n['slotsizes'], n['slotcode']).addService(googletag.pubads());
#           }
#
#           googletag.pubads().enableSingleRequest();
#           googletag.enableServices();
#       });
#
#       var pbjs = pbjs || {};
#       pbjs.que = pbjs.que || [];
#
#       prebid_config.setBidderSettings(pbjs);
#       prebid_config.setConfig(pbjs);
#       prebid_config.setAnalyticsSettings(pbjs);
#
#       pbjs.que.push(function() {
#         pbjs.addAdUnits(adUnits);
#         if(device === "desktop"){
#           pbjs.requestBids({
#             timeout: adUnits.length ? PREBID_TIMEOUT : 100,
#             adUnitCodes: ['div-gpt-ad-Reverso_Ctxt_D_Result_300x250_ATF', 'div-gpt-ad-Reverso_Ctxt_D_Result_300x250_BTF'],
#             bidsBackHandler: sendAdserverRequest
#           });
#         }
#         });
#
#       function isGptPubadsDefined() {
#         return window.googletag && typeof window.googletag.pubads === "function" && typeof window.googletag.pubads().getSlots === "function";
#       }
#
#       function refreshBids(adUnitCodes) {
#           if (!isGptPubadsDefined()) {
#             setTimeout(function() {
#               refreshBids(adUnitCodes);
#             }, 100);
#             return;
#           }
#           refresh_adsetup = prebid_config.getAdSetup(adUnitCodes) || [];
#           refresh_adunits = prebid_config.getAdUnits(refresh_adsetup) || [];
#           var gptAdSlots = [];
#           for (i in refresh_adsetup) {
#             gptAdSlots.push(slots[refresh_adsetup[i].slotcode]);
#           }
#           if(refresh_adunits.length && (typeof(abp) == 'undefined' || !abp)){
#             pbjs.que.push(function() {
#               pbjs.requestBids({
#                 timeout: PREBID_TIMEOUT,
#                 adUnitCodes: refresh_adunits.map(function (x) { return x.code; }),
#                 bidsBackHandler: function() {
#                   pbjs.setTargetingForGPTAsync(adUnitCodes);
#                   googletag.pubads().refresh(gptAdSlots, {changeCorrelator: false});
#                 }
#               });
#             });
#           }
#           else{
#               googletag.pubads().refresh(gptAdSlots, {changeCorrelator: false});
#           }
#       }
#
#       function setReversoTargeting() {
#           var adtargeting = {};
#
#           adtargeting['abtest'] = GA_VARIATION || 0;
#           adtargeting['Interface'] = 'RU';
#           adtargeting['device'] = device;
#           adtargeting['Status'] = 'prod';
#
#             adtargeting['Direction'] = 'RU-EN';
#
#
#           if(typeof(abp) != 'undefined' && abp){
#             adtargeting['abp'] = '1';
#         	}
#
#           for (var i in adtargeting) {
#             googletag.pubads().clearTargeting(i);
#             googletag.pubads().setTargeting(i, adtargeting[i]);
#           }
#       }
#
#       function sendAdserverRequest() {
#           if (pbjs.adserverRequestSent) return;
#           pbjs.adserverRequestSent = true;
#           googletag.cmd.push(function() {
#               pbjs.que.push(function() {
#                   setReversoTargeting();
#                   if(device === "desktop"){
#                       pbjs.setTargetingForGPTAsync(['div-gpt-ad-Reverso_Ctxt_D_Result_300x250_ATF', 'div-gpt-ad-Reverso_Ctxt_D_Result_300x250_BTF']);
#                       googletag.pubads().refresh([slots['div-gpt-ad-Reverso_Ctxt_D_Result_300x250_ATF'], slots['div-gpt-ad-Reverso_Ctxt_D_Result_300x250_BTF']], {changeCorrelator: false});
#                   }
#               });
#           });
#       }
#
#       setTimeout(function() {sendAdserverRequest();}, (PREBID_TIMEOUT*1.5));
# 	}
#    </script>
#   </meta>
#  </head>
#  <body class="locked mobile-locked noticed">
#   <div class="loading-pannel">
#    <span class="icon">
#    </span>
#   </div>
#   <div class=" results" id="wrapper">
#    <section id="top-content">
#     <a class="reverso-logo nonselectable no-loading" href="/%D0%BF%D0%B5%D1%80%D0%B5%D0%B2%D0%BE%D0%B4/" title="Reverso Context: поисковая система для переводов в контексте">
#      <div class="logo">
#       <span class="icon reverso-logo-red">
#       </span>
#       <span class="icon reverso-logo-blue">
#       </span>
#      </div>
#      <div class="text">
#       <span class="icon reverso-text">
#       </span>
#       <span class="icon context-text">
#       </span>
#      </div>
#     </a>
#     <div class="closed" id="mobile-menu">
#      <span class="icon menu">
#      </span>
#      <div class="floating-menu">
#       <a class="option register" href="https://account.reverso.net/register/context.reverso.net/ru?utm_source=contextweb&amp;utm_medium=usertopmenu&amp;utm_campaign=register">
#        <span class="icon add-user">
#        </span>
#        <span class="text">
#         Зарегистрироваться
#        </span>
#       </a>
#       <a class="option login" href="https://account.reverso.net/login/context.reverso.net/ru?utm_source=contextweb&amp;utm_medium=usertopmenu&amp;utm_campaign=login">
#        <span class="icon login">
#        </span>
#        <span class="text">
#         Войти
#        </span>
#       </a>
#       <button class="font-resize grey" data-size="0">
#        <span class="icon font-resize">
#        </span>
#        <span class="text">
#         Font size
#        </span>
#       </button>
#       <a class="option help grey" href="/%D0%BF%D0%B5%D1%80%D0%B5%D0%B2%D0%BE%D0%B4/about">
#        <span class="icon help">
#        </span>
#        <span class="text">
#         Помощь
#        </span>
#       </a>
#       <button class="option locale grey">
#        <span class="icon lang">
#        </span>
#        <span class="text">
#         русский
#        </span>
#        <span class="icon down-caret">
#        </span>
#       </button>
#       <div class="interface-langs closed">
#        <button class="option" data-value="ar">
#         العربية
#        </button>
#        <button class="option" data-value="de">
#         Deutsch
#        </button>
#        <button class="option" data-value="en">
#         English
#        </button>
#        <button class="option" data-value="es">
#         Español
#        </button>
#        <button class="option" data-value="fr">
#         Français
#        </button>
#        <button class="option" data-value="he">
#         עברית
#        </button>
#        <button class="option" data-value="it">
#         Italiano
#        </button>
#        <button class="option" data-value="ja">
#         日本語
#        </button>
#        <button class="option" data-value="nl">
#         Nederlands
#        </button>
#        <button class="option" data-value="pl">
#         Polski
#        </button>
#        <button class="option" data-value="pt">
#         Português
#        </button>
#        <button class="option" data-value="ro">
#         Română
#        </button>
#        <button class="option selected" data-value="ru">
#         Русский
#        </button>
#        <button class="option" data-value="tr">
#         Türkçe
#        </button>
#       </div>
#      </div>
#     </div>
#     <div class="selector closed nonselectable" id="top-menu">
#      <span class="option front icon horizontal-dots">
#      </span>
#      <span class="option front space-filler">
#       ···
#      </span>
#      <div class="drop-down">
#       <a class="option translation" href="http://www.reverso.net/text_translation.aspx?lang=RU" target="_blank">
#        <span class="icon lang">
#        </span>
#        <span class="text">
#         Перевод
#        </span>
#       </a>
#       <a class="option dictionary" href="https://dictionary.reverso.net" target="_blank">
#        <span class="icon dictionary">
#        </span>
#        <span class="text">
#         Словарь
#        </span>
#       </a>
#       <a class="option speller" href="http://www.reverso.net/spell-checker/english-spelling-grammar/" target="_blank">
#        <span class="icon spellcheck">
#        </span>
#        <span class="text">
#         Корректор
#        </span>
#       </a>
#       <a class="option conjugation" href="http://glagol.reverso.net/%D1%81%D0%BF%D1%80%D1%8F%D0%B6%D0%B5%D0%BD%D0%B8%D0%B5-%D1%80%D1%83%D1%81%D1%81%D0%BA%D0%B8%D0%B9.html" target="_blank">
#        <span class="icon conjugator">
#        </span>
#        <span class="text">
#         Спряжение
#        </span>
#       </a>
#       <a class="option synonyms" href="https://synonyms.reverso.net/%D1%81%D0%B8%D0%BD%D0%BE%D0%BD%D0%B8%D0%BC%D1%8B/" target="_blank">
#        <span class="icon synonyms">
#        </span>
#        <span class="text">
#         Синонимы
#        </span>
#       </a>
#       <a class="option grammar" href="http://grammar.reverso.net/" target="_blank">
#        <span class="icon translate">
#        </span>
#        <span class="text">
#         Грамматика
#        </span>
#       </a>
#       <a class="option document" href="https://documents.reverso.net/Default.aspx?lang=en" target="_blank">
#        <span class="icon document">
#        </span>
#        <span class="text">
#         Перевод документов и сайтов
#        </span>
#       </a>
#       <a class="option corporate" href="https://www.corporate-translation.reverso.com/">
#        <span class="icon corporate">
#        </span>
#        <span class="text">
#         Корпоративные решения
#        </span>
#       </a>
#       <a class="option newsletter" href="http://www.reverso.net/tricks.aspx?type=3&amp;lang=RU" target="_blank">
#        <span class="icon mail">
#        </span>
#        <span class="text">
#         Новостная рассылка
#        </span>
#       </a>
#       <a class="option help" href="/%D0%BF%D0%B5%D1%80%D0%B5%D0%B2%D0%BE%D0%B4/about">
#        <span class="icon help">
#        </span>
#        <span class="text">
#         Помощь
#        </span>
#       </a>
#      </div>
#     </div>
#     <div class="selector closed double nonselectable" id="lang-selector">
#      <span class="option front">
#       ru
#      </span>
#      <span class="icon down-caret">
#      </span>
#      <span class="option front space-filler">
#       ···
#      </span>
#      <div class="drop-down">
#       <div class="option" data-value="ar">
#        العربية
#       </div>
#       <div class="option" data-value="de">
#        Deutsch
#       </div>
#       <div class="option" data-value="en">
#        English
#       </div>
#       <div class="option" data-value="es">
#        Español
#       </div>
#       <div class="option" data-value="fr">
#        Français
#       </div>
#       <div class="option" data-value="he">
#        עברית
#       </div>
#       <div class="option" data-value="it">
#        Italiano
#       </div>
#       <div class="option" data-value="ja">
#        日本語
#       </div>
#       <div class="option" data-value="nl">
#        Nederlands
#       </div>
#       <div class="option" data-value="pl">
#        Polski
#       </div>
#       <div class="option" data-value="pt">
#        Português
#       </div>
#       <div class="option" data-value="ro">
#        Română
#       </div>
#       <div class="option selected" data-value="ru">
#        Русский
#       </div>
#       <div class="option" data-value="tr">
#        Türkçe
#       </div>
#      </div>
#     </div>
#     <button class="icon font-resize" data-size="0" title="Кликните, чтобы увеличить или уменьшить размер текста.">
#     </button>
#     <div class="reverso-links">
#      <a class="translation-link" href="http://www.reverso.net/text_translation.aspx?lang=RU" target="_blank">
#       Перевод
#      </a>
#      <a class="dictionary-link" href="https://dictionary.reverso.net" target="_blank">
#       Словарь
#      </a>
#      <a class="speller-link" href="http://www.reverso.net/spell-checker/english-spelling-grammar/" target="_blank">
#       Корректор
#      </a>
#      <a class="conjugation-link" href="http://glagol.reverso.net/%D1%81%D0%BF%D1%80%D1%8F%D0%B6%D0%B5%D0%BD%D0%B8%D0%B5-%D1%80%D1%83%D1%81%D1%81%D0%BA%D0%B8%D0%B9.html" target="_blank">
#       Спряжение
#      </a>
#      <a class="synonyms-link " href="https://synonyms.reverso.net/%D1%81%D0%B8%D0%BD%D0%BE%D0%BD%D0%B8%D0%BC%D1%8B/" target="_blank">
#       Синонимы
#      </a>
#      <a class="grammar-link last" href="http://grammar.reverso.net/" target="_blank">
#       Грамматика
#      </a>
#     </div>
#     <div class="social-content">
#      <a class="facebook-link icon facebook" href="https://www.facebook.com/Reverso.net?ref=ts" target="_blank" title="Facebook">
#      </a>
#      <a class="twitter-link icon twitter" href="https://twitter.com/ReversoEN" target="_blank" title="Twitter">
#      </a>
#      <a class="instagram-link icon instagram" href="https://www.instagram.com/reverso_app/?hl=ru" target="_blank" title="Instagram">
#      </a>
#     </div>
#     <!-- end top-bar -->
#    </section>
#    <section id="reverso-nav">
#     <a class="translation-link" href="http://www.reverso.net/text_translation.aspx?lang=RU" target="_blank">
#      Перевод
#     </a>
#     <span>
#      Context
#     </span>
#     <a class="conjugation-link" href="http://glagol.reverso.net/%D1%81%D0%BF%D1%80%D1%8F%D0%B6%D0%B5%D0%BD%D0%B8%D0%B5-%D1%80%D1%83%D1%81%D1%81%D0%BA%D0%B8%D0%B9.html" target="_blank">
#      Спряжение
#     </a>
#     <a class="synonyms-link" href="https://synonyms.reverso.net/%D1%81%D0%B8%D0%BD%D0%BE%D0%BD%D0%B8%D0%BC%D1%8B/" target="_blank">
#      Синонимы
#     </a>
#    </section>
#    <section id="body-content">
#     <div class="right-content">
#      <section id="subtop-content">
#       <script>
#        var register_link = "https://account.reverso.net/register/context.reverso.net/ru?utm_source=contextweb&utm_medium={0}&utm_campaign=register";
#     var login_link = "https://account.reverso.net/login/context.reverso.net/ru?utm_source=contextweb&utm_medium={0}&utm_campaign=login";
#       </script>
#       <div class="selector closed nonselectable " id="user-menu">
#        <span class="icon down-caret">
#        </span>
#        <span class="option front">
#         <span class="icon user">
#          <span class="icon rocket">
#          </span>
#         </span>
#         Присоединиться к Reverso
#        </span>
#        <div class="drop-down">
#         <a class="option register" href="https://account.reverso.net/register/context.reverso.net/ru?utm_source=contextweb&amp;utm_medium=usertopmenu&amp;utm_campaign=register">
#          <span class="icon add-user">
#          </span>
#          <span class="text">
#           Зарегистрироваться
#          </span>
#         </a>
#         <a class="option login" href="https://account.reverso.net/login/context.reverso.net/ru?utm_source=contextweb&amp;utm_medium=usertopmenu&amp;utm_campaign=login">
#          <span class="icon login">
#          </span>
#          <span class="text">
#           Войти
#          </span>
#         </a>
#         <span class="option facebook" data-url="null" id="fb-content">
#          <span class="icon facebook">
#          </span>
#          <span class="text">
#           Войти через Facebook
#          </span>
#         </span>
#         <span class="option google" data-url="null" id="google-content">
#          <span class="icon google3">
#          </span>
#          <span class="text">
#           Войти через Google
#          </span>
#         </span>
#        </div>
#       </div>
#       <div id="title-content">
#       </div>
#      </section>
#      <div id="rca">
#       <!-- /64378609/Context_300x250_Top -->
#       <span class="rca-title">
#        Реклама
#       </span>
#       <div class="rca" id="div-gpt-ad-Reverso_Ctxt_D_Result_300x250_ATF">
#        <script type="text/javascript">
#         if(!window.mobilecheck()) {
#         googletag.cmd.push(function() {
#           googletag.display('div-gpt-ad-Reverso_Ctxt_D_Result_300x250_ATF');
#         });
#       }
#        </script>
#       </div>
#       <div id="side-badges">
#        <a class="badge extension disabled mobile-hidden" href="" id="extension-badge" target="_blank">
#         <span class="logo">
#         </span>
#         <span class="text">
#          Добавить Reverso в {0}
#          <b>
#           Бесплатно
#          </b>
#         </span>
#        </a>
#        <div class="badges pannel">
#         <a class="text" href="/перевод/mobile-app?utm_source=contextweb&amp;utm_medium=banner&amp;utm_campaign=ctxtresultpage&amp;utm_content=ctxtappdl">
#          Скачать наше
#          <b>
#           бесплатное
#          </b>
#          приложение
#         </a>
#         <a class="badge and no-loading ru" href="/перевод/mobile-app?utm_source=contextweb&amp;utm_medium=banner&amp;utm_campaign=ctxtresultpage&amp;utm_content=ctxtappdl">
#         </a>
#         <a class="badge ios no-loading ru" href="/перевод/mobile-app?utm_source=contextweb&amp;utm_medium=banner&amp;utm_campaign=ctxtresultpage&amp;utm_content=ctxtappdl">
#         </a>
#        </div>
#       </div>
#       <!-- /64378609/Context_300x250_Bottom -->
#       <span class="rca-title">
#        Реклама
#       </span>
#       <div class="rca" id="div-gpt-ad-Reverso_Ctxt_D_Result_300x250_BTF">
#        <script type="text/javascript">
#         if(!window.mobilecheck()) {
#         googletag.cmd.push(function() {
#           googletag.display('div-gpt-ad-Reverso_Ctxt_D_Result_300x250_BTF');
#         });
#       }
#        </script>
#       </div>
#       <!-- /64378609/Context_300x600 -->
#       <span class="rca-title disabled tall-rca">
#        Реклама
#       </span>
#       <div class="rca disabled tall-rca" id="div-gpt-ad-Reverso_Ctxt_D_Result_300x600_BTF">
#        <script type="text/javascript">
#         if(!window.mobilecheck()) {
# 		  googletag.cmd.push(function() {
# 			googletag.display('div-gpt-ad-Reverso_Ctxt_D_Result_300x600_BTF');
# 		  });
#         }
#        </script>
#       </div>
#      </div>
#     </div>
#     <div class="left-content">
#      <div class="popup closed" id="register-popup-bottom">
#       <div class="header">
#        <span class="title">
#         Присоединяйтесь к Reverso, это
#         <b>
#          удобно и бесплатно
#         </b>
#         !
#        </span>
#        <button class="icon up-arrow" title="закрыть">
#        </button>
#       </div>
#       <div class="body wide-container">
#        <a class="button register" href="https://account.reverso.net/register/context.reverso.net/ru?utm_source=contextweb&amp;utm_medium=floatingpopup&amp;utm_campaign=register">
#         <span class="icon add-user">
#         </span>
#         Зарегистрироваться
#        </a>
#        <a class="button login" href="https://account.reverso.net/login/context.reverso.net/ru?utm_source=contextweb&amp;utm_medium=floatingpopup&amp;utm_campaign=login">
#         <span class="icon login">
#         </span>
#         Войти
#        </a>
#       </div>
#      </div>
#      <section id="search-content">
#       <div id="search">
#        <div class="ltr" id="search-input">
#         <div class="icons">
#          <button class="icon exclude" title="Кликните здесь, чтобы исключить некоторые слова из поиска. Например, слово1 -{слово2} : будут найдены примеры, которые содержат слово1 и НЕ содержат слово2">
#          </button>
#          <button class="icon cancel" title="Очистить ввод">
#          </button>
#         </div>
#         <input autocapitalize="none" autocomplete="off" class="keyboardInput ui-autocomplete-input ltr" id="entry" name="text" placeholder="Введите или вставьте текст" tabindex="1" type="text" value="наличие"/>
#        </div>
#        <div class="nonselectable" id="pair-selector">
#         <div class="selector double closed" id="src-selector" tabindex="2">
#          <span class="icon down-caret">
#          </span>
#          <span class="option front" data-value="ru">
#           русский
#          </span>
#          <span class="space-filler">
#          </span>
#          <div class="drop-down">
#           <span class="option" data-value="ar">
#            арабский
#           </span>
#           <span class="option" data-value="de">
#            немецкий
#           </span>
#           <span class="option" data-value="en">
#            английский
#           </span>
#           <span class="option" data-value="es">
#            испанский
#           </span>
#           <span class="option" data-value="fr">
#            французский
#           </span>
#           <span class="option" data-value="he">
#            иврит
#           </span>
#           <span class="option" data-value="it">
#            итальянский
#           </span>
#           <span class="option" data-value="ja">
#            японский
#           </span>
#           <span class="option" data-value="nl">
#            голландский
#           </span>
#           <span class="option" data-value="pl">
#            польский
#           </span>
#           <span class="option" data-value="pt">
#            португальский
#           </span>
#           <span class="option" data-value="ro">
#            румынский
#           </span>
#           <span class="option selected" data-value="ru">
#            русский
#           </span>
#           <span class="option" data-value="tr">
#            турецкий
#           </span>
#          </div>
#         </div>
#         <div class="swap-content" title="Сменить направление перевода">
#          <div class="icons" tabindex="3">
#           <span class="icon reverso-top">
#           </span>
#           <span class="icon reverso-bottom">
#           </span>
#          </div>
#         </div>
#         <div class="selector double closed" id="trg-selector" tabindex="4">
#          <span class="icon down-caret">
#          </span>
#          <span class="option front" data-value="en">
#           английский
#          </span>
#          <span class="space-filler">
#          </span>
#          <div class="drop-down">
#           <span class="option" data-value="ar">
#            арабский
#           </span>
#           <span class="option" data-value="de">
#            немецкий
#           </span>
#           <span class="option selected" data-value="en">
#            английский
#           </span>
#           <span class="option" data-value="es">
#            испанский
#           </span>
#           <span class="option" data-value="fr">
#            французский
#           </span>
#           <span class="option" data-value="he">
#            иврит
#           </span>
#           <span class="option" data-value="it">
#            итальянский
#           </span>
#           <span class="option" data-value="ja">
#            японский
#           </span>
#           <span class="option" data-value="nl">
#            голландский
#           </span>
#           <span class="option" data-value="pl">
#            польский
#           </span>
#           <span class="option" data-value="pt">
#            португальский
#           </span>
#           <span class="option" data-value="ro">
#            румынский
#           </span>
#           <span class="option" data-value="ru">
#            русский
#           </span>
#           <span class="option" data-value="tr">
#            турецкий
#           </span>
#          </div>
#         </div>
#        </div>
#        <button class="icon search" id="search-button" tabindex="5" title="Поиск">
#        </button>
#        <div class="exclude-content">
#         <button class="icon add disabled">
#         </button>
#         <div class="input-content">
#          <input placeholder="Исключить из поиска"/>
#         </div>
#        </div>
#       </div>
#      </section>
#      <section id="notice-content">
#       <div id="search-links">
#        <a class="icon synonyms" data-value="synonyms" href="https://synonyms.reverso.net/%D1%81%D0%B8%D0%BD%D0%BE%D0%BD%D0%B8%D0%BC%D1%8B/ru/%D0%BD%D0%B0%D0%BB%D0%B8%D1%87%D0%B8%D0%B5" target="_blank" title="Искать в Синонимы">
#        </a>
#        <button class="icon conjugator disabled" data-value="conjugator" title="Искать в Спряжение">
#        </button>
#        <button class="icon web" data-url="https://www.google.com/search?hl=ru&amp;q=" data-value="web" title="Искать в Интернете">
#        </button>
#        <button class="icon wikipedia" data-url="https://ru.wikipedia.org/wiki/" data-value="wikipedia" title="Искать в Wikipedia">
#        </button>
#        <button class="icon images" data-url="https://www.google.com/search?hl=ru&amp;tbm=isch&amp;q=" data-value="images" title="Искать в Картинках">
#        </button>
#        <button class="icon dictionary disabled" data-value="definition" title="Искать в Oпределение">
#        </button>
#       </div>
#       <div class="notice" id="seealso-content">
#        <span class="icon info">
#        </span>
#        <span class="message">
#         Посмотреть также:
#        </span>
#        <a class="" href="/перевод/русский-английский/%D0%BE%D0%B1%D0%B5%D1%81%D0%BF%D0%B5%D1%87%D0%B8%D1%82%D1%8C+%D0%BD%D0%B0%D0%BB%D0%B8%D1%87%D0%B8%D0%B5">
#         обеспечить наличие
#        </a>
#        <a class="" href="/перевод/русский-английский/%D0%BF%D1%80%D0%B5%D0%B4%D0%BF%D0%BE%D0%BB%D0%B0%D0%B3%D0%B0%D0%B5%D1%82+%D0%BD%D0%B0%D0%BB%D0%B8%D1%87%D0%B8%D0%B5">
#         предполагает наличие
#        </a>
#        <a class="" href="/перевод/русский-английский/%D0%BE%D0%B1%D0%B5%D1%81%D0%BF%D0%B5%D1%87%D0%B8%D0%B2%D0%B0%D1%82%D1%8C+%D0%BD%D0%B0%D0%BB%D0%B8%D1%87%D0%B8%D0%B5">
#         обеспечивать наличие
#        </a>
#       </div>
#       <script>
#        sendGA("send", "event", "seealso", "display", "ru-en");
#       </script>
#       <div class="notice" id="rude">
#        <i class="icon warning">
#        </i>
#        <span class="message">
#         На основании Вашего запроса эти примеры могут содержать грубую лексику.
#        </span>
#       </div>
#       <div class="notice" id="colloquial">
#        <i class="icon warning">
#        </i>
#        <span class="message">
#         На основании Вашего запроса эти примеры могут содержать разговорную лексику.
#        </span>
#       </div>
#      </section>
#      <section id="top-results">
#       <section class="" id="search-options">
#        <button class="icon down-arrow detailed-view closed" title="Показать подробности и рекомендации">
#        </button>
#        <div class="title-content">
#         <h1>
#          Перевод "наличие" на английский
#         </h1>
#        </div>
#       </section>
#       <div id="pos-filters">
#        <button class="n" data-index="0" data-pos="n." title="Показать все переводы, отмеченные как Существительное">
#         Сущ.
#        </button>
#        <button class="adv" data-index="1" data-pos="adv." title="Показать все переводы, отмеченные как Наречие ">
#         Нареч.
#        </button>
#        <button class="adj" data-index="2" data-pos="adj." title="Показать все переводы, отмеченные как Прилагательное">
#         Прил.
#        </button>
#        <div id="synonyms-button-container">
#         <a class="icon synonyms" dir=" ltr " href="https://synonyms.reverso.net/%D1%81%D0%B8%D0%BD%D0%BE%D0%BD%D0%B8%D0%BC%D1%8B/ru/%D0%BD%D0%B0%D0%BB%D0%B8%D1%87%D0%B8%D0%B5" id="synonyms-button" target="_blank" title="Синонимы">
#         </a>
#        </div>
#       </div>
#       <div class="wide-container" id="filtered-entry">
#       </div>
#       <div class="wide-container" id="translations-content">
#        <a class="translation ltr dict n" data-freq="3281" data-pos="[n]" data-pos-index="0" data-posgroup="1" href="/перевод/английский-русский/availability" lang="en" title="&lt;div class='nobold'&gt;Посмотреть примеры с переводом &lt;em class='translation'&gt;availability&lt;/em&gt;&lt;br&gt;Существительное&lt;br&gt;(3281 примеров, содержащих перевод)&lt;/div&gt;">
#         <div class="pos-mark">
#          <span class="n" title="Существительное">
#          </span>
#         </div>
#         availability
#        </a>
#        <a class="translation ltr dict n" data-freq="1938" data-pos="[n]" data-pos-index="0" data-posgroup="1" href="/перевод/английский-русский/existence" lang="en" title="&lt;div class='nobold'&gt;Посмотреть примеры с переводом &lt;em class='translation'&gt;existence&lt;/em&gt;&lt;br&gt;Существительное&lt;br&gt;(1938 примеров, содержащих перевод)&lt;/div&gt;">
#         <div class="pos-mark">
#          <span class="n" title="Существительное">
#          </span>
#         </div>
#         existence
#        </a>
#        <a class="translation ltr dict n" data-freq="1160" data-pos="[n]" data-pos-index="0" data-posgroup="1" href="/перевод/английский-русский/presence" lang="en" title="&lt;div class='nobold'&gt;Посмотреть примеры с переводом &lt;em class='translation'&gt;presence&lt;/em&gt;&lt;br&gt;Существительное&lt;br&gt;(1160 примеров, содержащих перевод)&lt;/div&gt;">
#         <div class="pos-mark">
#          <span class="n" title="Существительное">
#          </span>
#         </div>
#         presence
#        </a>
#        <a class="translation ltr dict n" data-freq="355" data-pos="[n]" data-pos-index="0" data-posgroup="1" href="/перевод/английский-русский/having" lang="en" title="&lt;div class='nobold'&gt;Посмотреть примеры с переводом &lt;em class='translation'&gt;having&lt;/em&gt;&lt;br&gt;Существительное&lt;br&gt;(355 примеров, содержащих перевод)&lt;/div&gt;">
#         <div class="pos-mark">
#          <span class="n" title="Существительное">
#          </span>
#         </div>
#         having
#        </a>
#        <a class="translation ltr dict n" data-freq="73" data-pos="[n]" data-pos-index="0" data-posgroup="1" href="/перевод/английский-русский/possession" lang="en" title="&lt;div class='nobold'&gt;Посмотреть примеры с переводом &lt;em class='translation'&gt;possession&lt;/em&gt;&lt;br&gt;Существительное&lt;br&gt;(73 примеров, содержащих перевод)&lt;/div&gt;">
#         <div class="pos-mark">
#          <span class="n" title="Существительное">
#          </span>
#         </div>
#         possession
#        </a>
#        <a class="translation ltr dict n" data-freq="64" data-pos="[n]" data-pos-index="0" data-posgroup="1" href="/перевод/английский-русский/provision" lang="en" title="&lt;div class='nobold'&gt;Посмотреть примеры с переводом &lt;em class='translation'&gt;provision&lt;/em&gt;&lt;br&gt;Существительное&lt;br&gt;(64 примеров, содержащих перевод)&lt;/div&gt;">
#         <div class="pos-mark">
#          <span class="n" title="Существительное">
#          </span>
#         </div>
#         provision
#        </a>
#        <div class="translation ltr dict first n" data-freq="15" data-pos="[n]" data-pos-index="0" data-posgroup="1" lang="en" title="&lt;div class='nobold'&gt;Посмотреть примеры с переводом &lt;em class='translation'&gt;occurrence&lt;/em&gt;&lt;br&gt;Существительное&lt;br&gt;(15 примеров, содержащих перевод)&lt;/div&gt;">
#         <div class="pos-mark">
#          <span class="n" title="Существительное">
#          </span>
#         </div>
#         occurrence
#        </div>
#        <a class="translation ltr dict adv" data-freq="135" data-pos="[adv]" data-pos-index="1" data-posgroup="2" href="/перевод/английский-русский/there+are" lang="en" title="&lt;div class='nobold'&gt;Посмотреть примеры с переводом &lt;em class='translation'&gt;there are&lt;/em&gt;&lt;br&gt;Наречие &lt;br&gt;(135 примеров, содержащих перевод)&lt;/div&gt;">
#         <div class="pos-mark">
#          <span class="adv" title="Наречие ">
#          </span>
#         </div>
#         there are
#        </a>
#        <a class="translation ltr dict adv" data-freq="75" data-pos="[adv]" data-pos-index="1" data-posgroup="2" href="/перевод/английский-русский/there+were" lang="en" title="&lt;div class='nobold'&gt;Посмотреть примеры с переводом &lt;em class='translation'&gt;there were&lt;/em&gt;&lt;br&gt;Наречие &lt;br&gt;(75 примеров, содержащих перевод)&lt;/div&gt;">
#         <div class="pos-mark">
#          <span class="adv" title="Наречие ">
#          </span>
#         </div>
#         there were
#        </a>
#        <a class="translation ltr dict first adv" data-freq="67" data-pos="[adv]" data-pos-index="1" data-posgroup="2" href="/перевод/английский-русский/there+is" lang="en" title="&lt;div class='nobold'&gt;Посмотреть примеры с переводом &lt;em class='translation'&gt;there is&lt;/em&gt;&lt;br&gt;Наречие &lt;br&gt;(67 примеров, содержащих перевод)&lt;/div&gt;">
#         <div class="pos-mark">
#          <span class="adv" title="Наречие ">
#          </span>
#         </div>
#         there is
#        </a>
#        <a class="translation ltr dict first mobile-hidden adj" data-freq="273" data-pos="[adj]" data-pos-index="2" data-posgroup="3" href="/перевод/английский-русский/available" lang="en" title="&lt;div class='nobold'&gt;Посмотреть примеры с переводом &lt;em class='translation'&gt;available&lt;/em&gt;&lt;br&gt;Прилагательное&lt;br&gt;(273 примеров, содержащих перевод)&lt;/div&gt;">
#         <div class="pos-mark">
#          <span class="adj" title="Прилагательное">
#          </span>
#         </div>
#         available
#        </a>
#        <a class="translation ltr dict mobile-hidden no-pos" data-freq="96" data-posgroup="6" href="/перевод/английский-русский/whether" lang="en" title="&lt;div class='nobold'&gt;Посмотреть примеры с переводом &lt;em class='translation'&gt;whether&lt;/em&gt;&lt;br&gt;(96 примеров, содержащих перевод)&lt;/div&gt;">
#         whether
#        </a>
#        <a class="translation ltr dict mobile-hidden no-pos" data-freq="65" data-posgroup="6" href="/перевод/английский-русский/existing" lang="en" title="&lt;div class='nobold'&gt;Посмотреть примеры с переводом &lt;em class='translation'&gt;existing&lt;/em&gt;&lt;br&gt;(65 примеров, содержащих перевод)&lt;/div&gt;">
#         existing
#        </a>
#        <a class="translation ltr dict mobile-hidden no-pos" data-freq="22" data-posgroup="6" href="/перевод/английский-русский/existed" lang="en" title="&lt;div class='nobold'&gt;Посмотреть примеры с переводом &lt;em class='translation'&gt;existed&lt;/em&gt;&lt;br&gt;(22 примеров, содержащих перевод)&lt;/div&gt;">
#         existed
#        </a>
#        <a class="translation indication ltr dict mobile-hidden no-pos" data-freq="155" data-posgroup="10" href="/перевод/английский-русский/adequate" lang="en" title="&lt;div class='nobold'&gt;Посмотреть примеры, содержащие &lt;em class='translation'&gt;adequate&lt;/em&gt;&lt;br&gt;(155 примеров, содержащих перевод)&lt;/div&gt;">
#         adequate
#        </a>
#       </div>
#       <section class="wide-container" id="filters-content">
#        <button class="other-content" data-negative=" -{availability} -{existence} -{presence} -{having} -{possession} -{provision} -{occurrence} -{there are} -{there were} -{there is} -{available} -{whether} -{existing} -{existed} -{adequate}" data-other="0">
#         Другие переводы
#        </button>
#        <div class="filter-form closed">
#         <button class="icon filter" title="Вы можете получить более точные результаты, указав слово или несколько слов, которые должен содержать перевод. В результате будут показаны только примеры, которые содержат эти слова.">
#         </button>
#         <button class="icon cancel" title="Очистить фильтр">
#         </button>
#         <div class="input-content">
#          <button class="icon exclude" title="Кликните здесь, чтобы исключить некоторые слова из поиска. Например, слово1 -{слово2} : будут найдены примеры, которые содержат слово1 и НЕ содержат слово2">
#          </button>
#          <input autocomplete="off" placeholder="Показать переводы, содержащие..." readonly=""/>
#         </div>
#        </div>
#       </section>
#       <section class="wide-container" id="top-suggestions">
#        <h3>
#         Предложения
#        </h3>
#        <div class="wide-container">
#         <div class="suggestion negative" title="Это предложение исключено из результатов">
#          <span class="icon pf">
#          </span>
#          <button class="text" data-url="/перевод/русский-английский/%D0%BE%D0%B1%D0%B5%D1%81%D0%BF%D0%B5%D1%87%D0%B8%D1%82%D1%8C+%D0%BD%D0%B0%D0%BB%D0%B8%D1%87%D0%B8%D0%B5">
#           обеспечить наличие
#          </button>
#          <span class="figure ">
#           1330
#          </span>
#         </div>
#         <div class="suggestion">
#          <a class="text" href="/перевод/русский-английский/%D0%BD%D0%B5%D1%81%D0%BC%D0%BE%D1%82%D1%80%D1%8F+%D0%BD%D0%B0+%D0%BD%D0%B0%D0%BB%D0%B8%D1%87%D0%B8%D0%B5">
#           несмотря на наличие
#          </a>
#          <span class="figure ">
#           1253
#          </span>
#         </div>
#         <div class="suggestion">
#          <a class="text" href="/перевод/русский-английский/%D1%8F%D0%B2%D0%BB%D1%8F%D0%B5%D1%82%D1%81%D1%8F+%D0%BD%D0%B0%D0%BB%D0%B8%D1%87%D0%B8%D0%B5">
#           является наличие
#          </a>
#          <span class="figure ">
#           1059
#          </span>
#         </div>
#         <div class="suggestion">
#          <a class="text" href="/перевод/русский-английский/%D1%82%D0%B0%D0%BA%D0%B6%D0%B5+%D0%BD%D0%B0%D0%BB%D0%B8%D1%87%D0%B8%D0%B5">
#           также наличие
#          </a>
#          <span class="figure ">
#           528
#          </span>
#         </div>
#         <div class="suggestion negative" title="Это предложение исключено из результатов">
#          <span class="icon pf">
#          </span>
#          <button class="text" data-url="/перевод/русский-английский/%D0%BF%D1%80%D0%B5%D0%B4%D0%BF%D0%BE%D0%BB%D0%B0%D0%B3%D0%B0%D0%B5%D1%82+%D0%BD%D0%B0%D0%BB%D0%B8%D1%87%D0%B8%D0%B5">
#           предполагает наличие
#          </button>
#          <span class="figure ">
#           502
#          </span>
#         </div>
#         <div class="suggestion">
#          <a class="text" href="/перевод/русский-английский/%D0%BD%D0%B0%D0%BB%D0%B8%D1%87%D0%B8%D0%B5+%D1%82%D0%B0%D0%BA%D0%B8%D1%85">
#           наличие таких
#          </a>
#          <span class="figure ">
#           432
#          </span>
#         </div>
#         <div class="suggestion">
#          <a class="text" href="/перевод/русский-английский/%D0%BD%D0%B5%D0%BE%D0%B1%D1%85%D0%BE%D0%B4%D0%B8%D0%BC%D0%BE+%D0%BD%D0%B0%D0%BB%D0%B8%D1%87%D0%B8%D0%B5">
#           необходимо наличие
#          </a>
#          <span class="figure ">
#           413
#          </span>
#         </div>
#         <div class="suggestion">
#          <a class="text" href="/перевод/русский-английский/%D0%BD%D0%B0%D0%BB%D0%B8%D1%87%D0%B8%D0%B5+%D0%B1%D0%BE%D0%BB%D1%8C%D1%88%D0%BE%D0%B3%D0%BE">
#           наличие большого
#          </a>
#          <span class="figure ">
#           315
#          </span>
#         </div>
#         <div class="suggestion negative" title="Это предложение исключено из результатов">
#          <span class="icon pf">
#          </span>
# ...
#        </button>
#       </div>
#       <div class="example blocked" id="MULTIUN-V1.EN-RU_8932275">
#        <div class="src ltr">
#         <span class="text">
#          В случае поверхностных вод
#          <em>
#           наличие
#          </em>
#          таких факторов можно легко установить посредством простого наблюдения.
#         </span>
#        </div>
#        <div class="trg ltr">
#         <span class="icon jump-right">
#         </span>
#         <span class="text" lang="en">
#          In the case of surface waters,
#          <a class="link_highlighted" href="/перевод/английский-русский/the+existence" rel="nofollow">
#           <em>
#            the existence
#           </em>
#          </a>
#          of such factors can be easily established by simple observation.
#         </span>
#        </div>
#        <div class="options">
#         <div class="src">
#          <button class="voice icon stopped" data-id="MULTIUN-V1.EN-RU_8932275" data-lang="ru" title="Произношение">
#          </button>
#         </div>
#         <div class="trg">
#          <button class="icon more-context" data-id="MULTIUN-V1.EN-RU_8932275" title="Посмотреть примеры для этого перевода в контексте (https://conferences.unite.un.org/UNCorpus)">
#          </button>
#          <button class="report icon thumb-down" data-id="MULTIUN-V1.EN-RU_8932275" title="Сообщить о проблеме в этом примере">
#          </button>
#          <button class="add icon addentry " data-id="MULTIUN-V1.EN-RU_8932275" data-text="In the case of surface waters, &lt;em&gt;the existence&lt;/em&gt; of such factors can be easily established by simple observation." data-url="https://dictionary.reverso.net/CollabDict.aspx?view=2&amp;lang=RU" title="Добавить этот перевод в коллективный словарь Reverso">
#          </button>
#          <button class="copy icon mobile-hidden" data-id="MULTIUN-V1.EN-RU_8932275" title="Скопировать перевод">
#          </button>
#          <button class="icon non-favourite " data-id="MULTIUN-V1.EN-RU_8932275" title="Отметить пример в качестве избранного">
#          </button>
#          <button class="voice icon stopped" data-id="MULTIUN-V1.EN-RU_8932275" data-lang="en" title="Произношение">
#          </button>
#         </div>
#        </div>
#        <button class="mobile-voice icon stopped " data-id="MULTIUN-V1.EN-RU_8932275">
#        </button>
#       </div>
#       <div class="example blocked" id="MULTIUN-V1.EN-RU_8934468">
#        <div class="src ltr">
#         <span class="text">
#          Комиссия сознает
#          <em>
#           наличие
#          </em>
#          таких других аспектов этого пункта повестки дня Генеральной Ассамблеи.
#         </span>
#        </div>
#        <div class="trg ltr">
#         <span class="icon jump-right">
#         </span>
#         <span class="text" lang="en">
#          The Commission is
#          <a class="link_highlighted" href="/перевод/английский-русский/mindful" rel="nofollow">
#           <em>
#            mindful
#           </em>
#          </a>
#          of such other aspects of the General Assembly's agenda item.
#         </span>
#        </div>
#        <div class="options">
#         <div class="src">
#          <button class="voice icon stopped" data-id="MULTIUN-V1.EN-RU_8934468" data-lang="ru" title="Произношение">
#          </button>
#         </div>
#         <div class="trg">
#          <button class="icon more-context" data-id="MULTIUN-V1.EN-RU_8934468" title="Посмотреть примеры для этого перевода в контексте (https://conferences.unite.un.org/UNCorpus)">
#          </button>
#          <button class="report icon thumb-down" data-id="MULTIUN-V1.EN-RU_8934468" title="Сообщить о проблеме в этом примере">
#          </button>
#          <button class="add icon addentry " data-id="MULTIUN-V1.EN-RU_8934468" data-text="The Commission is &lt;em&gt;mindful&lt;/em&gt; of such other aspects of the General Assembly's agenda item." data-url="https://dictionary.reverso.net/CollabDict.aspx?view=2&amp;lang=RU" title="Добавить этот перевод в коллективный словарь Reverso">
#          </button>
#          <button class="copy icon mobile-hidden" data-id="MULTIUN-V1.EN-RU_8934468" title="Скопировать перевод">
#          </button>
#          <button class="icon non-favourite " data-id="MULTIUN-V1.EN-RU_8934468" title="Отметить пример в качестве избранного">
#          </button>
#          <button class="voice icon stopped" data-id="MULTIUN-V1.EN-RU_8934468" data-lang="en" title="Произношение">
#          </button>
#         </div>
#        </div>
#        <button class="mobile-voice icon stopped " data-id="MULTIUN-V1.EN-RU_8934468">
#        </button>
#       </div>
#       <div class="popup wide-container" id="blocked-rude-results-banner">
#        <div class="header">
#        </div>
#        <div class="body">
#         <span>
#          Возможно неприемлемое содержание
#         </span>
#         <div class="buttons-content">
#          <button class="button close">
#           Показать
#          </button>
#         </div>
#         <span class="disclaimer">
#          Примеры предназначены только для помощи в переводе искомых слов и выражений в различных контекстах. Мы не выбираем и не утверждаем примеры, и они могут содержать неприемлемые слова или идеи. Пожалуйста, сообщайте нам о примерах, которые, на Ваш взгляд, необходимо исправить или удалить. Грубые или разговорные переводы обычно отмечены красным или оранжевым цветом.
#         </span>
#        </div>
#       </div>
#       <div class="popup wide-container" id="blocked-results-banner">
#        <div class="header">
#         <button class="icon close">
#         </button>
#        </div>
#        <div class="body">
#         <span>
#          Зарегистрируйтесь, чтобы увидеть больше примеров.
#         </span>
#         <div class="buttons-content">
#          <a class="button register" href="https://account.reverso.net/register/context.reverso.net/ru?utm_source=contextweb&amp;utm_medium=blockedexamples&amp;utm_campaign=register">
#           Зарегистрироваться
#          </a>
#          <a class="button login" href="https://account.reverso.net/login/context.reverso.net/ru?utm_source=contextweb&amp;utm_medium=blockedexamples&amp;utm_campaign=login">
#           Войти
#          </a>
#         </div>
#        </div>
#       </div>
#      </section>
#      <section id="no-results">
#       <span class="wide-container message">
#        Ничего не найдено для этого значения.
#       </span>
#       <div class="wide-container">
#        <button data-ga="display-noexamples" id="add-example" title='Предложить пример для "наличие"'>
#         Предложить пример
#        </button>
#       </div>
#      </section>
#      <section id="examples-bottom">
#       <div class="loading-pannel">
#        <span class="icon">
#        </span>
#       </div>
#       <button class="button load-more unregistered" id="load-more-examples">
#        Больше примеров
#       </button>
#       <div class="wide-container" data-exact="28474" id="result-info">
#        <p>
#         Результатов:
#         <span id="nrows">
#          28474
#         </span>
#         . Точных совпадений:
#         <span id="nrows_exact">
#          28474
#         </span>
#         . Затраченное время:
#         <span id="time">
#          87
#         </span>
#         мс
#        </p>
#       </div>
#       <div class="wide-container">
#        <button data-ga="display-examplesbottom" id="add-example" title='Предложить пример для "наличие"'>
#         Предложить пример
#        </button>
#       </div>
#       <section class="wide-container" id="bottom-suggestions">
#        <div class="suggestion hidden" title="Это предложение исключено из результатов">
#         <span class="text" data-url="/перевод/русский-английский/%D0%BE%D0%B1%D0%B5%D1%81%D0%BF%D0%B5%D1%87%D0%B8%D1%82%D1%8C+%D0%BD%D0%B0%D0%BB%D0%B8%D1%87%D0%B8%D0%B5">
#          обеспечить наличие
#         </span>
#         <span class="figure ">
#          1330
#         </span>
#        </div>
#        <div class="suggestion">
#         <a class="text" href="/перевод/русский-английский/%D0%BD%D0%B5%D1%81%D0%BC%D0%BE%D1%82%D1%80%D1%8F+%D0%BD%D0%B0+%D0%BD%D0%B0%D0%BB%D0%B8%D1%87%D0%B8%D0%B5">
#          несмотря на наличие
#         </a>
#         <span class="figure ">
#          1253
#         </span>
#        </div>
#        <div class="suggestion">
#         <a class="text" href="/перевод/русский-английский/%D1%8F%D0%B2%D0%BB%D1%8F%D0%B5%D1%82%D1%81%D1%8F+%D0%BD%D0%B0%D0%BB%D0%B8%D1%87%D0%B8%D0%B5">
#          является наличие
#         </a>
#         <span class="figure ">
#          1059
#         </span>
#        </div>
#        <div class="suggestion">
#         <a class="text" href="/перевод/русский-английский/%D1%82%D0%B0%D0%BA%D0%B6%D0%B5+%D0%BD%D0%B0%D0%BB%D0%B8%D1%87%D0%B8%D0%B5">
#          также наличие
#         </a>
#         <span class="figure ">
#          528
#         </span>
#        </div>
#        <div class="suggestion hidden" title="Это предложение исключено из результатов">
#         <span class="text" data-url="/перевод/русский-английский/%D0%BF%D1%80%D0%B5%D0%B4%D0%BF%D0%BE%D0%BB%D0%B0%D0%B3%D0%B0%D0%B5%D1%82+%D0%BD%D0%B0%D0%BB%D0%B8%D1%87%D0%B8%D0%B5">
#          предполагает наличие
#         </span>
#         <span class="figure ">
#          502
#         </span>
#        </div>
#        <div class="suggestion">
#         <a class="text" href="/перевод/русский-английский/%D0%BD%D0%B0%D0%BB%D0%B8%D1%87%D0%B8%D0%B5+%D1%82%D0%B0%D0%BA%D0%B8%D1%85">
#          наличие таких
#         </a>
#         <span class="figure ">
#          432
#         </span>
#        </div>
#        <div class="suggestion">
#         <a class="text" href="/перевод/русский-английский/%D0%BD%D0%B5%D0%BE%D0%B1%D1%85%D0%BE%D0%B4%D0%B8%D0%BC%D0%BE+%D0%BD%D0%B0%D0%BB%D0%B8%D1%87%D0%B8%D0%B5">
#          необходимо наличие
#         </a>
#         <span class="figure ">
#          413
#         </span>
#        </div>
#        <div class="suggestion">
#         <a class="text" href="/перевод/русский-английский/%D0%BD%D0%B0%D0%BB%D0%B8%D1%87%D0%B8%D0%B5+%D0%B1%D0%BE%D0%BB%D1%8C%D1%88%D0%BE%D0%B3%D0%BE">
#          наличие большого
#         </a>
#         <span class="figure ">
#          315
#         </span>
#        </div>
#        <div class="suggestion hidden" title="Это предложение исключено из результатов">
#         <span class="text" data-url="/перевод/русский-английский/%D0%BE%D0%B1%D0%B5%D1%81%D0%BF%D0%B5%D1%87%D0%B8%D0%B2%D0%B0%D1%82%D1%8C+%D0%BD%D0%B0%D0%BB%D0%B8%D1%87%D0%B8%D0%B5">
#          обеспечивать наличие
#         </span>
#         <span class="figure ">
#          303
#         </span>
#        </div>
#        <button class="icon other other-suggestions" data-negative="-{обеспечить наличие} -{несмотря на наличие} -{является наличие} -{также наличие} -{предполагает наличие} -{наличие таких} -{необходимо наличие} -{наличие большого} -{обеспечивать наличие}" title="Другие переводы">
#        </button>
#       </section>
#      </section>
#     </div>
#     <!-- /64378609/Context_MegaBanner_Bottom -->
#     <div class="hidden" id="bottom-mega-rca-box">
#      <div class="bottom-rca mega-rca" id="div-gpt-ad-Reverso_Ctxt_D_Result_728x90_BTF">
#       <script type="text/javascript">
#        if(!window.mobilecheck()) {
#           googletag.cmd.push(function() {
#             googletag.display('div-gpt-ad-Reverso_Ctxt_D_Result_728x90_BTF');
#           });
#         }
#       </script>
#      </div>
#      <span class="rca-title rca-title-vertical bottom-rca">
#       Реклама
#      </span>
#     </div>
#    </section>
#    <section id="sitemaps">
#     <p>
#      Индекс слова:
#      <a href="/перевод/index/русский-английский/w-1-300.html">
#       1-300
#      </a>
#      ,
#      <a href="/перевод/index/русский-английский/w-301-600.html">
#       301-600
#      </a>
#      ,
#      <a href="/перевод/index/русский-английский/w-601-900.html">
#       601-900
#      </a>
#      ,
#      <a href="/перевод/index/русский-английский/w.html">
#       Больше
#      </a>
#      <p>
#       Индекс выражения:
#       <a href="/перевод/index/русский-английский/e-1-400.html">
#        1-400
#       </a>
#       ,
#       <a href="/перевод/index/русский-английский/e-401-800.html">
#        401-800
#       </a>
#       ,
#       <a href="/перевод/index/русский-английский/e-801-1200.html">
#        801-1200
#       </a>
#       ,
#       <a href="/перевод/index/русский-английский/e.html">
#        Больше
#       </a>
#       <p>
#        Индекс фразы:
#        <a href="/перевод/index/русский-английский/p-1-400.html">
#         1-400
#        </a>
#        ,
#        <a href="/перевод/index/русский-английский/p-401-800.html">
#         401-800
#        </a>
#        ,
#        <a href="/перевод/index/русский-английский/p-801-1200.html">
#         801-1200
#        </a>
#        ,
#        <a href="/перевод/index/русский-английский/p.html">
#         Больше
#        </a>
#       </p>
#      </p>
#     </p>
#    </section>
#    <p class="developers wide-container">
#     Разработано Prompsit Language Engineering для Softissimo
#    </p>
#    <section id="footer">
#     <div class="wide-container">
#      <a href="/перевод/about">
#       Что такое контекстный словарь
#      </a>
#      <a class="app-link" href="/перевод/mobile-app">
#       Скачать приложение
#      </a>
#      <a href="http://www.reverso.net/feedback.aspx?type=3&amp;lang=RU" target="_blank">
#       Контакты
#      </a>
#      <a href="/перевод/legal">
#       Правовые вопросы
#      </a>
#     </div>
#     <div class="wide-container">
#      <a href="/translation/">
#       Translation in context
#      </a>
#      <a href="/traduction/">
#       Traduction en contexte
#      </a>
#      <a href="/traduccion/">
#       Traducción en contexto
#      </a>
#      <a href="/traducao/">
#       Tradução em contexto
#      </a>
#      <a href="/traduzione/">
#       Traduzione in contesto
#      </a>
#      <a href="/übersetzung/">
#       Übersetzung im Kontext
#      </a>
#      <a href="/الترجمة/">
#       الترجمة في السياق
#      </a>
#      <a href="/翻訳/">
#       文脈に沿った翻訳
#      </a>
#      <a href="/vertaling/">
#       Vertaling in context
#      </a>
#      <a href="/תרגום/">
#       תרגום בהקשר
#      </a>
#      <a href="/tłumaczenie/">
#       Tłumaczenie w kontekście
#      </a>
#      <a href="/traducere/">
#       Traducere în context
#      </a>
#      <a href="/çeviri/">
#       İçerik tercümesi
#      </a>
#     </div>
#     <div class="wide-container">
#      <a href="https://synonyms.reverso.net/%D1%81%D0%B8%D0%BD%D0%BE%D0%BD%D0%B8%D0%BC%D1%8B/" target="_blank">
#       Синонимы
#      </a>
#      <a href="http://glagol.reverso.net/%D1%81%D0%BF%D1%80%D1%8F%D0%B6%D0%B5%D0%BD%D0%B8%D0%B5-%D1%80%D1%83%D1%81%D1%81%D0%BA%D0%B8%D0%B9.html" target="_blank">
#       Спряжение
#      </a>
#      <a href="https://www.corporate-translation.reverso.com/" target="_blank">
#       Reverso Corporate
#      </a>
#     </div>
#     <p class="copy">
#      ©  2013-2019 Softissimo Inc. Все права защищены.
#     </p>
#    </section>
#   </div>
#   <script src="https://cdn.reverso.net/context/v51300/js/bst.constants-ru.js" type="text/javascript">
#   </script>
#   <script src="https://cdn.reverso.net/context/v51300/js/bst.scripts.js" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    !function(f,b,e,v,n,t,s){if(f.fbq)return;n=f.fbq=function(){n.callMethod?
#   n.callMethod.apply(n,arguments):n.queue.push(arguments)};if(!f._fbq)f._fbq=n;
#   n.push=n;n.loaded=!0;n.version='2.0';n.queue=[];t=b.createElement(e);t.async=!0;
#   t.src=v;s=b.getElementsByTagName(e)[0];s.parentNode.insertBefore(t,s)}(window,
#   document,'script','https://connect.facebook.net/en_US/fbevents.js');
#   fbq('init', '1090291004350551');
#   fbq('track', "PageView");
#
#   var ezt = ezt ||[];
#   (function(){
#     var elem = document.createElement('script');
#     elem.src = (document.location.protocol == "https:" ? "https://secure" : "http://pixel") + ".quantserve.com/aquant.js?a=p-9z6v4xdJwT5Z-";
#     elem.async = true;
#     elem.type = "text/javascript";
#     var scpt = document.getElementsByTagName('script')[0];
#     scpt.parentNode.insertBefore(elem,scpt);
#   }());
#   ezt.push({qacct: 'p-9z6v4xdJwT5Z-', labels: 'context', uid: '' });
#   </script>
#   <noscript>
#    <img alt="" height="1" src="//pixel.quantserve.com/pixel/p-9z6v4xdJwT5Z-.gif?labels=context" style="display: none;" width="1"/>
#    <img alt="" height="1" src="https://www.facebook.com/tr?id=1090291004350551&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/>
#   </noscript>
#  </body>
# </html>

# %% [markdown]
# # ПЕРВЫЙ ПЕРЕВОД

# %%
url = "https://context.reverso.net/перевод/русский-английский/наличие"
login = {'inUserName': 'n.babakov@lingualeo.com', 'inUserPass': '33vec33'}
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/537.36'}
response = requests.get(url, headers=headers, data = login)
response.encoding = 'utf-8' 

soup = bs(response.text, 'html.parser')
#soup = bs(response.text, 'lxml')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="ru">
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <title>
#    book - Перевод на русский - примеры английский | Reverso Context
#   </title>
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
#   <meta content='Перевод контекст "book" c английский на русский от Reverso Context: to book, book about, comic book, new book, address book' name="description"/>
#   <link href="https://context.reverso.net/translation/english-russian/book" hreflang="en" rel="alternate"/>
#   <link href="https://context.reverso.net/%D0%BF%D0%B5%D1%80%D0%B5%D0%B2%D0%BE%D0%B4/%D0%B0%D0%BD%D0%B3%D0%BB%D0%B8%D0%B9%D1%81%D0%BA%D0%B8%D0%B9-%D1%80%D1%83%D1%81%D1%81%D0%BA%D0%B8%D0%B9/book" hreflang="ru" rel="alternate"/>
#   <link href="android-app://com.softissimo.reverso.context/reversocontext/context.reverso.net/%D0%BF%D0%B5%D1%80%D0%B5%D0%B2%D0%BE%D0%B4/%D0%B0%D0%BD%D0%B3%D0%BB%D0%B8%D0%B9%D1%81%D0%BA%D0%B8%D0%B9-%D1%80%D1%83%D1%81%D1%81%D0%BA%D0%B8%D0%B9/book" rel="alternate"/>
#   <meta content="app-id=919979642, app-argument=reversocontext://context.reverso.net/%D0%BF%D0%B5%D1%80%D0%B5%D0%B2%D0%BE%D0%B4/%D0%B0%D0%BD%D0%B3%D0%BB%D0%B8%D0%B9%D1%81%D0%BA%D0%B8%D0%B9-%D1%80%D1%83%D1%81%D1%81%D0%BA%D0%B8%D0%B9/book" name="apple-itunes-app"/>
#   <link href="/%D0%BF%D0%B5%D1%80%D0%B5%D0%B2%D0%BE%D0%B4/%D0%B0%D0%BD%D0%B3%D0%BB%D0%B8%D0%B9%D1%81%D0%BA%D0%B8%D0%B9-%D1%80%D1%83%D1%81%D1%81%D0%BA%D0%B8%D0%B9/book" rel="canonical"/>
#   <script type="text/javascript">
#    var request = {
#     srctext: "book",
#     trgtext: "",
#     srclang: "en",
#     trglang: "ru",
#     rpage: 1,
#     rmode: 0,
#     original: "book"
#   };
#   </script>
#   <meta content="значение слова, перевод в контексте, перевод онлайн, Reverso Context, идиомы в контексте, инструмент поиска переводов, идиоматический перевод, перевод идиом, пример перевода, примеры перевода, Английский, Французский, Испанский, Иврит, Русский, Арабский, Португальский, Итальянский, Немецкий, Голландский, Польский, Иврит, идиоматические переводы, двуязычный конкорданс, контекстный словарь, пример употребления, примеры употребления, перевод в контексте, любители языка, контекстный пример, идиоматические выражения, словарь, примеры и идиомы, инструмент составления конкорданса" name="keywords"/>
#   <meta content="app-id=com.softissimo.reverso.context" name="google-play-app"/>
#   <meta content="notranslate" name="google">
#    <meta content="initial-scale=1.0" name="viewport"/>
#    <link href="https://cdn.reverso.net/context/v51300/images/reverso-context-logo-for-facebook.png" rel="image_src"/>
#    <link href="https://cdn.reverso.net/context/v51300/images/reverso-context.ico" rel="shortcut icon"/>
#    <link href="https://cdn.reverso.net/context/v51300/images/reverso-context-app-fav-apple.png" rel="apple-touch-icon"/>
#    <link href="https://cdn.reverso.net/context/v51300/images/reverso-context-app-fav-apple-16x16.png" rel="apple-touch-icon" sizes="16x16"/>
#    <link href="https://cdn.reverso.net/context/v51300/images/reverso-context-app-fav-apple-72x72.png" rel="apple-touch-icon" sizes="72x72"/>
#    <link href="https://cdn.reverso.net/context/v51300/images/reverso-context-app-fav-apple-114x114.png" rel="apple-touch-icon" sizes="114x114"/>
#    <style class="font-family">
#     @font-face{font-family:'contexticons';font-display: swap;src:url('https://cdn.reverso.net/context/v51300/fonts/contexticons.eot?phzsmg');src:url('https://cdn.reverso.net/context/v51300/fonts/contexticons.eot?phzsmg#iefix') format('embedded-opentype'),url('https://cdn.reverso.net/context/v51300/fonts/contexticons.ttf?phzsmg') format('truetype'),url('https://cdn.reverso.net/context/v51300/fonts/contexticons.woff?phzsmg') format('woff'),url('https://cdn.reverso.net/context/v51300/fonts/contexticons.svg?phzsmg#contexticons') format('svg');font-weight: normal;font-style: normal;}
#    </style>
#    <link href="https://fonts.googleapis.com/css?family=Montserrat:300,400,500,700|Roboto+Condensed:300,400&amp;subset=cyrillic,cyrillic-ext,latin-ext" rel="stylesheet"/>
#    <link href="https://cdn.reverso.net/context/v51300/css/bst.style.css" rel="stylesheet" type="text/css"/>
#    <script src="//cdn.reverso.net/abp/v1/Static/JS/advertising.js?ch=1" type="text/javascript">
#    </script>
#    <script src="//cdn.reverso.net/abp/v1/Static/JS/advertising.js?ch=2" type="text/javascript">
#    </script>
#    <script async="" src="//cdn.reverso.net/predib/predib-0-33-0.js" type="text/javascript">
#    </script>
#    <script src="//cdn.reverso.net/predib/conf/reverso_context.js" type="text/javascript">
#    </script>
#    <script type="text/javascript">
#     if(typeof window.request === "undefined") {
#     window.request = {
#       srctext: "",
#       trgtext: "",
#       srclang: "en",
#       trglang: "ru",
#       rpage: 1,
#       rmode: 0
#     };
#   }
#   var logLOCD = false;
#   var context_path = '';
#   var special_chars = "،؟י¬¿¡ºª·؛";
#   var is_rtl = false;
#
#   window.mobilecheck = function() {
#     var check = false;
#     (function (a) {
#       if (/(android|bb\d+|meego).+mobile|avantgo|bada\/|blackberry|blazer|compal|elaine|fennec|hiptop|iemobile|ip(hone|od)|iris|kindle|lge |maemo|midp|mmp|mobile.+firefox|netfront|opera m(ob|in)i|palm( os)?|phone|p(ixi|re)\/|plucker|pocket|psp|series(4|6)0|symbian|treo|up\.(browser|link)|vodafone|wap|windows ce|xda|xiino/i.test(a)||/1207|6310|6590|3gso|4thp|50[1-6]i|770s|802s|a wa|abac|ac(er|oo|s\-)|ai(ko|rn)|al(av|ca|co)|amoi|an(ex|ny|yw)|aptu|ar(ch|go)|as(te|us)|attw|au(di|\-m|r |s )|avan|be(ck|ll|nq)|bi(lb|rd)|bl(ac|az)|br(e|v)w|bumb|bw\-(n|u)|c55\/|capi|ccwa|cdm\-|cell|chtm|cldc|cmd\-|co(mp|nd)|craw|da(it|ll|ng)|dbte|dc\-s|devi|dica|dmob|do(c|p)o|ds(12|\-d)|el(49|ai)|em(l2|ul)|er(ic|k0)|esl8|ez([4-7]0|os|wa|ze)|fetc|fly(\-|_)|g1 u|g560|gene|gf\-5|g\-mo|go(\.w|od)|gr(ad|un)|haie|hcit|hd\-(m|p|t)|hei\-|hi(pt|ta)|hp( i|ip)|hs\-c|ht(c(\-| |_|a|g|p|s|t)|tp)|hu(aw|tc)|i\-(20|go|ma)|i230|iac( |\-|\/)|ibro|idea|ig01|ikom|im1k|inno|ipaq|iris|ja(t|v)a|jbro|jemu|jigs|kddi|keji|kgt( |\/)|klon|kpt |kwc\-|kyo(c|k)|le(no|xi)|lg( g|\/(k|l|u)|50|54|\-[a-w])|libw|lynx|m1\-w|m3ga|m50\/|ma(te|ui|xo)|mc(01|21|ca)|m\-cr|me(rc|ri)|mi(o8|oa|ts)|mmef|mo(01|02|bi|de|do|t(\-| |o|v)|zz)|mt(50|p1|v )|mwbp|mywa|n10[0-2]|n20[2-3]|n30(0|2)|n50(0|2|5)|n7(0(0|1)|10)|ne((c|m)\-|on|tf|wf|wg|wt)|nok(6|i)|nzph|o2im|op(ti|wv)|oran|owg1|p800|pan(a|d|t)|pdxg|pg(13|\-([1-8]|c))|phil|pire|pl(ay|uc)|pn\-2|po(ck|rt|se)|prox|psio|pt\-g|qa\-a|qc(07|12|21|32|60|\-[2-7]|i\-)|qtek|r380|r600|raks|rim9|ro(ve|zo)|s55\/|sa(ge|ma|mm|ms|ny|va)|sc(01|h\-|oo|p\-)|sdk\/|se(c(\-|0|1)|47|mc|nd|ri)|sgh\-|shar|sie(\-|m)|sk\-0|sl(45|id)|sm(al|ar|b3|it|t5)|so(ft|ny)|sp(01|h\-|v\-|v )|sy(01|mb)|t2(18|50)|t6(00|10|18)|ta(gt|lk)|tcl\-|tdg\-|tel(i|m)|tim\-|t\-mo|to(pl|sh)|ts(70|m\-|m3|m5)|tx\-9|up(\.b|g1|si)|utst|v400|v750|veri|vi(rg|te)|vk(40|5[0-3]|\-v)|vm40|voda|vulc|vx(52|53|60|61|70|80|81|83|85|98)|w3c(\-| )|webc|whit|wi(g |nc|nw)|wmlb|wonu|x700|yas\-|your|zeto|zte\-/i.test(a.substr(0,4)))
#         check = true
#       })(navigator.userAgent || navigator.vendor || window.opera);
#     return check;
#   };
#
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#     (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#     m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   var ga_log = [];
#
#   function sendGA(command, type, category, action, label, options) {
#     var object = {
#       "command": command,
#       "type": type,
#       "category": category,
#       "action": action,
#       "label": label
#     };
#     ga_log.push(object);
#     if(label !== undefined) ga(command, type, category, action, label, options);
#     else if(action !== undefined) ga(command, type, category, action, options);
#     else if(category !== undefined) ga(command, type, category, options);
#     else ga(command, type, options);
#   };
#
#   sendGA('create', 'UA-2834324-41', 'reverso.net');
#   sendGA('create', 'UA-2834324-49', 'auto', 'keywordTracker');
#   sendGA('require', 'displayfeatures');
#   sendGA('keywordTracker.require', 'displayfeatures');
#   sendGA('set', 'dimension1', logLOCD ? (is_premium ? 'premium' : 'registered') : 'anonymous');
#
#     sendGA('set', 'dimension4', typeof(adblock)=='undefined' ? 'yes' : (typeof(abp)!='undefined' && abp ? 'abp' : 'no' ));
#
#   sendGA('send', 'pageview', '/bst/result/en-ru/1w/translations-precomputed');
#   sendGA('keywordTracker.send', 'pageview');
#
#     var googletag = googletag || {};
#     googletag.cmd = googletag.cmd || [];
#
#     googletag.cmd.push(function() {
#         googletag.pubads().disableInitialLoad();
#         setReversoTargeting();
#     });
#     if (typeof (adblock) != 'undefined') {
#       var device = (window.mobilecheck() ? "mobile" : (window.innerWidth>1024 ? "desktop" : "tablet"));
#
#       var prebid_config = prebid_config || new prebidConfig();
#       var PREBID_TIMEOUT = prebid_config.getTimeout() || 800;
#       var GA_VARIATION = typeof(prebid_config) != 'undefined' ? prebid_config.getVariation() : 0;
#
#       var ads_array = [];
#       if (device === "desktop") {
#         ads_array = ['Reverso_Ctxt_D_Result_300x250_ATF', 'Reverso_Ctxt_D_Result_300x250_BTF', 'Reverso_Ctxt_D_Result_300x600_BTF', 'Reverso_Ctxt_D_Result_728x90_BTF']
#       }
#       else if (device === "mobile") {
#         ads_array = ['Reverso_Ctxt_M_Result_320x50_BTF'];
#       }
#       else {
#         ads_array = ['Reverso_Ctxt_D_Result_728x90_BTF'];
#       }
#
#         ads_array.push('Reverso_Ctxt_R_Result_InFeed_ATF');
#
#
#       var adsetup = prebid_config.getAdSetup(ads_array) || [];
#       var adUnits = prebid_config.getAdUnits(adsetup) || [];
#
#       if(typeof(abp) != 'undefined' && abp){adUnits=[];}
#
#       (function() {
#           var gads = document.createElement('script');
#           gads.async = true;
#           gads.type = 'text/javascript';
#           var useSSL = 'https:' == document.location.protocol;
#           gads.src = (useSSL ? 'https:' : 'http:') +
#           '//www.googletagservices.com/tag/js/gpt.js';
#           var node = document.getElementsByTagName('script')[0];
#           node.parentNode.insertBefore(gads, node);
#       })();
#
#       var slots = [];
#
#       googletag.cmd.push(function() {
#           for (var i in adsetup) {
#             n = adsetup[i];
#             slots[n['slotcode']] = googletag.defineSlot('/2629866/'+n['slotname'][0], n['slotsizes'], n['slotcode']).addService(googletag.pubads());
#           }
#
#           googletag.pubads().enableSingleRequest();
#           googletag.enableServices();
#       });
#
#       var pbjs = pbjs || {};
#       pbjs.que = pbjs.que || [];
#
#       prebid_config.setBidderSettings(pbjs);
#       prebid_config.setConfig(pbjs);
#       prebid_config.setAnalyticsSettings(pbjs);
#
#       pbjs.que.push(function() {
#         pbjs.addAdUnits(adUnits);
#         if(device === "desktop"){
#           pbjs.requestBids({
#             timeout: adUnits.length ? PREBID_TIMEOUT : 100,
#             adUnitCodes: ['div-gpt-ad-Reverso_Ctxt_D_Result_300x250_ATF', 'div-gpt-ad-Reverso_Ctxt_D_Result_300x250_BTF'],
#             bidsBackHandler: sendAdserverRequest
#           });
#         }
#         });
#
#       function isGptPubadsDefined() {
#         return window.googletag && typeof window.googletag.pubads === "function" && typeof window.googletag.pubads().getSlots === "function";
#       }
#
#       function refreshBids(adUnitCodes) {
#           if (!isGptPubadsDefined()) {
#             setTimeout(function() {
#               refreshBids(adUnitCodes);
#             }, 100);
#             return;
#           }
#           refresh_adsetup = prebid_config.getAdSetup(adUnitCodes) || [];
#           refresh_adunits = prebid_config.getAdUnits(refresh_adsetup) || [];
#           var gptAdSlots = [];
#           for (i in refresh_adsetup) {
#             gptAdSlots.push(slots[refresh_adsetup[i].slotcode]);
#           }
#           if(refresh_adunits.length && (typeof(abp) == 'undefined' || !abp)){
#             pbjs.que.push(function() {
#               pbjs.requestBids({
#                 timeout: PREBID_TIMEOUT,
#                 adUnitCodes: refresh_adunits.map(function (x) { return x.code; }),
#                 bidsBackHandler: function() {
#                   pbjs.setTargetingForGPTAsync(adUnitCodes);
#                   googletag.pubads().refresh(gptAdSlots, {changeCorrelator: false});
#                 }
#               });
#             });
#           }
#           else{
#               googletag.pubads().refresh(gptAdSlots, {changeCorrelator: false});
#           }
#       }
#
#       function setReversoTargeting() {
#           var adtargeting = {};
#
#           adtargeting['abtest'] = GA_VARIATION || 0;
#           adtargeting['Interface'] = 'RU';
#           adtargeting['device'] = device;
#           adtargeting['Status'] = 'prod';
#
#             adtargeting['Direction'] = 'EN-RU';
#
#
#           if(typeof(abp) != 'undefined' && abp){
#             adtargeting['abp'] = '1';
#         	}
#
#           for (var i in adtargeting) {
#             googletag.pubads().clearTargeting(i);
#             googletag.pubads().setTargeting(i, adtargeting[i]);
#           }
#       }
#
#       function sendAdserverRequest() {
#           if (pbjs.adserverRequestSent) return;
#           pbjs.adserverRequestSent = true;
#           googletag.cmd.push(function() {
#               pbjs.que.push(function() {
#                   setReversoTargeting();
#                   if(device === "desktop"){
#                       pbjs.setTargetingForGPTAsync(['div-gpt-ad-Reverso_Ctxt_D_Result_300x250_ATF', 'div-gpt-ad-Reverso_Ctxt_D_Result_300x250_BTF']);
#                       googletag.pubads().refresh([slots['div-gpt-ad-Reverso_Ctxt_D_Result_300x250_ATF'], slots['div-gpt-ad-Reverso_Ctxt_D_Result_300x250_BTF']], {changeCorrelator: false});
#                   }
#               });
#           });
#       }
#
#       setTimeout(function() {sendAdserverRequest();}, (PREBID_TIMEOUT*1.5));
# 	}
#    </script>
#   </meta>
#  </head>
#  <body class="locked mobile-locked noticed">
#   <div class="loading-pannel">
#    <span class="icon">
#    </span>
#   </div>
#   <div class=" results" id="wrapper">
#    <section id="top-content">
#     <a class="reverso-logo nonselectable no-loading" href="/%D0%BF%D0%B5%D1%80%D0%B5%D0%B2%D0%BE%D0%B4/" title="Reverso Context: поисковая система для переводов в контексте">
#      <div class="logo">
#       <span class="icon reverso-logo-red">
#       </span>
#       <span class="icon reverso-logo-blue">
#       </span>
#      </div>
#      <div class="text">
#       <span class="icon reverso-text">
#       </span>
#       <span class="icon context-text">
#       </span>
#      </div>
#     </a>
#     <div class="closed" id="mobile-menu">
#      <span class="icon menu">
#      </span>
#      <div class="floating-menu">
#       <a class="option register" href="https://account.reverso.net/register/context.reverso.net/ru?utm_source=contextweb&amp;utm_medium=usertopmenu&amp;utm_campaign=register">
#        <span class="icon add-user">
#        </span>
#        <span class="text">
#         Зарегистрироваться
#        </span>
#       </a>
#       <a class="option login" href="https://account.reverso.net/login/context.reverso.net/ru?utm_source=contextweb&amp;utm_medium=usertopmenu&amp;utm_campaign=login">
#        <span class="icon login">
#        </span>
#        <span class="text">
#         Войти
#        </span>
#       </a>
#       <button class="font-resize grey" data-size="0">
#        <span class="icon font-resize">
#        </span>
#        <span class="text">
#         Font size
#        </span>
#       </button>
#       <a class="option help grey" href="/%D0%BF%D0%B5%D1%80%D0%B5%D0%B2%D0%BE%D0%B4/about">
#        <span class="icon help">
#        </span>
#        <span class="text">
#         Помощь
#        </span>
#       </a>
#       <button class="option locale grey">
#        <span class="icon lang">
#        </span>
#        <span class="text">
#         русский
#        </span>
#        <span class="icon down-caret">
#        </span>
#       </button>
#       <div class="interface-langs closed">
#        <button class="option" data-value="ar">
#         العربية
#        </button>
#        <button class="option" data-value="de">
#         Deutsch
#        </button>
#        <button class="option" data-value="en">
#         English
#        </button>
#        <button class="option" data-value="es">
#         Español
#        </button>
#        <button class="option" data-value="fr">
#         Français
#        </button>
#        <button class="option" data-value="he">
#         עברית
#        </button>
#        <button class="option" data-value="it">
#         Italiano
#        </button>
#        <button class="option" data-value="ja">
#         日本語
#        </button>
#        <button class="option" data-value="nl">
#         Nederlands
#        </button>
#        <button class="option" data-value="pl">
#         Polski
#        </button>
#        <button class="option" data-value="pt">
#         Português
#        </button>
#        <button class="option" data-value="ro">
#         Română
#        </button>
#        <button class="option selected" data-value="ru">
#         Русский
#        </button>
#        <button class="option" data-value="tr">
#         Türkçe
#        </button>
#       </div>
#      </div>
#     </div>
#     <div class="selector closed nonselectable" id="top-menu">
#      <span class="option front icon horizontal-dots">
#      </span>
#      <span class="option front space-filler">
#       ···
#      </span>
#      <div class="drop-down">
#       <a class="option translation" href="http://www.reverso.net/text_translation.aspx?lang=RU" target="_blank">
#        <span class="icon lang">
#        </span>
#        <span class="text">
#         Перевод
#        </span>
#       </a>
#       <a class="option dictionary" href="https://dictionary.reverso.net" target="_blank">
#        <span class="icon dictionary">
#        </span>
#        <span class="text">
#         Словарь
#        </span>
#       </a>
#       <a class="option speller" href="http://www.reverso.net/spell-checker/english-spelling-grammar/" target="_blank">
#        <span class="icon spellcheck">
#        </span>
#        <span class="text">
#         Корректор
#        </span>
#       </a>
#       <a class="option conjugation" href="http://glagol.reverso.net/%D1%81%D0%BF%D1%80%D1%8F%D0%B6%D0%B5%D0%BD%D0%B8%D0%B5-%D1%80%D1%83%D1%81%D1%81%D0%BA%D0%B8%D0%B9.html" target="_blank">
#        <span class="icon conjugator">
#        </span>
#        <span class="text">
#         Спряжение
#        </span>
#       </a>
#       <a class="option synonyms" href="https://synonyms.reverso.net/%D1%81%D0%B8%D0%BD%D0%BE%D0%BD%D0%B8%D0%BC%D1%8B/" target="_blank">
#        <span class="icon synonyms">
#        </span>
#        <span class="text">
#         Синонимы
#        </span>
#       </a>
#       <a class="option grammar" href="http://grammar.reverso.net/" target="_blank">
#        <span class="icon translate">
#        </span>
#        <span class="text">
#         Грамматика
#        </span>
#       </a>
#       <a class="option document" href="https://documents.reverso.net/Default.aspx?lang=en" target="_blank">
#        <span class="icon document">
#        </span>
#        <span class="text">
#         Перевод документов и сайтов
#        </span>
#       </a>
#       <a class="option corporate" href="https://www.corporate-translation.reverso.com/">
#        <span class="icon corporate">
#        </span>
#        <span class="text">
#         Корпоративные решения
#        </span>
#       </a>
#       <a class="option newsletter" href="http://www.reverso.net/tricks.aspx?type=3&amp;lang=RU" target="_blank">
#        <span class="icon mail">
#        </span>
#        <span class="text">
#         Новостная рассылка
#        </span>
#       </a>
#       <a class="option help" href="/%D0%BF%D0%B5%D1%80%D0%B5%D0%B2%D0%BE%D0%B4/about">
#        <span class="icon help">
#        </span>
#        <span class="text">
#         Помощь
#        </span>
#       </a>
#      </div>
#     </div>
#     <div class="selector closed double nonselectable" id="lang-selector">
#      <span class="option front">
#       ru
#      </span>
#      <span class="icon down-caret">
#      </span>
#      <span class="option front space-filler">
#       ···
#      </span>
#      <div class="drop-down">
#       <div class="option" data-value="ar">
#        العربية
#       </div>
#       <div class="option" data-value="de">
#        Deutsch
#       </div>
#       <div class="option" data-value="en">
#        English
#       </div>
#       <div class="option" data-value="es">
#        Español
#       </div>
#       <div class="option" data-value="fr">
#        Français
#       </div>
#       <div class="option" data-value="he">
#        עברית
#       </div>
#       <div class="option" data-value="it">
#        Italiano
#       </div>
#       <div class="option" data-value="ja">
#        日本語
#       </div>
#       <div class="option" data-value="nl">
#        Nederlands
#       </div>
#       <div class="option" data-value="pl">
#        Polski
#       </div>
#       <div class="option" data-value="pt">
#        Português
#       </div>
#       <div class="option" data-value="ro">
#        Română
#       </div>
#       <div class="option selected" data-value="ru">
#        Русский
#       </div>
#       <div class="option" data-value="tr">
#        Türkçe
#       </div>
#      </div>
#     </div>
#     <button class="icon font-resize" data-size="0" title="Кликните, чтобы увеличить или уменьшить размер текста.">
#     </button>
#     <div class="reverso-links">
#      <a class="translation-link" href="http://www.reverso.net/text_translation.aspx?lang=RU" target="_blank">
#       Перевод
#      </a>
#      <a class="dictionary-link" href="https://dictionary.reverso.net" target="_blank">
#       Словарь
#      </a>
#      <a class="speller-link" href="http://www.reverso.net/spell-checker/english-spelling-grammar/" target="_blank">
#       Корректор
#      </a>
#      <a class="conjugation-link" href="http://glagol.reverso.net/%D1%81%D0%BF%D1%80%D1%8F%D0%B6%D0%B5%D0%BD%D0%B8%D0%B5-%D1%80%D1%83%D1%81%D1%81%D0%BA%D0%B8%D0%B9.html" target="_blank">
#       Спряжение
#      </a>
#      <a class="synonyms-link " href="https://synonyms.reverso.net/%D1%81%D0%B8%D0%BD%D0%BE%D0%BD%D0%B8%D0%BC%D1%8B/" target="_blank">
#       Синонимы
#      </a>
#      <a class="grammar-link last" href="http://grammar.reverso.net/" target="_blank">
#       Грамматика
#      </a>
#     </div>
#     <div class="social-content">
#      <a class="facebook-link icon facebook" href="https://www.facebook.com/Reverso.net?ref=ts" target="_blank" title="Facebook">
#      </a>
#      <a class="twitter-link icon twitter" href="https://twitter.com/ReversoEN" target="_blank" title="Twitter">
#      </a>
#      <a class="instagram-link icon instagram" href="https://www.instagram.com/reverso_app/?hl=ru" target="_blank" title="Instagram">
#      </a>
#     </div>
#     <!-- end top-bar -->
#    </section>
#    <section id="reverso-nav">
#     <a class="translation-link" href="http://www.reverso.net/text_translation.aspx?lang=RU" target="_blank">
#      Перевод
#     </a>
#     <span>
#      Context
#     </span>
#     <a class="conjugation-link" href="http://glagol.reverso.net/%D1%81%D0%BF%D1%80%D1%8F%D0%B6%D0%B5%D0%BD%D0%B8%D0%B5-%D1%80%D1%83%D1%81%D1%81%D0%BA%D0%B8%D0%B9.html" target="_blank">
#      Спряжение
#     </a>
#     <a class="synonyms-link" href="https://synonyms.reverso.net/%D1%81%D0%B8%D0%BD%D0%BE%D0%BD%D0%B8%D0%BC%D1%8B/" target="_blank">
#      Синонимы
#     </a>
#    </section>
#    <section id="body-content">
#     <div class="right-content">
#      <section id="subtop-content">
#       <script>
#        var register_link = "https://account.reverso.net/register/context.reverso.net/ru?utm_source=contextweb&utm_medium={0}&utm_campaign=register";
#     var login_link = "https://account.reverso.net/login/context.reverso.net/ru?utm_source=contextweb&utm_medium={0}&utm_campaign=login";
#       </script>
#       <div class="selector closed nonselectable " id="user-menu">
#        <span class="icon down-caret">
#        </span>
#        <span class="option front">
#         <span class="icon user">
#          <span class="icon rocket">
#          </span>
#         </span>
#         Присоединиться к Reverso
#        </span>
#        <div class="drop-down">
#         <a class="option register" href="https://account.reverso.net/register/context.reverso.net/ru?utm_source=contextweb&amp;utm_medium=usertopmenu&amp;utm_campaign=register">
#          <span class="icon add-user">
#          </span>
#          <span class="text">
#           Зарегистрироваться
#          </span>
#         </a>
#         <a class="option login" href="https://account.reverso.net/login/context.reverso.net/ru?utm_source=contextweb&amp;utm_medium=usertopmenu&amp;utm_campaign=login">
#          <span class="icon login">
#          </span>
#          <span class="text">
#           Войти
#          </span>
#         </a>
#         <span class="option facebook" data-url="null" id="fb-content">
#          <span class="icon facebook">
#          </span>
#          <span class="text">
#           Войти через Facebook
#          </span>
#         </span>
#         <span class="option google" data-url="null" id="google-content">
#          <span class="icon google3">
#          </span>
#          <span class="text">
#           Войти через Google
#          </span>
#         </span>
#        </div>
#       </div>
#       <div id="title-content">
#       </div>
#      </section>
#      <div id="rca">
#       <!-- /64378609/Context_300x250_Top -->
#       <span class="rca-title">
#        Реклама
#       </span>
#       <div class="rca" id="div-gpt-ad-Reverso_Ctxt_D_Result_300x250_ATF">
#        <script type="text/javascript">
#         if(!window.mobilecheck()) {
#         googletag.cmd.push(function() {
#           googletag.display('div-gpt-ad-Reverso_Ctxt_D_Result_300x250_ATF');
#         });
#       }
#        </script>
#       </div>
#       <div id="side-badges">
#        <a class="badge extension disabled mobile-hidden" href="" id="extension-badge" target="_blank">
#         <span class="logo">
#         </span>
#         <span class="text">
#          Добавить Reverso в {0}
#          <b>
#           Бесплатно
#          </b>
#         </span>
#        </a>
#        <div class="badges pannel">
#         <a class="text" href="/перевод/mobile-app?utm_source=contextweb&amp;utm_medium=banner&amp;utm_campaign=ctxtresultpage&amp;utm_content=ctxtappdl">
#          Скачать наше
#          <b>
#           бесплатное
#          </b>
#          приложение
#         </a>
#         <a class="badge and no-loading ru" href="/перевод/mobile-app?utm_source=contextweb&amp;utm_medium=banner&amp;utm_campaign=ctxtresultpage&amp;utm_content=ctxtappdl">
#         </a>
#         <a class="badge ios no-loading ru" href="/перевод/mobile-app?utm_source=contextweb&amp;utm_medium=banner&amp;utm_campaign=ctxtresultpage&amp;utm_content=ctxtappdl">
#         </a>
#        </div>
#       </div>
#       <!-- /64378609/Context_300x250_Bottom -->
#       <span class="rca-title">
#        Реклама
#       </span>
#       <div class="rca" id="div-gpt-ad-Reverso_Ctxt_D_Result_300x250_BTF">
#        <script type="text/javascript">
#         if(!window.mobilecheck()) {
#         googletag.cmd.push(function() {
#           googletag.display('div-gpt-ad-Reverso_Ctxt_D_Result_300x250_BTF');
#         });
#       }
#        </script>
#       </div>
#       <!-- /64378609/Context_300x600 -->
#       <span class="rca-title disabled tall-rca">
#        Реклама
#       </span>
#       <div class="rca disabled tall-rca" id="div-gpt-ad-Reverso_Ctxt_D_Result_300x600_BTF">
#        <script type="text/javascript">
#         if(!window.mobilecheck()) {
# 		  googletag.cmd.push(function() {
# 			googletag.display('div-gpt-ad-Reverso_Ctxt_D_Result_300x600_BTF');
# 		  });
#         }
#        </script>
#       </div>
#      </div>
#     </div>
#     <div class="left-content">
#      <div class="popup closed" id="register-popup-bottom">
#       <div class="header">
#        <span class="title">
#         Присоединяйтесь к Reverso, это
#         <b>
#          удобно и бесплатно
#         </b>
#         !
#        </span>
#        <button class="icon up-arrow" title="закрыть">
#        </button>
#       </div>
#       <div class="body wide-container">
#        <a class="button register" href="https://account.reverso.net/register/context.reverso.net/ru?utm_source=contextweb&amp;utm_medium=floatingpopup&amp;utm_campaign=register">
#         <span class="icon add-user">
#         </span>
#         Зарегистрироваться
#        </a>
#        <a class="button login" href="https://account.reverso.net/login/context.reverso.net/ru?utm_source=contextweb&amp;utm_medium=floatingpopup&amp;utm_campaign=login">
#         <span class="icon login">
#         </span>
#         Войти
#        </a>
#       </div>
#      </div>
#      <section id="search-content">
#       <div id="search">
#        <div class="ltr" id="search-input">
#         <div class="icons">
#          <button class="icon exclude" title="Кликните здесь, чтобы исключить некоторые слова из поиска. Например, слово1 -{слово2} : будут найдены примеры, которые содержат слово1 и НЕ содержат слово2">
#          </button>
#          <button class="icon cancel" title="Очистить ввод">
#          </button>
#         </div>
#         <input autocapitalize="none" autocomplete="off" class="keyboardInput ui-autocomplete-input ltr" id="entry" name="text" placeholder="Введите или вставьте текст" tabindex="1" type="text" value="book"/>
#        </div>
#        <div class="nonselectable" id="pair-selector">
#         <div class="selector double closed" id="src-selector" tabindex="2">
#          <span class="icon down-caret">
#          </span>
#          <span class="option front" data-value="en">
#           английский
#          </span>
#          <span class="space-filler">
#          </span>
#          <div class="drop-down">
#           <span class="option" data-value="ar">
#            арабский
#           </span>
#           <span class="option" data-value="de">
#            немецкий
#           </span>
#           <span class="option selected" data-value="en">
#            английский
#           </span>
#           <span class="option" data-value="es">
#            испанский
#           </span>
#           <span class="option" data-value="fr">
#            французский
#           </span>
#           <span class="option" data-value="he">
#            иврит
#           </span>
#           <span class="option" data-value="it">
#            итальянский
#           </span>
#           <span class="option" data-value="ja">
#            японский
#           </span>
#           <span class="option" data-value="nl">
#            голландский
#           </span>
#           <span class="option" data-value="pl">
#            польский
#           </span>
#           <span class="option" data-value="pt">
#            португальский
#           </span>
#           <span class="option" data-value="ro">
#            румынский
#           </span>
#           <span class="option" data-value="ru">
#            русский
#           </span>
#           <span class="option" data-value="tr">
#            турецкий
#           </span>
#          </div>
#         </div>
#         <div class="swap-content" title="Сменить направление перевода">
#          <div class="icons" tabindex="3">
#           <span class="icon reverso-top">
#           </span>
#           <span class="icon reverso-bottom">
#           </span>
#          </div>
#         </div>
#         <div class="selector double closed" id="trg-selector" tabindex="4">
#          <span class="icon down-caret">
#          </span>
#          <span class="option front" data-value="ru">
#           русский
#          </span>
#          <span class="space-filler">
#          </span>
#          <div class="drop-down">
#           <span class="option" data-value="ar">
#            арабский
#           </span>
#           <span class="option" data-value="de">
#            немецкий
#           </span>
#           <span class="option" data-value="en">
#            английский
#           </span>
#           <span class="option" data-value="es">
#            испанский
#           </span>
#           <span class="option" data-value="fr">
#            французский
#           </span>
#           <span class="option" data-value="he">
#            иврит
#           </span>
#           <span class="option" data-value="it">
#            итальянский
#           </span>
#           <span class="option" data-value="ja">
#            японский
#           </span>
#           <span class="option" data-value="nl">
#            голландский
#           </span>
#           <span class="option" data-value="pl">
#            польский
#           </span>
#           <span class="option" data-value="pt">
#            португальский
#           </span>
#           <span class="option" data-value="ro">
#            румынский
#           </span>
#           <span class="option selected" data-value="ru">
#            русский
#           </span>
#           <span class="option" data-value="tr">
#            турецкий
#           </span>
#          </div>
#         </div>
#        </div>
#        <button class="icon search" id="search-button" tabindex="5" title="Поиск">
#        </button>
#        <div class="exclude-content">
#         <button class="icon add disabled">
#         </button>
#         <div class="input-content">
#          <input placeholder="Исключить из поиска"/>
#         </div>
#        </div>
#       </div>
#      </section>
#      <section id="notice-content">
#       <div id="search-links">
#        <a class="icon synonyms" data-value="synonyms" href="https://synonyms.reverso.net/%D1%81%D0%B8%D0%BD%D0%BE%D0%BD%D0%B8%D0%BC%D1%8B/en/book" target="_blank" title="Искать в Синонимы">
#        </a>
#        <a class="icon conjugator" data-value="conjugator" href="http://glagol.reverso.net/%D1%81%D0%BF%D1%80%D1%8F%D0%B6%D0%B5%D0%BD%D0%B8%D0%B5-%D0%B0%D0%BD%D0%B3%D0%BB%D0%B8%D0%B9%D1%81%D0%BA%D0%B8%D0%B9-%D0%B3%D0%BB%D0%B0%D0%B3%D0%BE%D0%BB-book.html" target="_blank" title="Искать в Спряжение">
#        </a>
#        <button class="icon web" data-url="https://www.google.com/search?hl=en&amp;q=" data-value="web" title="Искать в Интернете">
#        </button>
#        <button class="icon wikipedia" data-url="https://en.wikipedia.org/wiki/" data-value="wikipedia" title="Искать в Wikipedia">
#        </button>
#        <button class="icon images" data-url="https://www.google.com/search?hl=en&amp;tbm=isch&amp;q=" data-value="images" title="Искать в Картинках">
#        </button>
#        <a class="icon dictionary" data-value="definition" href="https://dictionary.reverso.net/english-definition/book" target="_blank" title="Искать в Oпределение">
#        </a>
#       </div>
#       <div class="notice" id="seealso-content">
#        <span class="icon info">
#        </span>
#        <span class="message">
#         Посмотреть также:
#        </span>
#        <a class="" href="/перевод/английский-русский/to+book">
#         to book
#        </a>
#        <a class="" href="/перевод/английский-русский/comic+book">
#         comic book
#        </a>
#        <a class="" href="/перевод/английский-русский/by+the+book">
#         by the book
#        </a>
#       </div>
#       <script>
#        sendGA("send", "event", "seealso", "display", "en-ru");
#       </script>
#       <div class="notice" id="conj_search">
#        <i class="icon info">
#        </i>
#        <a class="suggestion" href="http://glagol.reverso.net/%D1%81%D0%BF%D1%80%D1%8F%D0%B6%D0%B5%D0%BD%D0%B8%D0%B5-%D0%B0%D0%BD%D0%B3%D0%BB%D0%B8%D0%B9%D1%81%D0%BA%D0%B8%D0%B9-%D0%B3%D0%BB%D0%B0%D0%B3%D0%BE%D0%BB-book.html" target="_blank">
#         Conjugation of this verb
#        </a>
#       </div>
#       <div class="notice" id="rude">
#        <i class="icon warning">
#        </i>
#        <span class="message">
#         На основании Вашего запроса эти примеры могут содержать грубую лексику.
#        </span>
#       </div>
#       <div class="notice" id="colloquial">
#        <i class="icon warning">
#        </i>
#        <span class="message">
#         На основании Вашего запроса эти примеры могут содержать разговорную лексику.
#        </span>
#       </div>
#      </section>
#      <section id="top-results">
#       <section class="" id="search-options">
#        <button class="icon down-arrow detailed-view closed" title="Показать подробности и рекомендации">
#        </button>
#        <div class="title-content">
#         <h1>
#          Перевод "book" на русский
#         </h1>
#        </div>
#       </section>
#       <div id="pos-filters">
#        <button class="n" data-index="0" data-pos="n." title="Показать все переводы, отмеченные как Существительное">
#         Сущ.
#        </button>
#        <button class="adj" data-index="1" data-pos="adj." title="Показать все переводы, отмеченные как Прилагательное">
#         Прил.
#        </button>
#        <button class="v" data-index="2" data-pos="v." title="Показать все переводы, отмеченные как Глагол">
#         Глагол
#        </button>
#        <div id="synonyms-button-container">
#         <a class="icon synonyms" dir=" ltr " href="https://synonyms.reverso.net/%D1%81%D0%B8%D0%BD%D0%BE%D0%BD%D0%B8%D0%BC%D1%8B/en/book" id="synonyms-button" target="_blank" title="Синонимы">
#         </a>
#        </div>
#       </div>
#       <div class="wide-container" id="filtered-entry">
#       </div>
#       <div class="wide-container" id="translations-content">
#        <a class="translation ltr dict n" data-freq="18521" data-pos="[nf]" data-pos-index="0" data-posgroup="1" href="/перевод/русский-английский/%D0%BA%D0%BD%D0%B8%D0%B3%D0%B0" title="&lt;div class='nobold'&gt;Посмотреть примеры с переводом &lt;em class='translation'&gt;книга&lt;/em&gt;&lt;br&gt;Существительное - женский род&lt;br&gt;(+10k примеров, содержащих перевод)&lt;/div&gt;">
#         <div class="pos-mark">
#          <span class="n" title="Существительное - женский род">
#          </span>
#         </div>
#         книга
#        </a>
#        <a class="translation ltr dict n" data-freq="1094" data-pos="[nf]" data-pos-index="0" data-posgroup="1" href="/перевод/русский-английский/%D0%BA%D0%BD%D0%B8%D0%B6%D0%BA%D0%B0" title="&lt;div class='nobold'&gt;Посмотреть примеры с переводом &lt;em class='translation'&gt;книжка&lt;/em&gt;&lt;br&gt;Существительное - женский род&lt;br&gt;(1094 примеров, содержащих перевод)&lt;/div&gt;">
#         <div class="pos-mark">
#          <span class="n" title="Существительное - женский род">
#          </span>
#         </div>
#         книжка
#        </a>
#        <a class="translation ltr dict n" data-freq="199" data-pos="[nm]" data-pos-index="0" data-posgroup="1" href="/перевод/русский-английский/%D1%81%D0%BF%D1%80%D0%B0%D0%B2%D0%BE%D1%87%D0%BD%D0%B8%D0%BA" title="&lt;div class='nobold'&gt;Посмотреть примеры с переводом &lt;em class='translation'&gt;справочник&lt;/em&gt;&lt;br&gt;Существительное - мужской род&lt;br&gt;(199 примеров, содержащих перевод)&lt;/div&gt;">
#         <div class="pos-mark">
#          <span class="n" title="Существительное - мужской род">
#          </span>
#         </div>
#         справочник
#        </a>
#        <a class="translation ltr dict n" data-freq="181" data-pos="[nm]" data-pos-index="0" data-posgroup="1" href="/перевод/русский-английский/%D1%83%D1%87%D0%B5%D0%B1%D0%BD%D0%B8%D0%BA" title="&lt;div class='nobold'&gt;Посмотреть примеры с переводом &lt;em class='translation'&gt;учебник&lt;/em&gt;&lt;br&gt;Существительное - мужской род&lt;br&gt;(181 примеров, содержащих перевод)&lt;/div&gt;">
#         <div class="pos-mark">
#          <span class="n" title="Существительное - мужской род">
#          </span>
#         </div>
#         учебник
#        </a>
#        <a class="translation ltr dict n" data-freq="89" data-pos="[nm]" data-pos-index="0" data-posgroup="1" href="/перевод/русский-английский/%D0%B6%D1%83%D1%80%D0%BD%D0%B0%D0%BB" title="&lt;div class='nobold'&gt;Посмотреть примеры с переводом &lt;em class='translation'&gt;журнал&lt;/em&gt;&lt;br&gt;Существительное - мужской род&lt;br&gt;(89 примеров, содержащих перевод)&lt;/div&gt;">
#         <div class="pos-mark">
#          <span class="n" title="Существительное - мужской род">
#          </span>
#         </div>
#         журнал
#        </a>
#        <a class="translation ltr dict n" data-freq="75" data-pos="[nm]" data-pos-index="0" data-posgroup="1" href="/перевод/русский-английский/%D0%B0%D0%BB%D1%8C%D0%B1%D0%BE%D0%BC" title="&lt;div class='nobold'&gt;Посмотреть примеры с переводом &lt;em class='translation'&gt;альбом&lt;/em&gt;&lt;br&gt;Существительное - мужской род&lt;br&gt;(75 примеров, содержащих перевод)&lt;/div&gt;">
#         <div class="pos-mark">
#          <span class="n" title="Существительное - мужской род">
#          </span>
#         </div>
#         альбом
#        </a>
#        <a class="translation ltr dict n" data-freq="73" data-pos="[n]" data-pos-index="0" data-posgroup="1" href="/перевод/русский-английский/%D1%82%D0%B5%D1%82%D1%80%D0%B0%D0%B4%D1%8C" title="&lt;div class='nobold'&gt;Посмотреть примеры с переводом &lt;em class='translation'&gt;тетрадь&lt;/em&gt;&lt;br&gt;Существительное&lt;br&gt;(73 примеров, содержащих перевод)&lt;/div&gt;">
#         <div class="pos-mark">
#          <span class="n" title="Существительное">
#          </span>
#         </div>
#         тетрадь
#        </a>
#        <a class="translation ltr dict first n" data-freq="60" data-pos="[nm]" data-pos-index="0" data-posgroup="1" href="/перевод/русский-английский/%D0%B1%D0%BB%D0%BE%D0%BA%D0%BD%D0%BE%D1%82" title="&lt;div class='nobold'&gt;Посмотреть примеры с переводом &lt;em class='translation'&gt;блокнот&lt;/em&gt;&lt;br&gt;Существительное - мужской род&lt;br&gt;(60 примеров, содержащих перевод)&lt;/div&gt;">
#         <div class="pos-mark">
#          <span class="n" title="Существительное - мужской род">
#          </span>
#         </div>
#         блокнот
#        </a>
#        <a class="translation ltr dict first adj" data-freq="743" data-pos="[adj]" data-pos-index="1" data-posgroup="2" href="/перевод/русский-английский/%D0%BA%D0%BD%D0%B8%D0%B6%D0%BD%D1%8B%D0%B9" title="&lt;div class='nobold'&gt;Посмотреть примеры с переводом &lt;em class='translation'&gt;книжный&lt;/em&gt;&lt;br&gt;Прилагательное&lt;br&gt;(743 примеров, содержащих перевод)&lt;/div&gt;">
#         <div class="pos-mark">
#          <span class="adj" title="Прилагательное">
#          </span>
#         </div>
#         книжный
#        </a>
#        <a class="translation ltr dict v" data-freq="205" data-pos="[v]" data-pos-index="2" data-posgroup="3" href="/перевод/русский-английский/%D0%B7%D0%B0%D0%B1%D1%80%D0%BE%D0%BD%D0%B8%D1%80%D0%BE%D0%B2%D0%B0%D1%82%D1%8C" title="&lt;div class='nobold'&gt;Посмотреть примеры с переводом &lt;em class='translation'&gt;забронировать&lt;/em&gt;&lt;br&gt;Глагол&lt;br&gt;(205 примеров, содержащих перевод)&lt;/div&gt;">
#         <div class="pos-mark">
#          <span class="v" title="Глагол">
#          </span>
#         </div>
#         забронировать
#        </a>
#        <a class="translation ltr dict mobile-hidden v" data-freq="166" data-pos="[v]" data-pos-index="2" data-posgroup="3" href="/перевод/русский-английский/%D0%B7%D0%B0%D0%BA%D0%B0%D0%B7%D0%B0%D1%82%D1%8C" title="&lt;div class='nobold'&gt;Посмотреть примеры с переводом &lt;em class='translation'&gt;заказать&lt;/em&gt;&lt;br&gt;Глагол&lt;br&gt;(166 примеров, содержащих перевод)&lt;/div&gt;">
#         <div class="pos-mark">
#          <span class="v" title="Глагол">
#          </span>
#         </div>
#         заказать
#        </a>
#        <a class="translation ltr dict mobile-hidden v" data-freq="37" data-pos="[v]" data-pos-index="2" data-posgroup="3" href="/перевод/русский-английский/%D0%B1%D1%80%D0%BE%D0%BD%D0%B8%D1%80%D0%BE%D0%B2%D0%B0%D1%82%D1%8C" title="&lt;div class='nobold'&gt;Посмотреть примеры с переводом &lt;em class='translation'&gt;бронировать&lt;/em&gt;&lt;br&gt;Глагол&lt;br&gt;(37 примеров, содержащих перевод)&lt;/div&gt;">
#         <div class="pos-mark">
#          <span class="v" title="Глагол">
#          </span>
#         </div>
#         бронировать
#        </a>
#        <div class="translation ltr dict mobile-hidden v" data-freq="18" data-pos="[v]" data-pos-index="2" data-posgroup="3" title="&lt;div class='nobold'&gt;Посмотреть примеры с переводом &lt;em class='translation'&gt;заказывать&lt;/em&gt;&lt;br&gt;Глагол&lt;br&gt;(18 примеров, содержащих перевод)&lt;/div&gt;">
#         <div class="pos-mark">
#          <span class="v" title="Глагол">
#          </span>
#         </div>
#         заказывать
#        </div>
#        <div class="translation ltr dict first mobile-hidden v" data-freq="6" data-pos="[v]" data-pos-index="2" data-posgroup="3" title="&lt;div class='nobold'&gt;Посмотреть примеры с переводом &lt;em class='translation'&gt;зарегистрировать&lt;/em&gt;&lt;br&gt;Глагол&lt;br&gt;(6 примеров, содержащих перевод)&lt;/div&gt;">
#         <div class="pos-mark">
#          <span class="v" title="Глагол">
#          </span>
#         </div>
#         зарегистрировать
#        </div>
#        <a class="translation ltr dict mobile-hidden n" data-freq="44" data-pos="[n]" data-pos-index="0" data-posgroup="4" href="/перевод/русский-английский/%D1%81%D0%B1%D0%BE%D1%80%D0%BD%D0%B8%D0%BA" title="&lt;div class='nobold'&gt;Посмотреть примеры с переводом &lt;em class='translation'&gt;сборник&lt;/em&gt;&lt;br&gt;Существительное&lt;br&gt;(44 примеров, содержащих перевод)&lt;/div&gt;">
#         <div class="pos-mark">
#          <span class="n" title="Существительное">
#          </span>
#         </div>
#         сборник
#        </a>
#        <a class="translation ltr dict mobile-hidden n" data-freq="40" data-pos="[nf]" data-pos-index="0" data-posgroup="4" href="/перевод/русский-английский/%D0%BA%D0%BD%D0%B8%D0%B6%D0%B5%D1%87%D0%BA%D0%B0" title="&lt;div class='nobold'&gt;Посмотреть примеры с переводом &lt;em class='translation'&gt;книжечка&lt;/em&gt;&lt;br&gt;Существительное - женский род&lt;br&gt;(40 примеров, содержащих перевод)&lt;/div&gt;">
#         <div class="pos-mark">
#          <span class="n" title="Существительное - женский род">
#          </span>
#         </div>
#         книжечка
#        </a>
#        <a class="translation ltr dict mobile-hidden translation-hidden no-pos" data-freq="102" data-posgroup="6" href="/перевод/русский-английский/%D0%BF%D1%80%D0%B0%D0%B2%D0%B8%D0%BB%D0%B0%D0%BC" title="&lt;div class='nobold'&gt;Посмотреть примеры с переводом &lt;em class='translation'&gt;правилам&lt;/em&gt;&lt;br&gt;(102 примеров, содержащих перевод)&lt;/div&gt;">
#         правилам
#        </a>
#        <div class="translation ltr dict mobile-hidden translation-hidden n" data-freq="7" data-pos="[nn]" data-pos-index="0" data-posgroup="4" title="&lt;div class='nobold'&gt;Посмотреть примеры с переводом &lt;em class='translation'&gt;либретто&lt;/em&gt;&lt;br&gt;Существительное - средний род&lt;br&gt;(7 примеров, содержащих перевод)&lt;/div&gt;">
#         <div class="pos-mark">
#          <span class="n" title="Существительное - средний род">
#          </span>
#         </div>
#         либретто
#        </div>
#        <div class="translation ltr dict mobile-hidden translation-hidden n" data-freq="2" data-pos="[n]" data-pos-index="0" data-posgroup="4" title="&lt;div class='nobold'&gt;Посмотреть примеры с переводом &lt;em class='translation'&gt;книжица&lt;/em&gt;&lt;br&gt;Существительное&lt;br&gt;(2 примеров, содержащих перевод)&lt;/div&gt;">
#         <div class="pos-mark">
#          <span class="n" title="Существительное">
#          </span>
#         </div>
#         книжица
#        </div>
#        <div class="translation icon horizontal-dots" title="Больше">
#        </div>
#       </div>
#       <section class="wide-container" id="filters-content">
#        <button class="other-content" data-negative=" -{книга} -{книжка} -{справочник} -{учебник} -{журнал} -{альбом} -{тетрадь} -{блокнот} -{книжный} -{забронировать} -{заказать} -{бронировать} -{заказывать} -{зарегистрировать} -{сборник} -{книжечка} -{правилам} -{либретто} -{книжица}" data-other="0">
#         Другие переводы
#        </button>
#        <div class="filter-form closed">
#         <button class="icon filter" title="Вы можете получить более точные результаты, указав слово или несколько слов, которые должен содержать перевод. В результате будут показаны только примеры, которые содержат эти слова.">
#         </button>
#         <button class="icon cancel" title="Очистить фильтр">
#         </button>
#         <div class="input-content">
#          <button class="icon exclude" title="Кликните здесь, чтобы исключить некоторые слова из поиска. Например, слово1 -{слово2} : будут найдены примеры, которые содержат слово1 и НЕ содержат слово2">
#          </button>
#          <input autocomplete="off" placeholder="Показать переводы, содержащие..." readonly=""/>
#         </div>
#        </div>
#       </section>
#       <section class="wide-container" id="top-suggestions">
#        <h3>
#         Предложения
# ...
#          </button>
#          <button class="add icon addentry " data-id="OPENSUBTITLES-2016.EN-RU_14980095" data-text="Но в моей &lt;em&gt;книжке&lt;/em&gt; с ним все в порядке." data-url="https://dictionary.reverso.net/CollabDict.aspx?view=2&amp;lang=RU" title="Добавить этот перевод в коллективный словарь Reverso">
#          </button>
#          <button class="copy icon mobile-hidden" data-id="OPENSUBTITLES-2016.EN-RU_14980095" title="Скопировать перевод">
#          </button>
#          <button class="icon non-favourite " data-id="OPENSUBTITLES-2016.EN-RU_14980095" title="Отметить пример в качестве избранного">
#          </button>
#          <button class="voice icon stopped" data-id="OPENSUBTITLES-2016.EN-RU_14980095" data-lang="ru" title="Произношение">
#          </button>
#         </div>
#        </div>
#        <button class="mobile-voice icon stopped played" data-id="OPENSUBTITLES-2016.EN-RU_14980095">
#        </button>
#       </div>
#       <div class="example blocked" id="OPENSUBTITLES-2016.EN-RU_14586129">
#        <div class="src ltr">
#         <span class="text" lang="en">
#          Literally wrote the
#          <em>
#           book
#          </em>
#          on modern naval warfare.
#         </span>
#        </div>
#        <div class="trg ltr">
#         <span class="icon jump-right">
#         </span>
#         <span class="text">
#          Он в буквальном смысле написал
#          <a class="link_highlighted" href="/перевод/русский-английский/%D0%BA%D0%BD%D0%B8%D0%B3%D1%83" rel="nofollow">
#           <em>
#            книгу
#           </em>
#          </a>
#          о современной войне на море.
#         </span>
#        </div>
#        <div class="options">
#         <div class="src">
#          <button class="voice icon stopped" data-id="OPENSUBTITLES-2016.EN-RU_14586129" data-lang="en" title="Произношение">
#          </button>
#         </div>
#         <div class="trg">
#          <button class="icon more-context" data-id="OPENSUBTITLES-2016.EN-RU_14586129" title="Посмотреть примеры для этого перевода в контексте (http://opus.nlpl.eu/OpenSubtitles2016.php)">
#          </button>
#          <button class="report icon thumb-down" data-id="OPENSUBTITLES-2016.EN-RU_14586129" title="Сообщить о проблеме в этом примере">
#          </button>
#          <button class="add icon addentry " data-id="OPENSUBTITLES-2016.EN-RU_14586129" data-text="Он в буквальном смысле написал &lt;em&gt;книгу&lt;/em&gt; о современной войне на море." data-url="https://dictionary.reverso.net/CollabDict.aspx?view=2&amp;lang=RU" title="Добавить этот перевод в коллективный словарь Reverso">
#          </button>
#          <button class="copy icon mobile-hidden" data-id="OPENSUBTITLES-2016.EN-RU_14586129" title="Скопировать перевод">
#          </button>
#          <button class="icon non-favourite " data-id="OPENSUBTITLES-2016.EN-RU_14586129" title="Отметить пример в качестве избранного">
#          </button>
#          <button class="voice icon stopped" data-id="OPENSUBTITLES-2016.EN-RU_14586129" data-lang="ru" title="Произношение">
#          </button>
#         </div>
#        </div>
#        <button class="mobile-voice icon stopped played" data-id="OPENSUBTITLES-2016.EN-RU_14586129">
#        </button>
#       </div>
#       <div class="example blocked" id="OPENSUBTITLES-2016.EN-RU_12878035">
#        <div class="src ltr">
#         <span class="text" lang="en">
#          Let me interview you for my
#          <em>
#           book
#          </em>
#          .
#         </span>
#        </div>
#        <div class="trg ltr">
#         <span class="icon jump-right">
#         </span>
#         <span class="text">
#          Позвольте мне взять у вас интервью для моей
#          <a class="link_highlighted" href="/перевод/русский-английский/%D0%BA%D0%BD%D0%B8%D0%B3%D0%B8" rel="nofollow">
#           <em>
#            книги
#           </em>
#          </a>
#          .
#         </span>
#        </div>
#        <div class="options">
#         <div class="src">
#          <button class="voice icon stopped" data-id="OPENSUBTITLES-2016.EN-RU_12878035" data-lang="en" title="Произношение">
#          </button>
#         </div>
#         <div class="trg">
#          <button class="icon more-context" data-id="OPENSUBTITLES-2016.EN-RU_12878035" title="Посмотреть примеры для этого перевода в контексте (http://opus.nlpl.eu/OpenSubtitles2016.php)">
#          </button>
#          <button class="report icon thumb-down" data-id="OPENSUBTITLES-2016.EN-RU_12878035" title="Сообщить о проблеме в этом примере">
#          </button>
#          <button class="add icon addentry " data-id="OPENSUBTITLES-2016.EN-RU_12878035" data-text="Позвольте мне взять у вас интервью для моей &lt;em&gt;книги&lt;/em&gt;." data-url="https://dictionary.reverso.net/CollabDict.aspx?view=2&amp;lang=RU" title="Добавить этот перевод в коллективный словарь Reverso">
#          </button>
#          <button class="copy icon mobile-hidden" data-id="OPENSUBTITLES-2016.EN-RU_12878035" title="Скопировать перевод">
#          </button>
#          <button class="icon non-favourite " data-id="OPENSUBTITLES-2016.EN-RU_12878035" title="Отметить пример в качестве избранного">
#          </button>
#          <button class="voice icon stopped" data-id="OPENSUBTITLES-2016.EN-RU_12878035" data-lang="ru" title="Произношение">
#          </button>
#         </div>
#        </div>
#        <button class="mobile-voice icon stopped played" data-id="OPENSUBTITLES-2016.EN-RU_12878035">
#        </button>
#       </div>
#       <div class="popup wide-container" id="blocked-rude-results-banner">
#        <div class="header">
#        </div>
#        <div class="body">
#         <span>
#          Возможно неприемлемое содержание
#         </span>
#         <div class="buttons-content">
#          <button class="button close">
#           Показать
#          </button>
#         </div>
#         <span class="disclaimer">
#          Примеры предназначены только для помощи в переводе искомых слов и выражений в различных контекстах. Мы не выбираем и не утверждаем примеры, и они могут содержать неприемлемые слова или идеи. Пожалуйста, сообщайте нам о примерах, которые, на Ваш взгляд, необходимо исправить или удалить. Грубые или разговорные переводы обычно отмечены красным или оранжевым цветом.
#         </span>
#        </div>
#       </div>
#       <div class="popup wide-container" id="blocked-results-banner">
#        <div class="header">
#         <button class="icon close">
#         </button>
#        </div>
#        <div class="body">
#         <span>
#          Зарегистрируйтесь, чтобы увидеть больше примеров.
#         </span>
#         <div class="buttons-content">
#          <a class="button register" href="https://account.reverso.net/register/context.reverso.net/ru?utm_source=contextweb&amp;utm_medium=blockedexamples&amp;utm_campaign=register">
#           Зарегистрироваться
#          </a>
#          <a class="button login" href="https://account.reverso.net/login/context.reverso.net/ru?utm_source=contextweb&amp;utm_medium=blockedexamples&amp;utm_campaign=login">
#           Войти
#          </a>
#         </div>
#        </div>
#       </div>
#      </section>
#      <section id="no-results">
#       <span class="wide-container message">
#        Ничего не найдено для этого значения.
#       </span>
#       <div class="wide-container">
#        <button data-ga="display-noexamples" id="add-example" title='Предложить пример для "book"'>
#         Предложить пример
#        </button>
#       </div>
#      </section>
#      <section id="examples-bottom">
#       <div class="loading-pannel">
#        <span class="icon">
#        </span>
#       </div>
#       <button class="button load-more unregistered" id="load-more-examples">
#        Больше примеров
#       </button>
#       <div class="wide-container" data-exact="25624" id="result-info">
#        <p>
#         Результатов:
#         <span id="nrows">
#          25624
#         </span>
#         . Точных совпадений:
#         <span id="nrows_exact">
#          25624
#         </span>
#         . Затраченное время:
#         <span id="time">
#          324
#         </span>
#         мс
#        </p>
#       </div>
#       <div class="wide-container">
#        <button data-ga="display-examplesbottom" id="add-example" title='Предложить пример для "book"'>
#         Предложить пример
#        </button>
#       </div>
#       <section class="wide-container" id="bottom-suggestions">
#        <div class="suggestion hidden" title="Это предложение исключено из результатов">
#         <span class="text" data-url="/перевод/английский-русский/to+book">
#          to book
#         </span>
#         <span class="figure ">
#          494
#         </span>
#        </div>
#        <div class="suggestion">
#         <a class="text" href="/перевод/английский-русский/book+about">
#          book about
#         </a>
#         <span class="figure ">
#          426
#         </span>
#        </div>
#        <div class="suggestion hidden" title="Это предложение исключено из результатов">
#         <span class="text" data-url="/перевод/английский-русский/comic+book">
#          comic book
#         </span>
#         <span class="figure ">
#          383
#         </span>
#        </div>
#        <div class="suggestion">
#         <a class="text" href="/перевод/английский-русский/new+book">
#          new book
#         </a>
#         <span class="figure ">
#          316
#         </span>
#        </div>
#        <div class="suggestion">
#         <a class="text" href="/перевод/английский-русский/address+book">
#          address book
#         </a>
#         <span class="figure ">
#          247
#         </span>
#        </div>
#        <div class="suggestion">
#         <a class="text" href="/перевод/английский-русский/blue+book">
#          blue book
#         </a>
#         <span class="figure ">
#          245
#         </span>
#        </div>
#        <div class="suggestion hidden" title="Это предложение исключено из результатов">
#         <span class="text" data-url="/перевод/английский-русский/by+the+book">
#          by the book
#         </span>
#         <span class="figure ">
#          236
#         </span>
#        </div>
#        <div class="suggestion">
#         <a class="text" href="/перевод/английский-русский/read+the+book">
#          read the book
#         </a>
#         <span class="figure ">
#          230
#         </span>
#        </div>
#        <div class="suggestion">
#         <a class="text" href="/перевод/английский-русский/read+a+book">
#          read a book
#         </a>
#         <span class="figure ">
#          230
#         </span>
#        </div>
#        <button class="icon other other-suggestions" data-negative="-{to book} -{book about} -{comic book} -{new book} -{address book} -{blue book} -{by the book} -{read the book} -{read a book}" title="Другие переводы">
#        </button>
#       </section>
#      </section>
#     </div>
#     <!-- /64378609/Context_MegaBanner_Bottom -->
#     <div class="hidden" id="bottom-mega-rca-box">
#      <div class="bottom-rca mega-rca" id="div-gpt-ad-Reverso_Ctxt_D_Result_728x90_BTF">
#       <script type="text/javascript">
#        if(!window.mobilecheck()) {
#           googletag.cmd.push(function() {
#             googletag.display('div-gpt-ad-Reverso_Ctxt_D_Result_728x90_BTF');
#           });
#         }
#       </script>
#      </div>
#      <span class="rca-title rca-title-vertical bottom-rca">
#       Реклама
#      </span>
#     </div>
#    </section>
#    <section id="sitemaps">
#     <p>
#      Индекс слова:
#      <a href="/перевод/index/английский-русский/w-1-300.html">
#       1-300
#      </a>
#      ,
#      <a href="/перевод/index/английский-русский/w-301-600.html">
#       301-600
#      </a>
#      ,
#      <a href="/перевод/index/английский-русский/w-601-900.html">
#       601-900
#      </a>
#      ,
#      <a href="/перевод/index/английский-русский/w.html">
#       Больше
#      </a>
#      <p>
#       Индекс выражения:
#       <a href="/перевод/index/английский-русский/e-1-400.html">
#        1-400
#       </a>
#       ,
#       <a href="/перевод/index/английский-русский/e-401-800.html">
#        401-800
#       </a>
#       ,
#       <a href="/перевод/index/английский-русский/e-801-1200.html">
#        801-1200
#       </a>
#       ,
#       <a href="/перевод/index/английский-русский/e.html">
#        Больше
#       </a>
#       <p>
#        Индекс фразы:
#        <a href="/перевод/index/английский-русский/p-1-400.html">
#         1-400
#        </a>
#        ,
#        <a href="/перевод/index/английский-русский/p-401-800.html">
#         401-800
#        </a>
#        ,
#        <a href="/перевод/index/английский-русский/p-801-1200.html">
#         801-1200
#        </a>
#        ,
#        <a href="/перевод/index/английский-русский/p.html">
#         Больше
#        </a>
#       </p>
#      </p>
#     </p>
#    </section>
#    <p class="developers wide-container">
#     Разработано Prompsit Language Engineering для Softissimo
#    </p>
#    <section id="footer">
#     <div class="wide-container">
#      <a href="/перевод/about">
#       Что такое контекстный словарь
#      </a>
#      <a class="app-link" href="/перевод/mobile-app">
#       Скачать приложение
#      </a>
#      <a href="http://www.reverso.net/feedback.aspx?type=3&amp;lang=RU" target="_blank">
#       Контакты
#      </a>
#      <a href="/перевод/legal">
#       Правовые вопросы
#      </a>
#     </div>
#     <div class="wide-container">
#      <a href="/translation/">
#       Translation in context
#      </a>
#      <a href="/traduction/">
#       Traduction en contexte
#      </a>
#      <a href="/traduccion/">
#       Traducción en contexto
#      </a>
#      <a href="/traducao/">
#       Tradução em contexto
#      </a>
#      <a href="/traduzione/">
#       Traduzione in contesto
#      </a>
#      <a href="/übersetzung/">
#       Übersetzung im Kontext
#      </a>
#      <a href="/الترجمة/">
#       الترجمة في السياق
#      </a>
#      <a href="/翻訳/">
#       文脈に沿った翻訳
#      </a>
#      <a href="/vertaling/">
#       Vertaling in context
#      </a>
#      <a href="/תרגום/">
#       תרגום בהקשר
#      </a>
#      <a href="/tłumaczenie/">
#       Tłumaczenie w kontekście
#      </a>
#      <a href="/traducere/">
#       Traducere în context
#      </a>
#      <a href="/çeviri/">
#       İçerik tercümesi
#      </a>
#     </div>
#     <div class="wide-container">
#      <a href="https://synonyms.reverso.net/%D1%81%D0%B8%D0%BD%D0%BE%D0%BD%D0%B8%D0%BC%D1%8B/" target="_blank">
#       Синонимы
#      </a>
#      <a href="http://glagol.reverso.net/%D1%81%D0%BF%D1%80%D1%8F%D0%B6%D0%B5%D0%BD%D0%B8%D0%B5-%D1%80%D1%83%D1%81%D1%81%D0%BA%D0%B8%D0%B9.html" target="_blank">
#       Спряжение
#      </a>
#      <a href="https://www.corporate-translation.reverso.com/" target="_blank">
#       Reverso Corporate
#      </a>
#     </div>
#     <p class="copy">
#      ©  2013-2019 Softissimo Inc. Все права защищены.
#     </p>
#    </section>
#   </div>
#   <script src="https://cdn.reverso.net/context/v51300/js/bst.constants-ru.js" type="text/javascript">
#   </script>
#   <script src="https://cdn.reverso.net/context/v51300/js/bst.scripts.js" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    !function(f,b,e,v,n,t,s){if(f.fbq)return;n=f.fbq=function(){n.callMethod?
#   n.callMethod.apply(n,arguments):n.queue.push(arguments)};if(!f._fbq)f._fbq=n;
#   n.push=n;n.loaded=!0;n.version='2.0';n.queue=[];t=b.createElement(e);t.async=!0;
#   t.src=v;s=b.getElementsByTagName(e)[0];s.parentNode.insertBefore(t,s)}(window,
#   document,'script','https://connect.facebook.net/en_US/fbevents.js');
#   fbq('init', '1090291004350551');
#   fbq('track', "PageView");
#
#   var ezt = ezt ||[];
#   (function(){
#     var elem = document.createElement('script');
#     elem.src = (document.location.protocol == "https:" ? "https://secure" : "http://pixel") + ".quantserve.com/aquant.js?a=p-9z6v4xdJwT5Z-";
#     elem.async = true;
#     elem.type = "text/javascript";
#     var scpt = document.getElementsByTagName('script')[0];
#     scpt.parentNode.insertBefore(elem,scpt);
#   }());
#   ezt.push({qacct: 'p-9z6v4xdJwT5Z-', labels: 'context', uid: '' });
#   </script>
#   <noscript>
#    <img alt="" height="1" src="//pixel.quantserve.com/pixel/p-9z6v4xdJwT5Z-.gif?labels=context" style="display: none;" width="1"/>
#    <img alt="" height="1" src="https://www.facebook.com/tr?id=1090291004350551&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/>
#   </noscript>
#  </body>
# </html>

# %%
soup = bs(response.text, 'html.parser')
#soup.title
for link in soup.find_all("a", attrs={"class" : "translation"}):
    #print (link)
    print(link.text.strip())
    #print("|||", link.text.strip(),"|||")
    #print ( )
# Out:
# Перевод
# книга
# книжка
# справочник
# учебник
# журнал
# альбом
# тетрадь
# блокнот
# книжный
# забронировать
# заказать
# бронировать
# сборник
# книжечка
# правилам

# %%
soup.find_all("em", class_="translation")
soup.find_all("em",attrs={"class" : "translation"})
for l in soup.find_all("a"):
    print (l)
# Out:
# <a class="reverso-logo nonselectable no-loading" href="/%D0%BF%D0%B5%D1%80%D0%B5%D0%B2%D0%BE%D0%B4/" title="Reverso Context: поисковая система для переводов в контексте">
# <div class="logo">
# <span class="icon reverso-logo-red"></span>
# <span class="icon reverso-logo-blue"></span>
# </div>
# <div class="text">
# <span class="icon reverso-text"></span>
# <span class="icon context-text"></span>
# </div>
# </a>
# <a class="option register" href="https://account.reverso.net/register/context.reverso.net/ru?utm_source=contextweb&amp;utm_medium=usertopmenu&amp;utm_campaign=register">
# <span class="icon add-user"></span>
# <span class="text">Зарегистрироваться</span>
# </a>
# <a class="option login" href="https://account.reverso.net/login/context.reverso.net/ru?utm_source=contextweb&amp;utm_medium=usertopmenu&amp;utm_campaign=login">
# <span class="icon login"></span>
# <span class="text">Войти</span>
# </a>
# <a class="option help grey" href="/%D0%BF%D0%B5%D1%80%D0%B5%D0%B2%D0%BE%D0%B4/about">
# <span class="icon help"></span>
# <span class="text">Помощь</span>
# </a>
# <a class="option translation" href="http://www.reverso.net/text_translation.aspx?lang=RU" target="_blank">
# <span class="icon lang"></span>
# <span class="text">Перевод</span>
# </a>
# <a class="option dictionary" href="https://dictionary.reverso.net" target="_blank">
# <span class="icon dictionary"></span>
# <span class="text">Словарь</span>
# </a>
# <a class="option speller" href="http://www.reverso.net/spell-checker/english-spelling-grammar/" target="_blank">
# <span class="icon spellcheck"></span>
# <span class="text">Корректор</span>
# </a>
# <a class="option conjugation" href="http://glagol.reverso.net/%D1%81%D0%BF%D1%80%D1%8F%D0%B6%D0%B5%D0%BD%D0%B8%D0%B5-%D1%80%D1%83%D1%81%D1%81%D0%BA%D0%B8%D0%B9.html" target="_blank">
# <span class="icon conjugator"></span>
# <span class="text">Спряжение</span>
# </a>
# <a class="option synonyms" href="https://synonyms.reverso.net/%D1%81%D0%B8%D0%BD%D0%BE%D0%BD%D0%B8%D0%BC%D1%8B/" target="_blank">
# <span class="icon synonyms"></span>
# <span class="text">Синонимы</span>
# </a>
# <a class="option grammar" href="http://grammar.reverso.net/" target="_blank">
# <span class="icon translate"></span>
# <span class="text">Грамматика</span>
# </a>
# <a class="option document" href="https://documents.reverso.net/Default.aspx?lang=en" target="_blank">
# <span class="icon document"></span>
# <span class="text">Перевод документов и сайтов</span>
# </a>
# <a class="option corporate" href="https://www.corporate-translation.reverso.com/">
# <span class="icon corporate"></span>
# <span class="text">Корпоративные решения</span>
# </a>
# <a class="option newsletter" href="http://www.reverso.net/tricks.aspx?type=3&amp;lang=RU" target="_blank">
# <span class="icon mail"></span>
# <span class="text">Новостная рассылка</span>
# </a>
# <a class="option help" href="/%D0%BF%D0%B5%D1%80%D0%B5%D0%B2%D0%BE%D0%B4/about">
# <span class="icon help"></span>
# <span class="text">Помощь</span>
# </a>
# <a class="translation-link" href="http://www.reverso.net/text_translation.aspx?lang=RU" target="_blank">
#       Перевод</a>
# <a class="dictionary-link" href="https://dictionary.reverso.net" target="_blank">
#       Словарь</a>
# <a class="speller-link" href="http://www.reverso.net/spell-checker/english-spelling-grammar/" target="_blank">
#       Корректор</a>
# <a class="conjugation-link" href="http://glagol.reverso.net/%D1%81%D0%BF%D1%80%D1%8F%D0%B6%D0%B5%D0%BD%D0%B8%D0%B5-%D1%80%D1%83%D1%81%D1%81%D0%BA%D0%B8%D0%B9.html" target="_blank">
#       Спряжение</a>
# <a class="synonyms-link " href="https://synonyms.reverso.net/%D1%81%D0%B8%D0%BD%D0%BE%D0%BD%D0%B8%D0%BC%D1%8B/" target="_blank">
#       Синонимы</a>
# <a class="grammar-link last" href="http://grammar.reverso.net/" target="_blank">
#       Грамматика</a>
# <a class="facebook-link icon facebook" href="https://www.facebook.com/Reverso.net?ref=ts" target="_blank" title="Facebook"></a>
# <a class="twitter-link icon twitter" href="https://twitter.com/ReversoEN" target="_blank" title="Twitter"></a>
# <a class="instagram-link icon instagram" href="https://www.instagram.com/reverso_app/?hl=ru" target="_blank" title="Instagram"></a>
# <a class="translation-link" href="http://www.reverso.net/text_translation.aspx?lang=RU" target="_blank">
#     Перевод</a>
# <a class="conjugation-link" href="http://glagol.reverso.net/%D1%81%D0%BF%D1%80%D1%8F%D0%B6%D0%B5%D0%BD%D0%B8%D0%B5-%D1%80%D1%83%D1%81%D1%81%D0%BA%D0%B8%D0%B9.html" target="_blank">
#     Спряжение</a>
# <a class="synonyms-link" href="https://synonyms.reverso.net/%D1%81%D0%B8%D0%BD%D0%BE%D0%BD%D0%B8%D0%BC%D1%8B/" target="_blank">
#     Синонимы</a>
# <a class="option register" href="https://account.reverso.net/register/context.reverso.net/ru?utm_source=contextweb&amp;utm_medium=usertopmenu&amp;utm_campaign=register">
# <span class="icon add-user"></span>
# <span class="text">Зарегистрироваться</span>
# </a>
# <a class="option login" href="https://account.reverso.net/login/context.reverso.net/ru?utm_source=contextweb&amp;utm_medium=usertopmenu&amp;utm_campaign=login">
# <span class="icon login"></span>
# <span class="text">Войти</span>
# </a>
# <a class="badge extension disabled mobile-hidden" href="" id="extension-badge" target="_blank">
# <span class="logo"></span>
# <span class="text">Добавить Reverso в {0} <b>Бесплатно</b></span>
# </a>
# <a class="text" href="/перевод/mobile-app?utm_source=contextweb&amp;utm_medium=banner&amp;utm_campaign=ctxtresultpage&amp;utm_content=ctxtappdl">Скачать наше <b>бесплатное</b> приложение</a>
# <a class="badge and no-loading ru" href="/перевод/mobile-app?utm_source=contextweb&amp;utm_medium=banner&amp;utm_campaign=ctxtresultpage&amp;utm_content=ctxtappdl">
# </a>
# <a class="badge ios no-loading ru" href="/перевод/mobile-app?utm_source=contextweb&amp;utm_medium=banner&amp;utm_campaign=ctxtresultpage&amp;utm_content=ctxtappdl">
# </a>
# <a class="button register" href="https://account.reverso.net/register/context.reverso.net/ru?utm_source=contextweb&amp;utm_medium=floatingpopup&amp;utm_campaign=register"><span class="icon add-user"></span>Зарегистрироваться</a>
# <a class="button login" href="https://account.reverso.net/login/context.reverso.net/ru?utm_source=contextweb&amp;utm_medium=floatingpopup&amp;utm_campaign=login"><span class="icon login"></span>Войти</a>
# <a class="icon synonyms" data-value="synonyms" href="https://synonyms.reverso.net/%D1%81%D0%B8%D0%BD%D0%BE%D0%BD%D0%B8%D0%BC%D1%8B/en/book" target="_blank" title="Искать в Синонимы"></a>
# <a class="icon conjugator" data-value="conjugator" href="http://glagol.reverso.net/%D1%81%D0%BF%D1%80%D1%8F%D0%B6%D0%B5%D0%BD%D0%B8%D0%B5-%D0%B0%D0%BD%D0%B3%D0%BB%D0%B8%D0%B9%D1%81%D0%BA%D0%B8%D0%B9-%D0%B3%D0%BB%D0%B0%D0%B3%D0%BE%D0%BB-book.html" target="_blank" title="Искать в Спряжение"></a>
# <a class="icon dictionary" data-value="definition" href="https://dictionary.reverso.net/english-definition/book" target="_blank" title="Искать в Oпределение"></a>
# <a class="" href="/перевод/английский-русский/to+book">to book</a>
# <a class="" href="/перевод/английский-русский/comic+book">comic book</a>
# <a class="" href="/перевод/английский-русский/by+the+book">by the book</a>
# <a class="suggestion" href="http://glagol.reverso.net/%D1%81%D0%BF%D1%80%D1%8F%D0%B6%D0%B5%D0%BD%D0%B8%D0%B5-%D0%B0%D0%BD%D0%B3%D0%BB%D0%B8%D0%B9%D1%81%D0%BA%D0%B8%D0%B9-%D0%B3%D0%BB%D0%B0%D0%B3%D0%BE%D0%BB-book.html" target="_blank">Conjugation of this verb</a>
# <a class="icon synonyms" dir=" ltr " href="https://synonyms.reverso.net/%D1%81%D0%B8%D0%BD%D0%BE%D0%BD%D0%B8%D0%BC%D1%8B/en/book" id="synonyms-button" target="_blank" title="Синонимы"></a>
# <a class="translation ltr dict n" data-freq="18521" data-pos="[nf]" data-pos-index="0" data-posgroup="1" href="/перевод/русский-английский/%D0%BA%D0%BD%D0%B8%D0%B3%D0%B0" title="&lt;div class='nobold'&gt;Посмотреть примеры с переводом &lt;em class='translation'&gt;книга&lt;/em&gt;&lt;br&gt;Существительное - женский род&lt;br&gt;(+10k примеров, содержащих перевод)&lt;/div&gt;">
# <div class="pos-mark">
# <span class="n" title="Существительное - женский род"></span>
# </div>
#           книга</a>
# <a class="translation ltr dict n" data-freq="1094" data-pos="[nf]" data-pos-index="0" data-posgroup="1" href="/перевод/русский-английский/%D0%BA%D0%BD%D0%B8%D0%B6%D0%BA%D0%B0" title="&lt;div class='nobold'&gt;Посмотреть примеры с переводом &lt;em class='translation'&gt;книжка&lt;/em&gt;&lt;br&gt;Существительное - женский род&lt;br&gt;(1094 примеров, содержащих перевод)&lt;/div&gt;">
# <div class="pos-mark">
# <span class="n" title="Существительное - женский род"></span>
# </div>
#           книжка</a>
# <a class="translation ltr dict n" data-freq="199" data-pos="[nm]" data-pos-index="0" data-posgroup="1" href="/перевод/русский-английский/%D1%81%D0%BF%D1%80%D0%B0%D0%B2%D0%BE%D1%87%D0%BD%D0%B8%D0%BA" title="&lt;div class='nobold'&gt;Посмотреть примеры с переводом &lt;em class='translation'&gt;справочник&lt;/em&gt;&lt;br&gt;Существительное - мужской род&lt;br&gt;(199 примеров, содержащих перевод)&lt;/div&gt;">
# <div class="pos-mark">
# <span class="n" title="Существительное - мужской род"></span>
# </div>
#           справочник</a>
# <a class="translation ltr dict n" data-freq="181" data-pos="[nm]" data-pos-index="0" data-posgroup="1" href="/перевод/русский-английский/%D1%83%D1%87%D0%B5%D0%B1%D0%BD%D0%B8%D0%BA" title="&lt;div class='nobold'&gt;Посмотреть примеры с переводом &lt;em class='translation'&gt;учебник&lt;/em&gt;&lt;br&gt;Существительное - мужской род&lt;br&gt;(181 примеров, содержащих перевод)&lt;/div&gt;">
# <div class="pos-mark">
# <span class="n" title="Существительное - мужской род"></span>
# </div>
#           учебник</a>
# <a class="translation ltr dict n" data-freq="89" data-pos="[nm]" data-pos-index="0" data-posgroup="1" href="/перевод/русский-английский/%D0%B6%D1%83%D1%80%D0%BD%D0%B0%D0%BB" title="&lt;div class='nobold'&gt;Посмотреть примеры с переводом &lt;em class='translation'&gt;журнал&lt;/em&gt;&lt;br&gt;Существительное - мужской род&lt;br&gt;(89 примеров, содержащих перевод)&lt;/div&gt;">
# <div class="pos-mark">
# <span class="n" title="Существительное - мужской род"></span>
# </div>
#           журнал</a>
# <a class="translation ltr dict n" data-freq="75" data-pos="[nm]" data-pos-index="0" data-posgroup="1" href="/перевод/русский-английский/%D0%B0%D0%BB%D1%8C%D0%B1%D0%BE%D0%BC" title="&lt;div class='nobold'&gt;Посмотреть примеры с переводом &lt;em class='translation'&gt;альбом&lt;/em&gt;&lt;br&gt;Существительное - мужской род&lt;br&gt;(75 примеров, содержащих перевод)&lt;/div&gt;">
# <div class="pos-mark">
# <span class="n" title="Существительное - мужской род"></span>
# </div>
#           альбом</a>
# <a class="translation ltr dict n" data-freq="73" data-pos="[n]" data-pos-index="0" data-posgroup="1" href="/перевод/русский-английский/%D1%82%D0%B5%D1%82%D1%80%D0%B0%D0%B4%D1%8C" title="&lt;div class='nobold'&gt;Посмотреть примеры с переводом &lt;em class='translation'&gt;тетрадь&lt;/em&gt;&lt;br&gt;Существительное&lt;br&gt;(73 примеров, содержащих перевод)&lt;/div&gt;">
# <div class="pos-mark">
# <span class="n" title="Существительное"></span>
# </div>
#           тетрадь</a>
# <a class="translation ltr dict first n" data-freq="60" data-pos="[nm]" data-pos-index="0" data-posgroup="1" href="/перевод/русский-английский/%D0%B1%D0%BB%D0%BE%D0%BA%D0%BD%D0%BE%D1%82" title="&lt;div class='nobold'&gt;Посмотреть примеры с переводом &lt;em class='translation'&gt;блокнот&lt;/em&gt;&lt;br&gt;Существительное - мужской род&lt;br&gt;(60 примеров, содержащих перевод)&lt;/div&gt;">
# <div class="pos-mark">
# <span class="n" title="Существительное - мужской род"></span>
# </div>
#           блокнот</a>
# <a class="translation ltr dict first adj" data-freq="743" data-pos="[adj]" data-pos-index="1" data-posgroup="2" href="/перевод/русский-английский/%D0%BA%D0%BD%D0%B8%D0%B6%D0%BD%D1%8B%D0%B9" title="&lt;div class='nobold'&gt;Посмотреть примеры с переводом &lt;em class='translation'&gt;книжный&lt;/em&gt;&lt;br&gt;Прилагательное&lt;br&gt;(743 примеров, содержащих перевод)&lt;/div&gt;">
# <div class="pos-mark">
# <span class="adj" title="Прилагательное"></span>
# </div>
#           книжный</a>
# <a class="translation ltr dict v" data-freq="205" data-pos="[v]" data-pos-index="2" data-posgroup="3" href="/перевод/русский-английский/%D0%B7%D0%B0%D0%B1%D1%80%D0%BE%D0%BD%D0%B8%D1%80%D0%BE%D0%B2%D0%B0%D1%82%D1%8C" title="&lt;div class='nobold'&gt;Посмотреть примеры с переводом &lt;em class='translation'&gt;забронировать&lt;/em&gt;&lt;br&gt;Глагол&lt;br&gt;(205 примеров, содержащих перевод)&lt;/div&gt;">
# <div class="pos-mark">
# <span class="v" title="Глагол"></span>
# </div>
#           забронировать</a>
# <a class="translation ltr dict mobile-hidden v" data-freq="166" data-pos="[v]" data-pos-index="2" data-posgroup="3" href="/перевод/русский-английский/%D0%B7%D0%B0%D0%BA%D0%B0%D0%B7%D0%B0%D1%82%D1%8C" title="&lt;div class='nobold'&gt;Посмотреть примеры с переводом &lt;em class='translation'&gt;заказать&lt;/em&gt;&lt;br&gt;Глагол&lt;br&gt;(166 примеров, содержащих перевод)&lt;/div&gt;">
# <div class="pos-mark">
# <span class="v" title="Глагол"></span>
# </div>
#           заказать</a>
# <a class="translation ltr dict mobile-hidden v" data-freq="37" data-pos="[v]" data-pos-index="2" data-posgroup="3" href="/перевод/русский-английский/%D0%B1%D1%80%D0%BE%D0%BD%D0%B8%D1%80%D0%BE%D0%B2%D0%B0%D1%82%D1%8C" title="&lt;div class='nobold'&gt;Посмотреть примеры с переводом &lt;em class='translation'&gt;бронировать&lt;/em&gt;&lt;br&gt;Глагол&lt;br&gt;(37 примеров, содержащих перевод)&lt;/div&gt;">
# <div class="pos-mark">
# <span class="v" title="Глагол"></span>
# </div>
#           бронировать</a>
# <a class="translation ltr dict mobile-hidden n" data-freq="44" data-pos="[n]" data-pos-index="0" data-posgroup="4" href="/перевод/русский-английский/%D1%81%D0%B1%D0%BE%D1%80%D0%BD%D0%B8%D0%BA" title="&lt;div class='nobold'&gt;Посмотреть примеры с переводом &lt;em class='translation'&gt;сборник&lt;/em&gt;&lt;br&gt;Существительное&lt;br&gt;(44 примеров, содержащих перевод)&lt;/div&gt;">
# <div class="pos-mark">
# <span class="n" title="Существительное"></span>
# </div>
#           сборник</a>
# <a class="translation ltr dict mobile-hidden n" data-freq="40" data-pos="[nf]" data-pos-index="0" data-posgroup="4" href="/перевод/русский-английский/%D0%BA%D0%BD%D0%B8%D0%B6%D0%B5%D1%87%D0%BA%D0%B0" title="&lt;div class='nobold'&gt;Посмотреть примеры с переводом &lt;em class='translation'&gt;книжечка&lt;/em&gt;&lt;br&gt;Существительное - женский род&lt;br&gt;(40 примеров, содержащих перевод)&lt;/div&gt;">
# <div class="pos-mark">
# <span class="n" title="Существительное - женский род"></span>
# </div>
#           книжечка</a>
# <a class="translation ltr dict mobile-hidden translation-hidden no-pos" data-freq="102" data-posgroup="6" href="/перевод/русский-английский/%D0%BF%D1%80%D0%B0%D0%B2%D0%B8%D0%BB%D0%B0%D0%BC" title="&lt;div class='nobold'&gt;Посмотреть примеры с переводом &lt;em class='translation'&gt;правилам&lt;/em&gt;&lt;br&gt;(102 примеров, содержащих перевод)&lt;/div&gt;">
#           правилам</a>
# <a class="text" href="/перевод/английский-русский/book+about" lang="en">book about</a>
# <a class="text" href="/перевод/английский-русский/new+book" lang="en">new book</a>
# <a class="text" href="/перевод/английский-русский/address+book" lang="en">address book</a>
# <a class="text" href="/перевод/английский-русский/blue+book" lang="en">blue book</a>
# <a class="text" href="/перевод/английский-русский/read+the+book" lang="en">read the book</a>
# <a class="text" href="/перевод/английский-русский/read+a+book" lang="en">read a book</a>
# <a class="link_highlighted" href="/перевод/русский-английский/%D0%BA%D0%BD%D0%B8%D0%B3%D0%B0" rel="nofollow"><em>книга</em></a>
# <a class="link_highlighted" href="/перевод/русский-английский/%D0%BA%D0%BD%D0%B8%D0%B3%D0%B0" rel="nofollow"><em>книга</em></a>
# <a class="link_highlighted" href="/перевод/русский-английский/%D0%BA%D0%BD%D0%B8%D0%B6%D0%BA%D0%B0" rel="nofollow"><em>книжка</em></a>
# <a class="link_highlighted" href="/перевод/русский-английский/%D0%BA%D0%BD%D0%B8%D0%B3%D0%B0" rel="nofollow"><em>книга</em></a>
# <a class="link_highlighted" href="/перевод/русский-английский/%D0%BA%D0%BD%D0%B8%D0%B3%D0%B0" rel="nofollow"><em>книга</em></a>
# <a class="link_highlighted" href="/перевод/русский-английский/%D0%BA%D0%BD%D0%B8%D0%B3%D0%B0" rel="nofollow"><em>книга</em></a>
# <a class="link_highlighted" href="/перевод/русский-английский/%D0%BA%D0%BD%D0%B8%D0%B3%D0%B0" rel="nofollow"><em>книга</em></a>
# <a class="link_highlighted" href="/перевод/русский-английский/%D0%BA%D0%BD%D0%B8%D0%B3%D0%B0" rel="nofollow"><em>книга</em></a>
# <a class="link_highlighted" href="/перевод/русский-английский/%D0%BA%D0%BD%D0%B8%D0%B3%D0%B0" rel="nofollow"><em>книга</em></a>
# <a class="link_highlighted" href="/перевод/русский-английский/%D0%9A%D0%BD%D0%B8%D0%B3%D0%B0" rel="nofollow"><em>Книга</em></a>
# <a class="link_highlighted" href="/перевод/русский-английский/%D0%9A%D0%BD%D0%B8%D0%B3%D0%B0" rel="nofollow"><em>Книга</em></a>
# <a class="link_highlighted" href="/перевод/русский-английский/%D0%9A%D0%BD%D0%B8%D0%B3%D0%B0" rel="nofollow"><em>Книга</em></a>
# <a class="link_highlighted" href="/перевод/русский-английский/%D0%BA%D0%BD%D0%B8%D0%B3%D0%B0" rel="nofollow"><em>книга</em></a>
# <a class="link_highlighted" href="/перевод/русский-английский/%D0%BA%D0%BD%D0%B8%D0%B3%D0%B0" rel="nofollow"><em>книга</em></a>
# <a class="link_highlighted" href="/перевод/русский-английский/%D0%BA%D0%BD%D0%B8%D0%B3%D0%B0" rel="nofollow"><em>книга</em></a>
# <a class="link_highlighted" href="/перевод/русский-английский/%D0%BA%D0%BD%D0%B8%D0%B3%D0%B0" rel="nofollow"><em>книга</em></a>
# <a class="link_highlighted" href="/перевод/русский-английский/%D0%BA%D0%BD%D0%B8%D0%B3%D0%B0" rel="nofollow"><em>книга</em></a>
# <a class="link_highlighted" href="/перевод/русский-английский/%D0%BA%D0%BD%D0%B8%D0%B6%D0%BD%D1%8B%D0%B5" rel="nofollow"><em>книжные</em></a>
# <a class="link_highlighted" href="/перевод/русский-английский/%D0%BA%D0%BD%D0%B8%D0%B3%D1%83" rel="nofollow"><em>книгу</em></a>
# <a class="link_highlighted" href="/перевод/русский-английский/%D0%B7%D0%B0%D0%BA%D0%B0%D0%B7%D0%B0%D1%82%D1%8C" rel="nofollow"><em>заказать</em></a>
# <a class="link_highlighted" href="/перевод/русский-английский/%D0%BA%D0%BD%D0%B8%D0%B3%D0%B8" rel="nofollow"><em>книги</em></a>
# <a class="link_highlighted" href="/перевод/русский-английский/%D0%B7%D0%B0%D0%BF%D0%B8%D1%81%D0%B0%D1%82%D1%8C+%D0%B5%D1%91" rel="nofollow"><em>записать её</em></a>
# <a class="link_highlighted" href="/перевод/русский-английский/%D0%BA%D0%BD%D0%B8%D0%B6%D0%BA%D0%B5" rel="nofollow"><em>книжке</em></a>
# <a class="link_highlighted" href="/перевод/русский-английский/%D0%BA%D0%BD%D0%B8%D0%B3%D1%83" rel="nofollow"><em>книгу</em></a>
# <a class="link_highlighted" href="/перевод/русский-английский/%D0%BA%D0%BD%D0%B8%D0%B3%D0%B8" rel="nofollow"><em>книги</em></a>
# <a class="button register" href="https://account.reverso.net/register/context.reverso.net/ru?utm_source=contextweb&amp;utm_medium=blockedexamples&amp;utm_campaign=register">Зарегистрироваться</a>
# <a class="button login" href="https://account.reverso.net/login/context.reverso.net/ru?utm_source=contextweb&amp;utm_medium=blockedexamples&amp;utm_campaign=login">Войти</a>
# <a class="text" href="/перевод/английский-русский/book+about">book about</a>
# <a class="text" href="/перевод/английский-русский/new+book">new book</a>
# <a class="text" href="/перевод/английский-русский/address+book">address book</a>
# <a class="text" href="/перевод/английский-русский/blue+book">blue book</a>
# <a class="text" href="/перевод/английский-русский/read+the+book">read the book</a>
# <a class="text" href="/перевод/английский-русский/read+a+book">read a book</a>
# <a href="/перевод/index/английский-русский/w-1-300.html">1-300</a>
# <a href="/перевод/index/английский-русский/w-301-600.html">301-600</a>
# <a href="/перевод/index/английский-русский/w-601-900.html">601-900</a>
# <a href="/перевод/index/английский-русский/w.html">Больше</a>
# <a href="/перевод/index/английский-русский/e-1-400.html">1-400</a>
# <a href="/перевод/index/английский-русский/e-401-800.html">401-800</a>
# <a href="/перевод/index/английский-русский/e-801-1200.html">801-1200</a>
# <a href="/перевод/index/английский-русский/e.html">Больше</a>
# <a href="/перевод/index/английский-русский/p-1-400.html">1-400</a>
# <a href="/перевод/index/английский-русский/p-401-800.html">401-800</a>
# <a href="/перевод/index/английский-русский/p-801-1200.html">801-1200</a>
# <a href="/перевод/index/английский-русский/p.html">Больше</a>
# <a href="/перевод/about">Что такое контекстный словарь</a>
# <a class="app-link" href="/перевод/mobile-app">Скачать приложение</a>
# <a href="http://www.reverso.net/feedback.aspx?type=3&amp;lang=RU" target="_blank">Контакты</a>
# <a href="/перевод/legal">Правовые вопросы</a>
# <a href="/translation/">Translation in context</a>
# <a href="/traduction/">Traduction en contexte</a>
# <a href="/traduccion/">Traducción en contexto</a>
# <a href="/traducao/">Tradução em contexto</a>
# <a href="/traduzione/">Traduzione in contesto</a>
# <a href="/übersetzung/">Übersetzung im Kontext</a>
# <a href="/الترجمة/">الترجمة في السياق</a>
# <a href="/翻訳/">文脈に沿った翻訳</a>
# <a href="/vertaling/">Vertaling in context</a>
# <a href="/תרגום/">תרגום בהקשר</a>
# <a href="/tłumaczenie/">Tłumaczenie w kontekście</a>
# <a href="/traducere/">Traducere în context</a>
# <a href="/çeviri/">İçerik tercümesi</a>
# <a href="https://synonyms.reverso.net/%D1%81%D0%B8%D0%BD%D0%BE%D0%BD%D0%B8%D0%BC%D1%8B/" target="_blank">Синонимы</a>
# <a href="http://glagol.reverso.net/%D1%81%D0%BF%D1%80%D1%8F%D0%B6%D0%B5%D0%BD%D0%B8%D0%B5-%D1%80%D1%83%D1%81%D1%81%D0%BA%D0%B8%D0%B9.html" target="_blank">Спряжение</a>
# <a href="https://www.corporate-translation.reverso.com/" target="_blank">Reverso Corporate</a>

# %% [markdown]
# # пример

# %%
url_ex = "https://context.reverso.net/перевод/русский-английский/книга"
headers_ex = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/537.36'}
response_ex = requests.get(url_ex, headers=headers_ex)
#response.encoding = 'utf-8'
soup_sub = bs(response_ex.text, 'html.parser')

# %%
print(soup_sub.prettify())
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="ru">
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <title>
#    book - Перевод на русский - примеры английский | Reverso Context
#   </title>
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
#   <meta content='Перевод контекст "book" c английский на русский от Reverso Context: to book, book about, comic book, new book, address book' name="description"/>
#   <link href="https://context.reverso.net/translation/english-russian/book" hreflang="en" rel="alternate"/>
#   <link href="https://context.reverso.net/%D0%BF%D0%B5%D1%80%D0%B5%D0%B2%D0%BE%D0%B4/%D0%B0%D0%BD%D0%B3%D0%BB%D0%B8%D0%B9%D1%81%D0%BA%D0%B8%D0%B9-%D1%80%D1%83%D1%81%D1%81%D0%BA%D0%B8%D0%B9/book" hreflang="ru" rel="alternate"/>
#   <link href="android-app://com.softissimo.reverso.context/reversocontext/context.reverso.net/%D0%BF%D0%B5%D1%80%D0%B5%D0%B2%D0%BE%D0%B4/%D0%B0%D0%BD%D0%B3%D0%BB%D0%B8%D0%B9%D1%81%D0%BA%D0%B8%D0%B9-%D1%80%D1%83%D1%81%D1%81%D0%BA%D0%B8%D0%B9/book" rel="alternate"/>
#   <meta content="app-id=919979642, app-argument=reversocontext://context.reverso.net/%D0%BF%D0%B5%D1%80%D0%B5%D0%B2%D0%BE%D0%B4/%D0%B0%D0%BD%D0%B3%D0%BB%D0%B8%D0%B9%D1%81%D0%BA%D0%B8%D0%B9-%D1%80%D1%83%D1%81%D1%81%D0%BA%D0%B8%D0%B9/book" name="apple-itunes-app"/>
#   <link href="/%D0%BF%D0%B5%D1%80%D0%B5%D0%B2%D0%BE%D0%B4/%D0%B0%D0%BD%D0%B3%D0%BB%D0%B8%D0%B9%D1%81%D0%BA%D0%B8%D0%B9-%D1%80%D1%83%D1%81%D1%81%D0%BA%D0%B8%D0%B9/book" rel="canonical"/>
#   <script type="text/javascript">
#    var request = {
#     srctext: "book",
#     trgtext: "",
#     srclang: "en",
#     trglang: "ru",
#     rpage: 1,
#     rmode: 0,
#     original: "book"
#   };
#   </script>
#   <meta content="значение слова, перевод в контексте, перевод онлайн, Reverso Context, идиомы в контексте, инструмент поиска переводов, идиоматический перевод, перевод идиом, пример перевода, примеры перевода, Английский, Французский, Испанский, Иврит, Русский, Арабский, Португальский, Итальянский, Немецкий, Голландский, Польский, Иврит, идиоматические переводы, двуязычный конкорданс, контекстный словарь, пример употребления, примеры употребления, перевод в контексте, любители языка, контекстный пример, идиоматические выражения, словарь, примеры и идиомы, инструмент составления конкорданса" name="keywords"/>
#   <meta content="app-id=com.softissimo.reverso.context" name="google-play-app"/>
#   <meta content="notranslate" name="google">
#    <meta content="initial-scale=1.0" name="viewport"/>
#    <link href="https://cdn.reverso.net/context/v51300/images/reverso-context-logo-for-facebook.png" rel="image_src"/>
#    <link href="https://cdn.reverso.net/context/v51300/images/reverso-context.ico" rel="shortcut icon"/>
#    <link href="https://cdn.reverso.net/context/v51300/images/reverso-context-app-fav-apple.png" rel="apple-touch-icon"/>
#    <link href="https://cdn.reverso.net/context/v51300/images/reverso-context-app-fav-apple-16x16.png" rel="apple-touch-icon" sizes="16x16"/>
#    <link href="https://cdn.reverso.net/context/v51300/images/reverso-context-app-fav-apple-72x72.png" rel="apple-touch-icon" sizes="72x72"/>
#    <link href="https://cdn.reverso.net/context/v51300/images/reverso-context-app-fav-apple-114x114.png" rel="apple-touch-icon" sizes="114x114"/>
#    <style class="font-family">
#     @font-face{font-family:'contexticons';font-display: swap;src:url('https://cdn.reverso.net/context/v51300/fonts/contexticons.eot?phzsmg');src:url('https://cdn.reverso.net/context/v51300/fonts/contexticons.eot?phzsmg#iefix') format('embedded-opentype'),url('https://cdn.reverso.net/context/v51300/fonts/contexticons.ttf?phzsmg') format('truetype'),url('https://cdn.reverso.net/context/v51300/fonts/contexticons.woff?phzsmg') format('woff'),url('https://cdn.reverso.net/context/v51300/fonts/contexticons.svg?phzsmg#contexticons') format('svg');font-weight: normal;font-style: normal;}
#    </style>
#    <link href="https://fonts.googleapis.com/css?family=Montserrat:300,400,500,700|Roboto+Condensed:300,400&amp;subset=cyrillic,cyrillic-ext,latin-ext" rel="stylesheet"/>
#    <link href="https://cdn.reverso.net/context/v51300/css/bst.style.css" rel="stylesheet" type="text/css"/>
#    <script src="//cdn.reverso.net/abp/v1/Static/JS/advertising.js?ch=1" type="text/javascript">
#    </script>
#    <script src="//cdn.reverso.net/abp/v1/Static/JS/advertising.js?ch=2" type="text/javascript">
#    </script>
#    <script async="" src="//cdn.reverso.net/predib/predib-0-33-0.js" type="text/javascript">
#    </script>
#    <script src="//cdn.reverso.net/predib/conf/reverso_context.js" type="text/javascript">
#    </script>
#    <script type="text/javascript">
#     if(typeof window.request === "undefined") {
#     window.request = {
#       srctext: "",
#       trgtext: "",
#       srclang: "en",
#       trglang: "ru",
#       rpage: 1,
#       rmode: 0
#     };
#   }
#   var logLOCD = false;
#   var context_path = '';
#   var special_chars = "،؟י¬¿¡ºª·؛";
#   var is_rtl = false;
#
#   window.mobilecheck = function() {
#     var check = false;
#     (function (a) {
#       if (/(android|bb\d+|meego).+mobile|avantgo|bada\/|blackberry|blazer|compal|elaine|fennec|hiptop|iemobile|ip(hone|od)|iris|kindle|lge |maemo|midp|mmp|mobile.+firefox|netfront|opera m(ob|in)i|palm( os)?|phone|p(ixi|re)\/|plucker|pocket|psp|series(4|6)0|symbian|treo|up\.(browser|link)|vodafone|wap|windows ce|xda|xiino/i.test(a)||/1207|6310|6590|3gso|4thp|50[1-6]i|770s|802s|a wa|abac|ac(er|oo|s\-)|ai(ko|rn)|al(av|ca|co)|amoi|an(ex|ny|yw)|aptu|ar(ch|go)|as(te|us)|attw|au(di|\-m|r |s )|avan|be(ck|ll|nq)|bi(lb|rd)|bl(ac|az)|br(e|v)w|bumb|bw\-(n|u)|c55\/|capi|ccwa|cdm\-|cell|chtm|cldc|cmd\-|co(mp|nd)|craw|da(it|ll|ng)|dbte|dc\-s|devi|dica|dmob|do(c|p)o|ds(12|\-d)|el(49|ai)|em(l2|ul)|er(ic|k0)|esl8|ez([4-7]0|os|wa|ze)|fetc|fly(\-|_)|g1 u|g560|gene|gf\-5|g\-mo|go(\.w|od)|gr(ad|un)|haie|hcit|hd\-(m|p|t)|hei\-|hi(pt|ta)|hp( i|ip)|hs\-c|ht(c(\-| |_|a|g|p|s|t)|tp)|hu(aw|tc)|i\-(20|go|ma)|i230|iac( |\-|\/)|ibro|idea|ig01|ikom|im1k|inno|ipaq|iris|ja(t|v)a|jbro|jemu|jigs|kddi|keji|kgt( |\/)|klon|kpt |kwc\-|kyo(c|k)|le(no|xi)|lg( g|\/(k|l|u)|50|54|\-[a-w])|libw|lynx|m1\-w|m3ga|m50\/|ma(te|ui|xo)|mc(01|21|ca)|m\-cr|me(rc|ri)|mi(o8|oa|ts)|mmef|mo(01|02|bi|de|do|t(\-| |o|v)|zz)|mt(50|p1|v )|mwbp|mywa|n10[0-2]|n20[2-3]|n30(0|2)|n50(0|2|5)|n7(0(0|1)|10)|ne((c|m)\-|on|tf|wf|wg|wt)|nok(6|i)|nzph|o2im|op(ti|wv)|oran|owg1|p800|pan(a|d|t)|pdxg|pg(13|\-([1-8]|c))|phil|pire|pl(ay|uc)|pn\-2|po(ck|rt|se)|prox|psio|pt\-g|qa\-a|qc(07|12|21|32|60|\-[2-7]|i\-)|qtek|r380|r600|raks|rim9|ro(ve|zo)|s55\/|sa(ge|ma|mm|ms|ny|va)|sc(01|h\-|oo|p\-)|sdk\/|se(c(\-|0|1)|47|mc|nd|ri)|sgh\-|shar|sie(\-|m)|sk\-0|sl(45|id)|sm(al|ar|b3|it|t5)|so(ft|ny)|sp(01|h\-|v\-|v )|sy(01|mb)|t2(18|50)|t6(00|10|18)|ta(gt|lk)|tcl\-|tdg\-|tel(i|m)|tim\-|t\-mo|to(pl|sh)|ts(70|m\-|m3|m5)|tx\-9|up(\.b|g1|si)|utst|v400|v750|veri|vi(rg|te)|vk(40|5[0-3]|\-v)|vm40|voda|vulc|vx(52|53|60|61|70|80|81|83|85|98)|w3c(\-| )|webc|whit|wi(g |nc|nw)|wmlb|wonu|x700|yas\-|your|zeto|zte\-/i.test(a.substr(0,4)))
#         check = true
#       })(navigator.userAgent || navigator.vendor || window.opera);
#     return check;
#   };
#
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#     (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#     m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   var ga_log = [];
#
#   function sendGA(command, type, category, action, label, options) {
#     var object = {
#       "command": command,
#       "type": type,
#       "category": category,
#       "action": action,
#       "label": label
#     };
#     ga_log.push(object);
#     if(label !== undefined) ga(command, type, category, action, label, options);
#     else if(action !== undefined) ga(command, type, category, action, options);
#     else if(category !== undefined) ga(command, type, category, options);
#     else ga(command, type, options);
#   };
#
#   sendGA('create', 'UA-2834324-41', 'reverso.net');
#   sendGA('create', 'UA-2834324-49', 'auto', 'keywordTracker');
#   sendGA('require', 'displayfeatures');
#   sendGA('keywordTracker.require', 'displayfeatures');
#   sendGA('set', 'dimension1', logLOCD ? (is_premium ? 'premium' : 'registered') : 'anonymous');
#
#     sendGA('set', 'dimension4', typeof(adblock)=='undefined' ? 'yes' : (typeof(abp)!='undefined' && abp ? 'abp' : 'no' ));
#
#   sendGA('send', 'pageview', '/bst/result/en-ru/1w/translations-precomputed');
#   sendGA('keywordTracker.send', 'pageview');
#
#     var googletag = googletag || {};
#     googletag.cmd = googletag.cmd || [];
#
#     googletag.cmd.push(function() {
#         googletag.pubads().disableInitialLoad();
#         setReversoTargeting();
#     });
#     if (typeof (adblock) != 'undefined') {
#       var device = (window.mobilecheck() ? "mobile" : (window.innerWidth>1024 ? "desktop" : "tablet"));
#
#       var prebid_config = prebid_config || new prebidConfig();
#       var PREBID_TIMEOUT = prebid_config.getTimeout() || 800;
#       var GA_VARIATION = typeof(prebid_config) != 'undefined' ? prebid_config.getVariation() : 0;
#
#       var ads_array = [];
#       if (device === "desktop") {
#         ads_array = ['Reverso_Ctxt_D_Result_300x250_ATF', 'Reverso_Ctxt_D_Result_300x250_BTF', 'Reverso_Ctxt_D_Result_300x600_BTF', 'Reverso_Ctxt_D_Result_728x90_BTF']
#       }
#       else if (device === "mobile") {
#         ads_array = ['Reverso_Ctxt_M_Result_320x50_BTF'];
#       }
#       else {
#         ads_array = ['Reverso_Ctxt_D_Result_728x90_BTF'];
#       }
#
#         ads_array.push('Reverso_Ctxt_R_Result_InFeed_ATF');
#
#
#       var adsetup = prebid_config.getAdSetup(ads_array) || [];
#       var adUnits = prebid_config.getAdUnits(adsetup) || [];
#
#       if(typeof(abp) != 'undefined' && abp){adUnits=[];}
#
#       (function() {
#           var gads = document.createElement('script');
#           gads.async = true;
#           gads.type = 'text/javascript';
#           var useSSL = 'https:' == document.location.protocol;
#           gads.src = (useSSL ? 'https:' : 'http:') +
#           '//www.googletagservices.com/tag/js/gpt.js';
#           var node = document.getElementsByTagName('script')[0];
#           node.parentNode.insertBefore(gads, node);
#       })();
#
#       var slots = [];
#
#       googletag.cmd.push(function() {
#           for (var i in adsetup) {
#             n = adsetup[i];
#             slots[n['slotcode']] = googletag.defineSlot('/2629866/'+n['slotname'][0], n['slotsizes'], n['slotcode']).addService(googletag.pubads());
#           }
#
#           googletag.pubads().enableSingleRequest();
#           googletag.enableServices();
#       });
#
#       var pbjs = pbjs || {};
#       pbjs.que = pbjs.que || [];
#
#       prebid_config.setBidderSettings(pbjs);
#       prebid_config.setConfig(pbjs);
#       prebid_config.setAnalyticsSettings(pbjs);
#
#       pbjs.que.push(function() {
#         pbjs.addAdUnits(adUnits);
#         if(device === "desktop"){
#           pbjs.requestBids({
#             timeout: adUnits.length ? PREBID_TIMEOUT : 100,
#             adUnitCodes: ['div-gpt-ad-Reverso_Ctxt_D_Result_300x250_ATF', 'div-gpt-ad-Reverso_Ctxt_D_Result_300x250_BTF'],
#             bidsBackHandler: sendAdserverRequest
#           });
#         }
#         });
#
#       function isGptPubadsDefined() {
#         return window.googletag && typeof window.googletag.pubads === "function" && typeof window.googletag.pubads().getSlots === "function";
#       }
#
#       function refreshBids(adUnitCodes) {
#           if (!isGptPubadsDefined()) {
#             setTimeout(function() {
#               refreshBids(adUnitCodes);
#             }, 100);
#             return;
#           }
#           refresh_adsetup = prebid_config.getAdSetup(adUnitCodes) || [];
#           refresh_adunits = prebid_config.getAdUnits(refresh_adsetup) || [];
#           var gptAdSlots = [];
#           for (i in refresh_adsetup) {
#             gptAdSlots.push(slots[refresh_adsetup[i].slotcode]);
#           }
#           if(refresh_adunits.length && (typeof(abp) == 'undefined' || !abp)){
#             pbjs.que.push(function() {
#               pbjs.requestBids({
#                 timeout: PREBID_TIMEOUT,
#                 adUnitCodes: refresh_adunits.map(function (x) { return x.code; }),
#                 bidsBackHandler: function() {
#                   pbjs.setTargetingForGPTAsync(adUnitCodes);
#                   googletag.pubads().refresh(gptAdSlots, {changeCorrelator: false});
#                 }
#               });
#             });
#           }
#           else{
#               googletag.pubads().refresh(gptAdSlots, {changeCorrelator: false});
#           }
#       }
#
#       function setReversoTargeting() {
#           var adtargeting = {};
#
#           adtargeting['abtest'] = GA_VARIATION || 0;
#           adtargeting['Interface'] = 'RU';
#           adtargeting['device'] = device;
#           adtargeting['Status'] = 'prod';
#
#             adtargeting['Direction'] = 'EN-RU';
#
#
#           if(typeof(abp) != 'undefined' && abp){
#             adtargeting['abp'] = '1';
#         	}
#
#           for (var i in adtargeting) {
#             googletag.pubads().clearTargeting(i);
#             googletag.pubads().setTargeting(i, adtargeting[i]);
#           }
#       }
#
#       function sendAdserverRequest() {
#           if (pbjs.adserverRequestSent) return;
#           pbjs.adserverRequestSent = true;
#           googletag.cmd.push(function() {
#               pbjs.que.push(function() {
#                   setReversoTargeting();
#                   if(device === "desktop"){
#                       pbjs.setTargetingForGPTAsync(['div-gpt-ad-Reverso_Ctxt_D_Result_300x250_ATF', 'div-gpt-ad-Reverso_Ctxt_D_Result_300x250_BTF']);
#                       googletag.pubads().refresh([slots['div-gpt-ad-Reverso_Ctxt_D_Result_300x250_ATF'], slots['div-gpt-ad-Reverso_Ctxt_D_Result_300x250_BTF']], {changeCorrelator: false});
#                   }
#               });
#           });
#       }
#
#       setTimeout(function() {sendAdserverRequest();}, (PREBID_TIMEOUT*1.5));
# 	}
#    </script>
#   </meta>
#  </head>
#  <body class="locked mobile-locked noticed">
#   <div class="loading-pannel">
#    <span class="icon">
#    </span>
#   </div>
#   <div class=" results" id="wrapper">
#    <section id="top-content">
#     <a class="reverso-logo nonselectable no-loading" href="/%D0%BF%D0%B5%D1%80%D0%B5%D0%B2%D0%BE%D0%B4/" title="Reverso Context: поисковая система для переводов в контексте">
#      <div class="logo">
#       <span class="icon reverso-logo-red">
#       </span>
#       <span class="icon reverso-logo-blue">
#       </span>
#      </div>
#      <div class="text">
#       <span class="icon reverso-text">
#       </span>
#       <span class="icon context-text">
#       </span>
#      </div>
#     </a>
#     <div class="closed" id="mobile-menu">
#      <span class="icon menu">
#      </span>
#      <div class="floating-menu">
#       <a class="option register" href="https://account.reverso.net/register/context.reverso.net/ru?utm_source=contextweb&amp;utm_medium=usertopmenu&amp;utm_campaign=register">
#        <span class="icon add-user">
#        </span>
#        <span class="text">
#         Зарегистрироваться
#        </span>
#       </a>
#       <a class="option login" href="https://account.reverso.net/login/context.reverso.net/ru?utm_source=contextweb&amp;utm_medium=usertopmenu&amp;utm_campaign=login">
#        <span class="icon login">
#        </span>
#        <span class="text">
#         Войти
#        </span>
#       </a>
#       <button class="font-resize grey" data-size="0">
#        <span class="icon font-resize">
#        </span>
#        <span class="text">
#         Font size
#        </span>
#       </button>
#       <a class="option help grey" href="/%D0%BF%D0%B5%D1%80%D0%B5%D0%B2%D0%BE%D0%B4/about">
#        <span class="icon help">
#        </span>
#        <span class="text">
#         Помощь
#        </span>
#       </a>
#       <button class="option locale grey">
#        <span class="icon lang">
#        </span>
#        <span class="text">
#         русский
#        </span>
#        <span class="icon down-caret">
#        </span>
#       </button>
#       <div class="interface-langs closed">
#        <button class="option" data-value="ar">
#         العربية
#        </button>
#        <button class="option" data-value="de">
#         Deutsch
#        </button>
#        <button class="option" data-value="en">
#         English
#        </button>
#        <button class="option" data-value="es">
#         Español
#        </button>
#        <button class="option" data-value="fr">
#         Français
#        </button>
#        <button class="option" data-value="he">
#         עברית
#        </button>
#        <button class="option" data-value="it">
#         Italiano
#        </button>
#        <button class="option" data-value="ja">
#         日本語
#        </button>
#        <button class="option" data-value="nl">
#         Nederlands
#        </button>
#        <button class="option" data-value="pl">
#         Polski
#        </button>
#        <button class="option" data-value="pt">
#         Português
#        </button>
#        <button class="option" data-value="ro">
#         Română
#        </button>
#        <button class="option selected" data-value="ru">
#         Русский
#        </button>
#        <button class="option" data-value="tr">
#         Türkçe
#        </button>
#       </div>
#      </div>
#     </div>
#     <div class="selector closed nonselectable" id="top-menu">
#      <span class="option front icon horizontal-dots">
#      </span>
#      <span class="option front space-filler">
#       ···
#      </span>
#      <div class="drop-down">
#       <a class="option translation" href="http://www.reverso.net/text_translation.aspx?lang=RU" target="_blank">
#        <span class="icon lang">
#        </span>
#        <span class="text">
#         Перевод
#        </span>
#       </a>
#       <a class="option dictionary" href="https://dictionary.reverso.net" target="_blank">
#        <span class="icon dictionary">
#        </span>
#        <span class="text">
#         Словарь
#        </span>
#       </a>
#       <a class="option speller" href="http://www.reverso.net/spell-checker/english-spelling-grammar/" target="_blank">
#        <span class="icon spellcheck">
#        </span>
#        <span class="text">
#         Корректор
#        </span>
#       </a>
#       <a class="option conjugation" href="http://glagol.reverso.net/%D1%81%D0%BF%D1%80%D1%8F%D0%B6%D0%B5%D0%BD%D0%B8%D0%B5-%D1%80%D1%83%D1%81%D1%81%D0%BA%D0%B8%D0%B9.html" target="_blank">
#        <span class="icon conjugator">
#        </span>
#        <span class="text">
#         Спряжение
#        </span>
#       </a>
#       <a class="option synonyms" href="https://synonyms.reverso.net/%D1%81%D0%B8%D0%BD%D0%BE%D0%BD%D0%B8%D0%BC%D1%8B/" target="_blank">
#        <span class="icon synonyms">
#        </span>
#        <span class="text">
#         Синонимы
#        </span>
#       </a>
#       <a class="option grammar" href="http://grammar.reverso.net/" target="_blank">
#        <span class="icon translate">
#        </span>
#        <span class="text">
#         Грамматика
#        </span>
#       </a>
#       <a class="option document" href="https://documents.reverso.net/Default.aspx?lang=en" target="_blank">
#        <span class="icon document">
#        </span>
#        <span class="text">
#         Перевод документов и сайтов
#        </span>
#       </a>
#       <a class="option corporate" href="https://www.corporate-translation.reverso.com/">
#        <span class="icon corporate">
#        </span>
#        <span class="text">
#         Корпоративные решения
#        </span>
#       </a>
#       <a class="option newsletter" href="http://www.reverso.net/tricks.aspx?type=3&amp;lang=RU" target="_blank">
#        <span class="icon mail">
#        </span>
#        <span class="text">
#         Новостная рассылка
#        </span>
#       </a>
#       <a class="option help" href="/%D0%BF%D0%B5%D1%80%D0%B5%D0%B2%D0%BE%D0%B4/about">
#        <span class="icon help">
#        </span>
#        <span class="text">
#         Помощь
#        </span>
#       </a>
#      </div>
#     </div>
#     <div class="selector closed double nonselectable" id="lang-selector">
#      <span class="option front">
#       ru
#      </span>
#      <span class="icon down-caret">
#      </span>
#      <span class="option front space-filler">
#       ···
#      </span>
#      <div class="drop-down">
#       <div class="option" data-value="ar">
#        العربية
#       </div>
#       <div class="option" data-value="de">
#        Deutsch
#       </div>
#       <div class="option" data-value="en">
#        English
#       </div>
#       <div class="option" data-value="es">
#        Español
#       </div>
#       <div class="option" data-value="fr">
#        Français
#       </div>
#       <div class="option" data-value="he">
#        עברית
#       </div>
#       <div class="option" data-value="it">
#        Italiano
#       </div>
#       <div class="option" data-value="ja">
#        日本語
#       </div>
#       <div class="option" data-value="nl">
#        Nederlands
#       </div>
#       <div class="option" data-value="pl">
#        Polski
#       </div>
#       <div class="option" data-value="pt">
#        Português
#       </div>
#       <div class="option" data-value="ro">
#        Română
#       </div>
#       <div class="option selected" data-value="ru">
#        Русский
#       </div>
#       <div class="option" data-value="tr">
#        Türkçe
#       </div>
#      </div>
#     </div>
#     <button class="icon font-resize" data-size="0" title="Кликните, чтобы увеличить или уменьшить размер текста.">
#     </button>
#     <div class="reverso-links">
#      <a class="translation-link" href="http://www.reverso.net/text_translation.aspx?lang=RU" target="_blank">
#       Перевод
#      </a>
#      <a class="dictionary-link" href="https://dictionary.reverso.net" target="_blank">
#       Словарь
#      </a>
#      <a class="speller-link" href="http://www.reverso.net/spell-checker/english-spelling-grammar/" target="_blank">
#       Корректор
#      </a>
#      <a class="conjugation-link" href="http://glagol.reverso.net/%D1%81%D0%BF%D1%80%D1%8F%D0%B6%D0%B5%D0%BD%D0%B8%D0%B5-%D1%80%D1%83%D1%81%D1%81%D0%BA%D0%B8%D0%B9.html" target="_blank">
#       Спряжение
#      </a>
#      <a class="synonyms-link " href="https://synonyms.reverso.net/%D1%81%D0%B8%D0%BD%D0%BE%D0%BD%D0%B8%D0%BC%D1%8B/" target="_blank">
#       Синонимы
#      </a>
#      <a class="grammar-link last" href="http://grammar.reverso.net/" target="_blank">
#       Грамматика
#      </a>
#     </div>
#     <div class="social-content">
#      <a class="facebook-link icon facebook" href="https://www.facebook.com/Reverso.net?ref=ts" target="_blank" title="Facebook">
#      </a>
#      <a class="twitter-link icon twitter" href="https://twitter.com/ReversoEN" target="_blank" title="Twitter">
#      </a>
#      <a class="instagram-link icon instagram" href="https://www.instagram.com/reverso_app/?hl=ru" target="_blank" title="Instagram">
#      </a>
#     </div>
#     <!-- end top-bar -->
#    </section>
#    <section id="reverso-nav">
#     <a class="translation-link" href="http://www.reverso.net/text_translation.aspx?lang=RU" target="_blank">
#      Перевод
#     </a>
#     <span>
#      Context
#     </span>
#     <a class="conjugation-link" href="http://glagol.reverso.net/%D1%81%D0%BF%D1%80%D1%8F%D0%B6%D0%B5%D0%BD%D0%B8%D0%B5-%D1%80%D1%83%D1%81%D1%81%D0%BA%D0%B8%D0%B9.html" target="_blank">
#      Спряжение
#     </a>
#     <a class="synonyms-link" href="https://synonyms.reverso.net/%D1%81%D0%B8%D0%BD%D0%BE%D0%BD%D0%B8%D0%BC%D1%8B/" target="_blank">
#      Синонимы
#     </a>
#    </section>
#    <section id="body-content">
#     <div class="right-content">
#      <section id="subtop-content">
#       <script>
#        var register_link = "https://account.reverso.net/register/context.reverso.net/ru?utm_source=contextweb&utm_medium={0}&utm_campaign=register";
#     var login_link = "https://account.reverso.net/login/context.reverso.net/ru?utm_source=contextweb&utm_medium={0}&utm_campaign=login";
#       </script>
#       <div class="selector closed nonselectable " id="user-menu">
#        <span class="icon down-caret">
#        </span>
#        <span class="option front">
#         <span class="icon user">
#          <span class="icon rocket">
#          </span>
#         </span>
#         Присоединиться к Reverso
#        </span>
#        <div class="drop-down">
#         <a class="option register" href="https://account.reverso.net/register/context.reverso.net/ru?utm_source=contextweb&amp;utm_medium=usertopmenu&amp;utm_campaign=register">
#          <span class="icon add-user">
#          </span>
#          <span class="text">
#           Зарегистрироваться
#          </span>
#         </a>
#         <a class="option login" href="https://account.reverso.net/login/context.reverso.net/ru?utm_source=contextweb&amp;utm_medium=usertopmenu&amp;utm_campaign=login">
#          <span class="icon login">
#          </span>
#          <span class="text">
#           Войти
#          </span>
#         </a>
#         <span class="option facebook" data-url="null" id="fb-content">
#          <span class="icon facebook">
#          </span>
#          <span class="text">
#           Войти через Facebook
#          </span>
#         </span>
#         <span class="option google" data-url="null" id="google-content">
#          <span class="icon google3">
#          </span>
#          <span class="text">
#           Войти через Google
#          </span>
#         </span>
#        </div>
#       </div>
#       <div id="title-content">
#       </div>
#      </section>
#      <div id="rca">
#       <!-- /64378609/Context_300x250_Top -->
#       <span class="rca-title">
#        Реклама
#       </span>
#       <div class="rca" id="div-gpt-ad-Reverso_Ctxt_D_Result_300x250_ATF">
#        <script type="text/javascript">
#         if(!window.mobilecheck()) {
#         googletag.cmd.push(function() {
#           googletag.display('div-gpt-ad-Reverso_Ctxt_D_Result_300x250_ATF');
#         });
#       }
#        </script>
#       </div>
#       <div id="side-badges">
#        <a class="badge extension disabled mobile-hidden" href="" id="extension-badge" target="_blank">
#         <span class="logo">
#         </span>
#         <span class="text">
#          Добавить Reverso в {0}
#          <b>
#           Бесплатно
#          </b>
#         </span>
#        </a>
#        <div class="badges pannel">
#         <a class="text" href="/перевод/mobile-app?utm_source=contextweb&amp;utm_medium=banner&amp;utm_campaign=ctxtresultpage&amp;utm_content=ctxtappdl">
#          Скачать наше
#          <b>
#           бесплатное
#          </b>
#          приложение
#         </a>
#         <a class="badge and no-loading ru" href="/перевод/mobile-app?utm_source=contextweb&amp;utm_medium=banner&amp;utm_campaign=ctxtresultpage&amp;utm_content=ctxtappdl">
#         </a>
#         <a class="badge ios no-loading ru" href="/перевод/mobile-app?utm_source=contextweb&amp;utm_medium=banner&amp;utm_campaign=ctxtresultpage&amp;utm_content=ctxtappdl">
#         </a>
#        </div>
#       </div>
#       <!-- /64378609/Context_300x250_Bottom -->
#       <span class="rca-title">
#        Реклама
#       </span>
#       <div class="rca" id="div-gpt-ad-Reverso_Ctxt_D_Result_300x250_BTF">
#        <script type="text/javascript">
#         if(!window.mobilecheck()) {
#         googletag.cmd.push(function() {
#           googletag.display('div-gpt-ad-Reverso_Ctxt_D_Result_300x250_BTF');
#         });
#       }
#        </script>
#       </div>
#       <!-- /64378609/Context_300x600 -->
#       <span class="rca-title disabled tall-rca">
#        Реклама
#       </span>
#       <div class="rca disabled tall-rca" id="div-gpt-ad-Reverso_Ctxt_D_Result_300x600_BTF">
#        <script type="text/javascript">
#         if(!window.mobilecheck()) {
# 		  googletag.cmd.push(function() {
# 			googletag.display('div-gpt-ad-Reverso_Ctxt_D_Result_300x600_BTF');
# 		  });
#         }
#        </script>
#       </div>
#      </div>
#     </div>
#     <div class="left-content">
#      <div class="popup closed" id="register-popup-bottom">
#       <div class="header">
#        <span class="title">
#         Присоединяйтесь к Reverso, это
#         <b>
#          удобно и бесплатно
#         </b>
#         !
#        </span>
#        <button class="icon up-arrow" title="закрыть">
#        </button>
#       </div>
#       <div class="body wide-container">
#        <a class="button register" href="https://account.reverso.net/register/context.reverso.net/ru?utm_source=contextweb&amp;utm_medium=floatingpopup&amp;utm_campaign=register">
#         <span class="icon add-user">
#         </span>
#         Зарегистрироваться
#        </a>
#        <a class="button login" href="https://account.reverso.net/login/context.reverso.net/ru?utm_source=contextweb&amp;utm_medium=floatingpopup&amp;utm_campaign=login">
#         <span class="icon login">
#         </span>
#         Войти
#        </a>
#       </div>
#      </div>
#      <section id="search-content">
#       <div id="search">
#        <div class="ltr" id="search-input">
#         <div class="icons">
#          <button class="icon exclude" title="Кликните здесь, чтобы исключить некоторые слова из поиска. Например, слово1 -{слово2} : будут найдены примеры, которые содержат слово1 и НЕ содержат слово2">
#          </button>
#          <button class="icon cancel" title="Очистить ввод">
#          </button>
#         </div>
#         <input autocapitalize="none" autocomplete="off" class="keyboardInput ui-autocomplete-input ltr" id="entry" name="text" placeholder="Введите или вставьте текст" tabindex="1" type="text" value="book"/>
#        </div>
#        <div class="nonselectable" id="pair-selector">
#         <div class="selector double closed" id="src-selector" tabindex="2">
#          <span class="icon down-caret">
#          </span>
#          <span class="option front" data-value="en">
#           английский
#          </span>
#          <span class="space-filler">
#          </span>
#          <div class="drop-down">
#           <span class="option" data-value="ar">
#            арабский
#           </span>
#           <span class="option" data-value="de">
#            немецкий
#           </span>
#           <span class="option selected" data-value="en">
#            английский
#           </span>
#           <span class="option" data-value="es">
#            испанский
#           </span>
#           <span class="option" data-value="fr">
#            французский
#           </span>
#           <span class="option" data-value="he">
#            иврит
#           </span>
#           <span class="option" data-value="it">
#            итальянский
#           </span>
#           <span class="option" data-value="ja">
#            японский
#           </span>
#           <span class="option" data-value="nl">
#            голландский
#           </span>
#           <span class="option" data-value="pl">
#            польский
#           </span>
#           <span class="option" data-value="pt">
#            португальский
#           </span>
#           <span class="option" data-value="ro">
#            румынский
#           </span>
#           <span class="option" data-value="ru">
#            русский
#           </span>
#           <span class="option" data-value="tr">
#            турецкий
#           </span>
#          </div>
#         </div>
#         <div class="swap-content" title="Сменить направление перевода">
#          <div class="icons" tabindex="3">
#           <span class="icon reverso-top">
#           </span>
#           <span class="icon reverso-bottom">
#           </span>
#          </div>
#         </div>
#         <div class="selector double closed" id="trg-selector" tabindex="4">
#          <span class="icon down-caret">
#          </span>
#          <span class="option front" data-value="ru">
#           русский
#          </span>
#          <span class="space-filler">
#          </span>
#          <div class="drop-down">
#           <span class="option" data-value="ar">
#            арабский
#           </span>
#           <span class="option" data-value="de">
#            немецкий
#           </span>
#           <span class="option" data-value="en">
#            английский
#           </span>
#           <span class="option" data-value="es">
#            испанский
#           </span>
#           <span class="option" data-value="fr">
#            французский
#           </span>
#           <span class="option" data-value="he">
#            иврит
#           </span>
#           <span class="option" data-value="it">
#            итальянский
#           </span>
#           <span class="option" data-value="ja">
#            японский
#           </span>
#           <span class="option" data-value="nl">
#            голландский
#           </span>
#           <span class="option" data-value="pl">
#            польский
#           </span>
#           <span class="option" data-value="pt">
#            португальский
#           </span>
#           <span class="option" data-value="ro">
#            румынский
#           </span>
#           <span class="option selected" data-value="ru">
#            русский
#           </span>
#           <span class="option" data-value="tr">
#            турецкий
#           </span>
#          </div>
#         </div>
#        </div>
#        <button class="icon search" id="search-button" tabindex="5" title="Поиск">
#        </button>
#        <div class="exclude-content">
#         <button class="icon add disabled">
#         </button>
#         <div class="input-content">
#          <input placeholder="Исключить из поиска"/>
#         </div>
#        </div>
#       </div>
#      </section>
#      <section id="notice-content">
#       <div id="search-links">
#        <a class="icon synonyms" data-value="synonyms" href="https://synonyms.reverso.net/%D1%81%D0%B8%D0%BD%D0%BE%D0%BD%D0%B8%D0%BC%D1%8B/en/book" target="_blank" title="Искать в Синонимы">
#        </a>
#        <a class="icon conjugator" data-value="conjugator" href="http://glagol.reverso.net/%D1%81%D0%BF%D1%80%D1%8F%D0%B6%D0%B5%D0%BD%D0%B8%D0%B5-%D0%B0%D0%BD%D0%B3%D0%BB%D0%B8%D0%B9%D1%81%D0%BA%D0%B8%D0%B9-%D0%B3%D0%BB%D0%B0%D0%B3%D0%BE%D0%BB-book.html" target="_blank" title="Искать в Спряжение">
#        </a>
#        <button class="icon web" data-url="https://www.google.com/search?hl=en&amp;q=" data-value="web" title="Искать в Интернете">
#        </button>
#        <button class="icon wikipedia" data-url="https://en.wikipedia.org/wiki/" data-value="wikipedia" title="Искать в Wikipedia">
#        </button>
#        <button class="icon images" data-url="https://www.google.com/search?hl=en&amp;tbm=isch&amp;q=" data-value="images" title="Искать в Картинках">
#        </button>
#        <a class="icon dictionary" data-value="definition" href="https://dictionary.reverso.net/english-definition/book" target="_blank" title="Искать в Oпределение">
#        </a>
#       </div>
#       <div class="notice" id="seealso-content">
#        <span class="icon info">
#        </span>
#        <span class="message">
#         Посмотреть также:
#        </span>
#        <a class="" href="/перевод/английский-русский/to+book">
#         to book
#        </a>
#        <a class="" href="/перевод/английский-русский/comic+book">
#         comic book
#        </a>
#        <a class="" href="/перевод/английский-русский/by+the+book">
#         by the book
#        </a>
#       </div>
#       <script>
#        sendGA("send", "event", "seealso", "display", "en-ru");
#       </script>
#       <div class="notice" id="conj_search">
#        <i class="icon info">
#        </i>
#        <a class="suggestion" href="http://glagol.reverso.net/%D1%81%D0%BF%D1%80%D1%8F%D0%B6%D0%B5%D0%BD%D0%B8%D0%B5-%D0%B0%D0%BD%D0%B3%D0%BB%D0%B8%D0%B9%D1%81%D0%BA%D0%B8%D0%B9-%D0%B3%D0%BB%D0%B0%D0%B3%D0%BE%D0%BB-book.html" target="_blank">
#         Conjugation of this verb
#        </a>
#       </div>
#       <div class="notice" id="rude">
#        <i class="icon warning">
#        </i>
#        <span class="message">
#         На основании Вашего запроса эти примеры могут содержать грубую лексику.
#        </span>
#       </div>
#       <div class="notice" id="colloquial">
#        <i class="icon warning">
#        </i>
#        <span class="message">
#         На основании Вашего запроса эти примеры могут содержать разговорную лексику.
#        </span>
#       </div>
#      </section>
#      <section id="top-results">
#       <section class="" id="search-options">
#        <button class="icon down-arrow detailed-view closed" title="Показать подробности и рекомендации">
#        </button>
#        <div class="title-content">
#         <h1>
#          Перевод "book" на русский
#         </h1>
#        </div>
#       </section>
#       <div id="pos-filters">
#        <button class="n" data-index="0" data-pos="n." title="Показать все переводы, отмеченные как Существительное">
#         Сущ.
#        </button>
#        <button class="adj" data-index="1" data-pos="adj." title="Показать все переводы, отмеченные как Прилагательное">
#         Прил.
#        </button>
#        <button class="v" data-index="2" data-pos="v." title="Показать все переводы, отмеченные как Глагол">
#         Глагол
#        </button>
#        <div id="synonyms-button-container">
#         <a class="icon synonyms" dir=" ltr " href="https://synonyms.reverso.net/%D1%81%D0%B8%D0%BD%D0%BE%D0%BD%D0%B8%D0%BC%D1%8B/en/book" id="synonyms-button" target="_blank" title="Синонимы">
#         </a>
#        </div>
#       </div>
#       <div class="wide-container" id="filtered-entry">
#       </div>
#       <div class="wide-container" id="translations-content">
#        <a class="translation ltr dict n" data-freq="18521" data-pos="[nf]" data-pos-index="0" data-posgroup="1" href="/перевод/русский-английский/%D0%BA%D0%BD%D0%B8%D0%B3%D0%B0" title="&lt;div class='nobold'&gt;Посмотреть примеры с переводом &lt;em class='translation'&gt;книга&lt;/em&gt;&lt;br&gt;Существительное - женский род&lt;br&gt;(+10k примеров, содержащих перевод)&lt;/div&gt;">
#         <div class="pos-mark">
#          <span class="n" title="Существительное - женский род">
#          </span>
#         </div>
#         книга
#        </a>
#        <a class="translation ltr dict n" data-freq="1094" data-pos="[nf]" data-pos-index="0" data-posgroup="1" href="/перевод/русский-английский/%D0%BA%D0%BD%D0%B8%D0%B6%D0%BA%D0%B0" title="&lt;div class='nobold'&gt;Посмотреть примеры с переводом &lt;em class='translation'&gt;книжка&lt;/em&gt;&lt;br&gt;Существительное - женский род&lt;br&gt;(1094 примеров, содержащих перевод)&lt;/div&gt;">
#         <div class="pos-mark">
#          <span class="n" title="Существительное - женский род">
#          </span>
#         </div>
#         книжка
#        </a>
#        <a class="translation ltr dict n" data-freq="199" data-pos="[nm]" data-pos-index="0" data-posgroup="1" href="/перевод/русский-английский/%D1%81%D0%BF%D1%80%D0%B0%D0%B2%D0%BE%D1%87%D0%BD%D0%B8%D0%BA" title="&lt;div class='nobold'&gt;Посмотреть примеры с переводом &lt;em class='translation'&gt;справочник&lt;/em&gt;&lt;br&gt;Существительное - мужской род&lt;br&gt;(199 примеров, содержащих перевод)&lt;/div&gt;">
#         <div class="pos-mark">
#          <span class="n" title="Существительное - мужской род">
#          </span>
#         </div>
#         справочник
#        </a>
#        <a class="translation ltr dict n" data-freq="181" data-pos="[nm]" data-pos-index="0" data-posgroup="1" href="/перевод/русский-английский/%D1%83%D1%87%D0%B5%D0%B1%D0%BD%D0%B8%D0%BA" title="&lt;div class='nobold'&gt;Посмотреть примеры с переводом &lt;em class='translation'&gt;учебник&lt;/em&gt;&lt;br&gt;Существительное - мужской род&lt;br&gt;(181 примеров, содержащих перевод)&lt;/div&gt;">
#         <div class="pos-mark">
#          <span class="n" title="Существительное - мужской род">
#          </span>
#         </div>
#         учебник
#        </a>
#        <a class="translation ltr dict n" data-freq="89" data-pos="[nm]" data-pos-index="0" data-posgroup="1" href="/перевод/русский-английский/%D0%B6%D1%83%D1%80%D0%BD%D0%B0%D0%BB" title="&lt;div class='nobold'&gt;Посмотреть примеры с переводом &lt;em class='translation'&gt;журнал&lt;/em&gt;&lt;br&gt;Существительное - мужской род&lt;br&gt;(89 примеров, содержащих перевод)&lt;/div&gt;">
#         <div class="pos-mark">
#          <span class="n" title="Существительное - мужской род">
#          </span>
#         </div>
#         журнал
#        </a>
#        <a class="translation ltr dict n" data-freq="75" data-pos="[nm]" data-pos-index="0" data-posgroup="1" href="/перевод/русский-английский/%D0%B0%D0%BB%D1%8C%D0%B1%D0%BE%D0%BC" title="&lt;div class='nobold'&gt;Посмотреть примеры с переводом &lt;em class='translation'&gt;альбом&lt;/em&gt;&lt;br&gt;Существительное - мужской род&lt;br&gt;(75 примеров, содержащих перевод)&lt;/div&gt;">
#         <div class="pos-mark">
#          <span class="n" title="Существительное - мужской род">
#          </span>
#         </div>
#         альбом
#        </a>
#        <a class="translation ltr dict n" data-freq="73" data-pos="[n]" data-pos-index="0" data-posgroup="1" href="/перевод/русский-английский/%D1%82%D0%B5%D1%82%D1%80%D0%B0%D0%B4%D1%8C" title="&lt;div class='nobold'&gt;Посмотреть примеры с переводом &lt;em class='translation'&gt;тетрадь&lt;/em&gt;&lt;br&gt;Существительное&lt;br&gt;(73 примеров, содержащих перевод)&lt;/div&gt;">
#         <div class="pos-mark">
#          <span class="n" title="Существительное">
#          </span>
#         </div>
#         тетрадь
#        </a>
#        <a class="translation ltr dict first n" data-freq="60" data-pos="[nm]" data-pos-index="0" data-posgroup="1" href="/перевод/русский-английский/%D0%B1%D0%BB%D0%BE%D0%BA%D0%BD%D0%BE%D1%82" title="&lt;div class='nobold'&gt;Посмотреть примеры с переводом &lt;em class='translation'&gt;блокнот&lt;/em&gt;&lt;br&gt;Существительное - мужской род&lt;br&gt;(60 примеров, содержащих перевод)&lt;/div&gt;">
#         <div class="pos-mark">
#          <span class="n" title="Существительное - мужской род">
#          </span>
#         </div>
#         блокнот
#        </a>
#        <a class="translation ltr dict first adj" data-freq="743" data-pos="[adj]" data-pos-index="1" data-posgroup="2" href="/перевод/русский-английский/%D0%BA%D0%BD%D0%B8%D0%B6%D0%BD%D1%8B%D0%B9" title="&lt;div class='nobold'&gt;Посмотреть примеры с переводом &lt;em class='translation'&gt;книжный&lt;/em&gt;&lt;br&gt;Прилагательное&lt;br&gt;(743 примеров, содержащих перевод)&lt;/div&gt;">
#         <div class="pos-mark">
#          <span class="adj" title="Прилагательное">
#          </span>
#         </div>
#         книжный
#        </a>
#        <a class="translation ltr dict v" data-freq="205" data-pos="[v]" data-pos-index="2" data-posgroup="3" href="/перевод/русский-английский/%D0%B7%D0%B0%D0%B1%D1%80%D0%BE%D0%BD%D0%B8%D1%80%D0%BE%D0%B2%D0%B0%D1%82%D1%8C" title="&lt;div class='nobold'&gt;Посмотреть примеры с переводом &lt;em class='translation'&gt;забронировать&lt;/em&gt;&lt;br&gt;Глагол&lt;br&gt;(205 примеров, содержащих перевод)&lt;/div&gt;">
#         <div class="pos-mark">
#          <span class="v" title="Глагол">
#          </span>
#         </div>
#         забронировать
#        </a>
#        <a class="translation ltr dict mobile-hidden v" data-freq="166" data-pos="[v]" data-pos-index="2" data-posgroup="3" href="/перевод/русский-английский/%D0%B7%D0%B0%D0%BA%D0%B0%D0%B7%D0%B0%D1%82%D1%8C" title="&lt;div class='nobold'&gt;Посмотреть примеры с переводом &lt;em class='translation'&gt;заказать&lt;/em&gt;&lt;br&gt;Глагол&lt;br&gt;(166 примеров, содержащих перевод)&lt;/div&gt;">
#         <div class="pos-mark">
#          <span class="v" title="Глагол">
#          </span>
#         </div>
#         заказать
#        </a>
#        <a class="translation ltr dict mobile-hidden v" data-freq="37" data-pos="[v]" data-pos-index="2" data-posgroup="3" href="/перевод/русский-английский/%D0%B1%D1%80%D0%BE%D0%BD%D0%B8%D1%80%D0%BE%D0%B2%D0%B0%D1%82%D1%8C" title="&lt;div class='nobold'&gt;Посмотреть примеры с переводом &lt;em class='translation'&gt;бронировать&lt;/em&gt;&lt;br&gt;Глагол&lt;br&gt;(37 примеров, содержащих перевод)&lt;/div&gt;">
#         <div class="pos-mark">
#          <span class="v" title="Глагол">
#          </span>
#         </div>
#         бронировать
#        </a>
#        <div class="translation ltr dict mobile-hidden v" data-freq="18" data-pos="[v]" data-pos-index="2" data-posgroup="3" title="&lt;div class='nobold'&gt;Посмотреть примеры с переводом &lt;em class='translation'&gt;заказывать&lt;/em&gt;&lt;br&gt;Глагол&lt;br&gt;(18 примеров, содержащих перевод)&lt;/div&gt;">
#         <div class="pos-mark">
#          <span class="v" title="Глагол">
#          </span>
#         </div>
#         заказывать
#        </div>
#        <div class="translation ltr dict first mobile-hidden v" data-freq="6" data-pos="[v]" data-pos-index="2" data-posgroup="3" title="&lt;div class='nobold'&gt;Посмотреть примеры с переводом &lt;em class='translation'&gt;зарегистрировать&lt;/em&gt;&lt;br&gt;Глагол&lt;br&gt;(6 примеров, содержащих перевод)&lt;/div&gt;">
#         <div class="pos-mark">
#          <span class="v" title="Глагол">
#          </span>
#         </div>
#         зарегистрировать
#        </div>
#        <a class="translation ltr dict mobile-hidden n" data-freq="44" data-pos="[n]" data-pos-index="0" data-posgroup="4" href="/перевод/русский-английский/%D1%81%D0%B1%D0%BE%D1%80%D0%BD%D0%B8%D0%BA" title="&lt;div class='nobold'&gt;Посмотреть примеры с переводом &lt;em class='translation'&gt;сборник&lt;/em&gt;&lt;br&gt;Существительное&lt;br&gt;(44 примеров, содержащих перевод)&lt;/div&gt;">
#         <div class="pos-mark">
#          <span class="n" title="Существительное">
#          </span>
#         </div>
#         сборник
#        </a>
#        <a class="translation ltr dict mobile-hidden n" data-freq="40" data-pos="[nf]" data-pos-index="0" data-posgroup="4" href="/перевод/русский-английский/%D0%BA%D0%BD%D0%B8%D0%B6%D0%B5%D1%87%D0%BA%D0%B0" title="&lt;div class='nobold'&gt;Посмотреть примеры с переводом &lt;em class='translation'&gt;книжечка&lt;/em&gt;&lt;br&gt;Существительное - женский род&lt;br&gt;(40 примеров, содержащих перевод)&lt;/div&gt;">
#         <div class="pos-mark">
#          <span class="n" title="Существительное - женский род">
#          </span>
#         </div>
#         книжечка
#        </a>
#        <a class="translation ltr dict mobile-hidden translation-hidden no-pos" data-freq="102" data-posgroup="6" href="/перевод/русский-английский/%D0%BF%D1%80%D0%B0%D0%B2%D0%B8%D0%BB%D0%B0%D0%BC" title="&lt;div class='nobold'&gt;Посмотреть примеры с переводом &lt;em class='translation'&gt;правилам&lt;/em&gt;&lt;br&gt;(102 примеров, содержащих перевод)&lt;/div&gt;">
#         правилам
#        </a>
#        <div class="translation ltr dict mobile-hidden translation-hidden n" data-freq="7" data-pos="[nn]" data-pos-index="0" data-posgroup="4" title="&lt;div class='nobold'&gt;Посмотреть примеры с переводом &lt;em class='translation'&gt;либретто&lt;/em&gt;&lt;br&gt;Существительное - средний род&lt;br&gt;(7 примеров, содержащих перевод)&lt;/div&gt;">
#         <div class="pos-mark">
#          <span class="n" title="Существительное - средний род">
#          </span>
#         </div>
#         либретто
#        </div>
#        <div class="translation ltr dict mobile-hidden translation-hidden n" data-freq="2" data-pos="[n]" data-pos-index="0" data-posgroup="4" title="&lt;div class='nobold'&gt;Посмотреть примеры с переводом &lt;em class='translation'&gt;книжица&lt;/em&gt;&lt;br&gt;Существительное&lt;br&gt;(2 примеров, содержащих перевод)&lt;/div&gt;">
#         <div class="pos-mark">
#          <span class="n" title="Существительное">
#          </span>
#         </div>
#         книжица
#        </div>
#        <div class="translation icon horizontal-dots" title="Больше">
#        </div>
#       </div>
#       <section class="wide-container" id="filters-content">
#        <button class="other-content" data-negative=" -{книга} -{книжка} -{справочник} -{учебник} -{журнал} -{альбом} -{тетрадь} -{блокнот} -{книжный} -{забронировать} -{заказать} -{бронировать} -{заказывать} -{зарегистрировать} -{сборник} -{книжечка} -{правилам} -{либретто} -{книжица}" data-other="0">
#         Другие переводы
#        </button>
#        <div class="filter-form closed">
#         <button class="icon filter" title="Вы можете получить более точные результаты, указав слово или несколько слов, которые должен содержать перевод. В результате будут показаны только примеры, которые содержат эти слова.">
#         </button>
#         <button class="icon cancel" title="Очистить фильтр">
#         </button>
#         <div class="input-content">
#          <button class="icon exclude" title="Кликните здесь, чтобы исключить некоторые слова из поиска. Например, слово1 -{слово2} : будут найдены примеры, которые содержат слово1 и НЕ содержат слово2">
#          </button>
#          <input autocomplete="off" placeholder="Показать переводы, содержащие..." readonly=""/>
#         </div>
#        </div>
#       </section>
#       <section class="wide-container" id="top-suggestions">
#        <h3>
#         Предложения
# ...
#          </button>
#          <button class="add icon addentry " data-id="OPENSUBTITLES-2016.EN-RU_14980095" data-text="Но в моей &lt;em&gt;книжке&lt;/em&gt; с ним все в порядке." data-url="https://dictionary.reverso.net/CollabDict.aspx?view=2&amp;lang=RU" title="Добавить этот перевод в коллективный словарь Reverso">
#          </button>
#          <button class="copy icon mobile-hidden" data-id="OPENSUBTITLES-2016.EN-RU_14980095" title="Скопировать перевод">
#          </button>
#          <button class="icon non-favourite " data-id="OPENSUBTITLES-2016.EN-RU_14980095" title="Отметить пример в качестве избранного">
#          </button>
#          <button class="voice icon stopped" data-id="OPENSUBTITLES-2016.EN-RU_14980095" data-lang="ru" title="Произношение">
#          </button>
#         </div>
#        </div>
#        <button class="mobile-voice icon stopped played" data-id="OPENSUBTITLES-2016.EN-RU_14980095">
#        </button>
#       </div>
#       <div class="example blocked" id="OPENSUBTITLES-2016.EN-RU_14586129">
#        <div class="src ltr">
#         <span class="text" lang="en">
#          Literally wrote the
#          <em>
#           book
#          </em>
#          on modern naval warfare.
#         </span>
#        </div>
#        <div class="trg ltr">
#         <span class="icon jump-right">
#         </span>
#         <span class="text">
#          Он в буквальном смысле написал
#          <a class="link_highlighted" href="/перевод/русский-английский/%D0%BA%D0%BD%D0%B8%D0%B3%D1%83" rel="nofollow">
#           <em>
#            книгу
#           </em>
#          </a>
#          о современной войне на море.
#         </span>
#        </div>
#        <div class="options">
#         <div class="src">
#          <button class="voice icon stopped" data-id="OPENSUBTITLES-2016.EN-RU_14586129" data-lang="en" title="Произношение">
#          </button>
#         </div>
#         <div class="trg">
#          <button class="icon more-context" data-id="OPENSUBTITLES-2016.EN-RU_14586129" title="Посмотреть примеры для этого перевода в контексте (http://opus.nlpl.eu/OpenSubtitles2016.php)">
#          </button>
#          <button class="report icon thumb-down" data-id="OPENSUBTITLES-2016.EN-RU_14586129" title="Сообщить о проблеме в этом примере">
#          </button>
#          <button class="add icon addentry " data-id="OPENSUBTITLES-2016.EN-RU_14586129" data-text="Он в буквальном смысле написал &lt;em&gt;книгу&lt;/em&gt; о современной войне на море." data-url="https://dictionary.reverso.net/CollabDict.aspx?view=2&amp;lang=RU" title="Добавить этот перевод в коллективный словарь Reverso">
#          </button>
#          <button class="copy icon mobile-hidden" data-id="OPENSUBTITLES-2016.EN-RU_14586129" title="Скопировать перевод">
#          </button>
#          <button class="icon non-favourite " data-id="OPENSUBTITLES-2016.EN-RU_14586129" title="Отметить пример в качестве избранного">
#          </button>
#          <button class="voice icon stopped" data-id="OPENSUBTITLES-2016.EN-RU_14586129" data-lang="ru" title="Произношение">
#          </button>
#         </div>
#        </div>
#        <button class="mobile-voice icon stopped played" data-id="OPENSUBTITLES-2016.EN-RU_14586129">
#        </button>
#       </div>
#       <div class="example blocked" id="OPENSUBTITLES-2016.EN-RU_12878035">
#        <div class="src ltr">
#         <span class="text" lang="en">
#          Let me interview you for my
#          <em>
#           book
#          </em>
#          .
#         </span>
#        </div>
#        <div class="trg ltr">
#         <span class="icon jump-right">
#         </span>
#         <span class="text">
#          Позвольте мне взять у вас интервью для моей
#          <a class="link_highlighted" href="/перевод/русский-английский/%D0%BA%D0%BD%D0%B8%D0%B3%D0%B8" rel="nofollow">
#           <em>
#            книги
#           </em>
#          </a>
#          .
#         </span>
#        </div>
#        <div class="options">
#         <div class="src">
#          <button class="voice icon stopped" data-id="OPENSUBTITLES-2016.EN-RU_12878035" data-lang="en" title="Произношение">
#          </button>
#         </div>
#         <div class="trg">
#          <button class="icon more-context" data-id="OPENSUBTITLES-2016.EN-RU_12878035" title="Посмотреть примеры для этого перевода в контексте (http://opus.nlpl.eu/OpenSubtitles2016.php)">
#          </button>
#          <button class="report icon thumb-down" data-id="OPENSUBTITLES-2016.EN-RU_12878035" title="Сообщить о проблеме в этом примере">
#          </button>
#          <button class="add icon addentry " data-id="OPENSUBTITLES-2016.EN-RU_12878035" data-text="Позвольте мне взять у вас интервью для моей &lt;em&gt;книги&lt;/em&gt;." data-url="https://dictionary.reverso.net/CollabDict.aspx?view=2&amp;lang=RU" title="Добавить этот перевод в коллективный словарь Reverso">
#          </button>
#          <button class="copy icon mobile-hidden" data-id="OPENSUBTITLES-2016.EN-RU_12878035" title="Скопировать перевод">
#          </button>
#          <button class="icon non-favourite " data-id="OPENSUBTITLES-2016.EN-RU_12878035" title="Отметить пример в качестве избранного">
#          </button>
#          <button class="voice icon stopped" data-id="OPENSUBTITLES-2016.EN-RU_12878035" data-lang="ru" title="Произношение">
#          </button>
#         </div>
#        </div>
#        <button class="mobile-voice icon stopped played" data-id="OPENSUBTITLES-2016.EN-RU_12878035">
#        </button>
#       </div>
#       <div class="popup wide-container" id="blocked-rude-results-banner">
#        <div class="header">
#        </div>
#        <div class="body">
#         <span>
#          Возможно неприемлемое содержание
#         </span>
#         <div class="buttons-content">
#          <button class="button close">
#           Показать
#          </button>
#         </div>
#         <span class="disclaimer">
#          Примеры предназначены только для помощи в переводе искомых слов и выражений в различных контекстах. Мы не выбираем и не утверждаем примеры, и они могут содержать неприемлемые слова или идеи. Пожалуйста, сообщайте нам о примерах, которые, на Ваш взгляд, необходимо исправить или удалить. Грубые или разговорные переводы обычно отмечены красным или оранжевым цветом.
#         </span>
#        </div>
#       </div>
#       <div class="popup wide-container" id="blocked-results-banner">
#        <div class="header">
#         <button class="icon close">
#         </button>
#        </div>
#        <div class="body">
#         <span>
#          Зарегистрируйтесь, чтобы увидеть больше примеров.
#         </span>
#         <div class="buttons-content">
#          <a class="button register" href="https://account.reverso.net/register/context.reverso.net/ru?utm_source=contextweb&amp;utm_medium=blockedexamples&amp;utm_campaign=register">
#           Зарегистрироваться
#          </a>
#          <a class="button login" href="https://account.reverso.net/login/context.reverso.net/ru?utm_source=contextweb&amp;utm_medium=blockedexamples&amp;utm_campaign=login">
#           Войти
#          </a>
#         </div>
#        </div>
#       </div>
#      </section>
#      <section id="no-results">
#       <span class="wide-container message">
#        Ничего не найдено для этого значения.
#       </span>
#       <div class="wide-container">
#        <button data-ga="display-noexamples" id="add-example" title='Предложить пример для "book"'>
#         Предложить пример
#        </button>
#       </div>
#      </section>
#      <section id="examples-bottom">
#       <div class="loading-pannel">
#        <span class="icon">
#        </span>
#       </div>
#       <button class="button load-more unregistered" id="load-more-examples">
#        Больше примеров
#       </button>
#       <div class="wide-container" data-exact="25624" id="result-info">
#        <p>
#         Результатов:
#         <span id="nrows">
#          25624
#         </span>
#         . Точных совпадений:
#         <span id="nrows_exact">
#          25624
#         </span>
#         . Затраченное время:
#         <span id="time">
#          113
#         </span>
#         мс
#        </p>
#       </div>
#       <div class="wide-container">
#        <button data-ga="display-examplesbottom" id="add-example" title='Предложить пример для "book"'>
#         Предложить пример
#        </button>
#       </div>
#       <section class="wide-container" id="bottom-suggestions">
#        <div class="suggestion hidden" title="Это предложение исключено из результатов">
#         <span class="text" data-url="/перевод/английский-русский/to+book">
#          to book
#         </span>
#         <span class="figure ">
#          494
#         </span>
#        </div>
#        <div class="suggestion">
#         <a class="text" href="/перевод/английский-русский/book+about">
#          book about
#         </a>
#         <span class="figure ">
#          426
#         </span>
#        </div>
#        <div class="suggestion hidden" title="Это предложение исключено из результатов">
#         <span class="text" data-url="/перевод/английский-русский/comic+book">
#          comic book
#         </span>
#         <span class="figure ">
#          383
#         </span>
#        </div>
#        <div class="suggestion">
#         <a class="text" href="/перевод/английский-русский/new+book">
#          new book
#         </a>
#         <span class="figure ">
#          316
#         </span>
#        </div>
#        <div class="suggestion">
#         <a class="text" href="/перевод/английский-русский/address+book">
#          address book
#         </a>
#         <span class="figure ">
#          247
#         </span>
#        </div>
#        <div class="suggestion">
#         <a class="text" href="/перевод/английский-русский/blue+book">
#          blue book
#         </a>
#         <span class="figure ">
#          245
#         </span>
#        </div>
#        <div class="suggestion hidden" title="Это предложение исключено из результатов">
#         <span class="text" data-url="/перевод/английский-русский/by+the+book">
#          by the book
#         </span>
#         <span class="figure ">
#          236
#         </span>
#        </div>
#        <div class="suggestion">
#         <a class="text" href="/перевод/английский-русский/read+the+book">
#          read the book
#         </a>
#         <span class="figure ">
#          230
#         </span>
#        </div>
#        <div class="suggestion">
#         <a class="text" href="/перевод/английский-русский/read+a+book">
#          read a book
#         </a>
#         <span class="figure ">
#          230
#         </span>
#        </div>
#        <button class="icon other other-suggestions" data-negative="-{to book} -{book about} -{comic book} -{new book} -{address book} -{blue book} -{by the book} -{read the book} -{read a book}" title="Другие переводы">
#        </button>
#       </section>
#      </section>
#     </div>
#     <!-- /64378609/Context_MegaBanner_Bottom -->
#     <div class="hidden" id="bottom-mega-rca-box">
#      <div class="bottom-rca mega-rca" id="div-gpt-ad-Reverso_Ctxt_D_Result_728x90_BTF">
#       <script type="text/javascript">
#        if(!window.mobilecheck()) {
#           googletag.cmd.push(function() {
#             googletag.display('div-gpt-ad-Reverso_Ctxt_D_Result_728x90_BTF');
#           });
#         }
#       </script>
#      </div>
#      <span class="rca-title rca-title-vertical bottom-rca">
#       Реклама
#      </span>
#     </div>
#    </section>
#    <section id="sitemaps">
#     <p>
#      Индекс слова:
#      <a href="/перевод/index/английский-русский/w-1-300.html">
#       1-300
#      </a>
#      ,
#      <a href="/перевод/index/английский-русский/w-301-600.html">
#       301-600
#      </a>
#      ,
#      <a href="/перевод/index/английский-русский/w-601-900.html">
#       601-900
#      </a>
#      ,
#      <a href="/перевод/index/английский-русский/w.html">
#       Больше
#      </a>
#      <p>
#       Индекс выражения:
#       <a href="/перевод/index/английский-русский/e-1-400.html">
#        1-400
#       </a>
#       ,
#       <a href="/перевод/index/английский-русский/e-401-800.html">
#        401-800
#       </a>
#       ,
#       <a href="/перевод/index/английский-русский/e-801-1200.html">
#        801-1200
#       </a>
#       ,
#       <a href="/перевод/index/английский-русский/e.html">
#        Больше
#       </a>
#       <p>
#        Индекс фразы:
#        <a href="/перевод/index/английский-русский/p-1-400.html">
#         1-400
#        </a>
#        ,
#        <a href="/перевод/index/английский-русский/p-401-800.html">
#         401-800
#        </a>
#        ,
#        <a href="/перевод/index/английский-русский/p-801-1200.html">
#         801-1200
#        </a>
#        ,
#        <a href="/перевод/index/английский-русский/p.html">
#         Больше
#        </a>
#       </p>
#      </p>
#     </p>
#    </section>
#    <p class="developers wide-container">
#     Разработано Prompsit Language Engineering для Softissimo
#    </p>
#    <section id="footer">
#     <div class="wide-container">
#      <a href="/перевод/about">
#       Что такое контекстный словарь
#      </a>
#      <a class="app-link" href="/перевод/mobile-app">
#       Скачать приложение
#      </a>
#      <a href="http://www.reverso.net/feedback.aspx?type=3&amp;lang=RU" target="_blank">
#       Контакты
#      </a>
#      <a href="/перевод/legal">
#       Правовые вопросы
#      </a>
#     </div>
#     <div class="wide-container">
#      <a href="/translation/">
#       Translation in context
#      </a>
#      <a href="/traduction/">
#       Traduction en contexte
#      </a>
#      <a href="/traduccion/">
#       Traducción en contexto
#      </a>
#      <a href="/traducao/">
#       Tradução em contexto
#      </a>
#      <a href="/traduzione/">
#       Traduzione in contesto
#      </a>
#      <a href="/übersetzung/">
#       Übersetzung im Kontext
#      </a>
#      <a href="/الترجمة/">
#       الترجمة في السياق
#      </a>
#      <a href="/翻訳/">
#       文脈に沿った翻訳
#      </a>
#      <a href="/vertaling/">
#       Vertaling in context
#      </a>
#      <a href="/תרגום/">
#       תרגום בהקשר
#      </a>
#      <a href="/tłumaczenie/">
#       Tłumaczenie w kontekście
#      </a>
#      <a href="/traducere/">
#       Traducere în context
#      </a>
#      <a href="/çeviri/">
#       İçerik tercümesi
#      </a>
#     </div>
#     <div class="wide-container">
#      <a href="https://synonyms.reverso.net/%D1%81%D0%B8%D0%BD%D0%BE%D0%BD%D0%B8%D0%BC%D1%8B/" target="_blank">
#       Синонимы
#      </a>
#      <a href="http://glagol.reverso.net/%D1%81%D0%BF%D1%80%D1%8F%D0%B6%D0%B5%D0%BD%D0%B8%D0%B5-%D1%80%D1%83%D1%81%D1%81%D0%BA%D0%B8%D0%B9.html" target="_blank">
#       Спряжение
#      </a>
#      <a href="https://www.corporate-translation.reverso.com/" target="_blank">
#       Reverso Corporate
#      </a>
#     </div>
#     <p class="copy">
#      ©  2013-2019 Softissimo Inc. Все права защищены.
#     </p>
#    </section>
#   </div>
#   <script src="https://cdn.reverso.net/context/v51300/js/bst.constants-ru.js" type="text/javascript">
#   </script>
#   <script src="https://cdn.reverso.net/context/v51300/js/bst.scripts.js" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    !function(f,b,e,v,n,t,s){if(f.fbq)return;n=f.fbq=function(){n.callMethod?
#   n.callMethod.apply(n,arguments):n.queue.push(arguments)};if(!f._fbq)f._fbq=n;
#   n.push=n;n.loaded=!0;n.version='2.0';n.queue=[];t=b.createElement(e);t.async=!0;
#   t.src=v;s=b.getElementsByTagName(e)[0];s.parentNode.insertBefore(t,s)}(window,
#   document,'script','https://connect.facebook.net/en_US/fbevents.js');
#   fbq('init', '1090291004350551');
#   fbq('track', "PageView");
#
#   var ezt = ezt ||[];
#   (function(){
#     var elem = document.createElement('script');
#     elem.src = (document.location.protocol == "https:" ? "https://secure" : "http://pixel") + ".quantserve.com/aquant.js?a=p-9z6v4xdJwT5Z-";
#     elem.async = true;
#     elem.type = "text/javascript";
#     var scpt = document.getElementsByTagName('script')[0];
#     scpt.parentNode.insertBefore(elem,scpt);
#   }());
#   ezt.push({qacct: 'p-9z6v4xdJwT5Z-', labels: 'context', uid: '' });
#   </script>
#   <noscript>
#    <img alt="" height="1" src="//pixel.quantserve.com/pixel/p-9z6v4xdJwT5Z-.gif?labels=context" style="display: none;" width="1"/>
#    <img alt="" height="1" src="https://www.facebook.com/tr?id=1090291004350551&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/>
#   </noscript>
#  </body>
# </html>

# %%
for l in soup_sub.find_all('span', attrs = {'class':'text'}):
    print(l)
# Out:
# <span class="text">Зарегистрироваться</span>
# <span class="text">Войти</span>
# <span class="text">Font size</span>
# <span class="text">Помощь</span>
# <span class="text">русский</span>
# <span class="text">Перевод</span>
# <span class="text">Словарь</span>
# <span class="text">Корректор</span>
# <span class="text">Спряжение</span>
# <span class="text">Синонимы</span>
# <span class="text">Грамматика</span>
# <span class="text">Перевод документов и сайтов</span>
# <span class="text">Корпоративные решения</span>
# <span class="text">Новостная рассылка</span>
# <span class="text">Помощь</span>
# <span class="text">Зарегистрироваться</span>
# <span class="text">Войти</span>
# <span class="text">Войти через Facebook</span>
# <span class="text">Войти через Google</span>
# <span class="text">Добавить Reverso в {0} <b>Бесплатно</b></span>
# <span class="text">
#           Недавно была опубликована <em>книга</em> Internet protocols.</span>
# <span class="text" lang="en">
#           Recently has published as a co-author with Ra-Ma the <a class="link_highlighted" href="/перевод/английский-русский/book" rel="nofollow"><em>book</em></a> entitled Internet protocols.</span>
# <span class="text">
#           Эта <em>книга</em> призвана разъяснить детям различные аспекты нищеты.</span>
# <span class="text" lang="en">
#           The <a class="link_highlighted" href="/перевод/английский-русский/book" rel="nofollow"><em>book</em></a> aimed to sensitize children to the different aspects of poverty.</span>
# <span class="text">
#           У меня с собой журналы и интересная <em>книга</em>.</span>
# <span class="text" lang="en">
#           Well, I brought lots of magazines and a good <a class="link_highlighted" href="/перевод/английский-русский/novel" rel="nofollow"><em>novel</em></a>.</span>
# <span class="text">
#           Эта <em>книга</em> имеется на веб-сайте УВКПЧ.</span>
# <span class="text" lang="en">
#           The <a class="link_highlighted" href="/перевод/английский-русский/book" rel="nofollow"><em>book</em></a> is available on the OHCHR web site.</span>
# <span class="text">
#           Это <em>книга</em> учета Стива Оуэна, со всеми записями.</span>
# <span class="text" lang="en">
#           It's Steve Owen's accounting <a class="link_highlighted" href="/перевод/английский-русский/book" rel="nofollow"><em>book</em></a>, with all the cooking.</span>
# <span class="text">
#           Моя любовная жизнь как открытая <em>книга</em> короткая и неприятная.</span>
# <span class="text" lang="en">
#           My love life is an open <a class="link_highlighted" href="/перевод/английский-русский/book" rel="nofollow"><em>book</em></a> and a short and nasty one.</span>
# <span class="text">
#           У него только письменные принадлежности и эта <em>книга</em>.</span>
# <span class="text" lang="en">
#           All he's got is writing stuff and this <a class="link_highlighted" href="/перевод/английский-русский/book" rel="nofollow"><em>book</em></a>.</span>
# <span class="text">
#           У него есть <em>книга</em> обо всем этом.</span>
# <span class="text" lang="en">
#           I mean, he has a <a class="link_highlighted" href="/перевод/английский-русский/book" rel="nofollow"><em>book</em></a> about all of this.</span>
# <span class="text">
#           Итак, Клео, эта <em>книга</em> вызвала столько разговоров...</span>
# <span class="text" lang="en">
#           So, Cleo, this <a class="link_highlighted" href="/перевод/английский-русский/book" rel="nofollow"><em>book</em></a> generating a lot of chatter.</span>
# <span class="text">
#           В печатном виде <em>книга</em> имеется пока только на немецком языке.</span>
# <span class="text" lang="en">
#           In a printed form the <a class="link_highlighted" href="/перевод/английский-русский/book" rel="nofollow"><em>book</em></a> is for the time being only available in German.</span>
# <span class="text">
#           Это не современная <em>книга</em>, это классика.</span>
# <span class="text" lang="en">
#           It's not a modern-day <a class="link_highlighted" href="/перевод/английский-русский/book" rel="nofollow"><em>book</em></a>, it's a classic.</span>
# <span class="text">
#           Грязная <em>книга</em> не является заменой для подруги.</span>
# <span class="text" lang="en">
#           A dirty <a class="link_highlighted" href="/перевод/английский-русский/book" rel="nofollow"><em>book</em></a> is not a substitute for a girlfriend.</span>
# <span class="text">
#           Это полезная <em>книга</em>, это не бульварщина.</span>
# <span class="text" lang="en">
#           It's a proper <a class="link_highlighted" href="/перевод/английский-русский/book" rel="nofollow"><em>book</em></a>, it's not trash.</span>
# <span class="text">
#           И мистер Гриффин, должен сказать, ваша <em>книга</em> отличная.</span>
# <span class="text" lang="en">
#           And Mr. Griffin, I just have to say, I loved your <a class="link_highlighted" href="/перевод/английский-русский/book" rel="nofollow"><em>book</em></a>.</span>
# <span class="text">
#           Это великая <em>книга</em> жизни, которая приносит благодать Небес.</span>
# <span class="text" lang="en">
#           It's a precious <a class="link_highlighted" href="/перевод/английский-русский/book" rel="nofollow"><em>book</em></a> of life that brings forth the blessings of Heaven.</span>
# <span class="text">
#           Будет представлена <em>книга</em> о наиболее важных достижениях Объединенного комитета.</span>
# <span class="text" lang="en">
#           A <a class="link_highlighted" href="/перевод/английский-русский/book" rel="nofollow"><em>book</em></a> on the major achievements of the Joint Committee will be presented.</span>
# <span class="text">
#           Эта <em>книга</em> - о поиске вашего предназначения или рока.</span>
# <span class="text" lang="en">
#           This <a class="link_highlighted" href="/перевод/английский-русский/book" rel="nofollow"><em>book</em></a> is about finding your soul's purpose or destiny.</span>
# <span class="text">
#           Мне нужна каждая <em>книга</em> из квартиры Лукиса и Ван Куна.</span>
# <span class="text" lang="en">
#           I want every <a class="link_highlighted" href="/перевод/английский-русский/book" rel="nofollow"><em>book</em></a> from Lukis's apartment and Van Coon's.</span>
# <span class="text">
#           Я хочу, чтобы вся <em>книга</em> была произведением искусства.</span>
# <span class="text" lang="en">
#           I aim for the whole <a class="link_highlighted" href="/перевод/английский-русский/book" rel="nofollow"><em>book</em></a> to be a work of beauty.</span>
# <span class="text">
#           Эта <em>книга</em> лучше, она намного сложнее, серьёзнее.</span>
# <span class="text" lang="en">
#           Well, it's a better <a class="link_highlighted" href="/перевод/английский-русский/book" rel="nofollow"><em>book</em></a>. It's so much more ambitious.</span>
# <span class="text" data-url="/перевод/русский-английский/%D0%B1%D0%B5%D0%BB%D0%B0%D1%8F+%D0%BA%D0%BD%D0%B8%D0%B3%D0%B0">белая книга</span>
# <span class="text" data-url="/перевод/русский-английский/%D0%BB%D1%8E%D0%B1%D0%B8%D0%BC%D0%B0%D1%8F+%D0%BA%D0%BD%D0%B8%D0%B3%D0%B0">любимая книга</span>

# %%
for l in soup_sub.find_all('span', attrs = {'class':'text', 'lang':'en'}):
    print(l.text)
# Out:
#           Recently has published as a co-author with Ra-Ma the book entitled Internet protocols.
#
#           The book aimed to sensitize children to the different aspects of poverty.
#
#           Well, I brought lots of magazines and a good novel.
#
#           The book is available on the OHCHR web site.
#
#           It's Steve Owen's accounting book, with all the cooking.
#
#           My love life is an open book and a short and nasty one.
#
#           All he's got is writing stuff and this book.
#
#           I mean, he has a book about all of this.
#
#           So, Cleo, this book generating a lot of chatter.
#
#           In a printed form the book is for the time being only available in German.
#
#           It's not a modern-day book, it's a classic.
#
#           A dirty book is not a substitute for a girlfriend.
#
#           It's a proper book, it's not trash.
#
#           And Mr. Griffin, I just have to say, I loved your book.
#
#           It's a precious book of life that brings forth the blessings of Heaven.
#
#           A book on the major achievements of the Joint Committee will be presented.
#
#           This book is about finding your soul's purpose or destiny.
#
#           I want every book from Lukis's apartment and Van Coon's.
#
#           I aim for the whole book to be a work of beauty.
#
#           Well, it's a better book. It's so much more ambitious.

# %%
soup.find_all('section',attrs={"id=" : "examples-content"})

# %%
for i in soup.find_all(span="text"):
    print(i)
    print("===")

# %%
for i in soup.find_all(id="examples-content"):
    print(i)
    print("===")

# %%
for l in soup.find_all('section'):
    try:
        if 'text' in l.span['class']:
            print (l.span.text)
            print ()
    except:
        pass

# %%
for link in soup.find_all('em'):
    print(link)
    print(link.em)
    print(link.get('class'))
    print(link.attrs)
    print("===")

# %%
#span class="text" lang="en"

# %%
soup = bs(response.text,"lxml")
allLines = soup.text.split('\n') 

for line in allLines: # you iterate through the list, and print the single lines
    if " book" in line:
        print("|||", line.strip(),"|||")
